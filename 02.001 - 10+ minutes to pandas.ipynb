# %% [markdown]
# # Setup
#
# This is following [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) for Pandas (v 2.x.x, as of this writing) but may take a little more than 10 minutes to finish. Lot's of small changes, references etc.

# %% [markdown]
# You can also open this notebook in Google Colab
#
# <a href="https://colab.research.google.com/github/shauryashaurya/learn-data-munging/blob/main/01.001%20-%2010%2B%20minutes%20to%20pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.24.4'

# %%
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# # Object creation

# %%
# Series - pass a list to pd.Series
s1 = pd.Series([1, 2, 3, np.nan, 5])

# %%
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
# create an index to use in the dataframe
# default frequency is D (day), so creates a DatetimeIndex of 10 days
dates = pd.date_range('20220619', periods=10)
dates
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# just in case you are wondering, here's [all the "offset aliases"](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases) for Datetime

# %%
# Dataframe - pass a Numpy array
# create a 10 row, 4 col random number array, index by dates, give some column names
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778
# 2022-06-24  0.317767 -0.304653 -0.395611 -0.599631
# 2022-06-25 -0.048513  0.653577  0.539982  0.397480
# 2022-06-26 -0.158157 -0.073843 -0.141581  1.142416
# 2022-06-27  0.525284 -0.979729  0.345773 -2.189424
# 2022-06-28  1.891567  0.348871 -1.245213  1.570340

# %%
# Create a dataframe by passing a dictionary of objects
# where each object can be converted into a series-like structure
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220619"),
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([3]*6, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train", "test", "train"]),
        "F": list("foofoo"),
        "G": "foo"
    }
)

df2
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %%
# the datatype of each of the columns would be different
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# G            object
# dtype: object

# %% [markdown]
# # Viewing Data

# %%
# top of the dataframe
df.head()
# Out:
#                    A         B         C         D
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778

# %%
# bottom 3 records of the dataframe
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-06-26 -0.158157 -0.073843 -0.141581  1.142416
# 2022-06-27  0.525284 -0.979729  0.345773 -2.189424
# 2022-06-28  1.891567  0.348871 -1.245213  1.570340

# %%
# index of the df
df.index
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# columns of the df
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# .to_numpy gives a NumPy representation of the dataframe
# this is expensive if all columns are of different data type
df.to_numpy()
# Out:
# array([[ 0.51684911,  2.19544599, -0.43161536, -0.84649899],
#        [ 1.15487386, -0.76042877, -1.78073515,  1.03440604],
#        [-0.9163477 ,  0.97616104, -0.45053593, -0.97529255],
#        [ 0.62861706,  0.53787837, -2.0677556 , -0.66079723],
#        [ 0.27401925, -0.56024263,  0.08944492, -0.04177786],
#        [ 0.31776655, -0.30465295, -0.3956105 , -0.59963148],
#        [-0.04851341,  0.65357656,  0.53998183,  0.39748043],
#        [-0.15815713, -0.07384349, -0.14158105,  1.14241592],
#        [ 0.52528434, -0.97972945,  0.34577335, -2.18942385],
#        [ 1.89156719,  0.34887077, -1.2452128 ,  1.57034006]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo']], dtype=object)

# %%
# quick summary stats
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.418596   0.203304  -0.553785  -0.116878
# std     0.755783   0.951490   0.876570   1.160544
# min    -0.916348  -0.979729  -2.067756  -2.189424
# 25%     0.032120  -0.496345  -1.046544  -0.800074
# 50%     0.417308   0.137514  -0.413613  -0.320705
# 75%     0.602784   0.624652   0.031688   0.875175
# max     1.891567   2.195446   0.539982   1.570340

# %% [markdown]
# 1. **count** = Count number of non-NA/null observations
# 1. **max** = Maximum of the values in the object
# 1. **min** = Minimum of the values in the object
# 1. **mean** = Mean of the values
# 1. **std** = Standard deviation of the observations
# 1. **25%** = Default lower percentile
# 1. **50%** = 50 percentile - same as the median
# 1. **75%** = Default upper percentile

# %%
# change the percentiles
df.describe(percentiles=[.1, .5, .9])
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.418596   0.203304  -0.553785  -0.116878
# std     0.755783   0.951490   0.876570   1.160544
# min    -0.916348  -0.979729  -2.067756  -2.189424
# 10%    -0.233976  -0.782359  -1.809437  -1.096706
# 50%     0.417308   0.137514  -0.413613  -0.320705
# 90%     1.228543   1.098090   0.365194   1.185208
# max     1.891567   2.195446   0.539982   1.570340

# %%
# E, F, G in d2 are not numeric, so do not come up in describe()
df2.describe()
# Out:
#          A                    B    C    D
# count  6.0                    6  6.0  6.0
# mean   1.0  2022-06-19 00:00:00  1.0  3.0
# min    1.0  2022-06-19 00:00:00  1.0  3.0
# 25%    1.0  2022-06-19 00:00:00  1.0  3.0
# 50%    1.0  2022-06-19 00:00:00  1.0  3.0
# 75%    1.0  2022-06-19 00:00:00  1.0  3.0
# max    1.0  2022-06-19 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
# transpose the data
# turn rows to columns and vice versa
df.T
# Out:
#    2022-06-19  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# A    0.516849    1.154874   -0.916348    0.628617    0.274019    0.317767
# B    2.195446   -0.760429    0.976161    0.537878   -0.560243   -0.304653
# C   -0.431615   -1.780735   -0.450536   -2.067756    0.089445   -0.395611
# D   -0.846499    1.034406   -0.975293   -0.660797   -0.041778   -0.599631
#
#    2022-06-25  2022-06-26  2022-06-27  2022-06-28
# A   -0.048513   -0.158157    0.525284    1.891567
# B    0.653577   -0.073843   -0.979729    0.348871
# C    0.539982   -0.141581    0.345773   -1.245213
# D    0.397480    1.142416   -2.189424    1.570340

# %% [markdown]
# ### [Axis in pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html?highlight=set_ax#pandas.DataFrame.set_axis)
#
# ```axis{0 or ‘index’, 1 or ‘columns’}```
#
# Always remember that when you specify:
# * ```axis=0``` or ```axis='index'``` you indicate that the operation should be along the _index_ (aka across the rows). More often than not indexes will go from top to bottom (vertically), but sometimes they may not (for e.g. if you use columns as index or when you have hierarchical or multi-index data).
# * ```axis=1``` or ```axis='columns'``` indicates the operation is along the columns
#
# When in doubt use the explicit version ```'index'``` or ```'columns'``` instead of ```0``` or ```1```

# %%
# sort along the axis - 1 = horizontal
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-06-19 -0.846499 -0.431615  2.195446  0.516849
# 2022-06-20  1.034406 -1.780735 -0.760429  1.154874
# 2022-06-21 -0.975293 -0.450536  0.976161 -0.916348
# 2022-06-22 -0.660797 -2.067756  0.537878  0.628617
# 2022-06-23 -0.041778  0.089445 -0.560243  0.274019
# 2022-06-24 -0.599631 -0.395611 -0.304653  0.317767
# 2022-06-25  0.397480  0.539982  0.653577 -0.048513
# 2022-06-26  1.142416 -0.141581 -0.073843 -0.158157
# 2022-06-27 -2.189424  0.345773 -0.979729  0.525284
# 2022-06-28  1.570340 -1.245213  0.348871  1.891567

# %%
# sort along the axis - 0 = vertical
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2022-06-28  1.891567  0.348871 -1.245213  1.570340
# 2022-06-27  0.525284 -0.979729  0.345773 -2.189424
# 2022-06-26 -0.158157 -0.073843 -0.141581  1.142416
# 2022-06-25 -0.048513  0.653577  0.539982  0.397480
# 2022-06-24  0.317767 -0.304653 -0.395611 -0.599631
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499

# %%
# sort ascending by values in a column
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293
# 2022-06-26 -0.158157 -0.073843 -0.141581  1.142416
# 2022-06-25 -0.048513  0.653577  0.539982  0.397480
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778
# 2022-06-24  0.317767 -0.304653 -0.395611 -0.599631
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499
# 2022-06-27  0.525284 -0.979729  0.345773 -2.189424
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406
# 2022-06-28  1.891567  0.348871 -1.245213  1.570340

# %%
# sort by non-numerical values
df2.sort_values(by="F", ascending=False)
# Out:
#      A          B    C  D      E  F    G
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo

# %%
# sort by two or more columns
df2.sort_values(by=["F", "E"])
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %% [markdown]
# # Selection

# %% [markdown]
# For production prefer the following instead of other data access methods (typical python methods like ["col"] or [a:b] slices etc.):
#
# ```.at, .iat, .loc and .iloc.```

# %% [markdown]
# ## Getting

# %%
# selecting a single column returns a Series object
df["A"]
# Out:
# 2022-06-19    0.516849
# 2022-06-20    1.154874
# 2022-06-21   -0.916348
# 2022-06-22    0.628617
# 2022-06-23    0.274019
# 2022-06-24    0.317767
# 2022-06-25   -0.048513
# 2022-06-26   -0.158157
# 2022-06-27    0.525284
# 2022-06-28    1.891567
# Freq: D, Name: A, dtype: float64

# %%
# selecting a slice
df[1:5]
# Out:
#                    A         B         C         D
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778

# %% [markdown]
# ## Selection by label

# %%
# selecting based on a label
df.loc[dates[0]]
# Out:
# A    0.516849
# B    2.195446
# C   -0.431615
# D   -0.846499
# Name: 2022-06-19 00:00:00, dtype: float64

# %%
# select on a multi-axis by lable
# I honestly do not know what the comment above means...help!
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-06-19  0.516849  2.195446
# 2022-06-20  1.154874 -0.760429
# 2022-06-21 -0.916348  0.976161
# 2022-06-22  0.628617  0.537878
# 2022-06-23  0.274019 -0.560243
# 2022-06-24  0.317767 -0.304653
# 2022-06-25 -0.048513  0.653577
# 2022-06-26 -0.158157 -0.073843
# 2022-06-27  0.525284 -0.979729
# 2022-06-28  1.891567  0.348871

# %%
# specific index value results in reduction of dimensions
res = df.loc["2022-06-20"]
print(res)
print("res.shape = ", res.shape, " vs. df.shape = ", df.shape)
# Out:
# A    1.154874
# B   -0.760429
# C   -1.780735
# D    1.034406
# Name: 2022-06-20 00:00:00, dtype: float64
# res.shape =  (4,)  vs. df.shape =  (10, 4)

# %%
# get to a specific scalar:
#
# method one
df.loc[dates[0], "A"]
# Out:
# 0.5168491129830927

# %%
#
# method two (slightly faster than method one)
df.at[dates[0], "A"]
# Out:
# 0.5168491129830927

# %% [markdown]
# ## Selection by position

# %%
df.iloc[2]
# Out:
# A   -0.916348
# B    0.976161
# C   -0.450536
# D   -0.975293
# Name: 2022-06-21 00:00:00, dtype: float64

# %%
# slices - similar to NumPy / Python - [row:slice, col:slice]
df.iloc[1:5, 0:2]
# Out:
#                    A         B
# 2022-06-20  1.154874 -0.760429
# 2022-06-21 -0.916348  0.976161
# 2022-06-22  0.628617  0.537878
# 2022-06-23  0.274019 -0.560243

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
df.iloc[[0, 1, 2, 6], [0, 2]]
# Out:
#                    A         C
# 2022-06-19  0.516849 -0.431615
# 2022-06-20  1.154874 -1.780735
# 2022-06-21 -0.916348 -0.450536
# 2022-06-25 -0.048513  0.539982

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
# change the order of columns, repeact a column
df.iloc[[0, 1, 2, 6], [2, 1, 0, 2]]
# Out:
#                    C         B         A         C
# 2022-06-19 -0.431615  2.195446  0.516849 -0.431615
# 2022-06-20 -1.780735 -0.760429  1.154874 -1.780735
# 2022-06-21 -0.450536  0.976161 -0.916348 -0.450536
# 2022-06-25  0.539982  0.653577 -0.048513  0.539982

# %%
# slice rows explicitly, keep all columns
df.iloc[[1, 2], :]
# Out:
#                    A         B         C         D
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293

# %%
# slice columns, keep all rows
df.iloc[:, [2, 3]]
# Out:
#                    C         D
# 2022-06-19 -0.431615 -0.846499
# 2022-06-20 -1.780735  1.034406
# 2022-06-21 -0.450536 -0.975293
# 2022-06-22 -2.067756 -0.660797
# 2022-06-23  0.089445 -0.041778
# 2022-06-24 -0.395611 -0.599631
# 2022-06-25  0.539982  0.397480
# 2022-06-26 -0.141581  1.142416
# 2022-06-27  0.345773 -2.189424
# 2022-06-28 -1.245213  1.570340

# %%
# everything, because you can
df.iloc[:, :]
# Out:
#                    A         B         C         D
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778
# 2022-06-24  0.317767 -0.304653 -0.395611 -0.599631
# 2022-06-25 -0.048513  0.653577  0.539982  0.397480
# 2022-06-26 -0.158157 -0.073843 -0.141581  1.142416
# 2022-06-27  0.525284 -0.979729  0.345773 -2.189424
# 2022-06-28  1.891567  0.348871 -1.245213  1.570340

# %%
# get to a scalar (2 methods, just like before)
#
# method one: use iloc
df.iloc[1, 2]
# Out:
# -1.7807351489834937

# %%
#
# method two: use iat
df.iat[1, 2]
# Out:
# -1.7807351489834937

# %% [markdown]
# ## Boolean Indexing

# %%
# use a value found in a single col to get data
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778
# 2022-06-24  0.317767 -0.304653 -0.395611 -0.599631
# 2022-06-27  0.525284 -0.979729  0.345773 -2.189424
# 2022-06-28  1.891567  0.348871 -1.245213  1.570340

# %%
# boolean across the entire DF - vals that don't match go NaN
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-06-19  0.516849  2.195446       NaN       NaN
# 2022-06-20  1.154874       NaN       NaN  1.034406
# 2022-06-21       NaN  0.976161       NaN       NaN
# 2022-06-22  0.628617  0.537878       NaN       NaN
# 2022-06-23  0.274019       NaN  0.089445       NaN
# 2022-06-24  0.317767       NaN       NaN       NaN
# 2022-06-25       NaN  0.653577  0.539982  0.397480
# 2022-06-26       NaN       NaN       NaN  1.142416
# 2022-06-27  0.525284       NaN  0.345773       NaN
# 2022-06-28  1.891567  0.348871       NaN  1.570340

# %%
# add another column
df11 = df.copy()
df11["E"] = ["one", "two", "three", "four",
             "two", "five", "one", "two", "three", "four"]
df11
# Out:
#                    A         B         C         D      E
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499    one
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406    two
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293  three
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797   four
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778    two
# 2022-06-24  0.317767 -0.304653 -0.395611 -0.599631   five
# 2022-06-25 -0.048513  0.653577  0.539982  0.397480    one
# 2022-06-26 -0.158157 -0.073843 -0.141581  1.142416    two
# 2022-06-27  0.525284 -0.979729  0.345773 -2.189424  three
# 2022-06-28  1.891567  0.348871 -1.245213  1.570340   four

# %%
# the isin() query - basically the in clause
df11[df11["E"].isin(["two", "five"])]
# Out:
#                    A         B         C         D     E
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406   two
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778   two
# 2022-06-24  0.317767 -0.304653 -0.395611 -0.599631  five
# 2022-06-26 -0.158157 -0.073843 -0.141581  1.142416   two

# %% [markdown]
# ## Setting values

# %%
# matching indexes auto-aligns values
s1 = pd.Series(range(11, 21), index=pd.date_range('20220619', periods=10))
s1
# Out:
# 2022-06-19    11
# 2022-06-20    12
# 2022-06-21    13
# 2022-06-22    14
# 2022-06-23    15
# 2022-06-24    16
# 2022-06-25    17
# 2022-06-26    18
# 2022-06-27    19
# 2022-06-28    20
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D   F
# 2022-06-19  0
# 2022-06-22 -0.628617 -0.537878 -2.067756 -5.0 -14
# 2022-06-23 -0.274019 -0.560243 -0.089445 -5.0 -15
# 2022-06-24 -0.317767 -0.304653 -0.395611 -5.0 -16
# 2022-06-25 -0.048513 -0.653577 -0.539982 -5.0 -17
# 2022-06-26 -0.158157 -0.073843 -0.141581 -5.0 -18
# 2022-06-27 -0.525284 -0.979729 -0.345773 -5.0 -19
# 2022-06-28 -1.891567 -0.348871 -1.245213 -5.0 -20

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### _reindex_
# change/add/delete index on a specified axis, returns a new dataframe

# %%
df13 = df.reindex(index=dates[0:4], columns=list(df.columns)+["G"])
df13
# Out:
#                    A         B         C         D   F   G
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499  11 NaN
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406  12 NaN
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293  13 NaN
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797  14 NaN

# %% [markdown]
# ### handling missing data
# 1. _```np.nan```_
# 1. _```pandas.isna()```_
# 1. ```df.dropna()```
# 1. ```df.fillna()```

# %%
# missing data in pandas is np.nan
df13.iat[1, 0] = np.nan
df13.iloc[1:, 5] = np.random.randint(1)
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499  11  NaN
# 2022-06-20       NaN -0.760429 -1.780735  1.034406  12  0.0
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293  13  0.0
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797  14  0.0

# %%
# get a boolean mask where values are NaN
df131 = pd.isna(df13)
df131
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# or just
pd.isna(df13)
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# the original is still there
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499  11  NaN
# 2022-06-20       NaN -0.760429 -1.780735  1.034406  12  0.0
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293  13  0.0
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797  14  0.0

# %%
# we are going to drop / replace values now, let's make a couple of copies of the dataframe
df132 = df13.copy()
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499  11  NaN
# 2022-06-20       NaN -0.760429 -1.780735  1.034406  12  0.0
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293  13  0.0
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797  14  0.0

# %%
# drop rows/columns that have missing data
# by default it returns a new dataframe, you may want to specify inplace=True for modifying current dataframe:
df_no_na = df132.dropna(how="any")
# how=‘any’ : If any NA values are present, drop that row or column.
# how=‘all’ : If all values are NA, drop that row or column.

# %%
# all rows/cols with missing data stripped
df_no_na
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293  13  0.0
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797  14  0.0

# %%
# original still intact
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499  11  NaN
# 2022-06-20       NaN -0.760429 -1.780735  1.034406  12  0.0
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293  13  0.0
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797  14  0.0

# %%
# drop missing data from original
df132.dropna(how="any", inplace=True)
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293  13  0.0
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797  14  0.0

# %%
# fill missing data
df133 = df13.copy()
df133.fillna(np.pi*1000)
# Out:
#                       A         B         C         D   F            G
# 2022-06-19     0.516849  2.195446 -0.431615 -0.846499  11  3141.592654
# 2022-06-20  3141.592654 -0.760429 -1.780735  1.034406  12     0.000000
# 2022-06-21    -0.916348  0.976161 -0.450536 -0.975293  13     0.000000
# 2022-06-22     0.628617  0.537878 -2.067756 -0.660797  14     0.000000

# %% [markdown]
# # Align and Join

# %% [markdown]
# There needs to be a bigger notebook for this topic.
# You need to know there's "joins" in Pandas just like in the SQL world,
# like join and left join and right join and inner and outer and all that...
# Here we'll explore these in the context of the align function - 'aligning' the indexes of two dataframes.
# Later we'll see these again in the context of _merging_ two data frames.

# %% [markdown]
# ## Create two datasets with _mismatched_ indexes

# %%
# date range indexes
idx1 = pd.date_range('2022-01-01',periods = 10)
# 2022-01-01', '2022-01-02' don't exist in idx2
# '2022-01-11', '2022-01-12' don't exist in idx1
idx2 = pd.date_range('2022-01-03',periods = 10)

# %%
# dataframes from indexes
d1 = pd.DataFrame(index = idx1, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

d2 = pd.DataFrame(index = idx2, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

# %% [markdown]
# ## Quick Aside: Rendering two dataframes side-by-side

# %% [markdown]
# The trick of rendering 2 dataframes side-by-side was from [this](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) stackoverflow question.

# %%
# we gon need to display both data frames side by side, so...
from IPython.display import display_html 
def render_df_side_by_side(a, b, a_title = "", b_title = ""):
    a_styler = a.style.set_table_attributes("style='display:inline'").set_caption(a_title)
    b_styler = b.style.set_table_attributes("style='display:inline'").set_caption(b_title)
    display_html(a_styler._repr_html_()+b_styler._repr_html_(), raw=True)

# %%
render_df_side_by_side(d1,d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5865" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5865_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e5865_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5865_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_e5865_row0_col0" class="data row0 col0" >0.263685</td>
#       <td id="T_e5865_row0_col1" class="data row0 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_e5865_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_e5865_row1_col0" class="data row1 col0" >0.913699</td>
#       <td id="T_e5865_row1_col1" class="data row1 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_e5865_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_e5865_row2_col0" class="data row2 col0" >0.417115</td>
#       <td id="T_e5865_row2_col1" class="data row2 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_e5865_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_e5865_row3_col0" class="data row3 col0" >0.735017</td>
#       <td id="T_e5865_row3_col1" class="data row3 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_e5865_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_e5865_row4_col0" class="data row4 col0" >0.535059</td>
#       <td id="T_e5865_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e5865_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_e5865_row5_col0" class="data row5 col0" >0.241058</td>
#       <td id="T_e5865_row5_col1" class="data row5 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_e5865_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_e5865_row6_col0" class="data row6 col0" >0.182430</td>
#       <td id="T_e5865_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e5865_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_e5865_row7_col0" class="data row7 col0" >0.365594</td>
#       <td id="T_e5865_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e5865_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_e5865_row8_col0" class="data row8 col0" >0.662357</td>
#       <td id="T_e5865_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e5865_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_e5865_row9_col0" class="data row9 col0" >0.461757</td>
#       <td id="T_e5865_row9_col1" class="data row9 col1" >23</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c1bbd" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1bbd_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_c1bbd_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1bbd_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_c1bbd_row0_col0" class="data row0 col0" >0.123370</td>
#       <td id="T_c1bbd_row0_col1" class="data row0 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_c1bbd_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_c1bbd_row1_col0" class="data row1 col0" >0.331096</td>
#       <td id="T_c1bbd_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_c1bbd_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_c1bbd_row2_col0" class="data row2 col0" >0.980851</td>
#       <td id="T_c1bbd_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c1bbd_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_c1bbd_row3_col0" class="data row3 col0" >0.881818</td>
#       <td id="T_c1bbd_row3_col1" class="data row3 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_c1bbd_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_c1bbd_row4_col0" class="data row4 col0" >0.227652</td>
#       <td id="T_c1bbd_row4_col1" class="data row4 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_c1bbd_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_c1bbd_row5_col0" class="data row5 col0" >0.904886</td>
#       <td id="T_c1bbd_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c1bbd_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_c1bbd_row6_col0" class="data row6 col0" >0.762181</td>
#       <td id="T_c1bbd_row6_col1" class="data row6 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_c1bbd_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_c1bbd_row7_col0" class="data row7 col0" >0.206356</td>
#       <td id="T_c1bbd_row7_col1" class="data row7 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_c1bbd_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_c1bbd_row8_col0" class="data row8 col0" >0.910520</td>
#       <td id="T_c1bbd_row8_col1" class="data row8 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_c1bbd_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_c1bbd_row9_col0" class="data row9 col0" >0.061782</td>
#       <td id="T_c1bbd_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table rendering/styling options is [a bigger discussion](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#) to be tackled later.

# %% [markdown]
# ## .add, .sub, .mul, .div etc.

# %% [markdown]
# flexible wrappers (```add, sub, mul, div, mod, pow```) to arithmetic operators: ```+, -, *, /, //, %, **```

# %%
# the +, -, *, /, //, %, ** operations align indexes to create a UNION of indexes
d3 = d1+d2
d4 = d1.sub(d2) #equivalent to d1-d2
d5 = d1*d2
d6 = d1.div(d2)

# %%
# indexs not present in the other dataframe get a NaN

# pandas v1.x
# d3.style.highlight_null(null_color='red')

# pandas v2.x+
d3.style.highlight_null(color='red')
# Out:
# <style type="text/css">
# #T_067f9_row0_col0, #T_067f9_row0_col1, #T_067f9_row1_col0, #T_067f9_row1_col1, #T_067f9_row10_col0, #T_067f9_row10_col1, #T_067f9_row11_col0, #T_067f9_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_067f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_067f9_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_067f9_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_067f9_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_067f9_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_067f9_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_067f9_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_067f9_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_067f9_row2_col0" class="data row2 col0" >0.540484</td>
#       <td id="T_067f9_row2_col1" class="data row2 col1" >36.000000</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_067f9_row3_col0" class="data row3 col0" >1.066113</td>
#       <td id="T_067f9_row3_col1" class="data row3 col1" >35.000000</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_067f9_row4_col0" class="data row4 col0" >1.515911</td>
#       <td id="T_067f9_row4_col1" class="data row4 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_067f9_row5_col0" class="data row5 col0" >1.122876</td>
#       <td id="T_067f9_row5_col1" class="data row5 col1" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_067f9_row6_col0" class="data row6 col0" >0.410082</td>
#       <td id="T_067f9_row6_col1" class="data row6 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_067f9_row7_col0" class="data row7 col0" >1.270480</td>
#       <td id="T_067f9_row7_col1" class="data row7 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_067f9_row8_col0" class="data row8 col0" >1.424538</td>
#       <td id="T_067f9_row8_col1" class="data row8 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_067f9_row9_col0" class="data row9 col0" >0.668113</td>
#       <td id="T_067f9_row9_col1" class="data row9 col1" >46.000000</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_067f9_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_067f9_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_067f9_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_067f9_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_067f9_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# div
d6.style.highlight_null(color='red')
# Out:
# <style type="text/css">
# #T_08223_row0_col0, #T_08223_row0_col1, #T_08223_row1_col0, #T_08223_row1_col1, #T_08223_row10_col0, #T_08223_row10_col1, #T_08223_row11_col0, #T_08223_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_08223">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08223_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_08223_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08223_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_08223_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_08223_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_08223_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_08223_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_08223_row2_col0" class="data row2 col0" >3.381017</td>
#       <td id="T_08223_row2_col1" class="data row2 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_08223_row3_col0" class="data row3 col0" >2.219950</td>
#       <td id="T_08223_row3_col1" class="data row3 col1" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_08223_row4_col0" class="data row4 col0" >0.545505</td>
#       <td id="T_08223_row4_col1" class="data row4 col1" >1.666667</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_08223_row5_col0" class="data row5 col0" >0.273365</td>
#       <td id="T_08223_row5_col1" class="data row5 col1" >0.958333</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_08223_row6_col0" class="data row6 col0" >0.801352</td>
#       <td id="T_08223_row6_col1" class="data row6 col1" >0.214286</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_08223_row7_col0" class="data row7 col0" >0.404022</td>
#       <td id="T_08223_row7_col1" class="data row7 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_08223_row8_col0" class="data row8 col0" >0.869028</td>
#       <td id="T_08223_row8_col1" class="data row8 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_08223_row9_col0" class="data row9 col0" >2.237672</td>
#       <td id="T_08223_row9_col1" class="data row9 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_08223_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_08223_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_08223_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_08223_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_08223_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### removing the NaN values from the resultant dataframe

# %%
# the + operation is UNION of indexes
d31 = d1+d2
# indexs not present in the other dataframe get a NaN
# do you can obvs remove nan values like before
d3.dropna().style.highlight_null(color='red')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1844e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1844e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_1844e_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1844e_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_1844e_row0_col0" class="data row0 col0" >0.540484</td>
#       <td id="T_1844e_row0_col1" class="data row0 col1" >36.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1844e_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_1844e_row1_col0" class="data row1 col0" >1.066113</td>
#       <td id="T_1844e_row1_col1" class="data row1 col1" >35.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1844e_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_1844e_row2_col0" class="data row2 col0" >1.515911</td>
#       <td id="T_1844e_row2_col1" class="data row2 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1844e_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_1844e_row3_col0" class="data row3 col0" >1.122876</td>
#       <td id="T_1844e_row3_col1" class="data row3 col1" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1844e_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_1844e_row4_col0" class="data row4 col0" >0.410082</td>
#       <td id="T_1844e_row4_col1" class="data row4 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1844e_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_1844e_row5_col0" class="data row5 col0" >1.270480</td>
#       <td id="T_1844e_row5_col1" class="data row5 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1844e_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_1844e_row6_col0" class="data row6 col0" >1.424538</td>
#       <td id="T_1844e_row6_col1" class="data row6 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1844e_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_1844e_row7_col0" class="data row7 col0" >0.668113</td>
#       <td id="T_1844e_row7_col1" class="data row7 col1" >46.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## df.align()

# %% [markdown]
# Pandas [align](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.align.html) works to join the dataframes in interesting ways.

# %%
# align returns two dataframes - left and right as a result of a join
# default join is outer - the union of indices will be used as index for left and right
left, right = d1.align(d2, join='outer')
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e38cd" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e38cd_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e38cd_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e38cd_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_e38cd_row0_col0" class="data row0 col0" >0.263685</td>
#       <td id="T_e38cd_row0_col1" class="data row0 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_
col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_cd23a_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_cd23a_row4_col0" class="data row4 col0" >0.227652</td>
#       <td id="T_cd23a_row4_col1" class="data row4 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_cd23a_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_cd23a_row5_col0" class="data row5 col0" >0.904886</td>
#       <td id="T_cd23a_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_cd23a_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_cd23a_row6_col0" class="data row6 col0" >0.762181</td>
#       <td id="T_cd23a_row6_col1" class="data row6 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_cd23a_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_cd23a_row7_col0" class="data row7 col0" >0.206356</td>
#       <td id="T_cd23a_row7_col1" class="data row7 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_cd23a_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_cd23a_row8_col0" class="data row8 col0" >0.910520</td>
#       <td id="T_cd23a_row8_col1" class="data row8 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_cd23a_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_cd23a_row9_col0" class="data row9 col0" >0.061782</td>
#       <td id="T_cd23a_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's more to explore in align, and it can get confusing, so beginners be careful, take time and try to work out the result before you execute to build intuition.

# %% [markdown]
# # Operations on data

# %% [markdown]
# ## Stats
#
# Operations in general *exclude* missing data

# %%
# arithmetic mean, for each column (axis = 0)
df.mean()
# Out:
# A     0.418596
# B     0.203304
# C    -0.553785
# D    -0.116878
# F    15.500000
# dtype: float64

# %%
# mean across a row (axis = 1)
df.mean(1)
# Out:
# 2022-06-19    2.486836
# 2022-06-20    2.329623
# 2022-06-21    2.326797
# 2022-06-22    2.487589
# 2022-06-23    2.952289
# 2022-06-24    3.003574
# 2022-06-25    3.708505
# 2022-06-26    3.753767
# 2022-06-27    3.340381
# 2022-06-28    4.513113
# Freq: D, dtype: float64

# %% [markdown]
# ## Apply

# %%
# apply custom lambdas
df.apply(lambda x: x.max()-x.min())
# Out:
# A    2.807915
# B    3.175175
# C    2.607737
# D    3.759764
# F    9.000000
# dtype: float64

# %%
df
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.516849  2.195446 -0.431615 -0.846499  11
# 2022-06-20  1.154874 -0.760429 -1.780735  1.034406  12
# 2022-06-21 -0.916348  0.976161 -0.450536 -0.975293  13
# 2022-06-22  0.628617  0.537878 -2.067756 -0.660797  14
# 2022-06-23  0.274019 -0.560243  0.089445 -0.041778  15
# 2022-06-24  0.317767 -0.304653 -0.395611 -0.599631  16
# 2022-06-25 -0.048513  0.653577  0.539982  0.397480  17
# 2022-06-26 -0.158157 -0.073843 -0.141581  1.142416  18
# 2022-06-27  0.525284 -0.979729  0.345773 -2.189424  19
# 2022-06-28  1.891567  0.348871 -1.245213  1.570340  20

# %%
# each subsequent value is a sum of all values before it in the respective column
cumsum_df = df.apply(np.cumsum)
render_df_side_by_side(df, cumsum_df, "OG Dataframe", "Cumulative Sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9156a" style='display:inline'>
#   <caption>OG Dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9156a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9156a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9156a_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9156a_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_9156a_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9156a_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_9156a_row0_col0" class="data row0 col0" >0.516849</td>
#       <td id="T_9156a_row0_col1" class="data row0 col1" >2.195446</td>
#       <td id="T_9156a_row0_col2" class="data row0 col2" >-0.431615</td>
#       <td id="T_9156a_row0_col3" class="data row0 col3" >-0.846499</td>
#       <td id="T_9156a_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_9156a_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_9156a_row1_col0" class="data row1 col0" >1.154874</td>
#       <td id="T_9156a_row1_col1" class="data row1 col1" >-0.760429</td>
#       <td id="T_9156a_row1_col2" class="data row1 col2" >-1.780735</td>
#       <td id="T_9156a_row1_col3" class="data row1 col3" >1.034406</td>
#       <td id="T_9156a_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_9156a_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_9156a_row2_col0" class="data row2 col0" >-0.916348</td>
#       <td id="T_9156a_row2_col1" class="data row2 col1" >0.976161</td>
#       <td id="T_9156a_row2_col2" class="data row2 col2" >-0.450536</td>
#       <td id="T_9156a_row2_col3" class="data row2 col3" >-0.975293</td>
#       <td id="T_9156a_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_9156a_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_9156a_row3_col0" class="data row3 col0" >0.628617</td>
#       <td id="T_9156a_row3_col1" class="data row3 col1" >0.537878</td>
#       <td id="T_9156a_row3_col2" class="data row3 col2" >-2.067756</td>
#       <td id="T_9156a_row3_col3" class="data row3 col3" >-0.660797</td>
#       <td id="T_9156a_row3_col4" class="data row3 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_9156a_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_9156a_row4_col0" class="data row4 col0" >0.274019</td>
#       <td id="T_9156a_row4_col1" class="data row4 col1" >-0.560243</td>
#       <td id="T_9156a_row4_col2" class="data row4 col2" >0.089445</td>
#       <td id="T_9156a_row4_col3" class="data row4 col3" >-0.041778</td>
#       <td id="T_9156a_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_9156a_level0_row5" class="row_heading level0 row5" >2022-06-24 00:00:00</th>
#       <td id="T_9156a_row5_col0" class="data row5 col0" >0.317767</td>
#       <td id="T_9156a_row5_col1" class="data row5 col1" >-0.304653</td>
#       <td id="T_9156a_row5_col2" class="data row5 col2" >-0.395611</td>
#       <td id="T_9156a_row5_col3" class="data row5 col3" >-0.599631</td>
#       <td id="T_9156a_row5_col4" class="data row5 col4" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9156a_level0_row6" class="row_heading level0 row6" >2022-06-25 00:00:00</th>
#       <td id="T_9156a_row6_col0" class="data row6 col0" >-0.048513</td>
#       <td id="T_9156a_row6_col1" class="data row6 col1" >0.653577</td>
#       <td id="T_9156a_row6_col2" class="data row6 col2" >0.539982</td>
#       <td id="T_9156a_row6_col3" class="data row6 col3" >0.397480</td>
#       <td id="T_9156a_row6_col4" class="data row6 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9156a_level0_row7" class="row_heading level0 row7" >2022-06-26 00:00:00</th>
#       <td id="T_9156a_row7_col0" class="data row7 col0" >-0.158157</td>
#       <td id="T_9156a_row7_col1" class="data row7 col1" >-0.073843</td>
#       <td id="T_9156a_row7_col2" class="data row7 col2" >-0.141581</td>
#       <td id="T_9156a_row7_col3" class="data row7 col3" >1.142416</td>
#       <td id="T_9156a_row7_col4" class="data row7 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_9156a_level0_row8" class="row_heading level0 row8" >2022-06-27 00:00:00</th>
#       <td id="T_9156a_row8_col0" class="data row8 col0" >0.525284</td>
#       <td id="T_9156a_row8_col1" class="data row8 col1" >-0.979729</td>
#       <td id="T_9156a_row8_col2" class="data row8 col2" >0.345773</td>
#       <td id="T_9156a_row8_col3" class="data row8 col3" >-2.189424</td>
#       <td id="T_9156a_row8_col4" class="data row8 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_9156a_level0_row9" class="row_heading level0 row9" >2022-06-28 00:00:00</th>
#       <td id="T_9156a_row9_col0" class="data row9 col0" >1.891567</td>
#       <td id="T_9156a_row9_col1" class="data row9 col1" >0.348871</td>
#       <td id="T_9156a_row9_col2" class="data row9 col2" >-1.245213</td>
#       <td id="T_9156a_row9_col3" class="data row9 col3" >1.570340</td>
#       <td id="T_9156a_row9_col4" class="data row9 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_5d1f8" style='display:inline'>
#   <caption>Cumulative Sum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d1f8_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_5d1f8_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_5d1f8_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_5d1f8_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_5d1f8_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d1f8_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_5d1f8_row0_col0" class="data row0 col0" >0.516849</td>
#       <td id="T_5d1f8_row0_col1" class="data row0 col1" >2.195446</td>
#       <td id="T_5d1f8_row0_col2" class="data row0 col2" >-0.431615</td>
#       <td id="T_5d1f8_row0_col3" class="data row0 col3" >-0.846499</td>
#       <td id="T_5d1f8_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_5d1f8_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_5d1f8_row1_col0" class="data row1 col0" >1.671723</td>
#       <td id="T_5d1f8_row1_col1" class="data row1 col1" >1.435017</td>
#       <td id="T_5d1f8_row1_col2" class="data row1 col2" >-2.212351</td>
#       <td id="T_5d1f8_row1_col3" class="data row1 col3" >0.187907</td>
#       <td id="T_5d1f8_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_5d1f8_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_5d1f8_row2_col0" class="data row2 col0" >0.755375</td>
#       <td id="T_5d1f8_row2_col1" class="data row2 col1" >2.411178</td>
#       <td id="T_5d1f8_row2_col2" class="data row2 col2" >-2.662886</td>
#       <td id="T_5d1f8_row2_col3" class="data row2 col3" >-0.787385</td>
#       <td id="T_5d1f8_row2_col4" class="data row2 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_5d1f8_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_5d1f8_row3_col0" class="data row3 col0" >1.383992</td>
#       <td id="T_5d1f8_row3_col1" class="data row3 col1" >2.949057</td>
#       <td id="T_5d1f8_row3_col2" class="data row3 col2" >-4.730642</td>
#       <td id="T_5d1f8_row3_col3" class="data row3 col3" >-1.448183</td>
#       <td id="T_5d1f8_row3_col4" class="data row3 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_5d1f8_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_5d1f8_row4_col0" class="data row4 col0" >1.658012</td>
#       <td id="T_5d1f8_row4_col1" class="data row4 col1" >2.388814</td>
#       <td id="T_5d1f8_row4_col2" class="data row4 col2" >-4.641197</td>
#       <td id="T_5d1f

# %% [markdown]
# ## Histogramming
#
# Frequencies, 'nuff said
#
# ```value_counts()```

# %%
series1 = pd.Series(np.random.randint(0,5, size = 25))
series1.value_counts()
# Out:
# 3    7
# 0    6
# 1    5
# 4    4
# 2    3
# Name: count, dtype: int64

# %% [markdown]
# ## String Methods

# %%
# build a series
some_string = "SERIes and Index are EqUIppeD WITh A seT Of stRINg PROCESSING METHoDs In tHe ```sTR``` attrIBute THAT MakE IT eASy To oPerATE ON EACh ELEmeNt OF The aRrAY. NOtE thAt PAtTERN-maTching in ```sTR``` gENeralLY UsES reGUlAr eXpreSsiONs bY DEfault (aND In Some cases AlwayS uSEs tHeM)."
str_series = pd.Series(some_string.split()) # split splits on whitespace by default

# %%
# manipulating the case - lower, upper etc.
# also the length of each string, split, replace, yada yada...
# very important when cleaning data (column names may have stupid whitespace, bad case, spacing etc.)
low = str_series.str.lower()
up = str_series.str.upper()

low_up_df = pd.DataFrame(
    {
        'og': str_series,
        'length': str_series.str.len(),
        'low': low,
        'up': up,
        'split_low_on_i': low.str.split('i', expand = False), # expand = True will break this usecase, try elsewhere
        'replace_a_with_star_in_low': low.str.replace('a','*', case=False, regex=True) # yeah, you can mess with regular expns
    })

low_up_df.tail(10)
# Out:
#              og  length          low           up  split_low_on_i  \
# 36  eXpreSsiONs      11  expressions  EXPRESSIONS  [express, ons]
# 37           bY       2           by           BY            [by]
# 38      DEfault       7      default      DEFAULT       [default]
# 39         (aND       4         (and         (AND          [(and]
# 40           In       2           in           IN           [, n]
# 41         Some       4         some         SOME          [some]
# 42        cases       5        cases        CASES         [cases]
# 43       AlwayS       6       always       ALWAYS        [always]
# 44         uSEs       4         uses         USES          [uses]
# 45       tHeM).       6       them).       THEM).        [them).]
#
#    replace_a_with_star_in_low
# 36                expressions
# 37                         by
# 38                    def*ult
# 39                       (*nd
# 40                         in
# 41                       some
# 42                      c*ses
# 43                     *lw*ys
# 44                       uses
# 45                     them).

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods) for more string operations.

# %% [markdown]
# # Merge
#
# Combine series and dataframes, use set logic for indexes and relational algebra for joins/merges

# %% [markdown]
# ## Concat
#
# Chill, we've done this before. The same join = inner/outer/left/right drill.

# %%
# let's make some more dataframes
concatDF = pd.DataFrame(np.random.randn(10,4)) # 10 rows and 4 columns of random numbers
pieces = [concatDF[:3], concatDF[3:7], concatDF[7:]]
reconstructedDF = pd.concat(pieces)
display('broken DFs: ',pieces)
render_df_side_by_side(concatDF, reconstructedDF, "OG", "Concatenated")
# Out:
# 'broken DFs: '
# [          0         1         2         3
#  0 -0.432366 -0.119545 -0.153949  1.121927
#  1 -1.687914  0.475201 -0.836731  0.202767
#  2 -1.626976 -0.335689 -1.981017  1.229656,
#            0         1         2         3
#  3 -0.459588  1.042864 -1.424863 -2.522755
#  4  0.383423 -1.387868 -0.418321 -0.021437
#  5  0.006047  1.640699  0.055818  0.690031
#  6 -0.805386 -1.233446 -0.896767 -0.499882,
#            0         1         2         3
#  7  0.447529  0.810787  0.503424  0.221449
#  8  0.489673 -0.902749 -0.946638 -0.649604
#  9 -0.060303  0.514115  0.184941  3.091788]
# <style type="text/css">
# </style>
# <table id="T_48e71" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48e71_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_48e71_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_48e71_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_48e71_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48e71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_
level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_48e71_row9_col0" class="data row9 col0" >-0.060303</td>
#       <td id="T_48e71_row9_col1" class="data row9 col1" >0.514115</td>
#       <td id="T_48e71_row9_col2" class="data row9 col2" >0.184941</td>
#       <td id="T_48e71_row9_col3" class="data row9 col3" >3.091788</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e530c" style='display:inline'>
#   <caption>Concatenated</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e530c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e530c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e530c_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_e530c_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e530c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e530c_row0_col0" class="data row0 col0" >-0.432366</td>
#       <td id="T_e530c_row0_col1" class="data row0 col1" >-0.119545</td>
#       <td id="T_e530c_row0_col2" class="data row0 col2" >-0.153949</td>
#       <td id="T_e530c_row0_col3" class="data row0 col3" >1.121927</td>
#     </tr>
#     <tr>
#       <th id="T_e530c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e530c_row1_col0" class="data row1 col0" >-1.687914</td>
#       <td id="T_e530c_row1_col1" class="data row1 col1" >0.475201</td>
#       <td id="T_e530c_row1_col2" class="data row1 col2" >-0.836731</td>
#       <td id="T_e530c_row1_col3" class="data row1 col3" >0.202767</td>
#     </tr>
#     <tr>
#       <th id="T_e530c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e530c_row2_col0" class="data row2 col0" >-1.626976</td>
#       <td id="T_e530c_row2_col1" class="data row2 col1" >-0.335689</td>
#       <td id="T_e530c_row2_col2" class="data row2 col2" >-1.981017</td>
#       <td id="T_e530c_row2_col3" class="data row2 col3" >1.229656</td>
#     </tr>
#     <tr>
#       <th id="T_e530c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e530c_row3_col0" class="data row3 col0" >-0.459588</td>
#       <td id="T_e530c_row3_col1" class="data row3 col1" >1.042864</td>
#       <td id="T_e530c_row3_col2" class="data row3 col2" >-1.424863</td>
#       <td id="T_e530c_row3_col3" class="data row3 col3" >-2.522755</td>
#     </tr>
#     <tr>
#       <th id="T_e530c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e530c_row4_col0" class="data row4 col0" >0.383423</td>
#       <td id="T_e530c_row4_col1" class="data row4 col1" >-1.387868</td>
#       <td id="T_e530c_row4_col2" class="data row4 col2" >-0.418321</td>
#       <td id="T_e530c_row4_col3" class="data row4 col3" >-0.021437</td>
#     </tr>
#     <tr>
#       <th id="T_e530c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e530c_row5_col0" class="data row5 col0" >0.006047</td>
#       <td id="T_e530c_row5_col1" class="data row5 col1" >1.640699</td>
#       <td id="T_e530c_row5_col2" class="data row5 col2" >0.055818</td>
#       <td id="T_e530c_row5_col3" class="data row5 col3" >0.690031</td>
#     </tr>
#     <tr>
#       <th id="T_e530c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e530c_row6_col0" class="data row6 col0" >-0.805386</td>
#       <td id="T_e530c_row6_col1" class="data row6 col1" >-1.233446</td>
#       <td id="T_e530c_row6_col2" class="data row6 col2" >-0.896767</td>
#       <td id="T_e530c_row6_col3" class="data row6 col3" >-0.499882</td>
#     </tr>
#     <tr>
#       <th id="T_e530c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e530c_row7_col0" class="data row7 col0" >0.447529</td>
#       <td id="T_e530c_row7_col1" class="data row7 col1" >0.810787</td>
#       <td id="T_e530c_row7_col2" class="data row7 col2" >0.503424</td>
#       <td id="T_e530c_row7_col3" class="data row7 col3" >0.221449</td>
#     </tr>
#     <tr>
#       <th id="T_e530c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e530c_row8_col0" class="data row8 co

# %% [markdown]
# _From the [page](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#concat)_:
# Adding a column to a DataFrame is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the DataFrame constructor instead of building a DataFrame by iteratively appending records to it.

# %% [markdown]
# ## Join
# SQL style merges.

# %%
# two data frames
sl = pd.Series(np.random.randint(10, size=6))
sr = sl.shift(2).fillna(0).astype(int)
left = pd.DataFrame(
    {
        'key': list('ABCDEF'),
        'lval': sl
    }
)

right = pd.DataFrame(
    {
        'key': list('ABBCDE'),
        'rval': sr
    }
)

# %%
render_df_side_by_side(left, right, 'left', 'right')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a46a" style='display:inline'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a46a_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_1a46a_level0_col1" class="col_heading level0 col1" >lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a46a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a46a_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_1a46a_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1a46a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a46a_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_1a46a_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1a46a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1a46a_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_1a46a_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1a46a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1a46a_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_1a46a_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1a46a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1a46a_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_1a46a_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1a46a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1a46a_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_1a46a_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_38749" style='display:inline'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38749_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_38749_level0_col1" class="col_heading level0 col1" >rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38749_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38749_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_38749_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_38749_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38749_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_38749_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_38749_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38749_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_38749_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_38749_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38749_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_38749_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_38749_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38749_row4_col0" class="data row4 col0" >D</td>
#       <td id="T_38749_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_38749_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38749_row5_col0" class="data row5 col0" >E</td>
#       <td id="T_38749_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pd.merge(left, right, on='key')
result
# Out:
#   key  lval  rval
# 0   A     0     0
# 1   B     0     0
# 2   B     0     0
# 3   C     2     0
# 4   D     4     2
# 5   E     4     4

# %% [markdown]
# # Grouping

# %% [markdown]
# "Group By" really means one or more of the following happening:
# 1. **Split**: data is broken into groups based on some criteria
# 2. **Apply**: a data operation is executed on each of those groups
# 3. **Combine**: the results are combined back into a data structure

# %%
grp_df = pd.DataFrame(
    {
        'colA': list('AABCAABDAA'),
        'colB': list('1234567890'),
        'colC': np.random.randn(10),
        'colD': np.random.randn(10)
    }
)
grp_df
# Out:
#   colA colB      colC      colD
# 0    A    1  0.231758 -0.415642
# 1    A    2 -0.236214 -0.178795
# 2    B    3 -0.599199 -0.332962
# 3    C    4  0.635060  0.307221
# 4    A    5  0.647307  0.162566
# 5    A    6 -0.055595  0.142542
# 6    B    7  0.638672  0.272814
# 7    D    8  0.247243 -0.773708
# 8    A    9 -0.471945  2.013728
# 9    A    0  0.855899 -0.374014

# %%
# a DataFrameGroupBy object object
grpby = grp_df.groupby('colA')

# list all the groups found
g = grpby.groups
g
# Out:
# {'A': [0, 1, 4, 5, 8, 9], 'B': [2, 6], 'C': [3], 'D': [7]}

# %%
# to create a dataframe from the group use something like
grpby.get_group('A')
# Out:
#   colA colB      colC      colD
# 0    A    1  0.231758 -0.415642
# 1    A    2 -0.236214 -0.178795
# 4    A    5  0.647307  0.162566
# 5    A    6 -0.055595  0.142542
# 8    A    9 -0.471945  2.013728
# 9    A    0  0.855899 -0.374014

# %% [markdown]
# ### Find all the groups

# %%
# but we may not know all the groups in the dataframe.
# so got to find a way to list all groups as dataframes.
# 
# some basic python helps create a list of groupby names
grpby_labels_list = [*g.keys()] # using the unpacking operator *
# alternatively
# grpby_labels_list = list(g.keys())
grpby_labels_list
# Out:
# ['A', 'B', 'C', 'D']

# %%
# create a dict where the group label is the key and the group dataframe is the value
grps = {lbl: grpby.get_group(lbl) for lbl in grpby_labels_list}

# now use the dict to access individual dataframes created out of the groupby operation
grps['B']

# question: can we create a dataframe of dataframes?
# Out:
#   colA colB      colC      colD
# 2    B    3 -0.599199 -0.332962
# 6    B    7  0.638672  0.272814

# %%
# You can see the datatype of the value is a pandas dataframe
type(grps['A'])
# Out:
# pandas.core.frame.DataFrame

# %%
# make a function of it all...
def get_all_groups(df_grpby):
    return {lbl: df_grpby.get_group(lbl) for lbl in list(df_grpby.groups.keys())}

# %%
grps = get_all_groups(grp_df.groupby('colA'))
grps
# Out:
# {'A':   colA colB      colC      colD
#  0    A    1  0.231758 -0.415642
#  1    A    2 -0.236214 -0.178795
#  4    A    5  0.647307  0.162566
#  5    A    6 -0.055595  0.142542
#  8    A    9 -0.471945  2.013728
#  9    A    0  0.855899 -0.374014,
#  'B':   colA colB      colC      colD
#  2    B    3 -0.599199 -0.332962
#  6    B    7  0.638672  0.272814,
#  'C':   colA colB     colC      colD
#  3    C    4  0.63506  0.307221,
#  'D':   colA colB      colC      colD
#  7    D    8  0.247243 -0.773708}

# %%
# get a sum of values from each group
grp_df.groupby('colA').sum()
# Out:
#         colB      colC      colD
# colA
# A     125690  0.971211  1.350385
# B         37  0.039473 -0.060148
# C          4  0.635060  0.307221
# D          8  0.247243 -0.773708

# %%
# let's add one more column to the dataframe
# we can try grouping on two columns
grp_df['colE'] = list('1231231231')
grp_df
# Out:
#   colA colB      colC      colD colE
# 0    A    1  0.231758 -0.415642    1
# 1    A    2 -0.236214 -0.178795    2
# 2    B    3 -0.599199 -0.332962    3
# 3    C    4  0.635060  0.307221    1
# 4    A    5  0.647307  0.162566    2
# 5    A    6 -0.055595  0.142542    3
# 6    B    7  0.638672  0.272814    1
# 7    D    8  0.247243 -0.773708    2
# 8    A    9 -0.471945  2.013728    3
# 9    A    0  0.855899 -0.374014    1

# %%
g2 = grp_df.groupby(['colA','colE'])
grps2 = get_all_groups(g2)
grps2
# Out:
# {('A',
#   '1'):   colA colB      colC      colD colE
#  0    A    1  0.231758 -0.415642    1
#  9    A    0  0.855899 -0.374014    1,
#  ('A',
#   '2'):   colA colB      colC      colD colE
#  1    A    2 -0.236214 -0.178795    2
#  4    A    5  0.647307  0.162566    2,
#  ('A',
#   '3'):   colA colB      colC      colD colE
#  5    A    6 -0.055595  0.142542    3
#  8    A    9 -0.471945  2.013728    3,
#  ('B',
#   '1'):   colA colB      colC      colD colE
#  6    B    7  0.638672  0.272814    1,
#  ('B',
#   '3'):   colA colB      colC      colD colE
#  2    B    3 -0.599199 -0.332962    3,
#  ('C',
#   '1'):   colA colB     colC      colD colE
#  3    C    4  0.63506  0.307221    1,
#  ('D',
#   '2'):   colA colB      colC      colD colE
#  7    D    8  0.247243 -0.773708    2}

# %%
render_df_side_by_side(grps2[('A','1')], grps2[('A','2')], 'A,1', 'A,2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_58274" style='display:inline'>
#   <caption>A,1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58274_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_58274_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_58274_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_58274_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_58274_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58274_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58274_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_58274_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_58274_row0_col2" class="data row0 col2" >0.231758</td>
#       <td id="T_58274_row0_col3" class="data row0 col3" >-0.415642</td>
#       <td id="T_58274_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_58274_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_58274_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_58274_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_58274_row1_col2" class="data row1 col2" >0.855899</td>
#       <td id="T_58274_row1_col3" class="data row1 col3" >-0.374014</td>
#       <td id="T_58274_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ec1ae" style='display:inline'>
#   <caption>A,2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec1ae_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_ec1ae_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_ec1ae_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_ec1ae_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_ec1ae_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec1ae_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ec1ae_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_ec1ae_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_ec1ae_row0_col2" class="data row0 col2" >-0.236214</td>
#       <td id="T_ec1ae_row0_col3" class="data row0 col3" >-0.178795</td>
#       <td id="T_ec1ae_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ec1ae_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_ec1ae_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_ec1ae_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_ec1ae_row1_col2" class="data row1 col2" >0.647307</td>
#       <td id="T_ec1ae_row1_col3" class="data row1 col3" >0.162566</td>
#       <td id="T_ec1ae_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reshaping
#
# Stacking and Pivot Tables.
# This really warrants more practice, at least go through [the page](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#)

# %% [markdown]
# ## Stacking

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %% [markdown]
# If the syntax [*expression](https://docs.python.org/dev/reference/expressions.html#calls) appears in the function call, expression must evaluate to an iterable. Elements from these iterables are treated as if they were additional positional arguments.
#
# ...although the *expression syntax may appear after explicit keyword arguments, it is processed before the keyword arguments (and any **expression arguments)

# %%
# starred expressions...
def f(a,b):
    print(a, ' ', b)
    
f (b=1, *(2,)) # works, the tuple (iterable) is expanded, 2 is assigned to a, then b fills the next argument slot
# f (a=1, *(2,)) # FAILS, multiple values for argument 'a'
# Out:
# 2   1

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
stack_idx = pd.MultiIndex.from_tuples(tuples, names = ['first', 'second'])

# %%
stack_df = pd.DataFrame(np.random.randn(8,2), index = stack_idx, columns = ['a','b'])
stack_df
# Out:
#                      a         b
# first second
# bar   one     1.399752  1.104867
#       two     2.257572  0.490835
# baz   one     0.370797 -0.310939
#       two    -0.096490  2.087477
# foo   one    -0.385560  2.501992
#       two     0.674896 -0.154312
# qux   one     0.779276  1.059089
#       two    -1.210043  3.257289

# %%
# stack really just combines the columns
stacked = stack_df.stack()
stacked
# Out:
# first  second
# bar    one     a    1.399752
#                b    1.104867
#        two     a    2.257572
#                b    0.490835
# baz    one     a    0.370797
#                b   -0.310939
#        two     a   -0.096490
#                b    2.087477
# foo    one     a   -0.385560
#                b    2.501992
#        two     a    0.674896
#                b   -0.154312
# qux    one     a    0.779276
#                b    1.059089
#        two     a   -1.210043
#                b    3.257289
# dtype: float64

# %%
# unstacked brings back the two columns
# by default unstacks the last level
unstacked = stacked.unstack()
unstacked
# Out:
#                      a         b
# first second
# bar   one     1.399752  1.104867
#       two     2.257572  0.490835
# baz   one     0.370797 -0.310939
#       two    -0.096490  2.087477
# foo   one    -0.385560  2.501992
#       two     0.674896 -0.154312
# qux   one     0.779276  1.059089
#       two    -1.210043  3.257289

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   a  1.399752  2.257572
#       b  1.104867  0.490835
# baz   a  0.370797 -0.096490
#       b -0.310939  2.087477
# foo   a -0.385560  0.674896
#       b  2.501992 -0.154312
# qux   a  0.779276 -1.210043
#       b  1.059089  3.257289

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    a  1.399752  0.370797 -0.385560  0.779276
#        b  1.104867 -0.310939  2.501992  1.059089
# two    a  2.257572 -0.096490  0.674896 -1.210043
#        b  0.490835  2.087477 -0.154312  3.257289

# %%
# you can basically pivot the columns and rows using a combination of stack() and unstack()
unstacked.unstack()
# Out:
#                a                   b
# second       one       two       one       two
# first
# bar     1.399752  2.257572  1.104867  0.490835
# baz     0.370797 -0.096490 -0.310939  2.087477
# foo    -0.385560  0.674896  2.501992 -0.154312
# qux     0.779276 -1.210043  1.059089  3.257289

# %% [markdown]
# ## Pivot Tables

# %%
# we're now just using data created in the pandas documentation - just cause, time.
pivot_tables_df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
pivot_tables_df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.444136  0.924781
# 1     one  B  foo  1.967271 -1.345390
# 2     two  C  foo -1.228525 -1.708172
# 3   three  A  bar  0.019861 -2.960868
# 4     one  B  bar  1.112396 -0.939254
# 5     one  C  bar  1.650048 -0.836505
# 6     two  A  foo  0.427204 -1.015996
# 7   three  B  foo  1.827979  0.021813
# 8     one  C  foo -0.561113  0.473242
# 9     one  A  bar  0.015788 -0.753523
# 10    two  B  bar -0.162859  0.605076
# 11  three  C  bar -0.016595  1.582530

# %%
# simple pivot tables - data, values to aggregate, index, columns to pivot along
pd.pivot_table(pivot_tables_df, values = 'D', index = ['A', 'B'], columns = ['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.015788  0.444136
#       B  1.112396  1.967271
#       C  1.650048 -0.561113
# three A  0.019861       NaN
#       B       NaN  1.827979
#       C -0.016595       NaN
# two   A       NaN  0.427204
#       B -0.162859       NaN
#       C       NaN -1.228525

# %%
# more'n one columns of values
# mark all NaN as zero (0)
pd.pivot_table(pivot_tables_df, values = ['D', 'E'], index = ['A', 'B'], columns = ['C']).fillna(0)
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A  0.015788  0.444136 -0.753523  0.924781
#       B  1.112396  1.967271 -0.939254 -1.345390
#       C  1.650048 -0.561113 -0.836505  0.473242
# three A  0.019861  0.000000 -2.960868  0.000000
#       B  0.000000  1.827979  0.000000  0.021813
#       C -0.016595  0.000000  1.582530  0.000000
# two   A  0.000000  0.427204  0.000000 -1.015996
#       B -0.162859  0.000000  0.605076  0.000000
#       C  0.000000 -1.228525  0.000000 -1.708172

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# We may need to resample data to a different time-frequency.
# Like get data every second and resample to data every 5 minutes and so on...

# %%
rng = pd.date_range('01/01/2022', periods = 1000, freq = 'S')

# %%
ts = pd.Series(np.random.randint(0,500, len(rng)), index=rng)

# %%
ts.resample('5min').sum()
# Out:
# 2022-01-01 00:00:00    74241
# 2022-01-01 00:05:00    70225
# 2022-01-01 00:10:00    75454
# 2022-01-01 00:15:00    24455
# Freq: 5T, dtype: int32

# %% [markdown]
# read up on [date offset strings](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) like '5min' etc.

# %% [markdown]
# ## Timezones

# %%
# timezone representation
rng2 = pd.date_range('01/01/2022', periods = 500, freq='D')
ts2 = pd.Series(np.random.randint(0,365, len(rng2)), index=rng2)
ts2_utc = ts2.tz_localize('UTC')

# %%
# convert to US/Eastern
ts2_utc.tz_convert('US/Eastern')
# Out:
# 2021-12-31 19:00:00-05:00    108
# 2022-01-01 19:00:00-05:00     40
# 2022-01-02 19:00:00-05:00    283
# 2022-01-03 19:00:00-05:00     66
# 2022-01-04 19:00:00-05:00    152
#                             ...
# 2023-05-10 20:00:00-04:00     12
# 2023-05-11 20:00:00-04:00     54
# 2023-05-12 20:00:00-04:00     29
# 2023-05-13 20:00:00-04:00    165
# 2023-05-14 20:00:00-04:00    155
# Freq: D, Length: 500, dtype: int32

# %% [markdown]
# ## Time span representations
#
# Converting between periods and timestamps.
#
# Period is a _timespan_ - span of time between two timestamps.

# %%
# month - end of each 
rng3 = pd.date_range('01/01/2022', periods = 12, freq='M')
rng3
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts3 = pd.Series(np.random.randn(len(rng3)), index = rng3)
ts3
# Out:
# 2022-01-31   -0.282444
# 2022-02-28    0.367342
# 2022-03-31    1.751676
# 2022-04-30    1.087034
# 2022-05-31   -0.113045
# 2022-06-30    0.437777
# 2022-07-31    0.980494
# 2022-08-31    0.941416
# 2022-09-30   -0.869580
# 2022-10-31    0.580761
# 2022-11-30    0.990872
# 2022-12-31    0.434061
# Freq: M, dtype: float64

# %%
ps = ts3.to_period()
ps
# Out:
# 2022-01   -0.282444
# 2022-02    0.367342
# 2022-03    1.751676
# 2022-04    1.087034
# 2022-05   -0.113045
# 2022-06    0.437777
# 2022-07    0.980494
# 2022-08    0.941416
# 2022-09   -0.869580
# 2022-10    0.580761
# 2022-11    0.990872
# 2022-12    0.434061
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2022-01-01   -0.282444
# 2022-02-01    0.367342
# 2022-03-01    1.751676
# 2022-04-01    1.087034
# 2022-05-01   -0.113045
# 2022-06-01    0.437777
# 2022-07-01    0.980494
# 2022-08-01    0.941416
# 2022-09-01   -0.869580
# 2022-10-01    0.580761
# 2022-11-01    0.990872
# 2022-12-01    0.434061
# Freq: MS, dtype: float64

# %% [markdown]
# A more complex use-case:
# convert a _quarterly frequency_ with _year ending in November_ to _9am_ of _the end of the month_ _following_ the _quarter end_

# %%
prng = pd.period_range('1990Q1', '2022Q4', freq='Q-NOV')
type(prng)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
ts4 = pd.Series(np.random.randn(len(prng)), index=prng)
ts4.head()
# Out:
# 1990Q1    0.214879
# 1990Q2   -0.148389
# 1990Q3    1.260150
# 1990Q4   -0.242816
# 1991Q1    0.392411
# Freq: Q-NOV, dtype: float64

# %%
ts4.index = (prng.asfreq('M', 'e') +1).asfreq('H', 's')+9
ts4.head()
# Out:
# 1990-03-01 09:00    0.214879
# 1990-06-01 09:00   -0.148389
# 1990-09-01 09:00    1.260150
# 1990-12-01 09:00   -0.242816
# 1991-03-01 09:00    0.392411
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
#
# [This page](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical-data).
#
# ##### Note: With v2.0+ there's some changes to how categorical data works - so this sections needs an update.
#
# For e.g., gender, social class, blood type, country affiliation, observation time or rating via Likert scales.
# Categorical data. Categories allow (usually) fixed number of possible values. Categorical data may have some order, but not support numerical operations (for e.g., 'strongly agree', 'agree', 'disagree', 'strongly disagree').

# %%
cat_df = pd.DataFrame(
    {"id": list('123456'), "raw_grade":list('abbaae')}
)
cat_df
# Out:
#   id raw_grade
# 0  1         a
# 1  2         b
# 2  3         b
# 3  4         a
# 4  5         a
# 5  6         e

# %%
# convert the raw_grade col to categories
cat_df['grade'] = cat_df['raw_grade'].astype('category')
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
cat_df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# can give more meaningful names here
# direct assignment to Series.cat.categories()
cat_df['grade'].cat.categories = ['very good', 'meh', 'very bad']
cat_df['grade']

# %%
cat_df

# %%
# list of categories 
list(cat_df['grade'].cat.categories)

# categorical.CategoricalAccessor encapsulates all changes to categoricals
# for e.g., set_categories or remove_categories
# dir(cat_df['grade'].cat)

# %%
# add more categories
cat_df['grade'] = cat_df['grade'].cat.set_categories(["very bad", "bad", "meh", "good", "very good"])
# new list of categories
list(cat_df['grade'].cat.categories)

# %%
# now when we can sort the dataframe in order of categories (not lexical)
sorted_cat_df = cat_df.sort_values(by='grade')
render_df_side_by_side(cat_df, sorted_cat_df, 'OG', 'Sorted')

# %%
# grouping
cat_grp = cat_df.groupby('grade')
cat_grp.get_group('very good')

# %%
# count elements
cat_grp.size()
