# %% [markdown]
# # Setup
#
# This is following [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) for Pandas (v 2.x.x, as of this writing) but may take a little more than 10 minutes to finish. Lot's of small changes, references etc.

# %% [markdown]
# You can also open this notebook in Google Colab
#
# <a href="https://colab.research.google.com/github/shauryashaurya/learn-data-munging/blob/main/02-Pandas/01.01-10%2B-minutes-to-Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.26.0'

# %%
pd.__version__
# Out:
# '2.1.1'

# %% [markdown]
# # Object creation

# %%
# Series - pass a list to pd.Series
s1 = pd.Series([1, 2, 3, np.nan, 5])

# %%
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
# create an index to use in the dataframe
# default frequency is D (day), so creates a DatetimeIndex of 10 days
dates = pd.date_range("20220619", periods=10)
dates
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# just in case you are wondering, here's [all the "offset aliases"](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases) for Datetime

# %%
# Dataframe - pass a Numpy array
# create a 10 row, 4 col random number array, index by dates, give some column names
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265
# 2022-06-28  1.057253  0.096951  0.333307  1.160199

# %%
# Create a dataframe by passing a dictionary of objects
# where each object can be converted into a series-like structure
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220619"),
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([3] * 6, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train", "test", "train"]),
        "F": list("foofoo"),
        "G": "foo",
    }
)

df2
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %%
# the datatype of each of the columns would be different
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# G           object
# dtype: object

# %% [markdown]
# # Viewing Data

# %%
# top of the dataframe
df.head()
# Out:
#                    A         B         C         D
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700

# %%
# bottom 3 records of the dataframe
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265
# 2022-06-28  1.057253  0.096951  0.333307  1.160199

# %%
# index of the df
df.index
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# columns of the df
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# .to_numpy gives a NumPy representation of the dataframe
# this is expensive if all columns are of different data type
# NumPy arrays support a single data type
# so with mixed data types, the data type of
# each element is
df.to_numpy()
# Out:
# array([[-0.16155383,  0.7801087 , -1.71605198, -0.80025534],
#        [-0.80167932,  0.02602592, -0.7653674 ,  0.32754998],
#        [ 1.05439522,  0.10785889,  1.36805948, -0.44581065],
#        [-1.40363445,  0.2233484 , -0.88452566,  0.19588564],
#        [-2.1701052 , -1.44209293,  0.40328056,  0.2167001 ],
#        [-0.2737351 , -1.55572138,  0.49411986, -1.17508734],
#        [ 0.57539342,  0.54323754,  0.81561102, -0.47690152],
#        [ 0.27748564,  0.75333925, -1.81365486,  1.22387508],
#        [-0.92004061, -0.37080179, -2.39811112,  0.58126532],
#        [ 1.05725275,  0.09695086,  0.33330723,  1.16019935]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo']], dtype=object)

# %%
# quick summary stats
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.276622  -0.083775  -0.416333   0.080742
# std     1.061558   0.823947   1.276917   0.799767
# min    -2.170105  -1.555721  -2.398111  -1.175087
# 25%    -0.890450  -0.271595  -1.508170  -0.469129
# 50%    -0.217644   0.102405  -0.216030   0.206293
# 75%     0.500916   0.463265   0.471410   0.517836
# max     1.057253   0.780109   1.368059   1.223875

# %% [markdown]
# 1. **count** = Count number of non-NA/null observations
# 1. **max** = Maximum of the values in the object
# 1. **min** = Minimum of the values in the object
# 1. **mean** = Mean of the values
# 1. **std** = Standard deviation of the observations
# 1. **25%** = Default lower percentile
# 1. **50%** = 50 percentile - same as the median
# 1. **75%** = Default upper percentile

# %%
# change the percentiles
df.describe(percentiles=[0.1, 0.5, 0.9])
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.276622  -0.083775  -0.416333   0.080742
# std     1.061558   0.823947   1.276917   0.799767
# min    -2.170105  -1.555721  -2.398111  -1.175087
# 10%    -1.480282  -1.453456  -1.872100  -0.837739
# 50%    -0.217644   0.102405  -0.216030   0.206293
# 90%     1.054681   0.756016   0.870856   1.166567
# max     1.057253   0.780109   1.368059   1.223875

# %%
# E, F, G in d2 are not numeric, so do not come up in describe()
df2.describe()
# Out:
#          A                    B    C    D
# count  6.0                    6  6.0  6.0
# mean   1.0  2022-06-19 00:00:00  1.0  3.0
# min    1.0  2022-06-19 00:00:00  1.0  3.0
# 25%    1.0  2022-06-19 00:00:00  1.0  3.0
# 50%    1.0  2022-06-19 00:00:00  1.0  3.0
# 75%    1.0  2022-06-19 00:00:00  1.0  3.0
# max    1.0  2022-06-19 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
# transpose the data
# turn rows to columns and vice versa
df.T
# Out:
#    2022-06-19  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# A   -0.161554   -0.801679    1.054395   -1.403634   -2.170105   -0.273735
# B    0.780109    0.026026    0.107859    0.223348   -1.442093   -1.555721
# C   -1.716052   -0.765367    1.368059   -0.884526    0.403281    0.494120
# D   -0.800255    0.327550   -0.445811    0.195886    0.216700   -1.175087
#
#    2022-06-25  2022-06-26  2022-06-27  2022-06-28
# A    0.575393    0.277486   -0.920041    1.057253
# B    0.543238    0.753339   -0.370802    0.096951
# C    0.815611   -1.813655   -2.398111    0.333307
# D   -0.476902    1.223875    0.581265    1.160199

# %% [markdown]
# ### [Axis in pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html?highlight=set_ax#pandas.DataFrame.set_axis)
#
# ```axis{0 or ‘index’, 1 or ‘columns’}```
#
# Always remember that when you specify:
# * ```axis=0``` or ```axis='index'``` you indicate that the operation should be along the _index_ (aka across the rows). More often than not indexes will go from top to bottom (vertically), but sometimes they may not (for e.g. if you use columns as index or when you have hierarchical or multi-index data).
# * ```axis=1``` or ```axis='columns'``` indicates the operation is along the columns
#
# When in doubt use the explicit version ```'index'``` or ```'columns'``` instead of ```0``` or ```1```

# %%
# sort along the axis - 1 = horizontal
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-06-19 -0.800255 -1.716052  0.780109 -0.161554
# 2022-06-20  0.327550 -0.765367  0.026026 -0.801679
# 2022-06-21 -0.445811  1.368059  0.107859  1.054395
# 2022-06-22  0.195886 -0.884526  0.223348 -1.403634
# 2022-06-23  0.216700  0.403281 -1.442093 -2.170105
# 2022-06-24 -1.175087  0.494120 -1.555721 -0.273735
# 2022-06-25 -0.476902  0.815611  0.543238  0.575393
# 2022-06-26  1.223875 -1.813655  0.753339  0.277486
# 2022-06-27  0.581265 -2.398111 -0.370802 -0.920041
# 2022-06-28  1.160199  0.333307  0.096951  1.057253

# %%
# sort along the axis - 0 = vertical
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2022-06-28  1.057253  0.096951  0.333307  1.160199
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255

# %%
# sort ascending by values in a column
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811
# 2022-06-28  1.057253  0.096951  0.333307  1.160199

# %%
# sort by non-numerical values
df2.sort_values(by="F", ascending=False)
# Out:
#      A          B    C  D      E  F    G
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo

# %%
# sort by two or more columns
df2.sort_values(by=["F", "E"])
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %% [markdown]
# # Selection

# %% [markdown]
# For production prefer the following instead of other data access methods (typical python methods like ["col"] or [a:b] slices etc.):
#
# ```.at, .iat, .loc and .iloc.```

# %% [markdown]
# ## Getting

# %%
# selecting a single column returns a Series object
df["A"]
# Out:
# 2022-06-19   -0.161554
# 2022-06-20   -0.801679
# 2022-06-21    1.054395
# 2022-06-22   -1.403634
# 2022-06-23   -2.170105
# 2022-06-24   -0.273735
# 2022-06-25    0.575393
# 2022-06-26    0.277486
# 2022-06-27   -0.920041
# 2022-06-28    1.057253
# Freq: D, Name: A, dtype: float64

# %%
# selecting a slice
df[1:5]
# Out:
#                    A         B         C         D
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700

# %% [markdown]
# ## Selection by label

# %%
# selecting based on a label
df.loc[dates[0]]
# Out:
# A   -0.161554
# B    0.780109
# C   -1.716052
# D   -0.800255
# Name: 2022-06-19 00:00:00, dtype: float64

# %%
# select on a multi-axis by lable
# I honestly do not know what the comment above means...help!
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-06-19 -0.161554  0.780109
# 2022-06-20 -0.801679  0.026026
# 2022-06-21  1.054395  0.107859
# 2022-06-22 -1.403634  0.223348
# 2022-06-23 -2.170105 -1.442093
# 2022-06-24 -0.273735 -1.555721
# 2022-06-25  0.575393  0.543238
# 2022-06-26  0.277486  0.753339
# 2022-06-27 -0.920041 -0.370802
# 2022-06-28  1.057253  0.096951

# %%
# specific index value results in reduction of dimensions
res = df.loc["2022-06-20"]
print(res)
print("res.shape = ", res.shape, " vs. df.shape = ", df.shape)
# Out:
# A   -0.801679
# B    0.026026
# C   -0.765367
# D    0.327550
# Name: 2022-06-20 00:00:00, dtype: float64
# res.shape =  (4,)  vs. df.shape =  (10, 4)

# %%
# get to a specific scalar:
#
# method one
df.loc[dates[0], "A"]
# Out:
# -0.1615538253751502

# %%
#
# method two (slightly faster than method one)
df.at[dates[0], "A"]
# Out:
# -0.1615538253751502

# %% [markdown]
# ## Selection by position

# %%
df.iloc[2]
# Out:
# A    1.054395
# B    0.107859
# C    1.368059
# D   -0.445811
# Name: 2022-06-21 00:00:00, dtype: float64

# %%
# slices - similar to NumPy / Python - [row:slice, col:slice]
df.iloc[1:5, 0:2]
# Out:
#                    A         B
# 2022-06-20 -0.801679  0.026026
# 2022-06-21  1.054395  0.107859
# 2022-06-22 -1.403634  0.223348
# 2022-06-23 -2.170105 -1.442093

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
df.iloc[[0, 1, 2, 6], [0, 2]]
# Out:
#                    A         C
# 2022-06-19 -0.161554 -1.716052
# 2022-06-20 -0.801679 -0.765367
# 2022-06-21  1.054395  1.368059
# 2022-06-25  0.575393  0.815611

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
# change the order of columns, repeact a column
df.iloc[[0, 1, 2, 6], [2, 1, 0, 2]]
# Out:
#                    C         B         A         C
# 2022-06-19 -1.716052  0.780109 -0.161554 -1.716052
# 2022-06-20 -0.765367  0.026026 -0.801679 -0.765367
# 2022-06-21  1.368059  0.107859  1.054395  1.368059
# 2022-06-25  0.815611  0.543238  0.575393  0.815611

# %%
# slice rows explicitly, keep all columns
df.iloc[[1, 2], :]
# Out:
#                    A         B         C         D
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811

# %%
# slice columns, keep all rows
df.iloc[:, [2, 3]]
# Out:
#                    C         D
# 2022-06-19 -1.716052 -0.800255
# 2022-06-20 -0.765367  0.327550
# 2022-06-21  1.368059 -0.445811
# 2022-06-22 -0.884526  0.195886
# 2022-06-23  0.403281  0.216700
# 2022-06-24  0.494120 -1.175087
# 2022-06-25  0.815611 -0.476902
# 2022-06-26 -1.813655  1.223875
# 2022-06-27 -2.398111  0.581265
# 2022-06-28  0.333307  1.160199

# %%
# everything, because you can
df.iloc[:, :]
# Out:
#                    A         B         C         D
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265
# 2022-06-28  1.057253  0.096951  0.333307  1.160199

# %%
# get to a scalar (2 methods, just like before)
#
# method one: use iloc
df.iloc[1, 2]
# Out:
# -0.7653674002156421

# %%
#
# method two: use iat
df.iat[1, 2]
# Out:
# -0.7653674002156421

# %% [markdown]
# ## Boolean Indexing

# %%
# use a value found in a single col to get data
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875
# 2022-06-28  1.057253  0.096951  0.333307  1.160199

# %%
# boolean across the entire DF - vals that don't match go NaN
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-06-19       NaN  0.780109       NaN       NaN
# 2022-06-20       NaN  0.026026       NaN  0.327550
# 2022-06-21  1.054395  0.107859  1.368059       NaN
# 2022-06-22       NaN  0.223348       NaN  0.195886
# 2022-06-23       NaN       NaN  0.403281  0.216700
# 2022-06-24       NaN       NaN  0.494120       NaN
# 2022-06-25  0.575393  0.543238  0.815611       NaN
# 2022-06-26  0.277486  0.753339       NaN  1.223875
# 2022-06-27       NaN       NaN       NaN  0.581265
# 2022-06-28  1.057253  0.096951  0.333307  1.160199

# %%
# add another column
df11 = df.copy()
df11["E"] = [
    "one",
    "two",
    "three",
    "four",
    "two",
    "five",
    "one",
    "two",
    "three",
    "four",
]
df11
# Out:
#                    A         B         C         D      E
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255    one
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550    two
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  three
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886   four
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700    two
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087   five
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902    one
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875    two
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265  three
# 2022-06-28  1.057253  0.096951  0.333307  1.160199   four

# %%
# the isin() query - basically the in clause
df11[df11["E"].isin(["two", "five"])]
# Out:
#                    A         B         C         D     E
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550   two
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700   two
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087  five
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875   two

# %% [markdown]
# ## Setting values

# %%
# matching indexes auto-aligns values
s1 = pd.Series(range(11, 21), index=pd.date_range("20220619", periods=10))
s1
# Out:
# 2022-06-19    11
# 2022-06-20    12
# 2022-06-21    13
# 2022-06-22    14
# 2022-06-23    15
# 2022-06-24    16
# 2022-06-25    17
# 2022-06-26    18
# 2022-06-27    19
# 2022-06-28    20
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255  11
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550  12
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700  15
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087  16
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902  17
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875  18
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265  19
# 2022-06-28  1.057253  0.096951  0.333307  1.160199  20

# %%
# setting values by label and position
# first let's make a quick copy
df12 = df.copy()
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255  11
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550  12
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700  15
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087  16
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902  17
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875  18
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265  19
# 2022-06-28  1.057253  0.096951  0.333307  1.160199  20

# %%
# set by label
df12.at[dates[0], "A"] = 0
# set by position
df12.iat[0, 1] = 0
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.000000  0.000000 -1.716052 -0.800255  11
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550  12
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700  15
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087  16
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902  17
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875  18
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265  19
# 2022-06-28  1.057253  0.096951  0.333307  1.160199  20

# %%
# kinda bigger replacement
df12.loc[:, "D"] = np.array([5] * len(df))
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000 -1.716052  5.0  11
# 2022-06-20 -0.801679  0.026026 -0.765367  5.0  12
# 2022-06-21  1.054395  0.107859  1.368059  5.0  13
# 2022-06-22 -1.403634  0.223348 -0.884526  5.0  14
# 2022-06-23 -2.170105 -1.442093  0.403281  5.0  15
# 2022-06-24 -0.273735 -1.555721  0.494120  5.0  16
# 2022-06-25  0.575393  0.543238  0.815611  5.0  17
# 2022-06-26  0.277486  0.753339 -1.813655  5.0  18
# 2022-06-27 -0.920041 -0.370802 -2.398111  5.0  19
# 2022-06-28  1.057253  0.096951  0.333307  5.0  20

# %%
# setting values using a boolean selection (aka where clause)
df12[df12 > 0] = -df12
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000 -1.716052 -5.0 -11
# 2022-06-20 -0.801679 -0.026026 -0.765367 -5.0 -12
# 2022-06-21 -1.054395 -0.107859 -1.368059 -5.0 -13
# 2022-06-22 -1.403634 -0.223348 -0.884526 -5.0 -14
# 2022-06-23 -2.170105 -1.442093 -0.403281 -5.0 -15
# 2022-06-24 -0.273735 -1.555721 -0.494120 -5.0 -16
# 2022-06-25 -0.575393 -0.543238 -0.815611 -5.0 -17
# 2022-06-26 -0.277486 -0.753339 -1.813655 -5.0 -18
# 2022-06-27 -0.920041 -0.370802 -2.398111 -5.0 -19
# 2022-06-28 -1.057253 -0.096951 -0.333307 -5.0 -20

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### _reindex_
# change/add/delete index on a specified axis, returns a new dataframe

# %%
df13 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["G"])
df13
# Out:
#                    A         B         C         D   F   G
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255  11 NaN
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550  12 NaN
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13 NaN
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14 NaN

# %% [markdown]
# ### handling missing data
# 1. _```np.nan```_
# 1. _```pandas.isna()```_
# 1. ```df.dropna()```
# 1. ```df.fillna()```

# %%
# missing data in pandas is np.nan
df13.iat[1, 0] = np.nan
df13.iloc[1:, 5] = np.random.randint(1)
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255  11  NaN
# 2022-06-20       NaN  0.026026 -0.765367  0.327550  12  0.0
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13  0.0
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14  0.0

# %%
# get a boolean mask where values are NaN
df131 = pd.isna(df13)
df131
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# or just
pd.isna(df13)
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# the original is still there
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255  11  NaN
# 2022-06-20       NaN  0.026026 -0.765367  0.327550  12  0.0
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13  0.0
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14  0.0

# %%
# we are going to drop / replace values now, let's make a couple of copies of the dataframe
df132 = df13.copy()
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255  11  NaN
# 2022-06-20       NaN  0.026026 -0.765367  0.327550  12  0.0
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13  0.0
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14  0.0

# %%
# drop rows/columns that have missing data
# by default it returns a new dataframe, you may want to specify inplace=True for modifying current dataframe:
df_no_na = df132.dropna(how="any")
# how=‘any’ : If any NA values are present, drop that row or column.
# how=‘all’ : If all values are NA, drop that row or column.

# %%
# all rows/cols with missing data stripped
df_no_na
# Out:
#                    A         B         C         D   F    G
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13  0.0
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14  0.0

# %%
# original still intact
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255  11  NaN
# 2022-06-20       NaN  0.026026 -0.765367  0.327550  12  0.0
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13  0.0
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14  0.0

# %%
# drop missing data from original
df132.dropna(how="any", inplace=True)
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13  0.0
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14  0.0

# %%
# fill missing data
df133 = df13.copy()
df133.fillna(np.pi * 1000)
# Out:
#                       A         B         C         D   F            G
# 2022-06-19    -0.161554  0.780109 -1.716052 -0.800255  11  3141.592654
# 2022-06-20  3141.592654  0.026026 -0.765367  0.327550  12     0.000000
# 2022-06-21     1.054395  0.107859  1.368059 -0.445811  13     0.000000
# 2022-06-22    -1.403634  0.223348 -0.884526  0.195886  14     0.000000

# %% [markdown]
# # Align and Join

# %% [markdown]
# There needs to be a bigger notebook for this topic.
# You need to know there's "joins" in Pandas just like in the SQL world,
# like join and left join and right join and inner and outer and all that...
# Here we'll explore these in the context of the align function - 'aligning' the indexes of two dataframes.
# Later we'll see these again in the context of _merging_ two data frames.

# %% [markdown]
# ## Create two datasets with _mismatched_ indexes

# %%
# date range indexes
idx1 = pd.date_range("2022-01-01", periods=10)
# 2022-01-01', '2022-01-02' don't exist in idx2
# '2022-01-11', '2022-01-12' don't exist in idx1
idx2 = pd.date_range("2022-01-03", periods=10)

# %%
# dataframes from indexes
d1 = pd.DataFrame(
    index=idx1,
    data={"A": np.random.rand(10), "B": np.random.randint(1, high=25, size=10)},
)

d2 = pd.DataFrame(
    index=idx2,
    data={"A": np.random.rand(10), "B": np.random.randint(1, high=25, size=10)},
)

# %% [markdown]
# ## Quick Aside: Rendering two dataframes side-by-side

# %% [markdown]
# The trick of rendering 2 dataframes side-by-side was from [this](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) stackoverflow question.

# %%
# we gon need to display both data frames side by side, so...
from IPython.display import display_html


def render_df_side_by_side(a, b, a_title="", b_title=""):
    a_styler = a.style.set_table_attributes("style='display:inline'").set_caption(
        a_title
    )
    b_styler = b.style.set_table_attributes("style='display:inline'").set_caption(
        b_title
    )
    display_html(a_styler._repr_html_() + b_styler._repr_html_(), raw=True)

# %%
render_df_side_by_side(d1, d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3e75d" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e75d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_3e75d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e75d_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_3e75d_row0_col0" class="data row0 col0" >0.903481</td>
#       <td id="T_3e75d_row0_col1" class="data row0 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_3e75d_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_3e75d_row1_col0" class="data row1 col0" >0.860529</td>
#       <td id="T_3e75d_row1_col1" class="data row1 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_3e75d_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_3e75d_row2_col0" class="data row2 col0" >0.341629</td>
#       <td id="T_3e75d_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_3e75d_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_3e75d_row3_col0" class="data row3 col0" >0.500474</td>
#       <td id="T_3e75d_row3_col1" class="data row3 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_3e75d_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_3e75d_row4_col0" class="data row4 col0" >0.548803</td>
#       <td id="T_3e75d_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3e75d_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_3e75d_row5_col0" class="data row5 col0" >0.852633</td>
#       <td id="T_3e75d_row5_col1" class="data row5 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_3e75d_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_3e75d_row6_col0" class="data row6 col0" >0.071512</td>
#       <td id="T_3e75d_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_3e75d_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_3e75d_row7_col0" class="data row7 col0" >0.665023</td>
#       <td id="T_3e75d_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3e75d_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_3e75d_row8_col0" class="data row8 col0" >0.811690</td>
#       <td id="T_3e75d_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_3e75d_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_3e75d_row9_col0" class="data row9 col0" >0.590189</td>
#       <td id="T_3e75d_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ab86b" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab86b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ab86b_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab86b_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_ab86b_row0_col0" class="data row0 col0" >0.231301</td>
#       <td id="T_ab86b_row0_col1" class="data row0 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_ab86b_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_ab86b_row1_col0" class="data row1 col0" >0.794938</td>
#       <td id="T_ab86b_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_ab86b_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_ab86b_row2_col0" class="data row2 col0" >0.365418</td>
#       <td id="T_ab86b_row2_col1" class="data row2 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_ab86b_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_ab86b_row3_col0" class="data row3 col0" >0.288303</td>
#       <td id="T_ab86b_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ab86b_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_ab86b_row4_col0" class="data row4 col0" >0.275777</td>
#       <td id="T_ab86b_row4_col1" class="data row4 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_ab86b_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_ab86b_row5_col0" class="data row5 col0" >0.719903</td>
#       <td id="T_ab86b_row5_col1" class="data row5 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_ab86b_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_ab86b_row6_col0" class="data row6 col0" >0.729015</td>
#       <td id="T_ab86b_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ab86b_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_ab86b_row7_col0" class="data row7 col0" >0.132025</td>
#       <td id="T_ab86b_row7_col1" class="data row7 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_ab86b_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_ab86b_row8_col0" class="data row8 col0" >0.035142</td>
#       <td id="T_ab86b_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ab86b_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_ab86b_row9_col0" class="data row9 col0" >0.563783</td>
#       <td id="T_ab86b_row9_col1" class="data row9 col1" >23</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table rendering/styling options is [a bigger discussion](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#) to be tackled later.

# %% [markdown]
# ## .add, .sub, .mul, .div etc.

# %% [markdown]
# flexible wrappers (```add, sub, mul, div, mod, pow```) to arithmetic operators: ```+, -, *, /, //, %, **```

# %%
# the +, -, *, /, //, %, ** operations align indexes to create a UNION of indexes
d3 = d1 + d2
d4 = d1.sub(d2)  # equivalent to d1-d2
d5 = d1 * d2
d6 = d1.div(d2)

# %%
# indexs not present in the other dataframe get a NaN

# pandas v1.x
# d3.style.highlight_null(null_color='red')

# pandas v2.x+
d3.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_d0006_row0_col0, #T_d0006_row0_col1, #T_d0006_row1_col0, #T_d0006_row1_col1, #T_d0006_row10_col0, #T_d0006_row10_col1, #T_d0006_row11_col0, #T_d0006_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_d0006">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0006_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d0006_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0006_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_d0006_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_d0006_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_d0006_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_d0006_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_d0006_row2_col0" class="data row2 col0" >0.572930</td>
#       <td id="T_d0006_row2_col1" class="data row2 col1" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_d0006_row3_col0" class="data row3 col0" >1.295413</td>
#       <td id="T_d0006_row3_col1" class="data row3 col1" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_d0006_row4_col0" class="data row4 col0" >0.914220</td>
#       <td id="T_d0006_row4_col1" class="data row4 col1" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_d0006_row5_col0" class="data row5 col0" >1.140936</td>
#       <td id="T_d0006_row5_col1" class="data row5 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_d0006_row6_col0" class="data row6 col0" >0.347289</td>
#       <td id="T_d0006_row6_col1" class="data row6 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_d0006_row7_col0" class="data row7 col0" >1.384926</td>
#       <td id="T_d0006_row7_col1" class="data row7 col1" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_d0006_row8_col0" class="data row8 col0" >1.540705</td>
#       <td id="T_d0006_row8_col1" class="data row8 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_d0006_row9_col0" class="data row9 col0" >0.722214</td>
#       <td id="T_d0006_row9_col1" class="data row9 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_d0006_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_d0006_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d0006_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_d0006_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_d0006_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# sub
d4.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_55e06_row0_col0, #T_55e06_row0_col1, #T_55e06_row1_col0, #T_55e06_row1_col1, #T_55e06_row10_col0, #T_55e06_row10_col1, #T_55e06_row11_col0, #T_55e06_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_55e06">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55e06_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_55e06_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55e06_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_55e06_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_55e06_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_55e06_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_55e06_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_55e06_row2_col0" class="data row2 col0" >0.110328</td>
#       <td id="T_55e06_row2_col1" class="data row2 col1" >-15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_55e06_row3_col0" class="data row3 col0" >-0.294464</td>
#       <td id="T_55e06_row3_col1" class="data row3 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_55e06_row4_col0" class="data row4 col0" >0.183385</td>
#       <td id="T_55e06_row4_col1" class="data row4 col1" >-11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_55e06_row5_col0" class="data row5 col0" >0.564330</td>
#       <td id="T_55e06_row5_col1" class="data row5 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_55e06_row6_col0" class="data row6 col0" >-0.204265</td>
#       <td id="T_55e06_row6_col1" class="data row6 col1" >-5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_55e06_row7_col0" class="data row7 col0" >-0.054880</td>
#       <td id="T_55e06_row7_col1" class="data row7 col1" >-9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_55e06_row8_col0" class="data row8 col0" >0.082676</td>
#       <td id="T_55e06_row8_col1" class="data row8 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_55e06_row9_col0" class="data row9 col0" >0.458164</td>
#       <td id="T_55e06_row9_col1" class="data row9 col1" >-14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_55e06_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_55e06_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_55e06_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_55e06_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_55e06_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mul
d5.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_9d623_row0_col0, #T_9d623_row0_col1, #T_9d623_row1_col0, #T_9d623_row1_col1, #T_9d623_row10_col0, #T_9d623_row10_col1, #T_9d623_row11_col0, #T_9d623_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_9d623">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d623_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9d623_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d623_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_9d623_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_9d623_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_9d623_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_9d623_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_9d623_row2_col0" class="data row2 col0" >0.079019</td>
#       <td id="T_9d623_row2_col1" class="data row2 col1" >216.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_9d623_row3_col0" class="data row3 col0" >0.397846</td>
#       <td id="T_9d623_row3_col1" class="data row3 col1" >184.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_9d623_row4_col0" class="data row4 col0" >0.200542</td>
#       <td id="T_9d623_row4_col1" class="data row4 col1" >210.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_9d623_row5_col0" class="data row5 col0" >0.245817</td>
#       <td id="T_9d623_row5_col1" class="data row5 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_9d623_row6_col0" class="data row6 col0" >0.019721</td>
#       <td id="T_9d623_row6_col1" class="data row6 col1" >126.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_9d623_row7_col0" class="data row7 col0" >0.478752</td>
#       <td id="T_9d623_row7_col1" class="data row7 col1" >252.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_9d623_row8_col0" class="data row8 col0" >0.591734</td>
#       <td id="T_9d623_row8_col1" class="data row8 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_9d623_row9_col0" class="data row9 col0" >0.077920</td>
#       <td id="T_9d623_row9_col1" class="data row9 col1" >72.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_9d623_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_9d623_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9d623_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_9d623_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_9d623_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# div
d6.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_cc275_row0_col0, #T_cc275_row0_col1, #T_cc275_row1_col0, #T_cc275_row1_col1, #T_cc275_row10_col0, #T_cc275_row10_col1, #T_cc275_row11_col0, #T_cc275_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_cc275">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc275_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_cc275_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc275_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_cc275_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_cc275_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_cc275_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_cc275_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_cc275_row2_col0" class="data row2 col0" >1.476988</td>
#       <td id="T_cc275_row2_col1" class="data row2 col1" >0.375000</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_cc275_row3_col0" class="data row3 col0" >0.629577</td>
#       <td id="T_cc275_row3_col1" class="data row3 col1" >2.875000</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_cc275_row4_col0" class="data row4 col0" >1.501852</td>
#       <td id="T_cc275_row4_col1" class="data row4 col1" >0.476190</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_cc275_row5_col0" class="data row5 col0" >2.957416</td>
#       <td id="T_cc275_row5_col1" class="data row5 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_cc275_row6_col0" class="data row6 col0" >0.259312</td>
#       <td id="T_cc275_row6_col1" class="data row6 col1" >0.642857</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_cc275_row7_col0" class="data row7 col0" >0.923767</td>
#       <td id="T_cc275_row7_col1" class="data row7 col1" >0.571429</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_cc275_row8_col0" class="data row8 col0" >1.113407</td>
#       <td id="T_cc275_row8_col1" class="data row8 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_cc275_row9_col0" class="data row9 col0" >4.470286</td>
#       <td id="T_cc275_row9_col1" class="data row9 col1" >0.222222</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_cc275_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_cc275_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc275_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_cc275_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_cc275_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### removing the NaN values from the resultant dataframe

# %%
# the + operation is UNION of indexes
d31 = d1 + d2
# indexs not present in the other dataframe get a NaN
# do you can obvs remove nan values like before
d3.dropna().style.highlight_null(color="red")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ececa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ececa_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ececa_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ececa_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_ececa_row0_col0" class="data row0 col0" >0.572930</td>
#       <td id="T_ececa_row0_col1" class="data row0 col1" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ececa_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_ececa_row1_col0" class="data row1 col0" >1.295413</td>
#       <td id="T_ececa_row1_col1" class="data row1 col1" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ececa_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_ececa_row2_col0" class="data row2 col0" >0.914220</td>
#       <td id="T_ececa_row2_col1" class="data row2 col1" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ececa_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_ececa_row3_col0" class="data row3 col0" >1.140936</td>
#       <td id="T_ececa_row3_col1" class="data row3 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ececa_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_ececa_row4_col0" class="data row4 col0" >0.347289</td>
#       <td id="T_ececa_row4_col1" class="data row4 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ececa_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_ececa_row5_col0" class="data row5 col0" >1.384926</td>
#       <td id="T_ececa_row5_col1" class="data row5 col1" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ececa_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_ececa_row6_col0" class="data row6 col0" >1.540705</td>
#       <td id="T_ececa_row6_col1" class="data row6 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ececa_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_ececa_row7_col0" class="data row7 col0" >0.722214</td>
#       <td id="T_ececa_row7_col1" class="data row7 col1" >22.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## df.align()

# %% [markdown]
# Pandas [align](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.align.html) works to join the dataframes in interesting ways.

# %%
# align returns two dataframes - left and right as a result of a join
# default join is outer - the union of indices will be used as index for left and right
left, right = d1.align(d2, join="outer")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4418b" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4418b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_4418b_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4418b_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_4418b_row0_col0" class="data row0 col0" >0.903481</td>
#       <td id="T_4418b_row0_col1" class="data row0 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_4418b_row1_col0" class="data row1 col0" >0.860529</td>
#       <td id="T_4418b_row1_col1" class="data row1 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_4418b_row2_col0" class="data row2 col0" >0.341629</td>
#       <td id="T_4418b_row2_col1" class="data row2 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_4418b_row3_col0" class="data row3 col0" >0.500474</td>
#       <td id="T_4418b_row3_col1" class="data row3 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_4418b_row4_col0" class="data row4 col0" >0.548803</td>
#       <td id="T_4418b_row4_col1" class="data row4 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_4418b_row5_col0" class="data row5 col0" >0.852633</td>
#       <td id="T_4418b_row5_col1" class="data row5 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_4418b_row6_col0" class="data row6 col0" >0.071512</td>
#       <td id="T_4418b_row6_col1" class="data row6 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_4418b_row7_col0" class="data row7 col0" >0.665023</td>
#       <td id="T_4418b_row7_col1" class="data row7 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_4418b_row8_col0" class="data row8 col0" >0.811690</td>
#       <td id="T_4418b_row8_col1" class="data row8 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_4418b_row9_col0" class="data row9 col0" >0.590189</td>
#       <td id="T_4418b_row9_col1" class="data row9 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_4418b_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_4418b_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4418b_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_4418b_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_4418b_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_a5874" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5874_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a5874_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5874_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_a5874_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a5874_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_a5874_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_a5874_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_a5874_row2_col0" class="data row2 col0" >0.231301</td>
#       <td id="T_a5874_row2_col1" class="data row2 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_a5874_row3_col0" class="data row3 col0" >0.794938</td>
#       <td id="T_a5874_row3_col1" class="data row3 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_a5874_row4_col0" class="data row4 col0" >0.365418</td>
#       <td id="T_a5874_row4_col1" class="data row4 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_a5874_row5_col0" class="data row5 col0" >0.288303</td>
#       <td id="T_a5874_row5_col1" class="data row5 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_a5874_row6_col0" class="data row6 col0" >0.275777</td>
#       <td id="T_a5874_row6_col1" class="data row6 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_a5874_row7_col0" class="data row7 col0" >0.719903</td>
#       <td id="T_a5874_row7_col1" class="data row7 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_a5874_row8_col0" class="data row8 col0" >0.729015</td>
#       <td id="T_a5874_row8_col1" class="data row8 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_a5874_row9_col0" class="data row9 col0" >0.132025</td>
#       <td id="T_a5874_row9_col1" class="data row9 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_a5874_row10_col0" class="data row10 col0" >0.035142</td>
#       <td id="T_a5874_row10_col1" class="data row10 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5874_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_a5874_row11_col0" class="data row11 col0" >0.563783</td>
#       <td id="T_a5874_row11_col1" class="data row11 col1" >23.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# inner join
left, right = d1.align(d2, join="inner")
render_df_side_by_side(d1, d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_53440" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53440_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_53440_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53440_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_53440_row0_col0" class="data row0 col0" >0.903481</td>
#       <td id="T_53440_row0_col1" class="data row0 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_53440_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_53440_row1_col0" class="data row1 col0" >0.860529</td>
#       <td id="T_53440_row1_col1" class="data row1 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_53440_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_53440_row2_col0" class="data row2 col0" >0.341629</td>
#       <td id="T_53440_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_53440_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_53440_row3_col0" class="data row3 col0" >0.500474</td>
#       <td id="T_53440_row3_col1" class="data row3 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_53440_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_53440_row4_col0" class="data row4 col0" >0.548803</td>
#       <td id="T_53440_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_53440_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_53440_row5_col0" class="data row5 col0" >0.852633</td>
#       <td id="T_53440_row5_col1" class="data row5 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_53440_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_53440_row6_col0" class="data row6 col0" >0.071512</td>
#       <td id="T_53440_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_53440_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_53440_row7_col0" class="data row7 col0" >0.665023</td>
#       <td id="T_53440_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_53440_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_53440_row8_col0" class="data row8 col0" >0.811690</td>
#       <td id="T_53440_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_53440_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_53440_row9_col0" class="data row9 col0" >0.590189</td>
#       <td id="T_53440_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_10148" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10148_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_10148_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10148_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_10148_row0_col0" class="data row0 col0" >0.231301</td>
#       <td id="T_10148_row0_col1" class="data row0 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_10148_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_10148_row1_col0" class="data row1 col0" >0.794938</td>
#       <td id="T_10148_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_10148_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_10148_row2_col0" class="data row2 col0" >0.365418</td>
#       <td id="T_10148_row2_col1" class="data row2 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_10148_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_10148_row3_col0" class="data row3 col0" >0.288303</td>
#       <td id="T_10148_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_10148_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_10148_row4_col0" class="data row4 col0" >0.275777</td>
#       <td id="T_10148_row4_col1" class="data row4 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_10148_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_10148_row5_col0" class="data row5 col0" >0.719903</td>
#       <td id="T_10148_row5_col1" class="data row5 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_10148_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_10148_row6_col0" class="data row6 col0" >0.729015</td>
#       <td id="T_10148_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_10148_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_10148_row7_col0" class="data row7 col0" >0.132025</td>
#       <td id="T_10148_row7_col1" class="data row7 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_10148_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_10148_row8_col0" class="data row8 col0" >0.035142</td>
#       <td id="T_10148_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_10148_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_10148_row9_col0" class="data row9 col0" >0.563783</td>
#       <td id="T_10148_row9_col1" class="data row9 col1" >23</td>
#     </tr>
#   </tbody>
# </table>

# %%
# we can fill the NaNs with a certain value if needed
# let's fill with -100 so we can see it clearly
left, right = d1.align(d2, join="outer", fill_value=-100)
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ecaf5" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecaf5_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ecaf5_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecaf5_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_ecaf5_row0_col0" class="data row0 col0" >0.903481</td>
#       <td id="T_ecaf5_row0_col1" class="data row0 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_ecaf5_row1_col0" class="data row1 col0" >0.860529</td>
#       <td id="T_ecaf5_row1_col1" class="data row1 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_ecaf5_row2_col0" class="data row2 col0" >0.341629</td>
#       <td id="T_ecaf5_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_ecaf5_row3_col0" class="data row3 col0" >0.500474</td>
#       <td id="T_ecaf5_row3_col1" class="data row3 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_ecaf5_row4_col0" class="data row4 col0" >0.548803</td>
#       <td id="T_ecaf5_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_ecaf5_row5_col0" class="data row5 col0" >0.852633</td>
#       <td id="T_ecaf5_row5_col1" class="data row5 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_ecaf5_row6_col0" class="data row6 col0" >0.071512</td>
#       <td id="T_ecaf5_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_ecaf5_row7_col0" class="data row7 col0" >0.665023</td>
#       <td id="T_ecaf5_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_ecaf5_row8_col0" class="data row8 col0" >0.811690</td>
#       <td id="T_ecaf5_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_ecaf5_row9_col0" class="data row9 col0" >0.590189</td>
#       <td id="T_ecaf5_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_ecaf5_row10_col0" class="data row10 col0" >-100.000000</td>
#       <td id="T_ecaf5_row10_col1" class="data row10 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_ecaf5_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_ecaf5_row11_col0" class="data row11 col0" >-100.000000</td>
#       <td id="T_ecaf5_row11_col1" class="data row11 col1" >-100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d6c83" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6c83_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d6c83_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6c83_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_d6c83_row0_col0" class="data row0 col0" >-100.000000</td>
#       <td id="T_d6c83_row0_col1" class="data row0 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_d6c83_row1_col0" class="data row1 col0" >-100.000000</td>
#       <td id="T_d6c83_row1_col1" class="data row1 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_d6c83_row2_col0" class="data row2 col0" >0.231301</td>
#       <td id="T_d6c83_row2_col1" class="data row2 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_d6c83_row3_col0" class="data row3 col0" >0.794938</td>
#       <td id="T_d6c83_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_d6c83_row4_col0" class="data row4 col0" >0.365418</td>
#       <td id="T_d6c83_row4_col1" class="data row4 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_d6c83_row5_col0" class="data row5 col0" >0.288303</td>
#       <td id="T_d6c83_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_d6c83_row6_col0" class="data row6 col0" >0.275777</td>
#       <td id="T_d6c83_row6_col1" class="data row6 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_d6c83_row7_col0" class="data row7 col0" >0.719903</td>
#       <td id="T_d6c83_row7_col1" class="data row7 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_d6c83_row8_col0" class="data row8 col0" >0.729015</td>
#       <td id="T_d6c83_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_d6c83_row9_col0" class="data row9 col0" >0.132025</td>
#       <td id="T_d6c83_row9_col1" class="data row9 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_d6c83_row10_col0" class="data row10 col0" >0.035142</td>
#       <td id="T_d6c83_row10_col1" class="data row10 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_d6c83_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_d6c83_row11_col0" class="data row11 col0" >0.563783</td>
#       <td id="T_d6c83_row11_col1" class="data row11 col1" >23</td>
#     </tr>
#   </tbody>
# </table>

# %%
# left join: left index is added to right, but not the other way
left, right = d1.align(d2, join="left")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_66953" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66953_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_66953_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66953_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_66953_row0_col0" class="data row0 col0" >0.903481</td>
#       <td id="T_66953_row0_col1" class="data row0 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_66953_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_66953_row1_col0" class="data row1 col0" >0.860529</td>
#       <td id="T_66953_row1_col1" class="data row1 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_66953_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_66953_row2_col0" class="data row2 col0" >0.341629</td>
#       <td id="T_66953_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_66953_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_66953_row3_col0" class="data row3 col0" >0.500474</td>
#       <td id="T_66953_row3_col1" class="data row3 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_66953_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_66953_row4_col0" class="data row4 col0" >0.548803</td>
#       <td id="T_66953_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_66953_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_66953_row5_col0" class="data row5 col0" >0.852633</td>
#       <td id="T_66953_row5_col1" class="data row5 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_66953_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_66953_row6_col0" class="data row6 col0" >0.071512</td>
#       <td id="T_66953_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_66953_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_66953_row7_col0" class="data row7 col0" >0.665023</td>
#       <td id="T_66953_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_66953_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_66953_row8_col0" class="data row8 col0" >0.811690</td>
#       <td id="T_66953_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_66953_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_66953_row9_col0" class="data row9 col0" >0.590189</td>
#       <td id="T_66953_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d7fd4" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7fd4_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d7fd4_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7fd4_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_d7fd4_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_d7fd4_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d7fd4_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_d7fd4_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_d7fd4_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d7fd4_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_d7fd4_row2_col0" class="data row2 col0" >0.231301</td>
#       <td id="T_d7fd4_row2_col1" class="data row2 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fd4_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_d7fd4_row3_col0" class="data row3 col0" >0.794938</td>
#       <td id="T_d7fd4_row3_col1" class="data row3 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fd4_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_d7fd4_row4_col0" class="data row4 col0" >0.365418</td>
#       <td id="T_d7fd4_row4_col1" class="data row4 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fd4_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_d7fd4_row5_col0" class="data row5 col0" >0.288303</td>
#       <td id="T_d7fd4_row5_col1" class="data row5 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fd4_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_d7fd4_row6_col0" class="data row6 col0" >0.275777</td>
#       <td id="T_d7fd4_row6_col1" class="data row6 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fd4_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_d7fd4_row7_col0" class="data row7 col0" >0.719903</td>
#       <td id="T_d7fd4_row7_col1" class="data row7 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fd4_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_d7fd4_row8_col0" class="data row8 col0" >0.729015</td>
#       <td id="T_d7fd4_row8_col1" class="data row8 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fd4_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_d7fd4_row9_col0" class="data row9 col0" >0.132025</td>
#       <td id="T_d7fd4_row9_col1" class="data row9 col1" >18.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# right join: right index is added to left, but not the other way
left, right = d1.align(d2, join="right")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_75293" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75293_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_75293_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75293_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_75293_row0_col0" class="data row0 col0" >0.341629</td>
#       <td id="T_75293_row0_col1" class="data row0 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75293_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_75293_row1_col0" class="data row1 col0" >0.500474</td>
#       <td id="T_75293_row1_col1" class="data row1 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75293_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_75293_row2_col0" class="data row2 col0" >0.548803</td>
#       <td id="T_75293_row2_col1" class="data row2 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75293_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_75293_row3_col0" class="data row3 col0" >0.852633</td>
#       <td id="T_75293_row3_col1" class="data row3 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75293_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_75293_row4_col0" class="data row4 col0" >0.071512</td>
#       <td id="T_75293_row4_col1" class="data row4 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75293_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_75293_row5_col0" class="data row5 col0" >0.665023</td>
#       <td id="T_75293_row5_col1" class="data row5 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75293_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_75293_row6_col0" class="data row6 col0" >0.811690</td>
#       <td id="T_75293_row6_col1" class="data row6 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75293_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_75293_row7_col0" class="data row7 col0" >0.590189</td>
#       <td id="T_75293_row7_col1" class="data row7 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75293_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_75293_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_75293_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_75293_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_75293_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_75293_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6494d" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6494d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6494d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6494d_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_6494d_row0_col0" class="data row0 col0" >0.231301</td>
#       <td id="T_6494d_row0_col1" class="data row0 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_6494d_row1_col0" class="data row1 col0" >0.794938</td>
#       <td id="T_6494d_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_6494d_row2_col0" class="data row2 col0" >0.365418</td>
#       <td id="T_6494d_row2_col1" class="data row2 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_6494d_row3_col0" class="data row3 col0" >0.288303</td>
#       <td id="T_6494d_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_6494d_row4_col0" class="data row4 col0" >0.275777</td>
#       <td id="T_6494d_row4_col1" class="data row4 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_6494d_row5_col0" class="data row5 col0" >0.719903</td>
#       <td id="T_6494d_row5_col1" class="data row5 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_6494d_row6_col0" class="data row6 col0" >0.729015</td>
#       <td id="T_6494d_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_6494d_row7_col0" class="data row7 col0" >0.132025</td>
#       <td id="T_6494d_row7_col1" class="data row7 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_6494d_row8_col0" class="data row8 col0" >0.035142</td>
#       <td id="T_6494d_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_6494d_row9_col0" class="data row9 col0" >0.563783</td>
#       <td id="T_6494d_row9_col1" class="data row9 col1" >23</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's more to explore in align, and it can get confusing, so beginners be careful, take time and try to work out the result before you execute to build intuition.

# %% [markdown]
# # Operations on data

# %% [markdown]
# ## Stats
#
# Operations in general *exclude* missing data

# %%
# arithmetic mean, for each column (axis = 0)
df.mean()
# Out:
# A    -0.276622
# B    -0.083775
# C    -0.416333
# D     0.080742
# F    15.500000
# dtype: float64

# %%
# mean across a row (axis = 1)
df.mean(1)
# Out:
# 2022-06-19    1.820450
# 2022-06-20    2.157306
# 2022-06-21    3.016901
# 2022-06-22    2.426215
# 2022-06-23    2.401557
# 2022-06-24    2.697915
# 2022-06-25    3.691468
# 2022-06-26    3.688209
# 2022-06-27    3.178462
# 2022-06-28    4.529542
# Freq: D, dtype: float64

# %% [markdown]
# ## Apply

# %%
# apply custom lambdas
df.apply(lambda x: x.max() - x.min())
# Out:
# A    3.227358
# B    2.335830
# C    3.766171
# D    2.398962
# F    9.000000
# dtype: float64

# %%
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -0.161554  0.780109 -1.716052 -0.800255  11
# 2022-06-20 -0.801679  0.026026 -0.765367  0.327550  12
# 2022-06-21  1.054395  0.107859  1.368059 -0.445811  13
# 2022-06-22 -1.403634  0.223348 -0.884526  0.195886  14
# 2022-06-23 -2.170105 -1.442093  0.403281  0.216700  15
# 2022-06-24 -0.273735 -1.555721  0.494120 -1.175087  16
# 2022-06-25  0.575393  0.543238  0.815611 -0.476902  17
# 2022-06-26  0.277486  0.753339 -1.813655  1.223875  18
# 2022-06-27 -0.920041 -0.370802 -2.398111  0.581265  19
# 2022-06-28  1.057253  0.096951  0.333307  1.160199  20

# %%
# each subsequent value is a sum of all values before it in the respective column
cumsum_df = df.apply(np.cumsum)
render_df_side_by_side(df, cumsum_df, "OG Dataframe", "Cumulative Sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_2ae5a" style='display:inline'>
#   <caption>OG Dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ae5a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_2ae5a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_2ae5a_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_2ae5a_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_2ae5a_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ae5a_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_2ae5a_row0_col0" class="data row0 col0" >-0.161554</td>
#       <td id="T_2ae5a_row0_col1" class="data row0 col1" >0.780109</td>
#       <td id="T_2ae5a_row0_col2" class="data row0 col2" >-1.716052</td>
#       <td id="T_2ae5a_row0_col3" class="data row0 col3" >-0.800255</td>
#       <td id="T_2ae5a_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_2ae5a_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_2ae5a_row1_col0" class="data row1 col0" >-0.801679</td>
#       <td id="T_2ae5a_row1_col1" class="data row1 col1" >0.026026</td>
#       <td id="T_2ae5a_row1_col2" class="data row1 col2" >-0.765367</td>
#       <td id="T_2ae5a_row1_col3" class="data row1 col3" >0.327550</td>
#       <td id="T_2ae5a_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_2ae5a_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_2ae5a_row2_col0" class="data row2 col0" >1.054395</td>
#       <td id="T_2ae5a_row2_col1" class="data row2 col1" >0.107859</td>
#       <td id="T_2ae5a_row2_col2" class="data row2 col2" >1.368059</td>
#       <td id="T_2ae5a_row2_col3" class="data row2 col3" >-0.445811</td>
#       <td id="T_2ae5a_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_2ae5a_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_2ae5a_row3_col0" class="data row3 col0" >-1.403634</td>
#       <td id="T_2ae5a_row3_col1" class="data row3 col1" >0.223348</td>
#       <td id="T_2ae5a_row3_col2" class="data row3 col2" >-0.884526</td>
#       <td id="T_2ae5a_row3_col3" class="data row3 col3" >0.195886</td>
#       <td id="T_2ae5a_row3_col4" class="data row3 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_2ae5a_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_2ae5a_row4_col0" class="data row4 col0" >-2.170105</td>
#       <td id="T_2ae5a_row4_col1" class="data row4 col1" >-1.442093</td>
#       <td id="T_2ae5a_row4_col2" class="data row4 col2" >0.403281</td>
#       <td id="T_2ae5a_row4_col3" class="data row4 col3" >0.216700</td>
#       <td id="T_2ae5a_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_2ae5a_level0_row5" class="row_heading level0 row5" >2022-06-24 00:00:00</th>
#       <td id="T_2ae5a_row5_col0" class="data row5 col0" >-0.273735</td>
#       <td id="T_2ae5a_row5_col1" class="data row5 col1" >-1.555721</td>
#       <td id="T_2ae5a_row5_col2" class="data row5 col2" >0.494120</td>
#       <td id="T_2ae5a_row5_col3" class="data row5 col3" >-1.175087</td>
#       <td id="T_2ae5a_row5_col4" class="data row5 col4" >16</td>
#     </tr>
#     <tr>
#       <th id="T_2ae5a_level0_row6" class="row_heading level0 row6" >2022-06-25 00:00:00</th>
#       <td id="T_2ae5a_row6_col0" class="data row6 col0" >0.575393</td>
#       <td id="T_2ae5a_row6_col1" class="data row6 col1" >0.543238</td>
#       <td id="T_2ae5a_row6_col2" class="data row6 col2" >0.815611</td>
#       <td id="T_2ae5a_row6_col3" class="data row6 col3" >-0.476902</td>
#       <td id="T_2ae5a_row6_col4" class="data row6 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_2ae5a_level0_row7" class="row_heading level0 row7" >2022-06-26 00:00:00</th>
#       <td id="T_2ae5a_row7_col0" class="data row7 col0" >0.277486</td>
#       <td id="T_2ae5a_row7_col1" class="data row7 col1" >0.753339</td>
#       <td id="T_2ae5a_row7_col2" class="data row7 col2" >-1.813655</td>
#       <td id="T_2ae5a_row7_col3" class="data row7 col3" >1.223875</td>
#       <td id="T_2ae5a_row7_col4" class="data row7 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_2ae5a_level0_row8" class="row_heading level0 row8" >2022-06-27 00:00:00</th>
#       <td id="T_2ae5a_row8_col0" class="data row8 col0" >-0.920041</td>
#       <td id="T_2ae5a_row8_col1" class="data row8 col1" >-0.370802</td>
#       <td id="T_2ae5a_row8_col2" class="data row8 col2" >-2.398111</td>
#       <td id="T_2ae5a_row8_col3" class="data row8 col3" >0.581265</td>
#       <td id="T_2ae5a_row8_col4" class="data row8 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_2ae5a_level0_row9" class="row_heading level0 row9" >2022-06-28 00:00:00</th>
#       <td id="T_2ae5a_row9_col0" class="data row9 col0" >1.057253</td>
#       <td id="T_2ae5a_row9_col1" class="data row9 col1" >0.096951</td>
#       <td id="T_2ae5a_row9_col2" class="data row9 col2" >0.333307</td>
#       <td id="T_2ae5a_row9_col3" class="data row9 col3" >1.160199</td>
#       <td id="T_2ae5a_row9_col4" class="data row9 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_65bb7" style='display:inline'>
#   <caption>Cumulative Sum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65bb7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_65bb7_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_65bb7_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_65bb7_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_65bb7_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65bb7_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_65bb7_row0_col0" class="data row0 col0" >-0.161554</td>
#       <td id="T_65bb7_row0_col1" class="data row0 col1" >0.780109</td>
#       <td id="T_65bb7_row0_col2" class="data row0 col2" >-1.716052</td>
#       <td id="T_65bb7_row0_col3" class="data row0 col3" >-0.800255</td>
#       <td id="T_65bb7_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_65bb7_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_65bb7_row1_col0" class="data row1 col0" >-0.963233</td>
#       <td id="T_65bb7_row1_col1" class="data row1 col1" >0.806135</td>
#       <td id="T_65bb7_row1_col2" class="data row1 col2" >-2.481419</td>
#       <td id="T_65bb7_row1_col3" class="data row1 col3" >-0.472705</td>
#       <td id="T_65bb7_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_65bb7_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_65bb7_row2_col0" class="data row2 col0" >0.091162</td>
#       <td id="T_65bb7_row2_col1" class="data row2 col1" >0.913994</td>
#       <td id="T_65bb7_row2_col2" class="data row2 col2" >-1.113360</td>
#       <td id="T_65bb7_row2_col3" class="data row2 col3" >-0.918516</td>
#       <td id="T_65bb7_row2_col4" class="data row2 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_65bb7_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_65bb7_row3_col0" class="data row3 col0" >-1.312472</td>
#       <td id="T_65bb7_row3_col1" class="data row3 col1" >1.137342</td>
#       <td id="T_65bb7_row3_col2" class="data row3 col2" >-1.997886</td>
#       <td id="T_65bb7_row3_col3" class="data row3 col3" >-0.722630</td>
#       <td id="T_65bb7_row3_col4" class="data row3 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_65bb7_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_65bb7_row4_col0" class="data row4 col0" >-3.482578</td>
#       <td id="T_65bb7_row4_col1" class="data row4 col1" >-0.304751</td>
#       <td id="T_65bb7_row4_col2" class="data row4 col2" >-1.594605</td>
#       <td id="T_6

# %% [markdown]
# ## Histogramming
#
# Frequencies, 'nuff said
#
# ```value_counts()```

# %%
series1 = pd.Series(np.random.randint(0, 5, size=25))
series1.value_counts()
# Out:
# 0    8
# 3    7
# 1    7
# 4    2
# 2    1
# Name: count, dtype: int64

# %% [markdown]
# ## String Methods

# %%
# build a series
some_string = "SERIes and Index are EqUIppeD WITh A seT Of stRINg PROCESSING METHoDs In tHe ```sTR``` attrIBute THAT MakE IT eASy To oPerATE ON EACh ELEmeNt OF The aRrAY. NOtE thAt PAtTERN-maTching in ```sTR``` gENeralLY UsES reGUlAr eXpreSsiONs bY DEfault (aND In Some cases AlwayS uSEs tHeM)."
str_series = pd.Series(some_string.split())  # split splits on whitespace by default

# %%
# manipulating the case - lower, upper etc.
# also the length of each string, split, replace, yada yada...
# very important when cleaning data (column names may have stupid whitespace, bad case, spacing etc.)
low = str_series.str.lower()
up = str_series.str.upper()

low_up_df = pd.DataFrame(
    {
        "og": str_series,
        "length": str_series.str.len(),
        "low": low,
        "up": up,
        "split_low_on_i": low.str.split(
            "i", expand=False
        ),  # expand = True will break this usecase, try elsewhere
        "replace_a_with_star_in_low": low.str.replace(
            "a", "*", case=False, regex=True
        ),  # yeah, you can mess with regular expns
    }
)

low_up_df.tail(10)
# Out:
#              og  length          low           up  split_low_on_i  \
# 36  eXpreSsiONs      11  expressions  EXPRESSIONS  [express, ons]
# 37           bY       2           by           BY            [by]
# 38      DEfault       7      default      DEFAULT       [default]
# 39         (aND       4         (and         (AND          [(and]
# 40           In       2           in           IN           [, n]
# 41         Some       4         some         SOME          [some]
# 42        cases       5        cases        CASES         [cases]
# 43       AlwayS       6       always       ALWAYS        [always]
# 44         uSEs       4         uses         USES          [uses]
# 45       tHeM).       6       them).       THEM).        [them).]
#
#    replace_a_with_star_in_low
# 36                expressions
# 37                         by
# 38                    def*ult
# 39                       (*nd
# 40                         in
# 41                       some
# 42                      c*ses
# 43                     *lw*ys
# 44                       uses
# 45                     them).

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods) for more string operations.

# %% [markdown]
# # Merge
#
# Combine series and dataframes, use set logic for indexes and relational algebra for joins/merges

# %% [markdown]
# ## Concat
#
# Chill, we've done this before. The same join = inner/outer/left/right drill.

# %%
# let's make some more dataframes
concatDF = pd.DataFrame(
    np.random.randn(10, 4)
)  # 10 rows and 4 columns of random numbers
pieces = [concatDF[:3], concatDF[3:7], concatDF[7:]]
reconstructedDF = pd.concat(pieces)
display("broken DFs: ", pieces)
render_df_side_by_side(concatDF, reconstructedDF, "OG", "Concatenated")
# Out:
# 'broken DFs: '
# [          0         1         2         3
#  0  0.533320  1.335722  0.441955  0.781734
#  1 -1.577649 -1.064618  0.186338 -0.983739
#  2  0.989040 -0.120039  0.348547 -0.418675,
#            0         1         2         3
#  3  0.110863 -2.749372  0.933766 -1.136921
#  4 -0.769617 -0.324856 -0.248470 -0.317666
#  5 -1.817356 -0.128594  1.414193 -0.858098
#  6 -0.966036  0.462087 -1.450937  1.342852,
#            0         1         2         3
#  7  2.243377 -0.419601 -0.250426  0.687115
#  8 -0.387763 -0.122755  0.997458 -1.051615
#  9  1.042432 -0.480239 -0.924921 -0.128279]
# <style type="text/css">
# </style>
# <table id="T_f0649" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0649_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f0649_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f0649_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f0649_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0649_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0649_row0_col0" class="data row0 col0" >0.533320</td>
#       <td id="T_f0649_row0_col1" class="data row0 col1" >1.335722</td>
#       <td id="T_f0649_row0_col2" class="data row0 col2" >0.441955</td>
#       <td id="T_f0649_row0_col3" class="data row0 col3" >0.781734</td>
#     </tr>
#     <tr>
#       <th id="T_f0649_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0649_row1_col0" class="data row1 col0" >-1.577649</td>
#       <td id="T_f0649_row1_col1" class="data row1 col1" >-1.064618</td>
#       <td id="T_f0649_row1_col2" class="data row1 col2" >0.186338</td>
#       <td id="T_f0649_row1_col3" class="data row1 col3" >-0.983739</td>
#     </tr>
#     <tr>
#       <th id="T_f0649_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f0649_row2_col0" class="data row2 col0" >0.989040</td>
#       <td id="T_f0649_row2_col1" class="data row2 col1" >-0.120039</td>
#       <td id="T_f0649_row2_col2" class="data row2 col2" >0.348547</td>
#       <td id="T_f0649_row2_col3" class="data row2 col3" >-0.418675</td>
#     </tr>
#     <tr>
#       <th id="T_f0649_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f0649_row3_col0" class="data row3 col0" >0.110863</td>
#       <td id="T_f0649_row3_col1" class="data row3 col1" >-2.749372</td>
#       <td id="T_f0649_row3_col2" class="data row3 col2" >0.933766</td>
#       <td id="T_f0649_row3_col3" class="data row3 col3" >-1.136921</td>
#     </tr>
#     <tr>
#       <th id="T_f0649_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f0649_row4_col0" class="data row4 col0" >-0.769617</td>
#       <td id="T_f0649_row4_col1" class="data row4 col1" >-0.324856</td>
#       <td id="T_f0649_row4_col2" class="data row4 col2" >-0.248470</td>
#       <td id="T_f0649_row4_col3" class="data row4 col3" >-0.317666</td>
#     </tr>
#     <tr>
#       <th id="T_f0649_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f0649_row5_col0" class="data row5 col0" >-1.817356</td>
#       <td id="T_f0649_row5_col1" class="data row5 col1" >-0.128594</td>
#       <td id="T_f0649_row5_col2" class="data row5 col2" >1.414193</td>
#       <td id="T_f0649_row5_col3" class="data row5 col3" >-0.858098</td>
#     </tr>
#     <tr>
#       <th id="T_f0649_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f0649_row6_col0" class="data row6 col0" >-0.966036</td>
#       <td id="T_f0649_row6_col1" class="data row6 col1" >0.462087</td>
#       <td id="T_f0649_row6_col2" class="data row6 col2" >-1.450937</td>
#       <td id="T_f0649_row6_col3" class="data row6 col3" >1.342852</td>
#     </tr>
#     <tr>
#       <th id="T_f0649_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f0649_row7_col0" class="data row7 col0" >2.243377</td>
#       <td id="T_f0649_row7_col1" class="data row7 col1" >-0.419601</td>
#       <td id="T_f0649_row7_col2" class="data row7 col2" >-0.250426</td>
#       <td id="T_f0649_row7_col3" class="data row7 col3" >0.687115</td>
#     </tr>
#     <tr>
#       <th id="T_f0649_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f0649_row8_col0" class="data row8 col0" >-0.387763</td>
#       <td id="T_f0649_row8_col1" class="data row8 col1" >-0.122755</td>
#       <td id="T_f0649_row8_col2" class="data row8 col2" >0.997458</td>
#       <td id="T_f0649_row8_col3" class="data row8 col3" >-1.051615</td>
#     </tr>
#     <tr>
#       <th id="T_f0649_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f0649_row9_col0" class="data row9 col0" >1.042432</td>
#       <td id="T_f0649_row9_col1" class="data row9 col1" >-0.480239</td>
#       <td id="T_f0649_row9_col2" class="data row9 col2" >-0.924921</td>
#       <td id="T_f0649_row9_col3" class="data row9 col3" >-0.128279</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4c257" style='display:inline'>
#   <caption>Concatenated</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c257_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4c257_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4c257_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_4c257_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c257_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c257_row0_col0" class="data row0 col0" >0.533320</td>
#       <td id="T_4c257_row0_col1" class="data row0 col1" >1.335722</td>
#       <td id="T_4c257_row0_col2" class="data row0 col2" >0.441955</td>
#       <td id="T_4c257_row0_col3" class="data row0 col3" >0.781734</td>
#     </tr>
#     <tr>
#       <th id="T_4c257_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c257_row1_col0" class="data row1 col0" >-1.577649</td>
#       <td id="T_4c257_row1_col1" class="data row1 col1" >-1.064618</td>
#       <td id="T_4c257_row1_col2" class="data row1 col2" >0.186338</td>
#       <td id="T_4c257_row1_col3" class="data row1 col3" >-0.983739</td>
#     </tr>
#     <tr>
#       <th id="T_4c257_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c257_row2_col0" class="data row2 col0" >0.989040</td>
#       <td id="T_4c257_row2_col1" class="data row2 col1" >-0.120039</td>
#       <td id="T_4c257_row2_col2" class="data row2 col2" >0.348547</td>
#       <td id="T_4c257_row2_col3" class="data row2 col3" >-0.418675</td>
#     </tr>
#     <tr>
#       <th id="T_4c257_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4c257_row3_col0" class="data row3 col0" >0.110863</td>
#       <td id="T_4c257_row3_col1" class="data row3 col1" >-2.749372</td>
#       <td id="T_4c257_row3_col2" class="data row3 col2" >0.933766</td>
#       <td id="T_4c257_row3_col3" class="data row3 col3" >-1.136921</td>
#     </tr>
#     <tr>
#       <th id="T_4c257_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4c257_row4_col0" class="data row4 col0" >-0.769617</td>
#       <td id="T_4c257_row4_col1" class="data row4 col1" >-0.324856</td>
#       <td id="T_4c257_row4_col2" class="data row4 col2" >-0.248470</td>
#       <td id="T_4c257_row4_col3" class="data row4 col3" >-0.317666</td>
#     </tr>
#     <tr>
#       <th id="T_4c257_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4c257_row5_col0" class="data row5 col0" >-1.817356</td>
#       <td id="T_4c257_row5_col1" class="data row5 col1" >-0.128594</td>
#       <td id="T_4c257_row5_col2" class="data row5 col2" >1.414193</td>
#       <td id="T_4c257_row5_col3" class="data row5 col3" >-0.858098</td>
#     </tr>
#     <tr>
#       <th id="T_4c257_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4c257_row6_col0" class="data row6 col0" >-0.966036</td>
#       <td id="T_4c257_row6_col1" class="data row6 col1" >0.462087</td>
#       <td id="T_4c257_row6_col2" class="data row6 col2" >-1.450937</td>
#       <td id="T_4c257_row6_col3" class="data row6 col3" >1.342852</td>
#     </tr>
#     <tr>
#       <th id="T_4c257_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4c257_row7_col0" class="data row7 col0" >2.243377</td>
#       <td id="T_4c257_row7_col1" class="data row7 col1" >-0.419601</td>
#       <td id="T_4c257_row7_col2" class="data row7 col2" >-0.250426</td>
#       <td id="T_4c257_row7_col3" class="data row7 col3" >0.687115</td>
#     </tr>
#     <tr>
#       <th id="T_4c257_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4c257_row8_col0" class="data row8

# %% [markdown]
# _From the [page](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#concat)_:
# Adding a column to a DataFrame is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the DataFrame constructor instead of building a DataFrame by iteratively appending records to it.

# %% [markdown]
# ## Join
# SQL style merges.

# %%
# two data frames
sl = pd.Series(np.random.randint(10, size=6))
sr = sl.shift(2).fillna(0).astype(int)
left = pd.DataFrame({"key": list("ABCDEF"), "lval": sl})

right = pd.DataFrame({"key": list("ABBCDE"), "rval": sr})

# %%
render_df_side_by_side(left, right, "left", "right")
# Out:
# <style type="text/css">
# </style>
# <table id="T_89fd0" style='display:inline'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89fd0_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_89fd0_level0_col1" class="col_heading level0 col1" >lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89fd0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89fd0_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_89fd0_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_89fd0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_89fd0_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_89fd0_row1_col1" class="data row1 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_89fd0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_89fd0_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_89fd0_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_89fd0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_89fd0_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_89fd0_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_89fd0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_89fd0_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_89fd0_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_89fd0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_89fd0_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_89fd0_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_146fb" style='display:inline'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_146fb_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_146fb_level0_col1" class="col_heading level0 col1" >rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_146fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_146fb_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_146fb_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_146fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_146fb_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_146fb_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_146fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_146fb_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_146fb_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_146fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_146fb_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_146fb_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_146fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_146fb_row4_col0" class="data row4 col0" >D</td>
#       <td id="T_146fb_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_146fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_146fb_row5_col0" class="data row5 col0" >E</td>
#       <td id="T_146fb_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pd.merge(left, right, on="key")
result
# Out:
#   key  lval  rval
# 0   A     1     0
# 1   B     5     0
# 2   B     5     1
# 3   C     6     5
# 4   D     6     6
# 5   E     7     6

# %% [markdown]
# # Grouping

# %% [markdown]
# "Group By" really means one or more of the following happening:
# 1. **Split**: data is broken into groups based on some criteria
# 2. **Apply**: a data operation is executed on each of those groups
# 3. **Combine**: the results are combined back into a data structure

# %%
grp_df = pd.DataFrame(
    {
        "colA": list("AABCAABDAA"),
        "colB": list("1234567890"),
        "colC": np.random.randn(10),
        "colD": np.random.randn(10),
    }
)
grp_df
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.127048  0.093000
# 1    A    2  0.038107  1.130463
# 2    B    3 -0.592078 -0.415108
# 3    C    4  0.511806 -0.979010
# 4    A    5 -0.513688 -1.706004
# 5    A    6  0.042700  0.731736
# 6    B    7 -0.431832  0.644149
# 7    D    8  0.152555  0.383412
# 8    A    9  0.040147 -0.796725
# 9    A    0  1.365643 -0.525948

# %%
# a DataFrameGroupBy object object
grpby = grp_df.groupby("colA")

# list all the groups found
g = grpby.groups
g
# Out:
# {'A': [0, 1, 4, 5, 8, 9], 'B': [2, 6], 'C': [3], 'D': [7]}

# %%
# to create a dataframe from the group use something like
grpby.get_group("A")
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.127048  0.093000
# 1    A    2  0.038107  1.130463
# 4    A    5 -0.513688 -1.706004
# 5    A    6  0.042700  0.731736
# 8    A    9  0.040147 -0.796725
# 9    A    0  1.365643 -0.525948

# %% [markdown]
# ### Find all the groups

# %%
# but we may not know all the groups in the dataframe.
# so got to find a way to list all groups as dataframes.
#
# some basic python helps create a list of groupby names
grpby_labels_list = [*g.keys()]  # using the unpacking operator *
# alternatively
# grpby_labels_list = list(g.keys())
grpby_labels_list
# Out:
# ['A', 'B', 'C', 'D']

# %%
# create a dict where the group label is the key and the group dataframe is the value
grps = {lbl: grpby.get_group(lbl) for lbl in grpby_labels_list}

# now use the dict to access individual dataframes created out of the groupby operation
grps["B"]

# question: can we create a dataframe of dataframes?
# Out:
#   colA colB      colC      colD
# 2    B    3 -0.592078 -0.415108
# 6    B    7 -0.431832  0.644149

# %%
# You can see the datatype of the value is a pandas dataframe
type(grps["A"])
# Out:
# pandas.core.frame.DataFrame

# %%
# make a function of it all...
def get_all_groups(df_grpby):
    return {lbl: df_grpby.get_group(lbl) for lbl in list(df_grpby.groups.keys())}

# %%
grps = get_all_groups(grp_df.groupby("colA"))
grps
# Out:
# {'A':   colA colB      colC      colD
#  0    A    1 -0.127048  0.093000
#  1    A    2  0.038107  1.130463
#  4    A    5 -0.513688 -1.706004
#  5    A    6  0.042700  0.731736
#  8    A    9  0.040147 -0.796725
#  9    A    0  1.365643 -0.525948,
#  'B':   colA colB      colC      colD
#  2    B    3 -0.592078 -0.415108
#  6    B    7 -0.431832  0.644149,
#  'C':   colA colB      colC     colD
#  3    C    4  0.511806 -0.97901,
#  'D':   colA colB      colC      colD
#  7    D    8  0.152555  0.383412}

# %%
# get a sum of values from each group
grp_df.groupby("colA").sum()
# Out:
#         colB      colC      colD
# colA
# A     125690  0.845860 -1.073477
# B         37 -1.023910  0.229041
# C          4  0.511806 -0.979010
# D          8  0.152555  0.383412

# %%
# let's add one more column to the dataframe
# we can try grouping on two columns
grp_df["colE"] = list("1231231231")
grp_df
# Out:
#   colA colB      colC      colD colE
# 0    A    1 -0.127048  0.093000    1
# 1    A    2  0.038107  1.130463    2
# 2    B    3 -0.592078 -0.415108    3
# 3    C    4  0.511806 -0.979010    1
# 4    A    5 -0.513688 -1.706004    2
# 5    A    6  0.042700  0.731736    3
# 6    B    7 -0.431832  0.644149    1
# 7    D    8  0.152555  0.383412    2
# 8    A    9  0.040147 -0.796725    3
# 9    A    0  1.365643 -0.525948    1

# %%
g2 = grp_df.groupby(["colA", "colE"])
grps2 = get_all_groups(g2)
grps2
# Out:
# {('A',
#   '1'):   colA colB      colC      colD colE
#  0    A    1 -0.127048  0.093000    1
#  9    A    0  1.365643 -0.525948    1,
#  ('A',
#   '2'):   colA colB      colC      colD colE
#  1    A    2  0.038107  1.130463    2
#  4    A    5 -0.513688 -1.706004    2,
#  ('A',
#   '3'):   colA colB      colC      colD colE
#  5    A    6  0.042700  0.731736    3
#  8    A    9  0.040147 -0.796725    3,
#  ('B',
#   '1'):   colA colB      colC      colD colE
#  6    B    7 -0.431832  0.644149    1,
#  ('B',
#   '3'):   colA colB      colC      colD colE
#  2    B    3 -0.592078 -0.415108    3,
#  ('C',
#   '1'):   colA colB      colC     colD colE
#  3    C    4  0.511806 -0.97901    1,
#  ('D',
#   '2'):   colA colB      colC      colD colE
#  7    D    8  0.152555  0.383412    2}

# %%
render_df_side_by_side(grps2[("A", "1")], grps2[("A", "2")], "A,1", "A,2")
# Out:
# <style type="text/css">
# </style>
# <table id="T_98e4a" style='display:inline'>
#   <caption>A,1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98e4a_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_98e4a_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_98e4a_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_98e4a_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_98e4a_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98e4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98e4a_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_98e4a_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_98e4a_row0_col2" class="data row0 col2" >-0.127048</td>
#       <td id="T_98e4a_row0_col3" class="data row0 col3" >0.093000</td>
#       <td id="T_98e4a_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_98e4a_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_98e4a_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_98e4a_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_98e4a_row1_col2" class="data row1 col2" >1.365643</td>
#       <td id="T_98e4a_row1_col3" class="data row1 col3" >-0.525948</td>
#       <td id="T_98e4a_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3e282" style='display:inline'>
#   <caption>A,2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e282_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_3e282_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_3e282_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_3e282_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_3e282_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e282_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3e282_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_3e282_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_3e282_row0_col2" class="data row0 col2" >0.038107</td>
#       <td id="T_3e282_row0_col3" class="data row0 col3" >1.130463</td>
#       <td id="T_3e282_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3e282_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_3e282_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_3e282_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_3e282_row1_col2" class="data row1 col2" >-0.513688</td>
#       <td id="T_3e282_row1_col3" class="data row1 col3" >-1.706004</td>
#       <td id="T_3e282_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reshaping
#
# Stacking and Pivot Tables.
# This really warrants more practice, at least go through [the page](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#)

# %% [markdown]
# ## Stacking

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %% [markdown]
# If the syntax [*expression](https://docs.python.org/dev/reference/expressions.html#calls) appears in the function call, expression must evaluate to an iterable. Elements from these iterables are treated as if they were additional positional arguments.
#
# ...although the *expression syntax may appear after explicit keyword arguments, it is processed before the keyword arguments (and any **expression arguments)

# %%
# starred expressions...
def f(a, b):
    print(a, " ", b)


f(
    b=1, *(2,)
)  # works, the tuple (iterable) is expanded, 2 is assigned to a, then b fills the next argument slot
# f (a=1, *(2,)) # FAILS, multiple values for argument 'a'
# Out:
# 2   1

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
stack_idx = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])

# %%
stack_df = pd.DataFrame(np.random.randn(8, 2), index=stack_idx, columns=["a", "b"])
stack_df
# Out:
#                      a         b
# first second
# bar   one     0.796701  1.669951
#       two    -0.581483 -0.717920
# baz   one    -0.277277  0.805624
#       two    -0.294362 -0.264247
# foo   one    -0.076507  0.989999
#       two     0.189443 -1.929023
# qux   one     1.163538  0.263025
#       two     0.800597 -0.682234

# %%
# stack really just combines the columns
stacked = stack_df.stack()
stacked
# Out:
# first  second
# bar    one     a    0.796701
#                b    1.669951
#        two     a   -0.581483
#                b   -0.717920
# baz    one     a   -0.277277
#                b    0.805624
#        two     a   -0.294362
#                b   -0.264247
# foo    one     a   -0.076507
#                b    0.989999
#        two     a    0.189443
#                b   -1.929023
# qux    one     a    1.163538
#                b    0.263025
#        two     a    0.800597
#                b   -0.682234
# dtype: float64

# %%
# unstacked brings back the two columns
# by default unstacks the last level
unstacked = stacked.unstack()
unstacked
# Out:
#                      a         b
# first second
# bar   one     0.796701  1.669951
#       two    -0.581483 -0.717920
# baz   one    -0.277277  0.805624
#       two    -0.294362 -0.264247
# foo   one    -0.076507  0.989999
#       two     0.189443 -1.929023
# qux   one     1.163538  0.263025
#       two     0.800597 -0.682234

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   a  0.796701 -0.581483
#       b  1.669951 -0.717920
# baz   a -0.277277 -0.294362
#       b  0.805624 -0.264247
# foo   a -0.076507  0.189443
#       b  0.989999 -1.929023
# qux   a  1.163538  0.800597
#       b  0.263025 -0.682234

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    a  0.796701 -0.277277 -0.076507  1.163538
#        b  1.669951  0.805624  0.989999  0.263025
# two    a -0.581483 -0.294362  0.189443  0.800597
#        b -0.717920 -0.264247 -1.929023 -0.682234

# %%
# you can basically pivot the columns and rows using a combination of stack() and unstack()
unstacked.unstack()
# Out:
#                a                   b
# second       one       two       one       two
# first
# bar     0.796701 -0.581483  1.669951 -0.717920
# baz    -0.277277 -0.294362  0.805624 -0.264247
# foo    -0.076507  0.189443  0.989999 -1.929023
# qux     1.163538  0.800597  0.263025 -0.682234

# %% [markdown]
# ## Pivot Tables

# %%
# we're now just using data created in the pandas documentation - just cause, time.
pivot_tables_df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
pivot_tables_df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.270786  0.743339
# 1     one  B  foo  0.348015  0.427104
# 2     two  C  foo -1.797046 -0.460178
# 3   three  A  bar -0.246865 -0.174089
# 4     one  B  bar -0.433718 -0.187302
# 5     one  C  bar  0.749680  0.328079
# 6     two  A  foo  0.534590  0.095463
# 7   three  B  foo  0.457922  0.324956
# 8     one  C  foo  1.575833  0.201381
# 9     one  A  bar  0.829713 -1.479981
# 10    two  B  bar -0.606439  0.356321
# 11  three  C  bar  0.529029 -1.618165

# %%
# simple pivot tables - data, values to aggregate, index, columns to pivot along
pd.pivot_table(pivot_tables_df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.829713 -0.270786
#       B -0.433718  0.348015
#       C  0.749680  1.575833
# three A -0.246865       NaN
#       B       NaN  0.457922
#       C  0.529029       NaN
# two   A       NaN  0.534590
#       B -0.606439       NaN
#       C       NaN -1.797046

# %%
# more'n one columns of values
# mark all NaN as zero (0)
pd.pivot_table(
    pivot_tables_df, values=["D", "E"], index=["A", "B"], columns=["C"]
).fillna(0)
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A  0.829713 -0.270786 -1.479981  0.743339
#       B -0.433718  0.348015 -0.187302  0.427104
#       C  0.749680  1.575833  0.328079  0.201381
# three A -0.246865  0.000000 -0.174089  0.000000
#       B  0.000000  0.457922  0.000000  0.324956
#       C  0.529029  0.000000 -1.618165  0.000000
# two   A  0.000000  0.534590  0.000000  0.095463
#       B -0.606439  0.000000  0.356321  0.000000
#       C  0.000000 -1.797046  0.000000 -0.460178

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# We may need to resample data to a different time-frequency.
# Like get data every second and resample to data every 5 minutes and so on...

# %%
rng = pd.date_range("01/01/2022", periods=1000, freq="S")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5min").sum()
# Out:
# 2022-01-01 00:00:00    72252
# 2022-01-01 00:05:00    70600
# 2022-01-01 00:10:00    72674
# 2022-01-01 00:15:00    22072
# Freq: 5T, dtype: int32

# %% [markdown]
# read up on [date offset strings](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) like '5min' etc.

# %% [markdown]
# ## Timezones

# %%
# timezone representation
rng2 = pd.date_range("01/01/2022", periods=500, freq="D")
ts2 = pd.Series(np.random.randint(0, 365, len(rng2)), index=rng2)
ts2_utc = ts2.tz_localize("UTC")

# %%
# convert to US/Eastern
ts2_utc.tz_convert("US/Eastern")
# Out:
# 2021-12-31 19:00:00-05:00    138
# 2022-01-01 19:00:00-05:00    183
# 2022-01-02 19:00:00-05:00    214
# 2022-01-03 19:00:00-05:00      4
# 2022-01-04 19:00:00-05:00     66
#                             ...
# 2023-05-10 20:00:00-04:00    281
# 2023-05-11 20:00:00-04:00    264
# 2023-05-12 20:00:00-04:00     36
# 2023-05-13 20:00:00-04:00    205
# 2023-05-14 20:00:00-04:00    178
# Freq: D, Length: 500, dtype: int32

# %% [markdown]
# ## Time span representations
#
# Converting between periods and timestamps.
#
# Period is a _timespan_ - span of time between two timestamps.

# %%
# month - end of each
rng3 = pd.date_range("01/01/2022", periods=12, freq="M")
rng3
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts3 = pd.Series(np.random.randn(len(rng3)), index=rng3)
ts3
# Out:
# 2022-01-31   -1.071114
# 2022-02-28    0.285208
# 2022-03-31   -1.116327
# 2022-04-30    0.005264
# 2022-05-31    1.070088
# 2022-06-30    0.572551
# 2022-07-31    0.464445
# 2022-08-31   -0.656659
# 2022-09-30   -1.514287
# 2022-10-31    0.794882
# 2022-11-30   -0.732974
# 2022-12-31   -0.187715
# Freq: M, dtype: float64

# %%
ps = ts3.to_period()
ps
# Out:
# 2022-01   -1.071114
# 2022-02    0.285208
# 2022-03   -1.116327
# 2022-04    0.005264
# 2022-05    1.070088
# 2022-06    0.572551
# 2022-07    0.464445
# 2022-08   -0.656659
# 2022-09   -1.514287
# 2022-10    0.794882
# 2022-11   -0.732974
# 2022-12   -0.187715
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2022-01-01   -1.071114
# 2022-02-01    0.285208
# 2022-03-01   -1.116327
# 2022-04-01    0.005264
# 2022-05-01    1.070088
# 2022-06-01    0.572551
# 2022-07-01    0.464445
# 2022-08-01   -0.656659
# 2022-09-01   -1.514287
# 2022-10-01    0.794882
# 2022-11-01   -0.732974
# 2022-12-01   -0.187715
# Freq: MS, dtype: float64

# %% [markdown]
# A more complex use-case:
# convert a _quarterly frequency_ with _year ending in November_ to _9am_ of _the end of the month_ _following_ the _quarter end_

# %%
prng = pd.period_range("1990Q1", "2022Q4", freq="Q-NOV")
type(prng)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
ts4 = pd.Series(np.random.randn(len(prng)), index=prng)
ts4.head()
# Out:
# 1990Q1   -0.966677
# 1990Q2   -0.533371
# 1990Q3    0.516920
# 1990Q4    0.536712
# 1991Q1   -0.620493
# Freq: Q-NOV, dtype: float64

# %%
ts4.index = (prng.asfreq("M", "e") + 1).asfreq("H", "s") + 9
ts4.head()
# Out:
# 1990-03-01 09:00   -0.966677
# 1990-06-01 09:00   -0.533371
# 1990-09-01 09:00    0.516920
# 1990-12-01 09:00    0.536712
# 1991-03-01 09:00   -0.620493
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
#
# [This page](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical-data).
#
# ##### Note: With v2.0+ some of these are breaking - so this sections needs an update.
#
# See [this issue on GitHub](https://github.com/pandas-dev/pandas/issues/52593)
#
# For e.g., gender, social class, blood type, country affiliation, observation time or rating via Likert scales.
#
# Categorical data. Categories allow (usually) fixed number of possible values. Categorical data may have some order, but not support numerical operations (for e.g., 'strongly agree', 'agree', 'disagree', 'strongly disagree').

# %%
cat_df = pd.DataFrame({"id": list("123456"), "raw_grade": list("abbaae")})
cat_df
# Out:
#   id raw_grade
# 0  1         a
# 1  2         b
# 2  3         b
# 3  4         a
# 4  5         a
# 5  6         e

# %%
# convert the raw_grade col to categories
cat_df["grade"] = cat_df["raw_grade"].astype("category")
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
cat_df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# this breaks with v2.0+
# [TODO] Find a fix

# can give more meaningful names here
# direct assignment to Series.cat.categories()
# cat_df["grade"].cat.categories = ["very good", "meh", "very bad"]
# cat_df["grade"]

# %%
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
list(cat_df["grade"].cat.categories)

# categorical.CategoricalAccessor encapsulates all changes to categoricals
# for e.g., set_categories or remove_categories
# dir(cat_df['grade'].cat)
# Out:
# ['a', 'b', 'e']

# %%
# add more categories
cat_df["grade"] = cat_df["grade"].cat.set_categories(
    ["very bad", "bad", "meh", "good", "very good"]
)
# new list of categories
list(cat_df["grade"].cat.categories)
# Out:
# ['very bad', 'bad', 'meh', 'good', 'very good']

# %%
# now when we can sort the dataframe in order of categories (not lexical)
sorted_cat_df = cat_df.sort_values(by="grade")
render_df_side_by_side(cat_df, sorted_cat_df, "OG", "Sorted")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f3d63" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3d63_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_f3d63_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_f3d63_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3d63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3d63_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f3d63_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_f3d63_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f3d63_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3d63_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f3d63_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_f3d63_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f3d63_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3d63_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f3d63_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_f3d63_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f3d63_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3d63_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f3d63_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_f3d63_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f3d63_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3d63_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_f3d63_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_f3d63_row4_col2" class="data row4 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f3d63_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f3d63_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_f3d63_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_f3d63_row5_col2" class="data row5 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e198d" style='display:inline'>
#   <caption>Sorted</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e198d_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_e198d_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_e198d_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e198d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e198d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e198d_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_e198d_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e198d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e198d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e198d_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_e198d_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e198d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e198d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e198d_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_e198d_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e198d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e198d_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e198d_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_e198d_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e198d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e198d_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e198d_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_e198d_row4_col2" class="data row4 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e198d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e198d_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_e198d_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_e198d_row5_col2" class="data row5 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# grouping
# cat_grp = cat_df.groupby("grade")
# cat_grp.get_group("very good")

# %%
# count elements
# cat_grp.size()
