# %% [markdown]
# # Setup
#
# This is following [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) for Pandas (v 2.x.x, as of this writing) but may take a little more than 10 minutes to finish. Lot's of small changes, references etc.

# %% [markdown]
# You can also open this notebook in Google Colab
#
# <a href="https://colab.research.google.com/github/shauryashaurya/learn-data-munging/blob/main/02-Pandas/01.01-10%2B-minutes-to-Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.26.2'

# %%
pd.__version__
# Out:
# '2.1.4'

# %% [markdown]
# # Object creation

# %%
# Series - pass a list to pd.Series
s1 = pd.Series([1, 2, 3, np.nan, 5])

# %%
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
# create an index to use in the dataframe
# default frequency is D (day), so creates a DatetimeIndex of 10 days
dates = pd.date_range("20220619", periods=10)
dates
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# just in case you are wondering, here's [all the "offset aliases"](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases) for Datetime

# %%
# Dataframe - pass a Numpy array
# create a 10 row, 4 col random number array, index by dates, give some column names
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2022-06-19  1.490793  1.717184  1.965029  0.388558
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572

# %%
# Create a dataframe by passing a dictionary of objects
# where each object can be converted into a series-like structure
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220619"),
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([3] * 6, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train", "test", "train"]),
        "F": list("foofoo"),
        "G": "foo",
    }
)

df2
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %%
# the datatype of each of the columns would be different
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# G           object
# dtype: object

# %% [markdown]
# # Viewing Data

# %%
# top of the dataframe
df.head()
# Out:
#                    A         B         C         D
# 2022-06-19  1.490793  1.717184  1.965029  0.388558
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254

# %%
# bottom 3 records of the dataframe
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572

# %%
# index of the df
df.index
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# columns of the df
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# .to_numpy gives a NumPy representation of the dataframe
# this is expensive if all columns are of different data type
# NumPy arrays support a single data type
# so with mixed data types, the data type of
# each element is
df.to_numpy()
# Out:
# array([[ 1.49079316,  1.71718367,  1.96502907,  0.38855801],
#        [-0.30242491, -0.19075729, -0.04469133,  1.00086365],
#        [-0.7026663 ,  1.40950005,  1.87656448, -0.89359827],
#        [-1.38795454,  1.37072278,  0.92673648, -0.03457188],
#        [-0.7898722 ,  0.18305068, -0.52807899,  1.46225422],
#        [-0.07113515, -1.5648252 , -0.57612576,  0.67316093],
#        [ 0.1285108 , -1.42119186,  0.37968695,  1.23072249],
#        [-0.18871186, -0.67708313, -1.01071468, -0.21905956],
#        [ 1.0106434 ,  1.34589237, -0.84688729, -0.02626555],
#        [ 0.26953799,  0.75167821, -0.34128481, -0.85357244]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo']], dtype=object)

# %%
# quick summary stats
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.054328   0.292417   0.180023   0.272849
# std     0.848509   1.217121   1.081654   0.822680
# min    -1.387955  -1.564825  -1.010715  -0.893598
# 25%    -0.602606  -0.555502  -0.564114  -0.172938
# 50%    -0.129924   0.467364  -0.192988   0.181146
# 75%     0.234281   1.364515   0.789974   0.918938
# max     1.490793   1.717184   1.965029   1.462254

# %% [markdown]
# 1. **count** = Count number of non-NA/null observations
# 1. **max** = Maximum of the values in the object
# 1. **min** = Minimum of the values in the object
# 1. **mean** = Mean of the values
# 1. **std** = Standard deviation of the observations
# 1. **25%** = Default lower percentile
# 1. **50%** = 50 percentile - same as the median
# 1. **75%** = Default upper percentile

# %%
# change the percentiles
df.describe(percentiles=[0.1, 0.5, 0.9])
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.054328   0.292417   0.180023   0.272849
# std     0.848509   1.217121   1.081654   0.822680
# min    -1.387955  -1.564825  -1.010715  -0.893598
# 10%    -0.849680  -1.435555  -0.863270  -0.857575
# 50%    -0.129924   0.467364  -0.192988   0.181146
# 90%     1.058658   1.440268   1.885411   1.253876
# max     1.490793   1.717184   1.965029   1.462254

# %%
# E, F, G in d2 are not numeric, so do not come up in describe()
df2.describe()
# Out:
#          A                    B    C    D
# count  6.0                    6  6.0  6.0
# mean   1.0  2022-06-19 00:00:00  1.0  3.0
# min    1.0  2022-06-19 00:00:00  1.0  3.0
# 25%    1.0  2022-06-19 00:00:00  1.0  3.0
# 50%    1.0  2022-06-19 00:00:00  1.0  3.0
# 75%    1.0  2022-06-19 00:00:00  1.0  3.0
# max    1.0  2022-06-19 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
# transpose the data
# turn rows to columns and vice versa
df.T
# Out:
#    2022-06-19  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# A    1.490793   -0.302425   -0.702666   -1.387955   -0.789872   -0.071135
# B    1.717184   -0.190757    1.409500    1.370723    0.183051   -1.564825
# C    1.965029   -0.044691    1.876564    0.926736   -0.528079   -0.576126
# D    0.388558    1.000864   -0.893598   -0.034572    1.462254    0.673161
#
#    2022-06-25  2022-06-26  2022-06-27  2022-06-28
# A    0.128511   -0.188712    1.010643    0.269538
# B   -1.421192   -0.677083    1.345892    0.751678
# C    0.379687   -1.010715   -0.846887   -0.341285
# D    1.230722   -0.219060   -0.026266   -0.853572

# %% [markdown]
# ### [Axis in pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html?highlight=set_ax#pandas.DataFrame.set_axis)
#
# ```axis{0 or ‘index’, 1 or ‘columns’}```
#
# Always remember that when you specify:
# * ```axis=0``` or ```axis='index'``` you indicate that the operation should be along the _index_ (aka across the rows). More often than not indexes will go from top to bottom (vertically), but sometimes they may not (for e.g. if you use columns as index or when you have hierarchical or multi-index data).
# * ```axis=1``` or ```axis='columns'``` indicates the operation is along the columns
#
# When in doubt use the explicit version ```'index'``` or ```'columns'``` instead of ```0``` or ```1```

# %%
# sort along the axis - 1 = horizontal
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-06-19  0.388558  1.965029  1.717184  1.490793
# 2022-06-20  1.000864 -0.044691 -0.190757 -0.302425
# 2022-06-21 -0.893598  1.876564  1.409500 -0.702666
# 2022-06-22 -0.034572  0.926736  1.370723 -1.387955
# 2022-06-23  1.462254 -0.528079  0.183051 -0.789872
# 2022-06-24  0.673161 -0.576126 -1.564825 -0.071135
# 2022-06-25  1.230722  0.379687 -1.421192  0.128511
# 2022-06-26 -0.219060 -1.010715 -0.677083 -0.188712
# 2022-06-27 -0.026266 -0.846887  1.345892  1.010643
# 2022-06-28 -0.853572 -0.341285  0.751678  0.269538

# %%
# sort along the axis - 0 = vertical
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864
# 2022-06-19  1.490793  1.717184  1.965029  0.388558

# %%
# sort ascending by values in a column
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266
# 2022-06-19  1.490793  1.717184  1.965029  0.388558

# %%
# sort by non-numerical values
df2.sort_values(by="F", ascending=False)
# Out:
#      A          B    C  D      E  F    G
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo

# %%
# sort by two or more columns
df2.sort_values(by=["F", "E"])
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %% [markdown]
# # Selection

# %% [markdown]
# For production prefer the following instead of other data access methods (typical python methods like ["col"] or [a:b] slices etc.):
#
# ```.at, .iat, .loc and .iloc.```

# %% [markdown]
# ## Getting

# %%
# selecting a single column returns a Series object
df["A"]
# Out:
# 2022-06-19    1.490793
# 2022-06-20   -0.302425
# 2022-06-21   -0.702666
# 2022-06-22   -1.387955
# 2022-06-23   -0.789872
# 2022-06-24   -0.071135
# 2022-06-25    0.128511
# 2022-06-26   -0.188712
# 2022-06-27    1.010643
# 2022-06-28    0.269538
# Freq: D, Name: A, dtype: float64

# %%
# selecting a slice
df[1:5]
# Out:
#                    A         B         C         D
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254

# %% [markdown]
# ## Selection by label

# %%
# selecting based on a label
df.loc[dates[0]]
# Out:
# A    1.490793
# B    1.717184
# C    1.965029
# D    0.388558
# Name: 2022-06-19 00:00:00, dtype: float64

# %%
# select on a multi-axis by lable
# I honestly do not know what the comment above means...help!
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-06-19  1.490793  1.717184
# 2022-06-20 -0.302425 -0.190757
# 2022-06-21 -0.702666  1.409500
# 2022-06-22 -1.387955  1.370723
# 2022-06-23 -0.789872  0.183051
# 2022-06-24 -0.071135 -1.564825
# 2022-06-25  0.128511 -1.421192
# 2022-06-26 -0.188712 -0.677083
# 2022-06-27  1.010643  1.345892
# 2022-06-28  0.269538  0.751678

# %%
# specific index value results in reduction of dimensions
res = df.loc["2022-06-20"]
print(res)
print("res.shape = ", res.shape, " vs. df.shape = ", df.shape)
# Out:
# A   -0.302425
# B   -0.190757
# C   -0.044691
# D    1.000864
# Name: 2022-06-20 00:00:00, dtype: float64
# res.shape =  (4,)  vs. df.shape =  (10, 4)

# %%
# get to a specific scalar:
#
# method one
df.loc[dates[0], "A"]
# Out:
# 1.4907931635352911

# %%
#
# method two (slightly faster than method one)
df.at[dates[0], "A"]
# Out:
# 1.4907931635352911

# %% [markdown]
# ## Selection by position

# %%
df.iloc[2]
# Out:
# A   -0.702666
# B    1.409500
# C    1.876564
# D   -0.893598
# Name: 2022-06-21 00:00:00, dtype: float64

# %%
# slices - similar to NumPy / Python - [row:slice, col:slice]
df.iloc[1:5, 0:2]
# Out:
#                    A         B
# 2022-06-20 -0.302425 -0.190757
# 2022-06-21 -0.702666  1.409500
# 2022-06-22 -1.387955  1.370723
# 2022-06-23 -0.789872  0.183051

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
df.iloc[[0, 1, 2, 6], [0, 2]]
# Out:
#                    A         C
# 2022-06-19  1.490793  1.965029
# 2022-06-20 -0.302425 -0.044691
# 2022-06-21 -0.702666  1.876564
# 2022-06-25  0.128511  0.379687

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
# change the order of columns, repeact a column
df.iloc[[0, 1, 2, 6], [2, 1, 0, 2]]
# Out:
#                    C         B         A         C
# 2022-06-19  1.965029  1.717184  1.490793  1.965029
# 2022-06-20 -0.044691 -0.190757 -0.302425 -0.044691
# 2022-06-21  1.876564  1.409500 -0.702666  1.876564
# 2022-06-25  0.379687 -1.421192  0.128511  0.379687

# %%
# slice rows explicitly, keep all columns
df.iloc[[1, 2], :]
# Out:
#                    A         B         C         D
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598

# %%
# slice columns, keep all rows
df.iloc[:, [2, 3]]
# Out:
#                    C         D
# 2022-06-19  1.965029  0.388558
# 2022-06-20 -0.044691  1.000864
# 2022-06-21  1.876564 -0.893598
# 2022-06-22  0.926736 -0.034572
# 2022-06-23 -0.528079  1.462254
# 2022-06-24 -0.576126  0.673161
# 2022-06-25  0.379687  1.230722
# 2022-06-26 -1.010715 -0.219060
# 2022-06-27 -0.846887 -0.026266
# 2022-06-28 -0.341285 -0.853572

# %%
# everything, because you can
df.iloc[:, :]
# Out:
#                    A         B         C         D
# 2022-06-19  1.490793  1.717184  1.965029  0.388558
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572

# %%
# get to a scalar (2 methods, just like before)
#
# method one: use iloc
df.iloc[1, 2]
# Out:
# -0.04469133447569132

# %%
#
# method two: use iat
df.iat[1, 2]
# Out:
# -0.04469133447569132

# %% [markdown]
# ## Boolean Indexing

# %%
# use a value found in a single col to get data
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2022-06-19  1.490793  1.717184  1.965029  0.388558
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572

# %%
# boolean across the entire DF - vals that don't match go NaN
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-06-19  1.490793  1.717184  1.965029  0.388558
# 2022-06-20       NaN       NaN       NaN  1.000864
# 2022-06-21       NaN  1.409500  1.876564       NaN
# 2022-06-22       NaN  1.370723  0.926736       NaN
# 2022-06-23       NaN  0.183051       NaN  1.462254
# 2022-06-24       NaN       NaN       NaN  0.673161
# 2022-06-25  0.128511       NaN  0.379687  1.230722
# 2022-06-26       NaN       NaN       NaN       NaN
# 2022-06-27  1.010643  1.345892       NaN       NaN
# 2022-06-28  0.269538  0.751678       NaN       NaN

# %%
# add another column
df11 = df.copy()
df11["E"] = [
    "one",
    "two",
    "three",
    "four",
    "two",
    "five",
    "one",
    "two",
    "three",
    "four",
]
df11
# Out:
#                    A         B         C         D      E
# 2022-06-19  1.490793  1.717184  1.965029  0.388558    one
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864    two
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  three
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572   four
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254    two
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161   five
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722    one
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060    two
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266  three
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572   four

# %%
# the isin() query - basically the in clause
df11[df11["E"].isin(["two", "five"])]
# Out:
#                    A         B         C         D     E
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864   two
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254   two
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161  five
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060   two

# %% [markdown]
# ## Setting values

# %%
# matching indexes auto-aligns values
s1 = pd.Series(range(11, 21), index=pd.date_range("20220619", periods=10))
s1
# Out:
# 2022-06-19    11
# 2022-06-20    12
# 2022-06-21    13
# 2022-06-22    14
# 2022-06-23    15
# 2022-06-24    16
# 2022-06-25    17
# 2022-06-26    18
# 2022-06-27    19
# 2022-06-28    20
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D   F
# 2022-06-19  1.490793  1.717184  1.965029  0.388558  11
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864  12
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254  15
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161  16
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722  17
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060  18
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266  19
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572  20

# %%
# setting values by label and position
# first let's make a quick copy
df12 = df.copy()
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  1.490793  1.717184  1.965029  0.388558  11
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864  12
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254  15
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161  16
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722  17
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060  18
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266  19
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572  20

# %%
# set by label
df12.at[dates[0], "A"] = 0
# set by position
df12.iat[0, 1] = 0
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.000000  0.000000  1.965029  0.388558  11
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864  12
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254  15
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161  16
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722  17
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060  18
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266  19
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572  20

# %%
# kinda bigger replacement
df12.loc[:, "D"] = np.array([5] * len(df))
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000  1.965029  5.0  11
# 2022-06-20 -0.302425 -0.190757 -0.044691  5.0  12
# 2022-06-21 -0.702666  1.409500  1.876564  5.0  13
# 2022-06-22 -1.387955  1.370723  0.926736  5.0  14
# 2022-06-23 -0.789872  0.183051 -0.528079  5.0  15
# 2022-06-24 -0.071135 -1.564825 -0.576126  5.0  16
# 2022-06-25  0.128511 -1.421192  0.379687  5.0  17
# 2022-06-26 -0.188712 -0.677083 -1.010715  5.0  18
# 2022-06-27  1.010643  1.345892 -0.846887  5.0  19
# 2022-06-28  0.269538  0.751678 -0.341285  5.0  20

# %%
# setting values using a boolean selection (aka where clause)
df12[df12 > 0] = -df12
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000 -1.965029 -5.0 -11
# 2022-06-20 -0.302425 -0.190757 -0.044691 -5.0 -12
# 2022-06-21 -0.702666 -1.409500 -1.876564 -5.0 -13
# 2022-06-22 -1.387955 -1.370723 -0.926736 -5.0 -14
# 2022-06-23 -0.789872 -0.183051 -0.528079 -5.0 -15
# 2022-06-24 -0.071135 -1.564825 -0.576126 -5.0 -16
# 2022-06-25 -0.128511 -1.421192 -0.379687 -5.0 -17
# 2022-06-26 -0.188712 -0.677083 -1.010715 -5.0 -18
# 2022-06-27 -1.010643 -1.345892 -0.846887 -5.0 -19
# 2022-06-28 -0.269538 -0.751678 -0.341285 -5.0 -20

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### _reindex_
# change/add/delete index on a specified axis, returns a new dataframe

# %%
df13 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["G"])
df13
# Out:
#                    A         B         C         D   F   G
# 2022-06-19  1.490793  1.717184  1.965029  0.388558  11 NaN
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864  12 NaN
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13 NaN
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14 NaN

# %% [markdown]
# ### handling missing data
# 1. _```np.nan```_
# 1. _```pandas.isna()```_
# 1. ```df.dropna()```
# 1. ```df.fillna()```

# %%
# missing data in pandas is np.nan
df13.iat[1, 0] = np.nan
df13.iloc[1:, 5] = np.random.randint(1)
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  1.490793  1.717184  1.965029  0.388558  11  NaN
# 2022-06-20       NaN -0.190757 -0.044691  1.000864  12  0.0
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13  0.0
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14  0.0

# %%
# get a boolean mask where values are NaN
df131 = pd.isna(df13)
df131
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# or just
pd.isna(df13)
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# the original is still there
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  1.490793  1.717184  1.965029  0.388558  11  NaN
# 2022-06-20       NaN -0.190757 -0.044691  1.000864  12  0.0
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13  0.0
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14  0.0

# %%
# we are going to drop / replace values now, let's make a couple of copies of the dataframe
df132 = df13.copy()
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  1.490793  1.717184  1.965029  0.388558  11  NaN
# 2022-06-20       NaN -0.190757 -0.044691  1.000864  12  0.0
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13  0.0
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14  0.0

# %%
# drop rows/columns that have missing data
# by default it returns a new dataframe, you may want to specify inplace=True for modifying current dataframe:
df_no_na = df132.dropna(how="any")
# how=‘any’ : If any NA values are present, drop that row or column.
# how=‘all’ : If all values are NA, drop that row or column.

# %%
# all rows/cols with missing data stripped
df_no_na
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13  0.0
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14  0.0

# %%
# original still intact
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  1.490793  1.717184  1.965029  0.388558  11  NaN
# 2022-06-20       NaN -0.190757 -0.044691  1.000864  12  0.0
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13  0.0
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14  0.0

# %%
# drop missing data from original
df132.dropna(how="any", inplace=True)
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13  0.0
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14  0.0

# %%
# fill missing data
df133 = df13.copy()
df133.fillna(np.pi * 1000)
# Out:
#                       A         B         C         D   F            G
# 2022-06-19     1.490793  1.717184  1.965029  0.388558  11  3141.592654
# 2022-06-20  3141.592654 -0.190757 -0.044691  1.000864  12     0.000000
# 2022-06-21    -0.702666  1.409500  1.876564 -0.893598  13     0.000000
# 2022-06-22    -1.387955  1.370723  0.926736 -0.034572  14     0.000000

# %% [markdown]
# # Align and Join

# %% [markdown]
# There needs to be a bigger notebook for this topic.
# You need to know there's "joins" in Pandas just like in the SQL world,
# like join and left join and right join and inner and outer and all that...
# Here we'll explore these in the context of the align function - 'aligning' the indexes of two dataframes.
# Later we'll see these again in the context of _merging_ two data frames.

# %% [markdown]
# ## Create two datasets with _mismatched_ indexes

# %%
# date range indexes
idx1 = pd.date_range("2022-01-01", periods=10)
# 2022-01-01', '2022-01-02' don't exist in idx2
# '2022-01-11', '2022-01-12' don't exist in idx1
idx2 = pd.date_range("2022-01-03", periods=10)

# %%
# dataframes from indexes
d1 = pd.DataFrame(
    index=idx1,
    data={"A": np.random.rand(10), "B": np.random.randint(1, high=25, size=10)},
)

d2 = pd.DataFrame(
    index=idx2,
    data={"A": np.random.rand(10), "B": np.random.randint(1, high=25, size=10)},
)

# %% [markdown]
# ## Quick Aside: Rendering two dataframes side-by-side

# %% [markdown]
# The trick of rendering 2 dataframes side-by-side was from [this](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) stackoverflow question.

# %%
# we gon need to display both data frames side by side, so...
from IPython.display import display_html


def render_df_side_by_side(a, b, a_title="", b_title=""):
    a_styler = a.style.set_table_attributes("style='display:inline'").set_caption(
        a_title
    )
    b_styler = b.style.set_table_attributes("style='display:inline'").set_caption(
        b_title
    )
    display_html(a_styler._repr_html_() + b_styler._repr_html_(), raw=True)

# %%
render_df_side_by_side(d1, d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_994dc" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_994dc_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_994dc_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_994dc_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_994dc_row0_col0" class="data row0 col0" >0.815202</td>
#       <td id="T_994dc_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_994dc_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_994dc_row1_col0" class="data row1 col0" >0.501617</td>
#       <td id="T_994dc_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_994dc_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_994dc_row2_col0" class="data row2 col0" >0.695826</td>
#       <td id="T_994dc_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_994dc_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_994dc_row3_col0" class="data row3 col0" >0.783537</td>
#       <td id="T_994dc_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_994dc_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_994dc_row4_col0" class="data row4 col0" >0.084822</td>
#       <td id="T_994dc_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_994dc_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_994dc_row5_col0" class="data row5 col0" >0.067977</td>
#       <td id="T_994dc_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_994dc_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_994dc_row6_col0" class="data row6 col0" >0.621901</td>
#       <td id="T_994dc_row6_col1" class="data row6 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_994dc_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_994dc_row7_col0" class="data row7 col0" >0.502426</td>
#       <td id="T_994dc_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_994dc_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_994dc_row8_col0" class="data row8 col0" >0.641340</td>
#       <td id="T_994dc_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_994dc_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_994dc_row9_col0" class="data row9 col0" >0.109366</td>
#       <td id="T_994dc_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4be45" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4be45_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_4be45_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4be45_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_4be45_row0_col0" class="data row0 col0" >0.822793</td>
#       <td id="T_4be45_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4be45_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_4be45_row1_col0" class="data row1 col0" >0.828359</td>
#       <td id="T_4be45_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4be45_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_4be45_row2_col0" class="data row2 col0" >0.394998</td>
#       <td id="T_4be45_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4be45_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_4be45_row3_col0" class="data row3 col0" >0.658907</td>
#       <td id="T_4be45_row3_col1" class="data row3 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_4be45_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_4be45_row4_col0" class="data row4 col0" >0.328324</td>
#       <td id="T_4be45_row4_col1" class="data row4 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_4be45_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_4be45_row5_col0" class="data row5 col0" >0.217138</td>
#       <td id="T_4be45_row5_col1" class="data row5 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_4be45_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_4be45_row6_col0" class="data row6 col0" >0.417794</td>
#       <td id="T_4be45_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_4be45_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_4be45_row7_col0" class="data row7 col0" >0.975882</td>
#       <td id="T_4be45_row7_col1" class="data row7 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_4be45_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_4be45_row8_col0" class="data row8 col0" >0.082168</td>
#       <td id="T_4be45_row8_col1" class="data row8 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_4be45_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_4be45_row9_col0" class="data row9 col0" >0.746943</td>
#       <td id="T_4be45_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table rendering/styling options is [a bigger discussion](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#) to be tackled later.

# %% [markdown]
# ## .add, .sub, .mul, .div etc.

# %% [markdown]
# flexible wrappers (```add, sub, mul, div, mod, pow```) to arithmetic operators: ```+, -, *, /, //, %, **```

# %%
# the +, -, *, /, //, %, ** operations align indexes to create a UNION of indexes
d3 = d1 + d2
d4 = d1.sub(d2)  # equivalent to d1-d2
d5 = d1 * d2
d6 = d1.div(d2)

# %%
# indexs not present in the other dataframe get a NaN

# pandas v1.x
# d3.style.highlight_null(null_color='red')

# pandas v2.x+
d3.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_37b44_row0_col0, #T_37b44_row0_col1, #T_37b44_row1_col0, #T_37b44_row1_col1, #T_37b44_row10_col0, #T_37b44_row10_col1, #T_37b44_row11_col0, #T_37b44_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_37b44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37b44_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_37b44_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37b44_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_37b44_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_37b44_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_37b44_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_37b44_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_37b44_row2_col0" class="data row2 col0" >1.518620</td>
#       <td id="T_37b44_row2_col1" class="data row2 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_37b44_row3_col0" class="data row3 col0" >1.611896</td>
#       <td id="T_37b44_row3_col1" class="data row3 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_37b44_row4_col0" class="data row4 col0" >0.479820</td>
#       <td id="T_37b44_row4_col1" class="data row4 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_37b44_row5_col0" class="data row5 col0" >0.726884</td>
#       <td id="T_37b44_row5_col1" class="data row5 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_37b44_row6_col0" class="data row6 col0" >0.950225</td>
#       <td id="T_37b44_row6_col1" class="data row6 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_37b44_row7_col0" class="data row7 col0" >0.719563</td>
#       <td id="T_37b44_row7_col1" class="data row7 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_37b44_row8_col0" class="data row8 col0" >1.059134</td>
#       <td id="T_37b44_row8_col1" class="data row8 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_37b44_row9_col0" class="data row9 col0" >1.085248</td>
#       <td id="T_37b44_row9_col1" class="data row9 col1" >34.000000</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_37b44_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_37b44_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_37b44_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_37b44_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_37b44_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# sub
d4.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_55b4c_row0_col0, #T_55b4c_row0_col1, #T_55b4c_row1_col0, #T_55b4c_row1_col1, #T_55b4c_row10_col0, #T_55b4c_row10_col1, #T_55b4c_row11_col0, #T_55b4c_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_55b4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55b4c_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_55b4c_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55b4c_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_55b4c_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_55b4c_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_55b4c_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_55b4c_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_55b4c_row2_col0" class="data row2 col0" >-0.126967</td>
#       <td id="T_55b4c_row2_col1" class="data row2 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_55b4c_row3_col0" class="data row3 col0" >-0.044822</td>
#       <td id="T_55b4c_row3_col1" class="data row3 col1" >-1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_55b4c_row4_col0" class="data row4 col0" >-0.310177</td>
#       <td id="T_55b4c_row4_col1" class="data row4 col1" >-9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_55b4c_row5_col0" class="data row5 col0" >-0.590930</td>
#       <td id="T_55b4c_row5_col1" class="data row5 col1" >-16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_55b4c_row6_col0" class="data row6 col0" >0.293577</td>
#       <td id="T_55b4c_row6_col1" class="data row6 col1" >-8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_55b4c_row7_col0" class="data row7 col0" >0.285288</td>
#       <td id="T_55b4c_row7_col1" class="data row7 col1" >-22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_55b4c_row8_col0" class="data row8 col0" >0.223547</td>
#       <td id="T_55b4c_row8_col1" class="data row8 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_55b4c_row9_col0" class="data row9 col0" >-0.866516</td>
#       <td id="T_55b4c_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_55b4c_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_55b4c_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_55b4c_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_55b4c_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_55b4c_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mul
d5.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_e80c1_row0_col0, #T_e80c1_row0_col1, #T_e80c1_row1_col0, #T_e80c1_row1_col1, #T_e80c1_row10_col0, #T_e80c1_row10_col1, #T_e80c1_row11_col0, #T_e80c1_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_e80c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e80c1_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e80c1_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e80c1_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_e80c1_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_e80c1_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_e80c1_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_e80c1_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_e80c1_row2_col0" class="data row2 col0" >0.572521</td>
#       <td id="T_e80c1_row2_col1" class="data row2 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_e80c1_row3_col0" class="data row3 col0" >0.649050</td>
#       <td id="T_e80c1_row3_col1" class="data row3 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_e80c1_row4_col0" class="data row4 col0" >0.033504</td>
#       <td id="T_e80c1_row4_col1" class="data row4 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_e80c1_row5_col0" class="data row5 col0" >0.044790</td>
#       <td id="T_e80c1_row5_col1" class="data row5 col1" >36.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_e80c1_row6_col0" class="data row6 col0" >0.204185</td>
#       <td id="T_e80c1_row6_col1" class="data row6 col1" >384.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_e80c1_row7_col0" class="data row7 col0" >0.109095</td>
#       <td id="T_e80c1_row7_col1" class="data row7 col1" >48.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_e80c1_row8_col0" class="data row8 col0" >0.267948</td>
#       <td id="T_e80c1_row8_col1" class="data row8 col1" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_e80c1_row9_col0" class="data row9 col0" >0.106728</td>
#       <td id="T_e80c1_row9_col1" class="data row9 col1" >289.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_e80c1_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_e80c1_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e80c1_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_e80c1_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_e80c1_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# div
d6.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_f58b9_row0_col0, #T_f58b9_row0_col1, #T_f58b9_row1_col0, #T_f58b9_row1_col1, #T_f58b9_row10_col0, #T_f58b9_row10_col1, #T_f58b9_row11_col0, #T_f58b9_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_f58b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f58b9_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f58b9_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f58b9_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_f58b9_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_f58b9_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_f58b9_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_f58b9_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_f58b9_row2_col0" class="data row2 col0" >0.845688</td>
#       <td id="T_f58b9_row2_col1" class="data row2 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_f58b9_row3_col0" class="data row3 col0" >0.945890</td>
#       <td id="T_f58b9_row3_col1" class="data row3 col1" >0.666667</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_f58b9_row4_col0" class="data row4 col0" >0.214739</td>
#       <td id="T_f58b9_row4_col1" class="data row4 col1" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_f58b9_row5_col0" class="data row5 col0" >0.103166</td>
#       <td id="T_f58b9_row5_col1" class="data row5 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_f58b9_row6_col0" class="data row6 col0" >1.894166</td>
#       <td id="T_f58b9_row6_col1" class="data row6 col1" >0.666667</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_f58b9_row7_col0" class="data row7 col0" >2.313859</td>
#       <td id="T_f58b9_row7_col1" class="data row7 col1" >0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_f58b9_row8_col0" class="data row8 col0" >1.535065</td>
#       <td id="T_f58b9_row8_col1" class="data row8 col1" >1.200000</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_f58b9_row9_col0" class="data row9 col0" >0.112069</td>
#       <td id="T_f58b9_row9_col1" class="data row9 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_f58b9_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_f58b9_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f58b9_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_f58b9_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_f58b9_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### removing the NaN values from the resultant dataframe

# %%
# the + operation is UNION of indexes
d31 = d1 + d2
# indexs not present in the other dataframe get a NaN
# do you can obvs remove nan values like before
d3.dropna().style.highlight_null(color="red")
# Out:
# <style type="text/css">
# </style>
# <table id="T_fc9e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc9e9_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_fc9e9_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc9e9_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_fc9e9_row0_col0" class="data row0 col0" >1.518620</td>
#       <td id="T_fc9e9_row0_col1" class="data row0 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9e9_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_fc9e9_row1_col0" class="data row1 col0" >1.611896</td>
#       <td id="T_fc9e9_row1_col1" class="data row1 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9e9_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_fc9e9_row2_col0" class="data row2 col0" >0.479820</td>
#       <td id="T_fc9e9_row2_col1" class="data row2 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9e9_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_fc9e9_row3_col0" class="data row3 col0" >0.726884</td>
#       <td id="T_fc9e9_row3_col1" class="data row3 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9e9_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_fc9e9_row4_col0" class="data row4 col0" >0.950225</td>
#       <td id="T_fc9e9_row4_col1" class="data row4 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9e9_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_fc9e9_row5_col0" class="data row5 col0" >0.719563</td>
#       <td id="T_fc9e9_row5_col1" class="data row5 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9e9_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_fc9e9_row6_col0" class="data row6 col0" >1.059134</td>
#       <td id="T_fc9e9_row6_col1" class="data row6 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9e9_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_fc9e9_row7_col0" class="data row7 col0" >1.085248</td>
#       <td id="T_fc9e9_row7_col1" class="data row7 col1" >34.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## df.align()

# %% [markdown]
# Pandas [align](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.align.html) works to join the dataframes in interesting ways.

# %%
# align returns two dataframes - left and right as a result of a join
# default join is outer - the union of indices will be used as index for left and right
left, right = d1.align(d2, join="outer")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f83db" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f83db_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f83db_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f83db_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_f83db_row0_col0" class="data row0 col0" >0.815202</td>
#       <td id="T_f83db_row0_col1" class="data row0 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_f83db_row1_col0" class="data row1 col0" >0.501617</td>
#       <td id="T_f83db_row1_col1" class="data row1 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_f83db_row2_col0" class="data row2 col0" >0.695826</td>
#       <td id="T_f83db_row2_col1" class="data row2 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_f83db_row3_col0" class="data row3 col0" >0.783537</td>
#       <td id="T_f83db_row3_col1" class="data row3 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_f83db_row4_col0" class="data row4 col0" >0.084822</td>
#       <td id="T_f83db_row4_col1" class="data row4 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_f83db_row5_col0" class="data row5 col0" >0.067977</td>
#       <td id="T_f83db_row5_col1" class="data row5 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_f83db_row6_col0" class="data row6 col0" >0.621901</td>
#       <td id="T_f83db_row6_col1" class="data row6 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_f83db_row7_col0" class="data row7 col0" >0.502426</td>
#       <td id="T_f83db_row7_col1" class="data row7 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_f83db_row8_col0" class="data row8 col0" >0.641340</td>
#       <td id="T_f83db_row8_col1" class="data row8 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_f83db_row9_col0" class="data row9 col0" >0.109366</td>
#       <td id="T_f83db_row9_col1" class="data row9 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_f83db_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_f83db_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f83db_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_f83db_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_f83db_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ab3c3" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab3c3_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ab3c3_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab3c3_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_ab3c3_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_ab3c3_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_ab3c3_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_ab3c3_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_ab3c3_row2_col0" class="data row2 col0" >0.822793</td>
#       <td id="T_ab3c3_row2_col1" class="data row2 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_ab3c3_row3_col0" class="data row3 col0" >0.828359</td>
#       <td id="T_ab3c3_row3_col1" class="data row3 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_ab3c3_row4_col0" class="data row4 col0" >0.394998</td>
#       <td id="T_ab3c3_row4_col1" class="data row4 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_ab3c3_row5_col0" class="data row5 col0" >0.658907</td>
#       <td id="T_ab3c3_row5_col1" class="data row5 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_ab3c3_row6_col0" class="data row6 col0" >0.328324</td>
#       <td id="T_ab3c3_row6_col1" class="data row6 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_ab3c3_row7_col0" class="data row7 col0" >0.217138</td>
#       <td id="T_ab3c3_row7_col1" class="data row7 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_ab3c3_row8_col0" class="data row8 col0" >0.417794</td>
#       <td id="T_ab3c3_row8_col1" class="data row8 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_ab3c3_row9_col0" class="data row9 col0" >0.975882</td>
#       <td id="T_ab3c3_row9_col1" class="data row9 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_ab3c3_row10_col0" class="data row10 col0" >0.082168</td>
#       <td id="T_ab3c3_row10_col1" class="data row10 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab3c3_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_ab3c3_row11_col0" class="data row11 col0" >0.746943</td>
#       <td id="T_ab3c3_row11_col1" class="data row11 col1" >13.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# inner join
left, right = d1.align(d2, join="inner")
render_df_side_by_side(d1, d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_edca7" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edca7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_edca7_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edca7_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_edca7_row0_col0" class="data row0 col0" >0.815202</td>
#       <td id="T_edca7_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_edca7_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_edca7_row1_col0" class="data row1 col0" >0.501617</td>
#       <td id="T_edca7_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_edca7_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_edca7_row2_col0" class="data row2 col0" >0.695826</td>
#       <td id="T_edca7_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_edca7_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_edca7_row3_col0" class="data row3 col0" >0.783537</td>
#       <td id="T_edca7_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_edca7_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_edca7_row4_col0" class="data row4 col0" >0.084822</td>
#       <td id="T_edca7_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_edca7_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_edca7_row5_col0" class="data row5 col0" >0.067977</td>
#       <td id="T_edca7_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_edca7_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_edca7_row6_col0" class="data row6 col0" >0.621901</td>
#       <td id="T_edca7_row6_col1" class="data row6 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_edca7_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_edca7_row7_col0" class="data row7 col0" >0.502426</td>
#       <td id="T_edca7_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_edca7_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_edca7_row8_col0" class="data row8 col0" >0.641340</td>
#       <td id="T_edca7_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_edca7_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_edca7_row9_col0" class="data row9 col0" >0.109366</td>
#       <td id="T_edca7_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_be275" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be275_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_be275_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be275_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_be275_row0_col0" class="data row0 col0" >0.822793</td>
#       <td id="T_be275_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_be275_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_be275_row1_col0" class="data row1 col0" >0.828359</td>
#       <td id="T_be275_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_be275_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_be275_row2_col0" class="data row2 col0" >0.394998</td>
#       <td id="T_be275_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_be275_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_be275_row3_col0" class="data row3 col0" >0.658907</td>
#       <td id="T_be275_row3_col1" class="data row3 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_be275_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_be275_row4_col0" class="data row4 col0" >0.328324</td>
#       <td id="T_be275_row4_col1" class="data row4 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_be275_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_be275_row5_col0" class="data row5 col0" >0.217138</td>
#       <td id="T_be275_row5_col1" class="data row5 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_be275_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_be275_row6_col0" class="data row6 col0" >0.417794</td>
#       <td id="T_be275_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_be275_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_be275_row7_col0" class="data row7 col0" >0.975882</td>
#       <td id="T_be275_row7_col1" class="data row7 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_be275_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_be275_row8_col0" class="data row8 col0" >0.082168</td>
#       <td id="T_be275_row8_col1" class="data row8 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_be275_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_be275_row9_col0" class="data row9 col0" >0.746943</td>
#       <td id="T_be275_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %%
# we can fill the NaNs with a certain value if needed
# let's fill with -100 so we can see it clearly
left, right = d1.align(d2, join="outer", fill_value=-100)
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_040ae" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_040ae_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_040ae_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_040ae_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_040ae_row0_col0" class="data row0 col0" >0.815202</td>
#       <td id="T_040ae_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_040ae_row1_col0" class="data row1 col0" >0.501617</td>
#       <td id="T_040ae_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_040ae_row2_col0" class="data row2 col0" >0.695826</td>
#       <td id="T_040ae_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_040ae_row3_col0" class="data row3 col0" >0.783537</td>
#       <td id="T_040ae_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_040ae_row4_col0" class="data row4 col0" >0.084822</td>
#       <td id="T_040ae_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_040ae_row5_col0" class="data row5 col0" >0.067977</td>
#       <td id="T_040ae_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_040ae_row6_col0" class="data row6 col0" >0.621901</td>
#       <td id="T_040ae_row6_col1" class="data row6 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_040ae_row7_col0" class="data row7 col0" >0.502426</td>
#       <td id="T_040ae_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_040ae_row8_col0" class="data row8 col0" >0.641340</td>
#       <td id="T_040ae_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_040ae_row9_col0" class="data row9 col0" >0.109366</td>
#       <td id="T_040ae_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_040ae_row10_col0" class="data row10 col0" >-100.000000</td>
#       <td id="T_040ae_row10_col1" class="data row10 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_040ae_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_040ae_row11_col0" class="data row11 col0" >-100.000000</td>
#       <td id="T_040ae_row11_col1" class="data row11 col1" >-100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e6e0b" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6e0b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e6e0b_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6e0b_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_e6e0b_row0_col0" class="data row0 col0" >-100.000000</td>
#       <td id="T_e6e0b_row0_col1" class="data row0 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_e6e0b_row1_col0" class="data row1 col0" >-100.000000</td>
#       <td id="T_e6e0b_row1_col1" class="data row1 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_e6e0b_row2_col0" class="data row2 col0" >0.822793</td>
#       <td id="T_e6e0b_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_e6e0b_row3_col0" class="data row3 col0" >0.828359</td>
#       <td id="T_e6e0b_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_e6e0b_row4_col0" class="data row4 col0" >0.394998</td>
#       <td id="T_e6e0b_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_e6e0b_row5_col0" class="data row5 col0" >0.658907</td>
#       <td id="T_e6e0b_row5_col1" class="data row5 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_e6e0b_row6_col0" class="data row6 col0" >0.328324</td>
#       <td id="T_e6e0b_row6_col1" class="data row6 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_e6e0b_row7_col0" class="data row7 col0" >0.217138</td>
#       <td id="T_e6e0b_row7_col1" class="data row7 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_e6e0b_row8_col0" class="data row8 col0" >0.417794</td>
#       <td id="T_e6e0b_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_e6e0b_row9_col0" class="data row9 col0" >0.975882</td>
#       <td id="T_e6e0b_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_e6e0b_row10_col0" class="data row10 col0" >0.082168</td>
#       <td id="T_e6e0b_row10_col1" class="data row10 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_e6e0b_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_e6e0b_row11_col0" class="data row11 col0" >0.746943</td>
#       <td id="T_e6e0b_row11_col1" class="data row11 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %%
# left join: left index is added to right, but not the other way
left, right = d1.align(d2, join="left")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_95314" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95314_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_95314_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95314_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_95314_row0_col0" class="data row0 col0" >0.815202</td>
#       <td id="T_95314_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_95314_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_95314_row1_col0" class="data row1 col0" >0.501617</td>
#       <td id="T_95314_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_95314_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_95314_row2_col0" class="data row2 col0" >0.695826</td>
#       <td id="T_95314_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_95314_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_95314_row3_col0" class="data row3 col0" >0.783537</td>
#       <td id="T_95314_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_95314_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_95314_row4_col0" class="data row4 col0" >0.084822</td>
#       <td id="T_95314_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_95314_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_95314_row5_col0" class="data row5 col0" >0.067977</td>
#       <td id="T_95314_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_95314_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_95314_row6_col0" class="data row6 col0" >0.621901</td>
#       <td id="T_95314_row6_col1" class="data row6 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_95314_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_95314_row7_col0" class="data row7 col0" >0.502426</td>
#       <td id="T_95314_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_95314_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_95314_row8_col0" class="data row8 col0" >0.641340</td>
#       <td id="T_95314_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_95314_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_95314_row9_col0" class="data row9 col0" >0.109366</td>
#       <td id="T_95314_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d5189" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5189_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d5189_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5189_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_d5189_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_d5189_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d5189_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_d5189_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_d5189_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d5189_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_d5189_row2_col0" class="data row2 col0" >0.822793</td>
#       <td id="T_d5189_row2_col1" class="data row2 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5189_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_d5189_row3_col0" class="data row3 col0" >0.828359</td>
#       <td id="T_d5189_row3_col1" class="data row3 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5189_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_d5189_row4_col0" class="data row4 col0" >0.394998</td>
#       <td id="T_d5189_row4_col1" class="data row4 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5189_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_d5189_row5_col0" class="data row5 col0" >0.658907</td>
#       <td id="T_d5189_row5_col1" class="data row5 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5189_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_d5189_row6_col0" class="data row6 col0" >0.328324</td>
#       <td id="T_d5189_row6_col1" class="data row6 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5189_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_d5189_row7_col0" class="data row7 col0" >0.217138</td>
#       <td id="T_d5189_row7_col1" class="data row7 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5189_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_d5189_row8_col0" class="data row8 col0" >0.417794</td>
#       <td id="T_d5189_row8_col1" class="data row8 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5189_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_d5189_row9_col0" class="data row9 col0" >0.975882</td>
#       <td id="T_d5189_row9_col1" class="data row9 col1" >17.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# right join: right index is added to left, but not the other way
left, right = d1.align(d2, join="right")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_69ea3" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69ea3_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_69ea3_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69ea3_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_69ea3_row0_col0" class="data row0 col0" >0.695826</td>
#       <td id="T_69ea3_row0_col1" class="data row0 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69ea3_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_69ea3_row1_col0" class="data row1 col0" >0.783537</td>
#       <td id="T_69ea3_row1_col1" class="data row1 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69ea3_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_69ea3_row2_col0" class="data row2 col0" >0.084822</td>
#       <td id="T_69ea3_row2_col1" class="data row2 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69ea3_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_69ea3_row3_col0" class="data row3 col0" >0.067977</td>
#       <td id="T_69ea3_row3_col1" class="data row3 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69ea3_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_69ea3_row4_col0" class="data row4 col0" >0.621901</td>
#       <td id="T_69ea3_row4_col1" class="data row4 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69ea3_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_69ea3_row5_col0" class="data row5 col0" >0.502426</td>
#       <td id="T_69ea3_row5_col1" class="data row5 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69ea3_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_69ea3_row6_col0" class="data row6 col0" >0.641340</td>
#       <td id="T_69ea3_row6_col1" class="data row6 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69ea3_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_69ea3_row7_col0" class="data row7 col0" >0.109366</td>
#       <td id="T_69ea3_row7_col1" class="data row7 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69ea3_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_69ea3_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_69ea3_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_69ea3_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_69ea3_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_69ea3_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7c7ae" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c7ae_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7c7ae_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c7ae_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_7c7ae_row0_col0" class="data row0 col0" >0.822793</td>
#       <td id="T_7c7ae_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7c7ae_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_7c7ae_row1_col0" class="data row1 col0" >0.828359</td>
#       <td id="T_7c7ae_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7c7ae_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_7c7ae_row2_col0" class="data row2 col0" >0.394998</td>
#       <td id="T_7c7ae_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7c7ae_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_7c7ae_row3_col0" class="data row3 col0" >0.658907</td>
#       <td id="T_7c7ae_row3_col1" class="data row3 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_7c7ae_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_7c7ae_row4_col0" class="data row4 col0" >0.328324</td>
#       <td id="T_7c7ae_row4_col1" class="data row4 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_7c7ae_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_7c7ae_row5_col0" class="data row5 col0" >0.217138</td>
#       <td id="T_7c7ae_row5_col1" class="data row5 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_7c7ae_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_7c7ae_row6_col0" class="data row6 col0" >0.417794</td>
#       <td id="T_7c7ae_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7c7ae_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_7c7ae_row7_col0" class="data row7 col0" >0.975882</td>
#       <td id="T_7c7ae_row7_col1" class="data row7 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_7c7ae_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_7c7ae_row8_col0" class="data row8 col0" >0.082168</td>
#       <td id="T_7c7ae_row8_col1" class="data row8 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_7c7ae_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_7c7ae_row9_col0" class="data row9 col0" >0.746943</td>
#       <td id="T_7c7ae_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's more to explore in align, and it can get confusing, so beginners be careful, take time and try to work out the result before you execute to build intuition.

# %% [markdown]
# # Operations on data

# %% [markdown]
# ## Stats
#
# Operations in general *exclude* missing data

# %%
# arithmetic mean, for each column (axis = 0)
df.mean()
# Out:
# A    -0.054328
# B     0.292417
# C     0.180023
# D     0.272849
# F    15.500000
# dtype: float64

# %%
# mean across a row (axis = 1)
df.mean(1)
# Out:
# 2022-06-19    3.312313
# 2022-06-20    2.492598
# 2022-06-21    2.937960
# 2022-06-22    2.974987
# 2022-06-23    3.065471
# 2022-06-24    2.892215
# 2022-06-25    3.463546
# 2022-06-26    3.180886
# 2022-06-27    4.096677
# 2022-06-28    3.965272
# Freq: D, dtype: float64

# %% [markdown]
# ## Apply

# %%
# apply custom lambdas
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.878748
# B    3.282009
# C    2.975744
# D    2.355852
# F    9.000000
# dtype: float64

# %%
df
# Out:
#                    A         B         C         D   F
# 2022-06-19  1.490793  1.717184  1.965029  0.388558  11
# 2022-06-20 -0.302425 -0.190757 -0.044691  1.000864  12
# 2022-06-21 -0.702666  1.409500  1.876564 -0.893598  13
# 2022-06-22 -1.387955  1.370723  0.926736 -0.034572  14
# 2022-06-23 -0.789872  0.183051 -0.528079  1.462254  15
# 2022-06-24 -0.071135 -1.564825 -0.576126  0.673161  16
# 2022-06-25  0.128511 -1.421192  0.379687  1.230722  17
# 2022-06-26 -0.188712 -0.677083 -1.010715 -0.219060  18
# 2022-06-27  1.010643  1.345892 -0.846887 -0.026266  19
# 2022-06-28  0.269538  0.751678 -0.341285 -0.853572  20

# %%
# each subsequent value is a sum of all values before it in the respective column
cumsum_df = df.apply(np.cumsum)
render_df_side_by_side(df, cumsum_df, "OG Dataframe", "Cumulative Sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8b9e" style='display:inline'>
#   <caption>OG Dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8b9e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b8b9e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b8b9e_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b8b9e_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_b8b9e_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8b9e_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_b8b9e_row0_col0" class="data row0 col0" >1.490793</td>
#       <td id="T_b8b9e_row0_col1" class="data row0 col1" >1.717184</td>
#       <td id="T_b8b9e_row0_col2" class="data row0 col2" >1.965029</td>
#       <td id="T_b8b9e_row0_col3" class="data row0 col3" >0.388558</td>
#       <td id="T_b8b9e_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_b8b9e_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_b8b9e_row1_col0" class="data row1 col0" >-0.302425</td>
#       <td id="T_b8b9e_row1_col1" class="data row1 col1" >-0.190757</td>
#       <td id="T_b8b9e_row1_col2" class="data row1 col2" >-0.044691</td>
#       <td id="T_b8b9e_row1_col3" class="data row1 col3" >1.000864</td>
#       <td id="T_b8b9e_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_b8b9e_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_b8b9e_row2_col0" class="data row2 col0" >-0.702666</td>
#       <td id="T_b8b9e_row2_col1" class="data row2 col1" >1.409500</td>
#       <td id="T_b8b9e_row2_col2" class="data row2 col2" >1.876564</td>
#       <td id="T_b8b9e_row2_col3" class="data row2 col3" >-0.893598</td>
#       <td id="T_b8b9e_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_b8b9e_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_b8b9e_row3_col0" class="data row3 col0" >-1.387955</td>
#       <td id="T_b8b9e_row3_col1" class="data row3 col1" >1.370723</td>
#       <td id="T_b8b9e_row3_col2" class="data row3 col2" >0.926736</td>
#       <td id="T_b8b9e_row3_col3" class="data row3 col3" >-0.034572</td>
#       <td id="T_b8b9e_row3_col4" class="data row3 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_b8b9e_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_b8b9e_row4_col0" class="data row4 col0" >-0.789872</td>
#       <td id="T_b8b9e_row4_col1" class="data row4 col1" >0.183051</td>
#       <td id="T_b8b9e_row4_col2" class="data row4 col2" >-0.528079</td>
#       <td id="T_b8b9e_row4_col3" class="data row4 col3" >1.462254</td>
#       <td id="T_b8b9e_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_b8b9e_level0_row5" class="row_heading level0 row5" >2022-06-24 00:00:00</th>
#       <td id="T_b8b9e_row5_col0" class="data row5 col0" >-0.071135</td>
#       <td id="T_b8b9e_row5_col1" class="data row5 col1" >-1.564825</td>
#       <td id="T_b8b9e_row5_col2" class="data row5 col2" >-0.576126</td>
#       <td id="T_b8b9e_row5_col3" class="data row5 col3" >0.673161</td>
#       <td id="T_b8b9e_row5_col4" class="data row5 col4" >16</td>
#     </tr>
#     <tr>
#       <th id="T_b8b9e_level0_row6" class="row_heading level0 row6" >2022-06-25 00:00:00</th>
#       <td id="T_b8b9e_row6_col0" class="data row6 col0" >0.128511</td>
#       <td id="T_b8b9e_row6_col1" class="data row6 col1" >-1.421192</td>
#       <td id="T_b8b9e_row6_col2" class="data row6 col2" >0.379687</td>
#       <td id="T_b8b9e_row6_col3" class="data row6 col3" >1.230722</td>
#       <td id="T_b8b9e_row6_col4" class="data row6 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_b8b9e_level0_row7" class="row_heading level0 row7" >2022-06-26 00:00:00</th>
#       <td id="T_b8b9e_row7_col0" class="data row7 col0" >-0.188712</td>
#       <td id="T_b8b9e_row7_col1" class="data row7 col1" >-0.677083</td>
#       <td id="T_b8b9e_row7_col2" class="data row7 col2" >-1.010715</td>
#       <td id="T_b8b9e_row7_col3" class="data row7 col3" >-0.219060</td>
#       <td id="T_b8b9e_row7_col4" class="data row7 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_b8b9e_level0_row8" class="row_heading level0 row8" >2022-06-27 00:00:00</th>
#       <td id="T_b8b9e_row8_col0" class="data row8 col0" >1.010643</td>
#       <td id="T_b8b9e_row8_col1" class="data row8 col1" >1.345892</td>
#       <td id="T_b8b9e_row8_col2" class="data row8 col2" >-0.846887</td>
#       <td id="T_b8b9e_row8_col3" class="data row8 col3" >-0.026266</td>
#       <td id="T_b8b9e_row8_col4" class="data row8 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_b8b9e_level0_row9" class="row_heading level0 row9" >2022-06-28 00:00:00</th>
#       <td id="T_b8b9e_row9_col0" class="data row9 col0" >0.269538</td>
#       <td id="T_b8b9e_row9_col1" class="data row9 col1" >0.751678</td>
#       <td id="T_b8b9e_row9_col2" class="data row9 col2" >-0.341285</td>
#       <td id="T_b8b9e_row9_col3" class="data row9 col3" >-0.853572</td>
#       <td id="T_b8b9e_row9_col4" class="data row9 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2abd7" style='display:inline'>
#   <caption>Cumulative Sum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2abd7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_2abd7_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_2abd7_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_2abd7_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_2abd7_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2abd7_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_2abd7_row0_col0" class="data row0 col0" >1.490793</td>
#       <td id="T_2abd7_row0_col1" class="data row0 col1" >1.717184</td>
#       <td id="T_2abd7_row0_col2" class="data row0 col2" >1.965029</td>
#       <td id="T_2abd7_row0_col3" class="data row0 col3" >0.388558</td>
#       <td id="T_2abd7_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_2abd7_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_2abd7_row1_col0" class="data row1 col0" >1.188368</td>
#       <td id="T_2abd7_row1_col1" class="data row1 col1" >1.526426</td>
#       <td id="T_2abd7_row1_col2" class="data row1 col2" >1.920338</td>
#       <td id="T_2abd7_row1_col3" class="data row1 col3" >1.389422</td>
#       <td id="T_2abd7_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_2abd7_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_2abd7_row2_col0" class="data row2 col0" >0.485702</td>
#       <td id="T_2abd7_row2_col1" class="data row2 col1" >2.935926</td>
#       <td id="T_2abd7_row2_col2" class="data row2 col2" >3.796902</td>
#       <td id="T_2abd7_row2_col3" class="data row2 col3" >0.495823</td>
#       <td id="T_2abd7_row2_col4" class="data row2 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_2abd7_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_2abd7_row3_col0" class="data row3 col0" >-0.902253</td>
#       <td id="T_2abd7_row3_col1" class="data row3 col1" >4.306649</td>
#       <td id="T_2abd7_row3_col2" class="data row3 col2" >4.723639</td>
#       <td id="T_2abd7_row3_col3" class="data row3 col3" >0.461252</td>
#       <td id="T_2abd7_row3_col4" class="data row3 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_2abd7_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_2abd7_row4_col0" class="data row4 col0" >-1.692125</td>
#       <td id="T_2abd7_row4_col1" class="data row4 col1" >4.489700</td>
#       <td id="T_2abd7_row4_col2" class="data row4 col2" >4.195560</td>
#       <td id="T_2abd7_row4

# %% [markdown]
# ## Histogramming
#
# Frequencies, 'nuff said
#
# ```value_counts()```

# %%
series1 = pd.Series(np.random.randint(0, 5, size=25))
series1.value_counts()
# Out:
# 2    8
# 4    7
# 1    4
# 3    4
# 0    2
# Name: count, dtype: int64

# %% [markdown]
# ## String Methods

# %%
# build a series
some_string = "SERIes and Index are EqUIppeD WITh A seT Of stRINg PROCESSING METHoDs In tHe ```sTR``` attrIBute THAT MakE IT eASy To oPerATE ON EACh ELEmeNt OF The aRrAY. NOtE thAt PAtTERN-maTching in ```sTR``` gENeralLY UsES reGUlAr eXpreSsiONs bY DEfault (aND In Some cases AlwayS uSEs tHeM)."
str_series = pd.Series(some_string.split())  # split splits on whitespace by default

# %%
# manipulating the case - lower, upper etc.
# also the length of each string, split, replace, yada yada...
# very important when cleaning data (column names may have stupid whitespace, bad case, spacing etc.)
low = str_series.str.lower()
up = str_series.str.upper()

low_up_df = pd.DataFrame(
    {
        "og": str_series,
        "length": str_series.str.len(),
        "low": low,
        "up": up,
        "split_low_on_i": low.str.split(
            "i", expand=False
        ),  # expand = True will break this usecase, try elsewhere
        "replace_a_with_star_in_low": low.str.replace(
            "a", "*", case=False, regex=True
        ),  # yeah, you can mess with regular expns
    }
)

low_up_df.tail(10)
# Out:
#              og  length          low           up  split_low_on_i  \
# 36  eXpreSsiONs      11  expressions  EXPRESSIONS  [express, ons]
# 37           bY       2           by           BY            [by]
# 38      DEfault       7      default      DEFAULT       [default]
# 39         (aND       4         (and         (AND          [(and]
# 40           In       2           in           IN           [, n]
# 41         Some       4         some         SOME          [some]
# 42        cases       5        cases        CASES         [cases]
# 43       AlwayS       6       always       ALWAYS        [always]
# 44         uSEs       4         uses         USES          [uses]
# 45       tHeM).       6       them).       THEM).        [them).]
#
#    replace_a_with_star_in_low
# 36                expressions
# 37                         by
# 38                    def*ult
# 39                       (*nd
# 40                         in
# 41                       some
# 42                      c*ses
# 43                     *lw*ys
# 44                       uses
# 45                     them).

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods) for more string operations.

# %% [markdown]
# # Merge
#
# Combine series and dataframes, use set logic for indexes and relational algebra for joins/merges

# %% [markdown]
# ## Concat
#
# Chill, we've done this before. The same join = inner/outer/left/right drill.

# %%
# let's make some more dataframes
concatDF = pd.DataFrame(
    np.random.randn(10, 4)
)  # 10 rows and 4 columns of random numbers
pieces = [concatDF[:3], concatDF[3:7], concatDF[7:]]
reconstructedDF = pd.concat(pieces)
display("broken DFs: ", pieces)
render_df_side_by_side(concatDF, reconstructedDF, "OG", "Concatenated")
# Out:
# 'broken DFs: '
# [          0         1         2         3
#  0 -0.272673 -1.259220  0.575186 -0.101705
#  1  1.090840 -0.509960 -0.721373  0.036194
#  2  0.376139 -0.362765  1.968798 -0.381588,
#            0         1         2         3
#  3  0.094216 -1.382267  1.026898 -0.111896
#  4 -0.075501 -0.020759 -0.193497  0.094144
#  5  1.135048 -0.162388 -0.105861  1.289731
#  6  1.426434  0.628651 -1.330087 -1.399903,
#            0         1         2         3
#  7  2.243143  1.125163  0.581517  0.000843
#  8  0.899371  0.293293 -2.258304  1.724288
#  9  0.935401 -0.005059  0.176094  0.089508]
# <style type="text/css">
# </style>
# <table id="T_bfc2e" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfc2e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_bfc2e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_bfc2e_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_bfc2e_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfc2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bfc2e_row0_col0" class="data row0 col0" >-0.272673</td>
#       <td id="T_bfc2e_row0_col1" class="data row0 col1" >-1.259220</td>
#       <td id="T_bfc2e_row0_col2" class="data row0 col2" >0.575186</td>
#       <td id="T_bfc2e_row0_col3" class="data row0 col3" >-0.101705</td>
#     </tr>
#     <tr>
#       <th id="T_bfc2e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bfc2e_row1_col0" class="data row1 col0" >1.090840</td>
#       <td id="T_bfc2e_row1_col1" class="data row1 col1" >-0.509960</td>
#       <td id="T_bfc2e_row1_col2" class="data row1 col2" >-0.721373</td>
#       <td id="T_bfc2e_row1_col3" class="data row1 col3" >0.036194</td>
#     </tr>
#     <tr>
#       <th id="T_bfc2e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bfc2e_row2_col0" class="data row2 col0" >0.376139</td>
#       <td id="T_bfc2e_row2_col1" class="data row2 col1" >-0.362765</td>
#       <td id="T_bfc2e_row2_col2" class="data row2 col2" >1.968798</td>
#       <td id="T_bfc2e_row2_col3" class="data row2 col3" >-0.381588</td>
#     </tr>
#     <tr>
#       <th id="T_bfc2e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bfc2e_row3_col0" class="data row3 col0" >0.094216</td>
#       <td id="T_bfc2e_row3_col1" class="data row3 col1" >-1.382267</td>
#       <td id="T_bfc2e_row3_col2" class="data row3 col2" >1.026898</td>
#       <td id="T_bfc2e_row3_col3" class="data row3 col3" >-0.111896</td>
#     </tr>
#     <tr>
#       <th id="T_bfc2e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bfc2e_row4_col0" class="data row4 col0" >-0.075501</td>
#       <td id="T_bfc2e_row4_col1" class="data row4 col1" >-0.020759</td>
#       <td id="T_bfc2e_row4_col2" class="data row4 col2" >-0.193497</td>
#       <td id="T_bfc2e_row4_col3" class="data row4 col3" >0.094144</td>
#     </tr>
#     <tr>
#       <th id="T_bfc2e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bfc2e_row5_col0" class="data row5 col0" >1.135048</td>
#       <td id="T_bfc2e_row5_col1" class="data row5 col1" >-0.162388</td>
#       <td id="T_bfc2e_row5_col2" class="data row5 col2" >-0.105861</td>
#       <td id="T_bfc2e_row5_col3" class="data row5 col3" >1.289731</td>
#     </tr>
#     <tr>
#       <th id="T_bfc2e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bfc2e_row6_col0" class="data row6 col0" >1.426434</td>
#       <td id="T_bfc2e_row6_col1" class="data row6 col1" >0.628651</td>
#       <td id="T_bfc2e_row6_col2" class="data row6 col2" >-1.330087</td>
#       <td id="T_bfc2e_row6_col3" class="data row6 col3" >-1.399903</td>
#     </tr>
#     <tr>
#       <th id="T_bfc2e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bfc2e_row7_col0" class="data row7 col0" >2.243143</td>
#       <td id="T_bfc2e_row7_col1" class="data row7 col1" >1.125163</td>
#       <td id="T_bfc2e_row7_col2" class="data row7 col2" >0.581517</td>
#       <td id="T_bfc2e_row7_col3" class="data row7 col3" >0.000843</td>
#     </tr>
#     <tr>
#       <th id="T_bfc2e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bfc2e_row8_col0" class="data row8 col0" >0.899371</td>
#       <td id="T_bfc2e_row8_col1" class="data row8 col1" >0.293293</td>
#       <td id="T_bfc2e_row8_col2" class="data row8 col2" >-2.258304</td>
#       <td id="T_bfc2e_row8_col3" class="data row8 col3" >1.724288</td>
#     </tr>
#     <tr>
#       <th id="T_bfc2e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bfc2e_row9_col0" class="data row9 col0" >0.935401</td>
#       <td id="T_bfc2e_row9_col1" class="data row9 col1" >-0.005059</td>
#       <td id="T_bfc2e_row9_col2" class="data row9 col2" >0.176094</td>
#       <td id="T_bfc2e_row9_col3" class="data row9 col3" >0.089508</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c2f27" style='display:inline'>
#   <caption>Concatenated</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2f27_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c2f27_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c2f27_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c2f27_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2f27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2f27_row0_col0" class="data row0 col0" >-0.272673</td>
#       <td id="T_c2f27_row0_col1" class="data row0 col1" >-1.259220</td>
#       <td id="T_c2f27_row0_col2" class="data row0 col2" >0.575186</td>
#       <td id="T_c2f27_row0_col3" class="data row0 col3" >-0.101705</td>
#     </tr>
#     <tr>
#       <th id="T_c2f27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c2f27_row1_col0" class="data row1 col0" >1.090840</td>
#       <td id="T_c2f27_row1_col1" class="data row1 col1" >-0.509960</td>
#       <td id="T_c2f27_row1_col2" class="data row1 col2" >-0.721373</td>
#       <td id="T_c2f27_row1_col3" class="data row1 col3" >0.036194</td>
#     </tr>
#     <tr>
#       <th id="T_c2f27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c2f27_row2_col0" class="data row2 col0" >0.376139</td>
#       <td id="T_c2f27_row2_col1" class="data row2 col1" >-0.362765</td>
#       <td id="T_c2f27_row2_col2" class="data row2 col2" >1.968798</td>
#       <td id="T_c2f27_row2_col3" class="data row2 col3" >-0.381588</td>
#     </tr>
#     <tr>
#       <th id="T_c2f27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c2f27_row3_col0" class="data row3 col0" >0.094216</td>
#       <td id="T_c2f27_row3_col1" class="data row3 col1" >-1.382267</td>
#       <td id="T_c2f27_row3_col2" class="data row3 col2" >1.026898</td>
#       <td id="T_c2f27_row3_col3" class="data row3 col3" >-0.111896</td>
#     </tr>
#     <tr>
#       <th id="T_c2f27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c2f27_row4_col0" class="data row4 col0" >-0.075501</td>
#       <td id="T_c2f27_row4_col1" class="data row4 col1" >-0.020759</td>
#       <td id="T_c2f27_row4_col2" class="data row4 col2" >-0.193497</td>
#       <td id="T_c2f27_row4_col3" class="data row4 col3" >0.094144</td>
#     </tr>
#     <tr>
#       <th id="T_c2f27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c2f27_row5_col0" class="data row5 col0" >1.135048</td>
#       <td id="T_c2f27_row5_col1" class="data row5 col1" >-0.162388</td>
#       <td id="T_c2f27_row5_col2" class="data row5 col2" >-0.105861</td>
#       <td id="T_c2f27_row5_col3" class="data row5 col3" >1.289731</td>
#     </tr>
#     <tr>
#       <th id="T_c2f27_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c2f27_row6_col0" class="data row6 col0" >1.426434</td>
#       <td id="T_c2f27_row6_col1" class="data row6 col1" >0.628651</td>
#       <td id="T_c2f27_row6_col2" class="data row6 col2" >-1.330087</td>
#       <td id="T_c2f27_row6_col3" class="data row6 col3" >-1.399903</td>
#     </tr>
#     <tr>
#       <th id="T_c2f27_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c2f27_row7_col0" class="data row7 col0" >2.243143</td>
#       <td id="T_c2f27_row7_col1" class="data row7 col1" >1.125163</td>
#       <td id="T_c2f27_row7_col2" class="data row7 col2" >0.581517</td>
#       <td id="T_c2f27_row7_col3" class="data row7 col3" >0.000843</td>
#     </tr>
#     <tr>
#       <th id="T_c2f27_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c2f27_row8_col0" class="data row8 col0" >0

# %% [markdown]
# _From the [page](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#concat)_:
# Adding a column to a DataFrame is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the DataFrame constructor instead of building a DataFrame by iteratively appending records to it.

# %% [markdown]
# ## Join
# SQL style merges.

# %%
# two data frames
sl = pd.Series(np.random.randint(10, size=6))
sr = sl.shift(2).fillna(0).astype(int)
left = pd.DataFrame({"key": list("ABCDEF"), "lval": sl})

right = pd.DataFrame({"key": list("ABBCDE"), "rval": sr})

# %%
render_df_side_by_side(left, right, "left", "right")
# Out:
# <style type="text/css">
# </style>
# <table id="T_92333" style='display:inline'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92333_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_92333_level0_col1" class="col_heading level0 col1" >lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92333_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92333_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_92333_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_92333_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92333_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_92333_row1_col1" class="data row1 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_92333_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92333_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_92333_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_92333_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92333_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_92333_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_92333_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_92333_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_92333_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_92333_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_92333_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_92333_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7962e" style='display:inline'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7962e_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_7962e_level0_col1" class="col_heading level0 col1" >rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7962e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7962e_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_7962e_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7962e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7962e_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_7962e_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7962e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7962e_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_7962e_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7962e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7962e_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_7962e_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7962e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7962e_row4_col0" class="data row4 col0" >D</td>
#       <td id="T_7962e_row4_col1" class="data row4 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_7962e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7962e_row5_col0" class="data row5 col0" >E</td>
#       <td id="T_7962e_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pd.merge(left, right, on="key")
result
# Out:
#   key  lval  rval
# 0   A     2     0
# 1   B     1     0
# 2   B     1     2
# 3   C     9     1
# 4   D     6     9
# 5   E     7     6

# %% [markdown]
# # Grouping

# %% [markdown]
# "Group By" really means one or more of the following happening:
# 1. **Split**: data is broken into groups based on some criteria
# 2. **Apply**: a data operation is executed on each of those groups
# 3. **Combine**: the results are combined back into a data structure

# %%
grp_df = pd.DataFrame(
    {
        "colA": list("AABCAABDAA"),
        "colB": list("1234567890"),
        "colC": np.random.randn(10),
        "colD": np.random.randn(10),
    }
)
grp_df
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.093382  1.017674
# 1    A    2 -0.682672 -0.734792
# 2    B    3 -1.552797 -0.078678
# 3    C    4 -0.531378  0.064230
# 4    A    5  0.580304 -0.281936
# 5    A    6  1.337946 -0.774003
# 6    B    7  0.741093 -0.364554
# 7    D    8 -0.115889  2.303335
# 8    A    9  0.157584 -0.871421
# 9    A    0 -0.352206 -0.085398

# %%
# a DataFrameGroupBy object object
grpby = grp_df.groupby("colA")

# list all the groups found
g = grpby.groups
g
# Out:
# {'A': [0, 1, 4, 5, 8, 9], 'B': [2, 6], 'C': [3], 'D': [7]}

# %%
# to create a dataframe from the group use something like
grpby.get_group("A")
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.093382  1.017674
# 1    A    2 -0.682672 -0.734792
# 4    A    5  0.580304 -0.281936
# 5    A    6  1.337946 -0.774003
# 8    A    9  0.157584 -0.871421
# 9    A    0 -0.352206 -0.085398

# %% [markdown]
# ### Find all the groups

# %%
# but we may not know all the groups in the dataframe.
# so got to find a way to list all groups as dataframes.
#
# some basic python helps create a list of groupby names
grpby_labels_list = [*g.keys()]  # using the unpacking operator *
# alternatively
# grpby_labels_list = list(g.keys())
grpby_labels_list
# Out:
# ['A', 'B', 'C', 'D']

# %%
# create a dict where the group label is the key and the group dataframe is the value
grps = {lbl: grpby.get_group(lbl) for lbl in grpby_labels_list}

# now use the dict to access individual dataframes created out of the groupby operation
grps["B"]

# question: can we create a dataframe of dataframes?
# Out:
#   colA colB      colC      colD
# 2    B    3 -1.552797 -0.078678
# 6    B    7  0.741093 -0.364554

# %%
# You can see the datatype of the value is a pandas dataframe
type(grps["A"])
# Out:
# pandas.core.frame.DataFrame

# %%
# make a function of it all...
def get_all_groups(df_grpby):
    return {lbl: df_grpby.get_group(lbl) for lbl in list(df_grpby.groups.keys())}

# %%
grps = get_all_groups(grp_df.groupby("colA"))
grps
# Out:
# {'A':   colA colB      colC      colD
#  0    A    1 -0.093382  1.017674
#  1    A    2 -0.682672 -0.734792
#  4    A    5  0.580304 -0.281936
#  5    A    6  1.337946 -0.774003
#  8    A    9  0.157584 -0.871421
#  9    A    0 -0.352206 -0.085398,
#  'B':   colA colB      colC      colD
#  2    B    3 -1.552797 -0.078678
#  6    B    7  0.741093 -0.364554,
#  'C':   colA colB      colC     colD
#  3    C    4 -0.531378  0.06423,
#  'D':   colA colB      colC      colD
#  7    D    8 -0.115889  2.303335}

# %%
# get a sum of values from each group
grp_df.groupby("colA").sum()
# Out:
#         colB      colC      colD
# colA
# A     125690  0.947574 -1.729876
# B         37 -0.811704 -0.443232
# C          4 -0.531378  0.064230
# D          8 -0.115889  2.303335

# %%
# let's add one more column to the dataframe
# we can try grouping on two columns
grp_df["colE"] = list("1231231231")
grp_df
# Out:
#   colA colB      colC      colD colE
# 0    A    1 -0.093382  1.017674    1
# 1    A    2 -0.682672 -0.734792    2
# 2    B    3 -1.552797 -0.078678    3
# 3    C    4 -0.531378  0.064230    1
# 4    A    5  0.580304 -0.281936    2
# 5    A    6  1.337946 -0.774003    3
# 6    B    7  0.741093 -0.364554    1
# 7    D    8 -0.115889  2.303335    2
# 8    A    9  0.157584 -0.871421    3
# 9    A    0 -0.352206 -0.085398    1

# %%
g2 = grp_df.groupby(["colA", "colE"])
grps2 = get_all_groups(g2)
grps2
# Out:
# {('A',
#   '1'):   colA colB      colC      colD colE
#  0    A    1 -0.093382  1.017674    1
#  9    A    0 -0.352206 -0.085398    1,
#  ('A',
#   '2'):   colA colB      colC      colD colE
#  1    A    2 -0.682672 -0.734792    2
#  4    A    5  0.580304 -0.281936    2,
#  ('A',
#   '3'):   colA colB      colC      colD colE
#  5    A    6  1.337946 -0.774003    3
#  8    A    9  0.157584 -0.871421    3,
#  ('B',
#   '1'):   colA colB      colC      colD colE
#  6    B    7  0.741093 -0.364554    1,
#  ('B',
#   '3'):   colA colB      colC      colD colE
#  2    B    3 -1.552797 -0.078678    3,
#  ('C',
#   '1'):   colA colB      colC     colD colE
#  3    C    4 -0.531378  0.06423    1,
#  ('D',
#   '2'):   colA colB      colC      colD colE
#  7    D    8 -0.115889  2.303335    2}

# %%
render_df_side_by_side(grps2[("A", "1")], grps2[("A", "2")], "A,1", "A,2")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4398d" style='display:inline'>
#   <caption>A,1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4398d_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_4398d_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_4398d_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_4398d_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_4398d_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4398d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4398d_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_4398d_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_4398d_row0_col2" class="data row0 col2" >-0.093382</td>
#       <td id="T_4398d_row0_col3" class="data row0 col3" >1.017674</td>
#       <td id="T_4398d_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4398d_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_4398d_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_4398d_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_4398d_row1_col2" class="data row1 col2" >-0.352206</td>
#       <td id="T_4398d_row1_col3" class="data row1 col3" >-0.085398</td>
#       <td id="T_4398d_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_75edb" style='display:inline'>
#   <caption>A,2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75edb_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_75edb_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_75edb_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_75edb_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_75edb_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75edb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_75edb_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_75edb_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_75edb_row0_col2" class="data row0 col2" >-0.682672</td>
#       <td id="T_75edb_row0_col3" class="data row0 col3" >-0.734792</td>
#       <td id="T_75edb_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_75edb_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_75edb_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_75edb_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_75edb_row1_col2" class="data row1 col2" >0.580304</td>
#       <td id="T_75edb_row1_col3" class="data row1 col3" >-0.281936</td>
#       <td id="T_75edb_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reshaping
#
# Stacking and Pivot Tables.
# This really warrants more practice, at least go through [the page](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#)

# %% [markdown]
# ## Stacking

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %% [markdown]
# If the syntax [*expression](https://docs.python.org/dev/reference/expressions.html#calls) appears in the function call, expression must evaluate to an iterable. Elements from these iterables are treated as if they were additional positional arguments.
#
# ...although the *expression syntax may appear after explicit keyword arguments, it is processed before the keyword arguments (and any **expression arguments)

# %%
# starred expressions...
def f(a, b):
    print(a, " ", b)


f(
    b=1, *(2,)
)  # works, the tuple (iterable) is expanded, 2 is assigned to a, then b fills the next argument slot
# f (a=1, *(2,)) # FAILS, multiple values for argument 'a'
# Out:
# 2   1

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
stack_idx = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])

# %%
stack_df = pd.DataFrame(np.random.randn(8, 2), index=stack_idx, columns=["a", "b"])
stack_df
# Out:
#                      a         b
# first second
# bar   one     0.507936  1.755927
#       two     1.649808 -0.829132
# baz   one    -0.537332 -0.510283
#       two     0.209079 -0.623160
# foo   one     1.087583  0.920587
#       two     1.900584 -0.285723
# qux   one    -0.034334  0.930731
#       two    -1.354884 -1.273963

# %%
# stack really just combines the columns
stacked = stack_df.stack()
stacked
# Out:
# first  second
# bar    one     a    0.507936
#                b    1.755927
#        two     a    1.649808
#                b   -0.829132
# baz    one     a   -0.537332
#                b   -0.510283
#        two     a    0.209079
#                b   -0.623160
# foo    one     a    1.087583
#                b    0.920587
#        two     a    1.900584
#                b   -0.285723
# qux    one     a   -0.034334
#                b    0.930731
#        two     a   -1.354884
#                b   -1.273963
# dtype: float64

# %%
# unstacked brings back the two columns
# by default unstacks the last level
unstacked = stacked.unstack()
unstacked
# Out:
#                      a         b
# first second
# bar   one     0.507936  1.755927
#       two     1.649808 -0.829132
# baz   one    -0.537332 -0.510283
#       two     0.209079 -0.623160
# foo   one     1.087583  0.920587
#       two     1.900584 -0.285723
# qux   one    -0.034334  0.930731
#       two    -1.354884 -1.273963

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   a  0.507936  1.649808
#       b  1.755927 -0.829132
# baz   a -0.537332  0.209079
#       b -0.510283 -0.623160
# foo   a  1.087583  1.900584
#       b  0.920587 -0.285723
# qux   a -0.034334 -1.354884
#       b  0.930731 -1.273963

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    a  0.507936 -0.537332  1.087583 -0.034334
#        b  1.755927 -0.510283  0.920587  0.930731
# two    a  1.649808  0.209079  1.900584 -1.354884
#        b -0.829132 -0.623160 -0.285723 -1.273963

# %%
# you can basically pivot the columns and rows using a combination of stack() and unstack()
unstacked.unstack()
# Out:
#                a                   b
# second       one       two       one       two
# first
# bar     0.507936  1.649808  1.755927 -0.829132
# baz    -0.537332  0.209079 -0.510283 -0.623160
# foo     1.087583  1.900584  0.920587 -0.285723
# qux    -0.034334 -1.354884  0.930731 -1.273963

# %% [markdown]
# ## Pivot Tables

# %%
# we're now just using data created in the pandas documentation - just cause, time.
pivot_tables_df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
pivot_tables_df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.427781 -0.651634
# 1     one  B  foo -1.989155  0.209103
# 2     two  C  foo -0.807340  1.182170
# 3   three  A  bar  1.127443  1.098792
# 4     one  B  bar -0.383951 -2.182137
# 5     one  C  bar -0.780801 -0.110037
# 6     two  A  foo  0.145130 -0.528027
# 7   three  B  foo  0.505087 -1.048263
# 8     one  C  foo -0.840982  0.155325
# 9     one  A  bar -0.426647 -0.176838
# 10    two  B  bar -2.737453  0.705873
# 11  three  C  bar -1.042815 -0.899821

# %%
# simple pivot tables - data, values to aggregate, index, columns to pivot along
pd.pivot_table(pivot_tables_df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -0.426647 -0.427781
#       B -0.383951 -1.989155
#       C -0.780801 -0.840982
# three A  1.127443       NaN
#       B       NaN  0.505087
#       C -1.042815       NaN
# two   A       NaN  0.145130
#       B -2.737453       NaN
#       C       NaN -0.807340

# %%
# more'n one columns of values
# mark all NaN as zero (0)
pd.pivot_table(
    pivot_tables_df, values=["D", "E"], index=["A", "B"], columns=["C"]
).fillna(0)
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A -0.426647 -0.427781 -0.176838 -0.651634
#       B -0.383951 -1.989155 -2.182137  0.209103
#       C -0.780801 -0.840982 -0.110037  0.155325
# three A  1.127443  0.000000  1.098792  0.000000
#       B  0.000000  0.505087  0.000000 -1.048263
#       C -1.042815  0.000000 -0.899821  0.000000
# two   A  0.000000  0.145130  0.000000 -0.528027
#       B -2.737453  0.000000  0.705873  0.000000
#       C  0.000000 -0.807340  0.000000  1.182170

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# We may need to resample data to a different time-frequency.
# Like get data every second and resample to data every 5 minutes and so on...

# %%
rng = pd.date_range("01/01/2022", periods=1000, freq="S")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5min").sum()
# Out:
# 2022-01-01 00:00:00    74344
# 2022-01-01 00:05:00    79271
# 2022-01-01 00:10:00    77821
# 2022-01-01 00:15:00    25398
# Freq: 5T, dtype: int32

# %% [markdown]
# read up on [date offset strings](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) like '5min' etc.

# %% [markdown]
# ## Timezones

# %%
# timezone representation
rng2 = pd.date_range("01/01/2022", periods=500, freq="D")
ts2 = pd.Series(np.random.randint(0, 365, len(rng2)), index=rng2)
ts2_utc = ts2.tz_localize("UTC")

# %%
# convert to US/Eastern
ts2_utc.tz_convert("US/Eastern")
# Out:
# 2021-12-31 19:00:00-05:00    235
# 2022-01-01 19:00:00-05:00    249
# 2022-01-02 19:00:00-05:00    183
# 2022-01-03 19:00:00-05:00    217
# 2022-01-04 19:00:00-05:00    172
#                             ...
# 2023-05-10 20:00:00-04:00    345
# 2023-05-11 20:00:00-04:00      9
# 2023-05-12 20:00:00-04:00    358
# 2023-05-13 20:00:00-04:00    263
# 2023-05-14 20:00:00-04:00    285
# Freq: D, Length: 500, dtype: int32

# %% [markdown]
# ## Time span representations
#
# Converting between periods and timestamps.
#
# Period is a _timespan_ - span of time between two timestamps.

# %%
# month - end of each
rng3 = pd.date_range("01/01/2022", periods=12, freq="M")
rng3
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts3 = pd.Series(np.random.randn(len(rng3)), index=rng3)
ts3
# Out:
# 2022-01-31    0.661047
# 2022-02-28    1.090167
# 2022-03-31   -0.635910
# 2022-04-30    0.733682
# 2022-05-31   -1.991069
# 2022-06-30    0.111172
# 2022-07-31   -1.386583
# 2022-08-31   -0.216225
# 2022-09-30    0.240700
# 2022-10-31   -0.211959
# 2022-11-30   -1.514275
# 2022-12-31   -1.737569
# Freq: M, dtype: float64

# %%
ps = ts3.to_period()
ps
# Out:
# 2022-01    0.661047
# 2022-02    1.090167
# 2022-03   -0.635910
# 2022-04    0.733682
# 2022-05   -1.991069
# 2022-06    0.111172
# 2022-07   -1.386583
# 2022-08   -0.216225
# 2022-09    0.240700
# 2022-10   -0.211959
# 2022-11   -1.514275
# 2022-12   -1.737569
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2022-01-01    0.661047
# 2022-02-01    1.090167
# 2022-03-01   -0.635910
# 2022-04-01    0.733682
# 2022-05-01   -1.991069
# 2022-06-01    0.111172
# 2022-07-01   -1.386583
# 2022-08-01   -0.216225
# 2022-09-01    0.240700
# 2022-10-01   -0.211959
# 2022-11-01   -1.514275
# 2022-12-01   -1.737569
# Freq: MS, dtype: float64

# %% [markdown]
# A more complex use-case:
# convert a _quarterly frequency_ with _year ending in November_ to _9am_ of _the end of the month_ _following_ the _quarter end_

# %%
prng = pd.period_range("1990Q1", "2022Q4", freq="Q-NOV")
type(prng)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
ts4 = pd.Series(np.random.randn(len(prng)), index=prng)
ts4.head()
# Out:
# 1990Q1   -1.693574
# 1990Q2    0.112639
# 1990Q3    0.635052
# 1990Q4   -1.686988
# 1991Q1   -0.730692
# Freq: Q-NOV, dtype: float64

# %%
ts4.index = (prng.asfreq("M", "e") + 1).asfreq("H", "s") + 9
ts4.head()
# Out:
# 1990-03-01 09:00   -1.693574
# 1990-06-01 09:00    0.112639
# 1990-09-01 09:00    0.635052
# 1990-12-01 09:00   -1.686988
# 1991-03-01 09:00   -0.730692
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
#
# [This page](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical-data).
#
# ##### Note: With v2.0+ some of these are breaking - so this sections needs an update.
#
# See [this issue on GitHub](https://github.com/pandas-dev/pandas/issues/52593)
#
# For e.g., gender, social class, blood type, country affiliation, observation time or rating via Likert scales.
#
# Categorical data. Categories allow (usually) fixed number of possible values. Categorical data may have some order, but not support numerical operations (for e.g., 'strongly agree', 'agree', 'disagree', 'strongly disagree').

# %%
cat_df = pd.DataFrame({"id": list("123456"), "raw_grade": list("abbaae")})
cat_df
# Out:
#   id raw_grade
# 0  1         a
# 1  2         b
# 2  3         b
# 3  4         a
# 4  5         a
# 5  6         e

# %%
# convert the raw_grade col to categories
cat_df["grade"] = cat_df["raw_grade"].astype("category")
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
cat_df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# this breaks with v2.0+
# [TODO] Find a fix

# can give more meaningful names here
# direct assignment to Series.cat.categories()
# cat_df["grade"].cat.categories = ["very good", "meh", "very bad"]
# cat_df["grade"]

# %%
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
list(cat_df["grade"].cat.categories)

# categorical.CategoricalAccessor encapsulates all changes to categoricals
# for e.g., set_categories or remove_categories
# dir(cat_df['grade'].cat)
# Out:
# ['a', 'b', 'e']

# %%
# add more categories
cat_df["grade"] = cat_df["grade"].cat.set_categories(
    ["very bad", "bad", "meh", "good", "very good"]
)
# new list of categories
list(cat_df["grade"].cat.categories)
# Out:
# ['very bad', 'bad', 'meh', 'good', 'very good']

# %%
# now when we can sort the dataframe in order of categories (not lexical)
sorted_cat_df = cat_df.sort_values(by="grade")
render_df_side_by_side(cat_df, sorted_cat_df, "OG", "Sorted")
# Out:
# <style type="text/css">
# </style>
# <table id="T_198e2" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_198e2_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_198e2_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_198e2_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_198e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_198e2_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_198e2_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_198e2_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_198e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_198e2_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_198e2_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_198e2_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_198e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_198e2_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_198e2_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_198e2_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_198e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_198e2_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_198e2_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_198e2_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_198e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_198e2_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_198e2_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_198e2_row4_col2" class="data row4 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_198e2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_198e2_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_198e2_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_198e2_row5_col2" class="data row5 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_39add" style='display:inline'>
#   <caption>Sorted</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39add_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_39add_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_39add_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39add_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39add_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_39add_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_39add_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_39add_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_39add_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_39add_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_39add_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_39add_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_39add_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_39add_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_39add_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_39add_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_39add_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_39add_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_39add_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_39add_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_39add_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_39add_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_39add_row4_col2" class="data row4 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_39add_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_39add_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_39add_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_39add_row5_col2" class="data row5 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# grouping
# cat_grp = cat_df.groupby("grade")
# cat_grp.get_group("very good")

# %%
# count elements
# cat_grp.size()
