# %% [markdown]
# # Setup
#
# This is following [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) for pandas 1.4.3 but may take a little more than 10 minutes to finish. Lot's of small changes, references etc.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Object creation

# %%
# Series - pass a list to pd.Series
s1 = pd.Series([1, 2, 3, np.nan, 5])

# %%
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
# create an index to use in the dataframe
# default frequency is D (day), so creates a DatetimeIndex of 10 days
dates = pd.date_range('20220619', periods=10)
dates
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# just in case you are wondering, here's [all the "offset aliases"](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases) for Datetime

# %%
# Dataframe - pass a Numpy array
# create a 10 row, 4 col random number array, index by dates, give some column names
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857
# 2022-06-27  0.240491  0.173858  0.429743  0.908007
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841

# %%
# Create a dataframe by passing a dictionary of objects
# where each object can be converted into a series-like structure
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220619"),
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([3]*6, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train", "test", "train"]),
        "F": list("foofoo"),
        "G": "foo"
    }
)

df2
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %%
# the datatype of each of the columns would be different
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# G            object
# dtype: object

# %% [markdown]
# # Viewing Data

# %%
# top of the dataframe
df.head()
# Out:
#                    A         B         C         D
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941

# %%
# bottom 3 records of the dataframe
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857
# 2022-06-27  0.240491  0.173858  0.429743  0.908007
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841

# %%
# index of the df
df.index
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# columns of the df
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# .to_numpy gives a NumPy representation of the dataframe
# this is expensive if all columns are of different data type
df.to_numpy()
# Out:
# array([[ 0.76427546,  0.63935853, -1.49113091,  1.7432936 ],
#        [ 0.58144857,  0.48344063, -0.62804774, -0.04344679],
#        [-0.89218703,  1.57504858, -0.38466769,  0.24938603],
#        [-1.1868908 ,  2.58524382, -0.20560865, -0.50738394],
#        [-0.16905888, -1.11812093, -0.13250303,  0.19694139],
#        [ 0.53536321, -2.16158209, -0.59724575,  1.89214746],
#        [ 0.5200721 ,  1.22241285,  1.03334097, -0.36208253],
#        [ 1.1468167 ,  1.97395169, -0.02577416,  0.95085685],
#        [ 0.24049106,  0.17385804,  0.42974299,  0.90800724],
#        [-1.93943217, -0.5743381 ,  2.35178855, -0.37784133]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo']], dtype=object)

# %%
# quick summary stats
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.039910   0.479927   0.034989   0.464988
# std     0.990571   1.459717   1.051677   0.870500
# min    -1.939432  -2.161582  -1.491131  -0.507384
# 25%    -0.711405  -0.387289  -0.544101  -0.282424
# 50%     0.380282   0.561400  -0.169056   0.223164
# 75%     0.569927   1.486890   0.315864   0.940144
# max     1.146817   2.585244   2.351789   1.892147

# %% [markdown]
# 1. **count** = Count number of non-NA/null observations
# 1. **max** = Maximum of the values in the object
# 1. **min** = Minimum of the values in the object
# 1. **mean** = Mean of the values
# 1. **std** = Standard deviation of the observations
# 1. **25%** = Default lower percentile
# 1. **50%** = 50 percentile - same as the median
# 1. **75%** = Default upper percentile

# %%
# change the percentiles
df.describe(percentiles=[.1, .5, .9])
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.039910   0.479927   0.034989   0.464988
# std     0.990571   1.459717   1.051677   0.870500
# min    -1.939432  -2.161582  -1.491131  -0.507384
# 10%    -1.262145  -1.222467  -0.714356  -0.390796
# 50%     0.380282   0.561400  -0.169056   0.223164
# 90%     0.802530   2.035081   1.165186   1.758179
# max     1.146817   2.585244   2.351789   1.892147

# %%
# E, F, G in d2 are not numeric, so do not come up in describe()
df2.describe()
# Out:
#          A    C    D
# count  6.0  6.0  6.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
# transpose the data
# turn rows to columns and vice versa
df.T
# Out:
#    2022-06-19  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# A    0.764275    0.581449   -0.892187   -1.186891   -0.169059    0.535363
# B    0.639359    0.483441    1.575049    2.585244   -1.118121   -2.161582
# C   -1.491131   -0.628048   -0.384668   -0.205609   -0.132503   -0.597246
# D    1.743294   -0.043447    0.249386   -0.507384    0.196941    1.892147
#
#    2022-06-25  2022-06-26  2022-06-27  2022-06-28
# A    0.520072    1.146817    0.240491   -1.939432
# B    1.222413    1.973952    0.173858   -0.574338
# C    1.033341   -0.025774    0.429743    2.351789
# D   -0.362083    0.950857    0.908007   -0.377841

# %% [markdown]
# ### [Axis in pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html?highlight=set_ax#pandas.DataFrame.set_axis)
#
# ```axis{0 or ‘index’, 1 or ‘columns’}```
#
# Always remember that when you specify:
# * ```axis=0``` or ```axis='index'``` you indicate that the operation should be along the _index_ (aka across the rows). More often than not indexes will go from top to bottom (vertically), but sometimes they may not (for e.g. if you use columns as index or when you have hierarchical or multi-index data).
# * ```axis=1``` or ```axis='columns'``` indicates the operation is along the columns
#
# When in doubt use the explicit version ```'index'``` or ```'columns'``` instead of ```0``` or ```1```

# %%
# sort along the axis - 1 = horizontal
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-06-19  1.743294 -1.491131  0.639359  0.764275
# 2022-06-20 -0.043447 -0.628048  0.483441  0.581449
# 2022-06-21  0.249386 -0.384668  1.575049 -0.892187
# 2022-06-22 -0.507384 -0.205609  2.585244 -1.186891
# 2022-06-23  0.196941 -0.132503 -1.118121 -0.169059
# 2022-06-24  1.892147 -0.597246 -2.161582  0.535363
# 2022-06-25 -0.362083  1.033341  1.222413  0.520072
# 2022-06-26  0.950857 -0.025774  1.973952  1.146817
# 2022-06-27  0.908007  0.429743  0.173858  0.240491
# 2022-06-28 -0.377841  2.351789 -0.574338 -1.939432

# %%
# sort along the axis - 0 = vertical
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841
# 2022-06-27  0.240491  0.173858  0.429743  0.908007
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294

# %%
# sort ascending by values in a column
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941
# 2022-06-27  0.240491  0.173858  0.429743  0.908007
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857

# %%
# sort by non-numerical values
df2.sort_values(by="F", ascending=False)
# Out:
#      A          B    C  D      E  F    G
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo

# %%
# sort by two or more columns
df2.sort_values(by=["F", "E"])
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %% [markdown]
# # Selection

# %% [markdown]
# For production prefer the following instead of other data access methods (typical python methods like ["col"] or [a:b] slices etc.):
#
# ```.at, .iat, .loc and .iloc.```

# %% [markdown]
# ## Getting

# %%
# selecting a single column returns a Series object
df["A"]
# Out:
# 2022-06-19    0.764275
# 2022-06-20    0.581449
# 2022-06-21   -0.892187
# 2022-06-22   -1.186891
# 2022-06-23   -0.169059
# 2022-06-24    0.535363
# 2022-06-25    0.520072
# 2022-06-26    1.146817
# 2022-06-27    0.240491
# 2022-06-28   -1.939432
# Freq: D, Name: A, dtype: float64

# %%
# selecting a slice
df[1:5]
# Out:
#                    A         B         C         D
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941

# %% [markdown]
# ## Selection by label

# %%
# selecting based on a label
df.loc[dates[0]]
# Out:
# A    0.764275
# B    0.639359
# C   -1.491131
# D    1.743294
# Name: 2022-06-19 00:00:00, dtype: float64

# %%
# select on a multi-axis by lable
# I honestly do not know what the comment above means...help!
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-06-19  0.764275  0.639359
# 2022-06-20  0.581449  0.483441
# 2022-06-21 -0.892187  1.575049
# 2022-06-22 -1.186891  2.585244
# 2022-06-23 -0.169059 -1.118121
# 2022-06-24  0.535363 -2.161582
# 2022-06-25  0.520072  1.222413
# 2022-06-26  1.146817  1.973952
# 2022-06-27  0.240491  0.173858
# 2022-06-28 -1.939432 -0.574338

# %%
# specific index value results in reduction of dimensions
res = df.loc["2022-06-20"]
print(res)
print("res.shape = ", res.shape, " vs. df.shape = ", df.shape)
# Out:
# A    0.581449
# B    0.483441
# C   -0.628048
# D   -0.043447
# Name: 2022-06-20 00:00:00, dtype: float64
# res.shape =  (4,)  vs. df.shape =  (10, 4)

# %%
# get to a specific scalar:
#
# method one
df.loc[dates[0], "A"]
# Out:
# 0.7642754569983843

# %%
#
# method two (slightly faster than method one)
df.at[dates[0], "A"]
# Out:
# 0.7642754569983843

# %% [markdown]
# ## Selection by position

# %%
df.iloc[2]
# Out:
# A   -0.892187
# B    1.575049
# C   -0.384668
# D    0.249386
# Name: 2022-06-21 00:00:00, dtype: float64

# %%
# slices - similar to NumPy / Python - [row:slice, col:slice]
df.iloc[1:5, 0:2]
# Out:
#                    A         B
# 2022-06-20  0.581449  0.483441
# 2022-06-21 -0.892187  1.575049
# 2022-06-22 -1.186891  2.585244
# 2022-06-23 -0.169059 -1.118121

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
df.iloc[[0, 1, 2, 6], [0, 2]]
# Out:
#                    A         C
# 2022-06-19  0.764275 -1.491131
# 2022-06-20  0.581449 -0.628048
# 2022-06-21 -0.892187 -0.384668
# 2022-06-25  0.520072  1.033341

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
# change the order of columns, repeact a column
df.iloc[[0, 1, 2, 6], [2, 1, 0, 2]]
# Out:
#                    C         B         A         C
# 2022-06-19 -1.491131  0.639359  0.764275 -1.491131
# 2022-06-20 -0.628048  0.483441  0.581449 -0.628048
# 2022-06-21 -0.384668  1.575049 -0.892187 -0.384668
# 2022-06-25  1.033341  1.222413  0.520072  1.033341

# %%
# slice rows explicitly, keep all columns
df.iloc[[1, 2], :]
# Out:
#                    A         B         C         D
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386

# %%
# slice columns, keep all rows
df.iloc[:, [2, 3]]
# Out:
#                    C         D
# 2022-06-19 -1.491131  1.743294
# 2022-06-20 -0.628048 -0.043447
# 2022-06-21 -0.384668  0.249386
# 2022-06-22 -0.205609 -0.507384
# 2022-06-23 -0.132503  0.196941
# 2022-06-24 -0.597246  1.892147
# 2022-06-25  1.033341 -0.362083
# 2022-06-26 -0.025774  0.950857
# 2022-06-27  0.429743  0.908007
# 2022-06-28  2.351789 -0.377841

# %%
# everything, because you can
df.iloc[:, :]
# Out:
#                    A         B         C         D
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857
# 2022-06-27  0.240491  0.173858  0.429743  0.908007
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841

# %%
# get to a scalar (2 methods, just like before)
#
# method one: use iloc
df.iloc[1, 2]
# Out:
# -0.6280477364031314

# %%
#
# method two: use iat
df.iat[1, 2]
# Out:
# -0.6280477364031314

# %% [markdown]
# ## Boolean Indexing

# %%
# use a value found in a single col to get data
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857
# 2022-06-27  0.240491  0.173858  0.429743  0.908007

# %%
# boolean across the entire DF - vals that don't match go NaN
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-06-19  0.764275  0.639359       NaN  1.743294
# 2022-06-20  0.581449  0.483441       NaN       NaN
# 2022-06-21       NaN  1.575049       NaN  0.249386
# 2022-06-22       NaN  2.585244       NaN       NaN
# 2022-06-23       NaN       NaN       NaN  0.196941
# 2022-06-24  0.535363       NaN       NaN  1.892147
# 2022-06-25  0.520072  1.222413  1.033341       NaN
# 2022-06-26  1.146817  1.973952       NaN  0.950857
# 2022-06-27  0.240491  0.173858  0.429743  0.908007
# 2022-06-28       NaN       NaN  2.351789       NaN

# %%
# add another column
df11 = df.copy()
df11["E"] = ["one", "two", "three", "four",
             "two", "five", "one", "two", "three", "four"]
df11
# Out:
#                    A         B         C         D      E
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294    one
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447    two
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  three
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384   four
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941    two
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147   five
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083    one
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857    two
# 2022-06-27  0.240491  0.173858  0.429743  0.908007  three
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841   four

# %%
# the isin() query - basically the in clause
df11[df11["E"].isin(["two", "five"])]
# Out:
#                    A         B         C         D     E
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447   two
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941   two
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147  five
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857   two

# %% [markdown]
# ## Setting values

# %%
# matching indexes auto-aligns values
s1 = pd.Series(range(11, 21), index=pd.date_range('20220619', periods=10))
s1
# Out:
# 2022-06-19    11
# 2022-06-20    12
# 2022-06-21    13
# 2022-06-22    14
# 2022-06-23    15
# 2022-06-24    16
# 2022-06-25    17
# 2022-06-26    18
# 2022-06-27    19
# 2022-06-28    20
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294  11
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447  12
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941  15
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147  16
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083  17
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857  18
# 2022-06-27  0.240491  0.173858  0.429743  0.908007  19
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841  20

# %%
# setting values by label and position
# first let's make a quick copy
df12 = df.copy()
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294  11
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447  12
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941  15
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147  16
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083  17
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857  18
# 2022-06-27  0.240491  0.173858  0.429743  0.908007  19
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841  20

# %%
# set by label
df12.at[dates[0], "A"] = 0
# set by position
df12.iat[0, 1] = 0
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.000000  0.000000 -1.491131  1.743294  11
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447  12
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941  15
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147  16
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083  17
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857  18
# 2022-06-27  0.240491  0.173858  0.429743  0.908007  19
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841  20

# %%
# kinda bigger replacement
df12.loc[:, "D"] = np.array([5]*len(df))
df12
# Out:
#                    A         B         C  D   F
# 2022-06-19  0.000000  0.000000 -1.491131  5  11
# 2022-06-20  0.581449  0.483441 -0.628048  5  12
# 2022-06-21 -0.892187  1.575049 -0.384668  5  13
# 2022-06-22 -1.186891  2.585244 -0.205609  5  14
# 2022-06-23 -0.169059 -1.118121 -0.132503  5  15
# 2022-06-24  0.535363 -2.161582 -0.597246  5  16
# 2022-06-25  0.520072  1.222413  1.033341  5  17
# 2022-06-26  1.146817  1.973952 -0.025774  5  18
# 2022-06-27  0.240491  0.173858  0.429743  5  19
# 2022-06-28 -1.939432 -0.574338  2.351789  5  20

# %%
# setting values using a boolean selection (aka where clause)
df12[df12 > 0] = -df12
df12
# Out:
#                    A         B         C  D   F
# 2022-06-19  0.000000  0.000000 -1.491131 -5 -11
# 2022-06-20 -0.581449 -0.483441 -0.628048 -5 -12
# 2022-06-21 -0.892187 -1.575049 -0.384668 -5 -13
# 2022-06-22 -1.186891 -2.585244 -0.205609 -5 -14
# 2022-06-23 -0.169059 -1.118121 -0.132503 -5 -15
# 2022-06-24 -0.535363 -2.161582 -0.597246 -5 -16
# 2022-06-25 -0.520072 -1.222413 -1.033341 -5 -17
# 2022-06-26 -1.146817 -1.973952 -0.025774 -5 -18
# 2022-06-27 -0.240491 -0.173858 -0.429743 -5 -19
# 2022-06-28 -1.939432 -0.574338 -2.351789 -5 -20

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### _reindex_
# change/add/delete index on a specified axis, returns a new dataframe

# %%
df13 = df.reindex(index=dates[0:4], columns=list(df.columns)+["G"])
df13
# Out:
#                    A         B         C         D   F   G
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294  11 NaN
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447  12 NaN
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13 NaN
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14 NaN

# %% [markdown]
# ### handling missing data
# 1. _```np.nan```_
# 1. _```pandas.isna()```_
# 1. ```df.dropna()```
# 1. ```df.fillna()```

# %%
# missing data in pandas is np.nan
df13.iat[1, 0] = np.nan
df13.iloc[1:, 5] = np.random.randint(1)
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294  11  NaN
# 2022-06-20       NaN  0.483441 -0.628048 -0.043447  12  0.0
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13  0.0
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14  0.0

# %%
# get a boolean mask where values are NaN
df131 = pd.isna(df13)
df131
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# or just
pd.isna(df13)
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# the original is still there
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294  11  NaN
# 2022-06-20       NaN  0.483441 -0.628048 -0.043447  12  0.0
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13  0.0
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14  0.0

# %%
# we are going to drop / replace values now, let's make a couple of copies of the dataframe
df132 = df13.copy()
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294  11  NaN
# 2022-06-20       NaN  0.483441 -0.628048 -0.043447  12  0.0
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13  0.0
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14  0.0

# %%
# drop rows/columns that have missing data
# by default it returns a new dataframe, you may want to specify inplace=True for modifying current dataframe:
df_no_na = df132.dropna(how="any")
# how=‘any’ : If any NA values are present, drop that row or column.
# how=‘all’ : If all values are NA, drop that row or column.

# %%
# all rows/cols with missing data stripped
df_no_na
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13  0.0
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14  0.0

# %%
# original still intact
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294  11  NaN
# 2022-06-20       NaN  0.483441 -0.628048 -0.043447  12  0.0
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13  0.0
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14  0.0

# %%
# drop missing data from original
df132.dropna(how="any", inplace=True)
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13  0.0
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14  0.0

# %%
# fill missing data
df133 = df13.copy()
df133.fillna(np.pi*1000)
# Out:
#                       A         B         C         D   F            G
# 2022-06-19     0.764275  0.639359 -1.491131  1.743294  11  3141.592654
# 2022-06-20  3141.592654  0.483441 -0.628048 -0.043447  12     0.000000
# 2022-06-21    -0.892187  1.575049 -0.384668  0.249386  13     0.000000
# 2022-06-22    -1.186891  2.585244 -0.205609 -0.507384  14     0.000000

# %% [markdown]
# # Align and Join

# %% [markdown]
# There needs to be a bigger notebook for this topic.
# You need to know there's "joins" in Pandas just like in the SQL world,
# like join and left join and right join and inner and outer and all that...
# Here we'll explore these in the context of the align function - 'aligning' the indexes of two dataframes.
# Later we'll see these again in the context of _merging_ two data frames.

# %% [markdown]
# ## Create two datasets with _mismatched_ indexes

# %%
# date range indexes
idx1 = pd.date_range('2022-01-01',periods = 10)
# 2022-01-01', '2022-01-02' don't exist in idx2
# '2022-01-11', '2022-01-12' don't exist in idx1
idx2 = pd.date_range('2022-01-03',periods = 10)

# %%
# dataframes from indexes
d1 = pd.DataFrame(index = idx1, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

d2 = pd.DataFrame(index = idx2, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

# %% [markdown]
# ## Quick Aside: Rendering two dataframes side-by-side

# %% [markdown]
# The trick of rendering 2 dataframes side-by-side was from [this](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) stackoverflow question.

# %%
# we gon need to display both data frames side by side, so...
from IPython.display import display_html 
def render_df_side_by_side(a, b, a_title = "", b_title = ""):
    a_styler = a.style.set_table_attributes("style='display:inline'").set_caption(a_title)
    b_styler = b.style.set_table_attributes("style='display:inline'").set_caption(b_title)
    display_html(a_styler._repr_html_()+b_styler._repr_html_(), raw=True)

# %%
render_df_side_by_side(d1,d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b645d" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b645d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b645d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b645d_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_b645d_row0_col0" class="data row0 col0" >0.430084</td>
#       <td id="T_b645d_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_b645d_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_b645d_row1_col0" class="data row1 col0" >0.545293</td>
#       <td id="T_b645d_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b645d_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_b645d_row2_col0" class="data row2 col0" >0.046510</td>
#       <td id="T_b645d_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b645d_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_b645d_row3_col0" class="data row3 col0" >0.631373</td>
#       <td id="T_b645d_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b645d_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_b645d_row4_col0" class="data row4 col0" >0.433272</td>
#       <td id="T_b645d_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b645d_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_b645d_row5_col0" class="data row5 col0" >0.730765</td>
#       <td id="T_b645d_row5_col1" class="data row5 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_b645d_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_b645d_row6_col0" class="data row6 col0" >0.770583</td>
#       <td id="T_b645d_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_b645d_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_b645d_row7_col0" class="data row7 col0" >0.545575</td>
#       <td id="T_b645d_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_b645d_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_b645d_row8_col0" class="data row8 col0" >0.409222</td>
#       <td id="T_b645d_row8_col1" class="data row8 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_b645d_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_b645d_row9_col0" class="data row9 col0" >0.758217</td>
#       <td id="T_b645d_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d1feb" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1feb_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d1feb_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1feb_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_d1feb_row0_col0" class="data row0 col0" >0.959643</td>
#       <td id="T_d1feb_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_d1feb_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_d1feb_row1_col0" class="data row1 col0" >0.507397</td>
#       <td id="T_d1feb_row1_col1" class="data row1 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_d1feb_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_d1feb_row2_col0" class="data row2 col0" >0.467795</td>
#       <td id="T_d1feb_row2_col1" class="data row2 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_d1feb_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_d1feb_row3_col0" class="data row3 col0" >0.065305</td>
#       <td id="T_d1feb_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d1feb_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_d1feb_row4_col0" class="data row4 col0" >0.499371</td>
#       <td id="T_d1feb_row4_col1" class="data row4 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_d1feb_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_d1feb_row5_col0" class="data row5 col0" >0.367412</td>
#       <td id="T_d1feb_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_d1feb_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_d1feb_row6_col0" class="data row6 col0" >0.768702</td>
#       <td id="T_d1feb_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d1feb_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_d1feb_row7_col0" class="data row7 col0" >0.071137</td>
#       <td id="T_d1feb_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d1feb_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_d1feb_row8_col0" class="data row8 col0" >0.451604</td>
#       <td id="T_d1feb_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d1feb_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_d1feb_row9_col0" class="data row9 col0" >0.794146</td>
#       <td id="T_d1feb_row9_col1" class="data row9 col1" >20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table rendering/styling options is [a bigger discussion](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#) to be tackled later.

# %% [markdown]
# ## .add, .sub, .mul, .div etc.

# %% [markdown]
# flexible wrappers (```add, sub, mul, div, mod, pow```) to arithmetic operators: ```+, -, *, /, //, %, **```

# %%
# the +, -, *, /, //, %, ** operations align indexes to create a UNION of indexes
d3 = d1+d2
d4 = d1.sub(d2) #equivalent to d1-d2
d5 = d1*d2
d6 = d1.div(d2)

# %%
# indexs not present in the other dataframe get a NaN
d3.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_c191c_row0_col0, #T_c191c_row0_col1, #T_c191c_row1_col0, #T_c191c_row1_col1, #T_c191c_row10_col0, #T_c191c_row10_col1, #T_c191c_row11_col0, #T_c191c_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_c191c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c191c_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_c191c_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c191c_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_c191c_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_c191c_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_c191c_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_c191c_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_c191c_row2_col0" class="data row2 col0" >1.006153</td>
#       <td id="T_c191c_row2_col1" class="data row2 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_c191c_row3_col0" class="data row3 col0" >1.138771</td>
#       <td id="T_c191c_row3_col1" class="data row3 col1" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_c191c_row4_col0" class="data row4 col0" >0.901067</td>
#       <td id="T_c191c_row4_col1" class="data row4 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_c191c_row5_col0" class="data row5 col0" >0.796070</td>
#       <td id="T_c191c_row5_col1" class="data row5 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_c191c_row6_col0" class="data row6 col0" >1.269954</td>
#       <td id="T_c191c_row6_col1" class="data row6 col1" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_c191c_row7_col0" class="data row7 col0" >0.912987</td>
#       <td id="T_c191c_row7_col1" class="data row7 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_c191c_row8_col0" class="data row8 col0" >1.177924</td>
#       <td id="T_c191c_row8_col1" class="data row8 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_c191c_row9_col0" class="data row9 col0" >0.829354</td>
#       <td id="T_c191c_row9_col1" class="data row9 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_c191c_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_c191c_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c191c_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_c191c_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_c191c_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# sub
d4.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_a59d3_row0_col0, #T_a59d3_row0_col1, #T_a59d3_row1_col0, #T_a59d3_row1_col1, #T_a59d3_row10_col0, #T_a59d3_row10_col1, #T_a59d3_row11_col0, #T_a59d3_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_a59d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a59d3_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a59d3_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a59d3_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_a59d3_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a59d3_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_a59d3_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_a59d3_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_a59d3_row2_col0" class="data row2 col0" >-0.913134</td>
#       <td id="T_a59d3_row2_col1" class="data row2 col1" >-6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_a59d3_row3_col0" class="data row3 col0" >0.123976</td>
#       <td id="T_a59d3_row3_col1" class="data row3 col1" >-9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_a59d3_row4_col0" class="data row4 col0" >-0.034523</td>
#       <td id="T_a59d3_row4_col1" class="data row4 col1" >-2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_a59d3_row5_col0" class="data row5 col0" >0.665460</td>
#       <td id="T_a59d3_row5_col1" class="data row5 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_a59d3_row6_col0" class="data row6 col0" >0.271212</td>
#       <td id="T_a59d3_row6_col1" class="data row6 col1" >-7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_a59d3_row7_col0" class="data row7 col0" >0.178163</td>
#       <td id="T_a59d3_row7_col1" class="data row7 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_a59d3_row8_col0" class="data row8 col0" >-0.359481</td>
#       <td id="T_a59d3_row8_col1" class="data row8 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_a59d3_row9_col0" class="data row9 col0" >0.687080</td>
#       <td id="T_a59d3_row9_col1" class="data row9 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_a59d3_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_a59d3_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a59d3_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_a59d3_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_a59d3_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mul
d5.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_b5ed2_row0_col0, #T_b5ed2_row0_col1, #T_b5ed2_row1_col0, #T_b5ed2_row1_col1, #T_b5ed2_row10_col0, #T_b5ed2_row10_col1, #T_b5ed2_row11_col0, #T_b5ed2_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_b5ed2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5ed2_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b5ed2_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5ed2_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_b5ed2_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_b5ed2_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_b5ed2_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_b5ed2_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_b5ed2_row2_col0" class="data row2 col0" >0.044633</td>
#       <td id="T_b5ed2_row2_col1" class="data row2 col1" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_b5ed2_row3_col0" class="data row3 col0" >0.320357</td>
#       <td id="T_b5ed2_row3_col1" class="data row3 col1" >190.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_b5ed2_row4_col0" class="data row4 col0" >0.202683</td>
#       <td id="T_b5ed2_row4_col1" class="data row4 col1" >48.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_b5ed2_row5_col0" class="data row5 col0" >0.047722</td>
#       <td id="T_b5ed2_row5_col1" class="data row5 col1" >69.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_b5ed2_row6_col0" class="data row6 col0" >0.384807</td>
#       <td id="T_b5ed2_row6_col1" class="data row6 col1" >228.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_b5ed2_row7_col0" class="data row7 col0" >0.200451</td>
#       <td id="T_b5ed2_row7_col1" class="data row7 col1" >165.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_b5ed2_row8_col0" class="data row8 col0" >0.314569</td>
#       <td id="T_b5ed2_row8_col1" class="data row8 col1" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_b5ed2_row9_col0" class="data row9 col0" >0.053937</td>
#       <td id="T_b5ed2_row9_col1" class="data row9 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_b5ed2_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_b5ed2_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b5ed2_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_b5ed2_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_b5ed2_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# div
d6.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_1364a_row0_col0, #T_1364a_row0_col1, #T_1364a_row1_col0, #T_1364a_row1_col1, #T_1364a_row10_col0, #T_1364a_row10_col1, #T_1364a_row11_col0, #T_1364a_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_1364a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1364a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_1364a_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1364a_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_1364a_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_1364a_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_1364a_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_1364a_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_1364a_row2_col0" class="data row2 col0" >0.048465</td>
#       <td id="T_1364a_row2_col1" class="data row2 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_1364a_row3_col0" class="data row3 col0" >1.244337</td>
#       <td id="T_1364a_row3_col1" class="data row3 col1" >0.526316</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_1364a_row4_col0" class="data row4 col0" >0.926200</td>
#       <td id="T_1364a_row4_col1" class="data row4 col1" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_1364a_row5_col0" class="data row5 col0" >11.190076</td>
#       <td id="T_1364a_row5_col1" class="data row5 col1" >7.666667</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_1364a_row6_col0" class="data row6 col0" >1.543107</td>
#       <td id="T_1364a_row6_col1" class="data row6 col1" >0.631579</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_1364a_row7_col0" class="data row7 col0" >1.484914</td>
#       <td id="T_1364a_row7_col1" class="data row7 col1" >1.363636</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_1364a_row8_col0" class="data row8 col0" >0.532354</td>
#       <td id="T_1364a_row8_col1" class="data row8 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_1364a_row9_col0" class="data row9 col0" >10.658510</td>
#       <td id="T_1364a_row9_col1" class="data row9 col1" >2.500000</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_1364a_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_1364a_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1364a_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_1364a_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_1364a_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### removing the NaN values from the resultant dataframe

# %%
# the + operation is UNION of indexes
d31 = d1+d2
# indexs not present in the other dataframe get a NaN
# do you can obvs remove nan values like before
d3.dropna().style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f86ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f86ac_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f86ac_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f86ac_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_f86ac_row0_col0" class="data row0 col0" >1.006153</td>
#       <td id="T_f86ac_row0_col1" class="data row0 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f86ac_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_f86ac_row1_col0" class="data row1 col0" >1.138771</td>
#       <td id="T_f86ac_row1_col1" class="data row1 col1" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f86ac_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_f86ac_row2_col0" class="data row2 col0" >0.901067</td>
#       <td id="T_f86ac_row2_col1" class="data row2 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f86ac_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_f86ac_row3_col0" class="data row3 col0" >0.796070</td>
#       <td id="T_f86ac_row3_col1" class="data row3 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f86ac_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_f86ac_row4_col0" class="data row4 col0" >1.269954</td>
#       <td id="T_f86ac_row4_col1" class="data row4 col1" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f86ac_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_f86ac_row5_col0" class="data row5 col0" >0.912987</td>
#       <td id="T_f86ac_row5_col1" class="data row5 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f86ac_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_f86ac_row6_col0" class="data row6 col0" >1.177924</td>
#       <td id="T_f86ac_row6_col1" class="data row6 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f86ac_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_f86ac_row7_col0" class="data row7 col0" >0.829354</td>
#       <td id="T_f86ac_row7_col1" class="data row7 col1" >14.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## df.align()

# %% [markdown]
# Pandas [align](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.align.html) works to join the dataframes in interesting ways.

# %%
# align returns two dataframes - left and right as a result of a join
# default join is outer - the union of indices will be used as index for left and right
left, right = d1.align(d2, join='outer')
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a2c56" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2c56_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a2c56_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2c56_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_a2c56_row0_col0" class="data row0 col0" >0.430084</td>
#       <td id="T_a2c56_row0_col1" class="data row0 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_a2c56_row1_col0" class="data row1 col0" >0.545293</td>
#       <td id="T_a2c56_row1_col1" class="data row1 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_a2c56_row2_col0" class="data row2 col0" >0.046510</td>
#       <td id="T_a2c56_row2_col1" class="data row2 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_a2c56_row3_col0" class="data row3 col0" >0.631373</td>
#       <td id="T_a2c56_row3_col1" class="data row3 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_a2c56_row4_col0" class="data row4 col0" >0.433272</td>
#       <td id="T_a2c56_row4_col1" class="data row4 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_a2c56_row5_col0" class="data row5 col0" >0.730765</td>
#       <td id="T_a2c56_row5_col1" class="data row5 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_a2c56_row6_col0" class="data row6 col0" >0.770583</td>
#       <td id="T_a2c56_row6_col1" class="data row6 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_a2c56_row7_col0" class="data row7 col0" >0.545575</td>
#       <td id="T_a2c56_row7_col1" class="data row7 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_a2c56_row8_col0" class="data row8 col0" >0.409222</td>
#       <td id="T_a2c56_row8_col1" class="data row8 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_a2c56_row9_col0" class="data row9 col0" >0.758217</td>
#       <td id="T_a2c56_row9_col1" class="data row9 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_a2c56_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_a2c56_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a2c56_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_a2c56_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_a2c56_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_498e9" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_498e9_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_498e9_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_498e9_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_498e9_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_498e9_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_498e9_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_498e9_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_498e9_row2_col0" class="data row2 col0" >0.959643</td>
#       <td id="T_498e9_row2_col1" class="data row2 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_498e9_row3_col0" class="data row3 col0" >0.507397</td>
#       <td id="T_498e9_row3_col1" class="data row3 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_498e9_row4_col0" class="data row4 col0" >0.467795</td>
#       <td id="T_498e9_row4_col1" class="data row4 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_498e9_row5_col0" class="data row5 col0" >0.065305</td>
#       <td id="T_498e9_row5_col1" class="data row5 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_498e9_row6_col0" class="data row6 col0" >0.499371</td>
#       <td id="T_498e9_row6_col1" class="data row6 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_498e9_row7_col0" class="data row7 col0" >0.367412</td>
#       <td id="T_498e9_row7_col1" class="data row7 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_498e9_row8_col0" class="data row8 col0" >0.768702</td>
#       <td id="T_498e9_row8_col1" class="data row8 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_498e9_row9_col0" class="data row9 col0" >0.071137</td>
#       <td id="T_498e9_row9_col1" class="data row9 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_498e9_row10_col0" class="data row10 col0" >0.451604</td>
#       <td id="T_498e9_row10_col1" class="data row10 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_498e9_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_498e9_row11_col0" class="data row11 col0" >0.794146</td>
#       <td id="T_498e9_row11_col1" class="data row11 col1" >20.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# inner join
left, right = d1.align(d2, join='inner')
render_df_side_by_side(d1,d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_05976" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05976_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_05976_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05976_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_05976_row0_col0" class="data row0 col0" >0.430084</td>
#       <td id="T_05976_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_05976_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_05976_row1_col0" class="data row1 col0" >0.545293</td>
#       <td id="T_05976_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_05976_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_05976_row2_col0" class="data row2 col0" >0.046510</td>
#       <td id="T_05976_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_05976_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_05976_row3_col0" class="data row3 col0" >0.631373</td>
#       <td id="T_05976_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_05976_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_05976_row4_col0" class="data row4 col0" >0.433272</td>
#       <td id="T_05976_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_05976_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_05976_row5_col0" class="data row5 col0" >0.730765</td>
#       <td id="T_05976_row5_col1" class="data row5 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_05976_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_05976_row6_col0" class="data row6 col0" >0.770583</td>
#       <td id="T_05976_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_05976_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_05976_row7_col0" class="data row7 col0" >0.545575</td>
#       <td id="T_05976_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_05976_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_05976_row8_col0" class="data row8 col0" >0.409222</td>
#       <td id="T_05976_row8_col1" class="data row8 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_05976_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_05976_row9_col0" class="data row9 col0" >0.758217</td>
#       <td id="T_05976_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_11955" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11955_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_11955_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11955_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_11955_row0_col0" class="data row0 col0" >0.959643</td>
#       <td id="T_11955_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_11955_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_11955_row1_col0" class="data row1 col0" >0.507397</td>
#       <td id="T_11955_row1_col1" class="data row1 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_11955_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_11955_row2_col0" class="data row2 col0" >0.467795</td>
#       <td id="T_11955_row2_col1" class="data row2 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_11955_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_11955_row3_col0" class="data row3 col0" >0.065305</td>
#       <td id="T_11955_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_11955_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_11955_row4_col0" class="data row4 col0" >0.499371</td>
#       <td id="T_11955_row4_col1" class="data row4 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_11955_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_11955_row5_col0" class="data row5 col0" >0.367412</td>
#       <td id="T_11955_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_11955_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_11955_row6_col0" class="data row6 col0" >0.768702</td>
#       <td id="T_11955_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_11955_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_11955_row7_col0" class="data row7 col0" >0.071137</td>
#       <td id="T_11955_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_11955_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_11955_row8_col0" class="data row8 col0" >0.451604</td>
#       <td id="T_11955_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_11955_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_11955_row9_col0" class="data row9 col0" >0.794146</td>
#       <td id="T_11955_row9_col1" class="data row9 col1" >20</td>
#     </tr>
#   </tbody>
# </table>

# %%
# we can fill the NaNs with a certain value if needed
# let's fill with -100 so we can see it clearly
left, right = d1.align(d2, join='outer', fill_value = -100) 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3647e" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3647e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_3647e_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3647e_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_3647e_row0_col0" class="data row0 col0" >0.430084</td>
#       <td id="T_3647e_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_3647e_row1_col0" class="data row1 col0" >0.545293</td>
#       <td id="T_3647e_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_3647e_row2_col0" class="data row2 col0" >0.046510</td>
#       <td id="T_3647e_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_3647e_row3_col0" class="data row3 col0" >0.631373</td>
#       <td id="T_3647e_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_3647e_row4_col0" class="data row4 col0" >0.433272</td>
#       <td id="T_3647e_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_3647e_row5_col0" class="data row5 col0" >0.730765</td>
#       <td id="T_3647e_row5_col1" class="data row5 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_3647e_row6_col0" class="data row6 col0" >0.770583</td>
#       <td id="T_3647e_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_3647e_row7_col0" class="data row7 col0" >0.545575</td>
#       <td id="T_3647e_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_3647e_row8_col0" class="data row8 col0" >0.409222</td>
#       <td id="T_3647e_row8_col1" class="data row8 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_3647e_row9_col0" class="data row9 col0" >0.758217</td>
#       <td id="T_3647e_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_3647e_row10_col0" class="data row10 col0" >-100.000000</td>
#       <td id="T_3647e_row10_col1" class="data row10 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_3647e_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_3647e_row11_col0" class="data row11 col0" >-100.000000</td>
#       <td id="T_3647e_row11_col1" class="data row11 col1" >-100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1936b" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1936b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_1936b_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1936b_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_1936b_row0_col0" class="data row0 col0" >-100.000000</td>
#       <td id="T_1936b_row0_col1" class="data row0 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_1936b_row1_col0" class="data row1 col0" >-100.000000</td>
#       <td id="T_1936b_row1_col1" class="data row1 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_1936b_row2_col0" class="data row2 col0" >0.959643</td>
#       <td id="T_1936b_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_1936b_row3_col0" class="data row3 col0" >0.507397</td>
#       <td id="T_1936b_row3_col1" class="data row3 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_1936b_row4_col0" class="data row4 col0" >0.467795</td>
#       <td id="T_1936b_row4_col1" class="data row4 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_1936b_row5_col0" class="data row5 col0" >0.065305</td>
#       <td id="T_1936b_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_1936b_row6_col0" class="data row6 col0" >0.499371</td>
#       <td id="T_1936b_row6_col1" class="data row6 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_1936b_row7_col0" class="data row7 col0" >0.367412</td>
#       <td id="T_1936b_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_1936b_row8_col0" class="data row8 col0" >0.768702</td>
#       <td id="T_1936b_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_1936b_row9_col0" class="data row9 col0" >0.071137</td>
#       <td id="T_1936b_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_1936b_row10_col0" class="data row10 col0" >0.451604</td>
#       <td id="T_1936b_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1936b_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_1936b_row11_col0" class="data row11 col0" >0.794146</td>
#       <td id="T_1936b_row11_col1" class="data row11 col1" >20</td>
#     </tr>
#   </tbody>
# </table>

# %%
# left join: left index is added to right, but not the other way
left, right = d1.align(d2, join='left') 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0bea8" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bea8_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0bea8_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bea8_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_0bea8_row0_col0" class="data row0 col0" >0.430084</td>
#       <td id="T_0bea8_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_0bea8_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_0bea8_row1_col0" class="data row1 col0" >0.545293</td>
#       <td id="T_0bea8_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_0bea8_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_0bea8_row2_col0" class="data row2 col0" >0.046510</td>
#       <td id="T_0bea8_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_0bea8_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_0bea8_row3_col0" class="data row3 col0" >0.631373</td>
#       <td id="T_0bea8_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0bea8_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_0bea8_row4_col0" class="data row4 col0" >0.433272</td>
#       <td id="T_0bea8_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_0bea8_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_0bea8_row5_col0" class="data row5 col0" >0.730765</td>
#       <td id="T_0bea8_row5_col1" class="data row5 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_0bea8_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_0bea8_row6_col0" class="data row6 col0" >0.770583</td>
#       <td id="T_0bea8_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_0bea8_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_0bea8_row7_col0" class="data row7 col0" >0.545575</td>
#       <td id="T_0bea8_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_0bea8_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_0bea8_row8_col0" class="data row8 col0" >0.409222</td>
#       <td id="T_0bea8_row8_col1" class="data row8 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_0bea8_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_0bea8_row9_col0" class="data row9 col0" >0.758217</td>
#       <td id="T_0bea8_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0d150" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d150_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0d150_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d150_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_0d150_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_0d150_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d150_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_0d150_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_0d150_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d150_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_0d150_row2_col0" class="data row2 col0" >0.959643</td>
#       <td id="T_0d150_row2_col1" class="data row2 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d150_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_0d150_row3_col0" class="data row3 col0" >0.507397</td>
#       <td id="T_0d150_row3_col1" class="data row3 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d150_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_0d150_row4_col0" class="data row4 col0" >0.467795</td>
#       <td id="T_0d150_row4_col1" class="data row4 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d150_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_0d150_row5_col0" class="data row5 col0" >0.065305</td>
#       <td id="T_0d150_row5_col1" class="data row5 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d150_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_0d150_row6_col0" class="data row6 col0" >0.499371</td>
#       <td id="T_0d150_row6_col1" class="data row6 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d150_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_0d150_row7_col0" class="data row7 col0" >0.367412</td>
#       <td id="T_0d150_row7_col1" class="data row7 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d150_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_0d150_row8_col0" class="data row8 col0" >0.768702</td>
#       <td id="T_0d150_row8_col1" class="data row8 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d150_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_0d150_row9_col0" class="data row9 col0" >0.071137</td>
#       <td id="T_0d150_row9_col1" class="data row9 col1" >4.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# right join: right index is added to left, but not the other way
left, right = d1.align(d2, join='right') 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e604" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e604_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0e604_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e604_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_0e604_row0_col0" class="data row0 col0" >0.046510</td>
#       <td id="T_0e604_row0_col1" class="data row0 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e604_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_0e604_row1_col0" class="data row1 col0" >0.631373</td>
#       <td id="T_0e604_row1_col1" class="data row1 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e604_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_0e604_row2_col0" class="data row2 col0" >0.433272</td>
#       <td id="T_0e604_row2_col1" class="data row2 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e604_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_0e604_row3_col0" class="data row3 col0" >0.730765</td>
#       <td id="T_0e604_row3_col1" class="data row3 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e604_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_0e604_row4_col0" class="data row4 col0" >0.770583</td>
#       <td id="T_0e604_row4_col1" class="data row4 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e604_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_0e604_row5_col0" class="data row5 col0" >0.545575</td>
#       <td id="T_0e604_row5_col1" class="data row5 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e604_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_0e604_row6_col0" class="data row6 col0" >0.409222</td>
#       <td id="T_0e604_row6_col1" class="data row6 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e604_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_0e604_row7_col0" class="data row7 col0" >0.758217</td>
#       <td id="T_0e604_row7_col1" class="data row7 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e604_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_0e604_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_0e604_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0e604_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_0e604_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_0e604_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_25306" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25306_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_25306_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25306_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_25306_row0_col0" class="data row0 col0" >0.959643</td>
#       <td id="T_25306_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_25306_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_25306_row1_col0" class="data row1 col0" >0.507397</td>
#       <td id="T_25306_row1_col1" class="data row1 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_25306_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_25306_row2_col0" class="data row2 col0" >0.467795</td>
#       <td id="T_25306_row2_col1" class="data row2 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_25306_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_25306_row3_col0" class="data row3 col0" >0.065305</td>
#       <td id="T_25306_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_25306_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_25306_row4_col0" class="data row4 col0" >0.499371</td>
#       <td id="T_25306_row4_col1" class="data row4 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_25306_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_25306_row5_col0" class="data row5 col0" >0.367412</td>
#       <td id="T_25306_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_25306_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_25306_row6_col0" class="data row6 col0" >0.768702</td>
#       <td id="T_25306_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_25306_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_25306_row7_col0" class="data row7 col0" >0.071137</td>
#       <td id="T_25306_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_25306_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_25306_row8_col0" class="data row8 col0" >0.451604</td>
#       <td id="T_25306_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_25306_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_25306_row9_col0" class="data row9 col0" >0.794146</td>
#       <td id="T_25306_row9_col1" class="data row9 col1" >20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's more to explore in align, and it can get confusing, so beginners be careful, take time and try to work out the result before you execute to build intuition.

# %% [markdown]
# # Operations on data

# %% [markdown]
# ## Stats
#
# Operations in general *exclude* missing data

# %%
# arithmetic mean, for each column (axis = 0)
df.mean()
# Out:
# A    -0.039910
# B     0.479927
# C     0.034989
# D     0.464988
# F    15.500000
# dtype: float64

# %%
# mean across a row (axis = 1)
df.mean(1)
# Out:
# 2022-06-19    2.531159
# 2022-06-20    2.478679
# 2022-06-21    2.709516
# 2022-06-22    2.937072
# 2022-06-23    2.755452
# 2022-06-24    3.133737
# 2022-06-25    3.882749
# 2022-06-26    4.409170
# 2022-06-27    4.150420
# 2022-06-28    3.892035
# Freq: D, dtype: float64

# %% [markdown]
# ## Apply

# %%
# apply custom lambdas
df.apply(lambda x: x.max()-x.min())
# Out:
# A    3.086249
# B    4.746826
# C    3.842919
# D    2.399531
# F    9.000000
# dtype: float64

# %%
df
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.764275  0.639359 -1.491131  1.743294  11
# 2022-06-20  0.581449  0.483441 -0.628048 -0.043447  12
# 2022-06-21 -0.892187  1.575049 -0.384668  0.249386  13
# 2022-06-22 -1.186891  2.585244 -0.205609 -0.507384  14
# 2022-06-23 -0.169059 -1.118121 -0.132503  0.196941  15
# 2022-06-24  0.535363 -2.161582 -0.597246  1.892147  16
# 2022-06-25  0.520072  1.222413  1.033341 -0.362083  17
# 2022-06-26  1.146817  1.973952 -0.025774  0.950857  18
# 2022-06-27  0.240491  0.173858  0.429743  0.908007  19
# 2022-06-28 -1.939432 -0.574338  2.351789 -0.377841  20

# %%
# each subsequent value is a sum of all values before it in the respective column
cumsum_df = df.apply(np.cumsum)
render_df_side_by_side(df, cumsum_df, "OG Dataframe", "Cumulative Sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_356f2" style='display:inline'>
#   <caption>OG Dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_356f2_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_356f2_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_356f2_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_356f2_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_356f2_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_356f2_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_356f2_row0_col0" class="data row0 col0" >0.764275</td>
#       <td id="T_356f2_row0_col1" class="data row0 col1" >0.639359</td>
#       <td id="T_356f2_row0_col2" class="data row0 col2" >-1.491131</td>
#       <td id="T_356f2_row0_col3" class="data row0 col3" >1.743294</td>
#       <td id="T_356f2_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_356f2_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_356f2_row1_col0" class="data row1 col0" >0.581449</td>
#       <td id="T_356f2_row1_col1" class="data row1 col1" >0.483441</td>
#       <td id="T_356f2_row1_col2" class="data row1 col2" >-0.628048</td>
#       <td id="T_356f2_row1_col3" class="data row1 col3" >-0.043447</td>
#       <td id="T_356f2_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_356f2_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_356f2_row2_col0" class="data row2 col0" >-0.892187</td>
#       <td id="T_356f2_row2_col1" class="data row2 col1" >1.575049</td>
#       <td id="T_356f2_row2_col2" class="data row2 col2" >-0.384668</td>
#       <td id="T_356f2_row2_col3" class="data row2 col3" >0.249386</td>
#       <td id="T_356f2_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_356f2_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_356f2_row3_col0" class="data row3 col0" >-1.186891</td>
#       <td id="T_356f2_row3_col1" class="data row3 col1" >2.585244</td>
#       <td id="T_356f2_row3_col2" class="data row3 col2" >-0.205609</td>
#       <td id="T_356f2_row3_col3" class="data row3 col3" >-0.507384</td>
#       <td id="T_356f2_row3_col4" class="data row3 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_356f2_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_356f2_row4_col0" class="data row4 col0" >-0.169059</td>
#       <td id="T_356f2_row4_col1" class="data row4 col1" >-1.118121</td>
#       <td id="T_356f2_row4_col2" class="data row4 col2" >-0.132503</td>
#       <td id="T_356f2_row4_col3" class="data row4 col3" >0.196941</td>
#       <td id="T_356f2_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_356f2_level0_row5" class="row_heading level0 row5" >2022-06-24 00:00:00</th>
#       <td id="T_356f2_row5_col0" class="data row5 col0" >0.535363</td>
#       <td id="T_356f2_row5_col1" class="data row5 col1" >-2.161582</td>
#       <td id="T_356f2_row5_col2" class="data row5 col2" >-0.597246</td>
#       <td id="T_356f2_row5_col3" class="data row5 col3" >1.892147</td>
#       <td id="T_356f2_row5_col4" class="data row5 col4" >16</td>
#     </tr>
#     <tr>
#       <th id="T_356f2_level0_row6" class="row_heading level0 row6" >2022-06-25 00:00:00</th>
#       <td id="T_356f2_row6_col0" class="data row6 col0" >0.520072</td>
#       <td id="T_356f2_row6_col1" class="data row6 col1" >1.222413</td>
#       <td id="T_356f2_row6_col2" class="data row6 col2" >1.033341</td>
#       <td id="T_356f2_row6_col3" class="data row6 col3" >-0.362083</td>
#       <td id="T_356f2_row6_col4" class="data row6 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_356f2_level0_row7" class="row_heading level0 row7" >2022-06-26 00:00:00</th>
#       <td id="T_356f2_row7_col0" class="data row7 col0" >1.146817</td>
#       <td id="T_356f2_row7_col1" class="data row7 col1" >1.973952</td>
#       <td id="T_356f2_row7_col2" class="data row7 col2" >-0.025774</td>
#       <td id="T_356f2_row7_col3" class="data row7 col3" >0.950857</td>
#       <td id="T_356f2_row7_col4" class="data row7 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_356f2_level0_row8" class="row_heading level0 row8" >2022-06-27 00:00:00</th>
#       <td id="T_356f2_row8_col0" class="data row8 col0" >0.240491</td>
#       <td id="T_356f2_row8_col1" class="data row8 col1" >0.173858</td>
#       <td id="T_356f2_row8_col2" class="data row8 col2" >0.429743</td>
#       <td id="T_356f2_row8_col3" class="data row8 col3" >0.908007</td>
#       <td id="T_356f2_row8_col4" class="data row8 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_356f2_level0_row9" class="row_heading level0 row9" >2022-06-28 00:00:00</th>
#       <td id="T_356f2_row9_col0" class="data row9 col0" >-1.939432</td>
#       <td id="T_356f2_row9_col1" class="data row9 col1" >-0.574338</td>
#       <td id="T_356f2_row9_col2" class="data row9 col2" >2.351789</td>
#       <td id="T_356f2_row9_col3" class="data row9 col3" >-0.377841</td>
#       <td id="T_356f2_row9_col4" class="data row9 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_46da8" style='display:inline'>
#   <caption>Cumulative Sum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46da8_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_46da8_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_46da8_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_46da8_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_46da8_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46da8_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_46da8_row0_col0" class="data row0 col0" >0.764275</td>
#       <td id="T_46da8_row0_col1" class="data row0 col1" >0.639359</td>
#       <td id="T_46da8_row0_col2" class="data row0 col2" >-1.491131</td>
#       <td id="T_46da8_row0_col3" class="data row0 col3" >1.743294</td>
#       <td id="T_46da8_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_46da8_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_46da8_row1_col0" class="data row1 col0" >1.345724</td>
#       <td id="T_46da8_row1_col1" class="data row1 col1" >1.122799</td>
#       <td id="T_46da8_row1_col2" class="data row1 col2" >-2.119179</td>
#       <td id="T_46da8_row1_col3" class="data row1 col3" >1.699847</td>
#       <td id="T_46da8_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_46da8_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_46da8_row2_col0" class="data row2 col0" >0.453537</td>
#       <td id="T_46da8_row2_col1" class="data row2 col1" >2.697848</td>
#       <td id="T_46da8_row2_col2" class="data row2 col2" >-2.503846</td>
#       <td id="T_46da8_row2_col3" class="data row2 col3" >1.949233</td>
#       <td id="T_46da8_row2_col4" class="data row2 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_46da8_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_46da8_row3_col0" class="data row3 col0" >-0.733354</td>
#       <td id="T_46da8_row3_col1" class="data row3 col1" >5.283092</td>
#       <td id="T_46da8_row3_col2" class="data row3 col2" >-2.709455</td>
#       <td id="T_46da8_row3_col3" class="data row3 col3" >1.441849</td>
#       <td id="T_46da8_row3_col4" class="data row3 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_46da8_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_46da8_row4_col0" class="data row4 col0" >-0.902413</td>
#       <td id="T_46da8_row4_col1" class="data row4 col1" >4.164971</td>
#       <td id="T_46da8_row4_col2" class="data row4 col2" >-2.841958</td>
#       <td id="T_46da8_ro

# %% [markdown]
# ## Histogramming
#
# Frequencies, 'nuff said
#
# ```value_counts()```

# %%
series1 = pd.Series(np.random.randint(0,5, size = 25))
series1.value_counts()
# Out:
# 4    7
# 1    7
# 3    6
# 0    3
# 2    2
# dtype: int64

# %% [markdown]
# ## String Methods

# %%
# build a series
some_string = "SERIes and Index are EqUIppeD WITh A seT Of stRINg PROCESSING METHoDs In tHe ```sTR``` attrIBute THAT MakE IT eASy To oPerATE ON EACh ELEmeNt OF The aRrAY. NOtE thAt PAtTERN-maTching in ```sTR``` gENeralLY UsES reGUlAr eXpreSsiONs bY DEfault (aND In Some cases AlwayS uSEs tHeM)."
str_series = pd.Series(some_string.split()) # split splits on whitespace by default

# %%
# manipulating the case - lower, upper etc.
# also the length of each string, split, replace, yada yada...
# very important when cleaning data (column names may have stupid whitespace, bad case, spacing etc.)
low = str_series.str.lower()
up = str_series.str.upper()

low_up_df = pd.DataFrame(
    {
        'og': str_series,
        'length': str_series.str.len(),
        'low': low,
        'up': up,
        'split_low_on_i': low.str.split('i', expand = False), # expand = True will break this usecase, try elsewhere
        'replace_a_with_star_in_low': low.str.replace('a','*', case=False, regex=True) # yeah, you can mess with regular expns
    })

low_up_df.tail(10)
# Out:
#              og  length          low           up  split_low_on_i  \
# 36  eXpreSsiONs      11  expressions  EXPRESSIONS  [express, ons]
# 37           bY       2           by           BY            [by]
# 38      DEfault       7      default      DEFAULT       [default]
# 39         (aND       4         (and         (AND          [(and]
# 40           In       2           in           IN           [, n]
# 41         Some       4         some         SOME          [some]
# 42        cases       5        cases        CASES         [cases]
# 43       AlwayS       6       always       ALWAYS        [always]
# 44         uSEs       4         uses         USES          [uses]
# 45       tHeM).       6       them).       THEM).        [them).]
#
#    replace_a_with_star_in_low
# 36                expressions
# 37                         by
# 38                    def*ult
# 39                       (*nd
# 40                         in
# 41                       some
# 42                      c*ses
# 43                     *lw*ys
# 44                       uses
# 45                     them).

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods) for more string operations.

# %% [markdown]
# # Merge
#
# Combine series and dataframes, use set logic for indexes and relational algebra for joins/merges

# %% [markdown]
# ## Concat
#
# Chill, we've done this before. The same join = inner/outer/left/right drill.

# %%
# let's make some more dataframes
concatDF = pd.DataFrame(np.random.randn(10,4)) # 10 rows and 4 columns of random numbers
pieces = [concatDF[:3], concatDF[3:7], concatDF[7:]]
reconstructedDF = pd.concat(pieces)
display('broken DFs: ',pieces)
render_df_side_by_side(concatDF, reconstructedDF, "OG", "Concatenated")
# Out:
# 'broken DFs: '
# [          0         1         2         3
#  0  0.290698  0.325834  0.474231 -1.498351
#  1 -1.087647 -1.369251  1.046744  1.282989
#  2  0.270277  0.122065  0.196379 -0.824481,
#            0         1         2         3
#  3 -1.480706 -0.592694 -0.510531 -0.911723
#  4  0.243441  0.264993  0.635155  0.456407
#  5  0.745012  0.328708 -0.757377  0.784530
#  6 -3.200286  0.649432 -2.230700 -1.278689,
#            0         1         2         3
#  7 -0.356644  1.961462 -0.013131  1.842533
#  8  1.876501 -0.481298 -0.571839 -0.763704
#  9  1.129902  1.074860 -0.941922 -0.575918]
# <style type="text/css">
# </style>
# <table id="T_7881c" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7881c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7881c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7881c_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_7881c_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7881c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7881c_row0_col0" class="data row0 col0" >0.290698</td>
#       <td id="T_7881c_row0_col1" class="data row0 col1" >0.325834</td>
#       <td id="T_7881c_row0_col2" class="data row0 col2" >0.474231</td>
#       <td id="T_7881c_row0_col3" class="data row0 col3" >-1.498351</td>
#     </tr>
#     <tr>
#       <th id="T_7881c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7881c_row1_col0" class="data row1 col0" >-1.087647</td>
#       <td id="T_7881c_row1_col1" class="data row1 col1" >-1.369251</td>
#       <td id="T_7881c_row1_col2" class="data row1 col2" >1.046744</td>
#       <td id="T_7881c_row1_col3" class="data row1 col3" >1.282989</td>
#     </tr>
#     <tr>
#       <th id="T_7881c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7881c_row2_col0" class="data row2 col0" >0.270277</td>
#       <td id="T_7881c_row2_col1" class="data row2 col1" >0.122065</td>
#       <td id="T_7881c_row2_col2" class="data row2 col2" >0.196379</td>
#       <td id="T_7881c_row2_col3" class="data row2 col3" >-0.824481</td>
#     </tr>
#     <tr>
#       <th id="T_7881c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7881c_row3_col0" class="data row3 col0" >-1.480706</td>
#       <td id="T_7881c_row3_col1" class="data row3 col1" >-0.592694</td>
#       <td id="T_7881c_row3_col2" class="data row3 col2" >-0.510531</td>
#       <td id="T_7881c_row3_col3" class="data row3 col3" >-0.911723</td>
#     </tr>
#     <tr>
#       <th id="T_7881c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7881c_row4_col0" class="data row4 col0" >0.243441</td>
#       <td id="T_7881c_row4_col1" class="data row4 col1" >0.264993</td>
#       <td id="T_7881c_row4_col2" class="data row4 col2" >0.635155</td>
#       <td id="T_7881c_row4_col3" class="data row4 col3" >0.456407</td>
#     </tr>
#     <tr>
#       <th id="T_7881c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7881c_row5_col0" class="data row5 col0" >0.745012</td>
#       <td id="T_7881c_row5_col1" class="data row5 col1" >0.328708</td>
#       <td id="T_7881c_row5_col2" class="data row5 col2" >-0.757377</td>
#       <td id="T_7881c_row5_col3" class="data row5 col3" >0.784530</td>
#     </tr>
#     <tr>
#       <th id="T_7881c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7881c_row6_col0" class="data row6 col0" >-3.200286</td>
#       <td id="T_7881c_row6_col1" class="data row6 col1" >0.649432</td>
#       <td id="T_7881c_row6_col2" class="data row6 col2" >-2.230700</td>
#       <td id="T_7881c_row6_col3" class="data row6 col3" >-1.278689</td>
#     </tr>
#     <tr>
#       <th id="T_7881c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7881c_row7_col0" class="data row7 col0" >-0.356644</td>
#       <td id="T_7881c_row7_col1" class="data row7 col1" >1.961462</td>
#       <td id="T_7881c_row7_col2" class="data row7 col2" >-0.013131</td>
#       <td id="T_7881c_row7_col3" class="data row7 col3" >1.842533</td>
#     </tr>
#     <tr>
#       <th id="T_7881c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7881c_row8_col0" class="data row8 col0" >1.876501</td>
#       <td id="T_7881c_row8_col1" class="data row8 col1" >-0.481298</td>
#       <td id="T_7881c_row8_col2" class="data row8 col2" >-0.571839</td>
#       <td id="T_7881c_row8_col3" class="data row8 col3" >-0.763704</td>
#     </tr>
#     <tr>
#       <th id="T_7881c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7881c_row9_col0" class="data row9 col0" >1.129902</td>
#       <td id="T_7881c_row9_col1" class="data row9 col1" >1.074860</td>
#       <td id="T_7881c_row9_col2" class="data row9 col2" >-0.941922</td>
#       <td id="T_7881c_row9_col3" class="data row9 col3" >-0.575918</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6fe74" style='display:inline'>
#   <caption>Concatenated</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fe74_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6fe74_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6fe74_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_6fe74_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fe74_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fe74_row0_col0" class="data row0 col0" >0.290698</td>
#       <td id="T_6fe74_row0_col1" class="data row0 col1" >0.325834</td>
#       <td id="T_6fe74_row0_col2" class="data row0 col2" >0.474231</td>
#       <td id="T_6fe74_row0_col3" class="data row0 col3" >-1.498351</td>
#     </tr>
#     <tr>
#       <th id="T_6fe74_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6fe74_row1_col0" class="data row1 col0" >-1.087647</td>
#       <td id="T_6fe74_row1_col1" class="data row1 col1" >-1.369251</td>
#       <td id="T_6fe74_row1_col2" class="data row1 col2" >1.046744</td>
#       <td id="T_6fe74_row1_col3" class="data row1 col3" >1.282989</td>
#     </tr>
#     <tr>
#       <th id="T_6fe74_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6fe74_row2_col0" class="data row2 col0" >0.270277</td>
#       <td id="T_6fe74_row2_col1" class="data row2 col1" >0.122065</td>
#       <td id="T_6fe74_row2_col2" class="data row2 col2" >0.196379</td>
#       <td id="T_6fe74_row2_col3" class="data row2 col3" >-0.824481</td>
#     </tr>
#     <tr>
#       <th id="T_6fe74_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6fe74_row3_col0" class="data row3 col0" >-1.480706</td>
#       <td id="T_6fe74_row3_col1" class="data row3 col1" >-0.592694</td>
#       <td id="T_6fe74_row3_col2" class="data row3 col2" >-0.510531</td>
#       <td id="T_6fe74_row3_col3" class="data row3 col3" >-0.911723</td>
#     </tr>
#     <tr>
#       <th id="T_6fe74_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6fe74_row4_col0" class="data row4 col0" >0.243441</td>
#       <td id="T_6fe74_row4_col1" class="data row4 col1" >0.264993</td>
#       <td id="T_6fe74_row4_col2" class="data row4 col2" >0.635155</td>
#       <td id="T_6fe74_row4_col3" class="data row4 col3" >0.456407</td>
#     </tr>
#     <tr>
#       <th id="T_6fe74_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6fe74_row5_col0" class="data row5 col0" >0.745012</td>
#       <td id="T_6fe74_row5_col1" class="data row5 col1" >0.328708</td>
#       <td id="T_6fe74_row5_col2" class="data row5 col2" >-0.757377</td>
#       <td id="T_6fe74_row5_col3" class="data row5 col3" >0.784530</td>
#     </tr>
#     <tr>
#       <th id="T_6fe74_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6fe74_row6_col0" class="data row6 col0" >-3.200286</td>
#       <td id="T_6fe74_row6_col1" class="data row6 col1" >0.649432</td>
#       <td id="T_6fe74_row6_col2" class="data row6 col2" >-2.230700</td>
#       <td id="T_6fe74_row6_col3" class="data row6 col3" >-1.278689</td>
#     </tr>
#     <tr>
#       <th id="T_6fe74_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6fe74_row7_col0" class="data row7 col0" >-0.356644</td>
#       <td id="T_6fe74_row7_col1" class="data row7 col1" >1.961462</td>
#       <td id="T_6fe74_row7_col2" class="data row7 col2" >-0.013131</td>
#       <td id="T_6fe74_row7_col3" class="data row7 col3" >1.842533</td>
#     </tr>
#     <tr>
#       <th id="T_6fe74_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6fe74_row8_col0" class="data row8 col0" >1.

# %% [markdown]
# _From the [page](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#concat)_:
# Adding a column to a DataFrame is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the DataFrame constructor instead of building a DataFrame by iteratively appending records to it.

# %% [markdown]
# ## Join
# SQL style merges.

# %%
# two data frames
sl = pd.Series(np.random.randint(10, size=6))
sr = sl.shift(2).fillna(0).astype(int)
left = pd.DataFrame(
    {
        'key': list('ABCDEF'),
        'lval': sl
    }
)

right = pd.DataFrame(
    {
        'key': list('ABBCDE'),
        'rval': sr
    }
)

# %%
render_df_side_by_side(left, right, 'left', 'right')
# Out:
# <style type="text/css">
# </style>
# <table id="T_34712" style='display:inline'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34712_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_34712_level0_col1" class="col_heading level0 col1" >lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34712_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34712_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_34712_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_34712_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34712_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_34712_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_34712_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34712_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_34712_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_34712_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34712_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_34712_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_34712_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34712_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_34712_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_34712_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34712_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_34712_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1f2ef" style='display:inline'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f2ef_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_1f2ef_level0_col1" class="col_heading level0 col1" >rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f2ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f2ef_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_1f2ef_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1f2ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f2ef_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_1f2ef_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1f2ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1f2ef_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_1f2ef_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1f2ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1f2ef_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_1f2ef_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1f2ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1f2ef_row4_col0" class="data row4 col0" >D</td>
#       <td id="T_1f2ef_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1f2ef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1f2ef_row5_col0" class="data row5 col0" >E</td>
#       <td id="T_1f2ef_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pd.merge(left, right, on='key')
result
# Out:
#   key  lval  rval
# 0   A     3     0
# 1   B     2     0
# 2   B     2     3
# 3   C     3     2
# 4   D     1     3
# 5   E     6     1

# %% [markdown]
# # Grouping

# %% [markdown]
# "Group By" really means one or more of the following happening:
# 1. **Split**: data is broken into groups based on some criteria
# 2. **Apply**: a data operation is executed on each of those groups
# 3. **Combine**: the results are combined back into a data structure

# %%
grp_df = pd.DataFrame(
    {
        'colA': list('AABCAABDAA'),
        'colB': list('1234567890'),
        'colC': np.random.randn(10),
        'colD': np.random.randn(10)
    }
)
grp_df
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.304601 -0.110025
# 1    A    2 -0.390113 -0.216180
# 2    B    3  0.596482 -0.853558
# 3    C    4 -0.166814 -0.686337
# 4    A    5 -0.751692 -0.247513
# 5    A    6 -0.644667  1.229837
# 6    B    7 -1.183478  2.281257
# 7    D    8 -1.509797 -0.797194
# 8    A    9  0.483607 -1.267803
# 9    A    0  0.428926 -0.706965

# %%
# a DataFrameGroupBy object object
grpby = grp_df.groupby('colA')

# list all the groups found
g = grpby.groups
g
# Out:
# {'A': [0, 1, 4, 5, 8, 9], 'B': [2, 6], 'C': [3], 'D': [7]}

# %%
# to create a dataframe from the group use something like
grpby.get_group('A')
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.304601 -0.110025
# 1    A    2 -0.390113 -0.216180
# 4    A    5 -0.751692 -0.247513
# 5    A    6 -0.644667  1.229837
# 8    A    9  0.483607 -1.267803
# 9    A    0  0.428926 -0.706965

# %% [markdown]
# ### Find all the groups

# %%
# but we may not know all the groups in the dataframe.
# so got to find a way to list all groups as dataframes.
# 
# some basic python helps create a list of groupby names
grpby_labels_list = [*g.keys()] # using the unpacking operator *
# alternatively
# grpby_labels_list = list(g.keys())
grpby_labels_list
# Out:
# ['A', 'B', 'C', 'D']

# %%
# create a dict where the group label is the key and the group dataframe is the value
grps = {lbl: grpby.get_group(lbl) for lbl in grpby_labels_list}

# now use the dict to access individual dataframes created out of the groupby operation
grps['B']

# question: can we create a dataframe of dataframes?
# Out:
#   colA colB      colC      colD
# 2    B    3  0.596482 -0.853558
# 6    B    7 -1.183478  2.281257

# %%
# You can see the datatype of the value is a pandas dataframe
type(grps['A'])
# Out:
# pandas.core.frame.DataFrame

# %%
# make a function of it all...
def get_all_groups(df_grpby):
    return {lbl: df_grpby.get_group(lbl) for lbl in list(df_grpby.groups.keys())}

# %%
grps = get_all_groups(grp_df.groupby('colA'))
grps
# Out:
# {'A':   colA colB      colC      colD
#  0    A    1 -0.304601 -0.110025
#  1    A    2 -0.390113 -0.216180
#  4    A    5 -0.751692 -0.247513
#  5    A    6 -0.644667  1.229837
#  8    A    9  0.483607 -1.267803
#  9    A    0  0.428926 -0.706965,
#  'B':   colA colB      colC      colD
#  2    B    3  0.596482 -0.853558
#  6    B    7 -1.183478  2.281257,
#  'C':   colA colB      colC      colD
#  3    C    4 -0.166814 -0.686337,
#  'D':   colA colB      colC      colD
#  7    D    8 -1.509797 -0.797194}

# %%
# get a sum of values from each group
grp_df.groupby('colA').sum()
# Out:
#           colC      colD
# colA
# A    -1.178541 -1.318649
# B    -0.586996  1.427699
# C    -0.166814 -0.686337
# D    -1.509797 -0.797194

# %%
# let's add one more column to the dataframe
# we can try grouping on two columns
grp_df['colE'] = list('1231231231')
grp_df
# Out:
#   colA colB      colC      colD colE
# 0    A    1 -0.304601 -0.110025    1
# 1    A    2 -0.390113 -0.216180    2
# 2    B    3  0.596482 -0.853558    3
# 3    C    4 -0.166814 -0.686337    1
# 4    A    5 -0.751692 -0.247513    2
# 5    A    6 -0.644667  1.229837    3
# 6    B    7 -1.183478  2.281257    1
# 7    D    8 -1.509797 -0.797194    2
# 8    A    9  0.483607 -1.267803    3
# 9    A    0  0.428926 -0.706965    1

# %%
g2 = grp_df.groupby(['colA','colE'])
grps2 = get_all_groups(g2)
grps2
# Out:
# {('A',
#   '1'):   colA colB      colC      colD colE
#  0    A    1 -0.304601 -0.110025    1
#  9    A    0  0.428926 -0.706965    1,
#  ('A',
#   '2'):   colA colB      colC      colD colE
#  1    A    2 -0.390113 -0.216180    2
#  4    A    5 -0.751692 -0.247513    2,
#  ('A',
#   '3'):   colA colB      colC      colD colE
#  5    A    6 -0.644667  1.229837    3
#  8    A    9  0.483607 -1.267803    3,
#  ('B',
#   '1'):   colA colB      colC      colD colE
#  6    B    7 -1.183478  2.281257    1,
#  ('B',
#   '3'):   colA colB      colC      colD colE
#  2    B    3  0.596482 -0.853558    3,
#  ('C',
#   '1'):   colA colB      colC      colD colE
#  3    C    4 -0.166814 -0.686337    1,
#  ('D',
#   '2'):   colA colB      colC      colD colE
#  7    D    8 -1.509797 -0.797194    2}

# %%
render_df_side_by_side(grps2[('A','1')], grps2[('A','2')], 'A,1', 'A,2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_10a55" style='display:inline'>
#   <caption>A,1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10a55_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_10a55_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_10a55_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_10a55_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_10a55_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10a55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10a55_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_10a55_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_10a55_row0_col2" class="data row0 col2" >-0.304601</td>
#       <td id="T_10a55_row0_col3" class="data row0 col3" >-0.110025</td>
#       <td id="T_10a55_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_10a55_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_10a55_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_10a55_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_10a55_row1_col2" class="data row1 col2" >0.428926</td>
#       <td id="T_10a55_row1_col3" class="data row1 col3" >-0.706965</td>
#       <td id="T_10a55_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1092c" style='display:inline'>
#   <caption>A,2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1092c_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_1092c_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_1092c_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_1092c_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_1092c_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1092c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1092c_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_1092c_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_1092c_row0_col2" class="data row0 col2" >-0.390113</td>
#       <td id="T_1092c_row0_col3" class="data row0 col3" >-0.216180</td>
#       <td id="T_1092c_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1092c_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_1092c_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_1092c_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_1092c_row1_col2" class="data row1 col2" >-0.751692</td>
#       <td id="T_1092c_row1_col3" class="data row1 col3" >-0.247513</td>
#       <td id="T_1092c_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reshaping
#
# Stacking and Pivot Tables.
# This really warrants more practice, at least go through [the page](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#)

# %% [markdown]
# ## Stacking

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %% [markdown]
# If the syntax [*expression](https://docs.python.org/dev/reference/expressions.html#calls) appears in the function call, expression must evaluate to an iterable. Elements from these iterables are treated as if they were additional positional arguments.
#
# ...although the *expression syntax may appear after explicit keyword arguments, it is processed before the keyword arguments (and any **expression arguments)

# %%
# starred expressions...
def f(a,b):
    print(a, ' ', b)
    
f (b=1, *(2,)) # works, the tuple (iterable) is expanded, 2 is assigned to a, then b fills the next argument slot
# f (a=1, *(2,)) # FAILS, multiple values for argument 'a'
# Out:
# 2   1

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
stack_idx = pd.MultiIndex.from_tuples(tuples, names = ['first', 'second'])

# %%
stack_df = pd.DataFrame(np.random.randn(8,2), index = stack_idx, columns = ['a','b'])
stack_df
# Out:
#                      a         b
# first second
# bar   one     1.247890 -0.018590
#       two     0.792805  0.396540
# baz   one     0.142108  1.187912
#       two     0.357376 -0.253848
# foo   one    -0.707444  0.434119
#       two    -0.004978 -1.035820
# qux   one     1.834909  0.494462
#       two     0.527301 -1.770904

# %%
# stack really just combines the columns
stacked = stack_df.stack()
stacked
# Out:
# first  second
# bar    one     a    1.247890
#                b   -0.018590
#        two     a    0.792805
#                b    0.396540
# baz    one     a    0.142108
#                b    1.187912
#        two     a    0.357376
#                b   -0.253848
# foo    one     a   -0.707444
#                b    0.434119
#        two     a   -0.004978
#                b   -1.035820
# qux    one     a    1.834909
#                b    0.494462
#        two     a    0.527301
#                b   -1.770904
# dtype: float64

# %%
# unstacked brings back the two columns
# by default unstacks the last level
unstacked = stacked.unstack()
unstacked
# Out:
#                      a         b
# first second
# bar   one     1.247890 -0.018590
#       two     0.792805  0.396540
# baz   one     0.142108  1.187912
#       two     0.357376 -0.253848
# foo   one    -0.707444  0.434119
#       two    -0.004978 -1.035820
# qux   one     1.834909  0.494462
#       two     0.527301 -1.770904

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   a  1.247890  0.792805
#       b -0.018590  0.396540
# baz   a  0.142108  0.357376
#       b  1.187912 -0.253848
# foo   a -0.707444 -0.004978
#       b  0.434119 -1.035820
# qux   a  1.834909  0.527301
#       b  0.494462 -1.770904

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    a  1.247890  0.142108 -0.707444  1.834909
#        b -0.018590  1.187912  0.434119  0.494462
# two    a  0.792805  0.357376 -0.004978  0.527301
#        b  0.396540 -0.253848 -1.035820 -1.770904

# %%
# you can basically pivot the columns and rows using a combination of stack() and unstack()
unstacked.unstack()
# Out:
#                a                   b
# second       one       two       one       two
# first
# bar     1.247890  0.792805 -0.018590  0.396540
# baz     0.142108  0.357376  1.187912 -0.253848
# foo    -0.707444 -0.004978  0.434119 -1.035820
# qux     1.834909  0.527301  0.494462 -1.770904

# %% [markdown]
# ## Pivot Tables

# %%
# we're now just using data created in the pandas documentation - just cause, time.
pivot_tables_df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
pivot_tables_df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.037935 -0.469289
# 1     one  B  foo  0.189130  0.139694
# 2     two  C  foo  1.087976 -1.465117
# 3   three  A  bar -1.391745  1.376082
# 4     one  B  bar -0.823663 -0.775347
# 5     one  C  bar  0.162146  0.071799
# 6     two  A  foo  0.829629 -0.502089
# 7   three  B  foo -0.931291 -0.815416
# 8     one  C  foo  0.861511  1.312100
# 9     one  A  bar -1.044935  0.387598
# 10    two  B  bar -1.357926  0.486459
# 11  three  C  bar  0.294503  0.196110

# %%
# simple pivot tables - data, values to aggregate, index, columns to pivot along
pd.pivot_table(pivot_tables_df, values = 'D', index = ['A', 'B'], columns = ['C'])
# Out:
# C             bar       foo
# A     B
# one   A -1.044935  0.037935
#       B -0.823663  0.189130
#       C  0.162146  0.861511
# three A -1.391745       NaN
#       B       NaN -0.931291
#       C  0.294503       NaN
# two   A       NaN  0.829629
#       B -1.357926       NaN
#       C       NaN  1.087976

# %%
# more'n one columns of values
# mark all NaN as zero (0)
pd.pivot_table(pivot_tables_df, values = ['D', 'E'], index = ['A', 'B'], columns = ['C']).fillna(0)
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A -1.044935  0.037935  0.387598 -0.469289
#       B -0.823663  0.189130 -0.775347  0.139694
#       C  0.162146  0.861511  0.071799  1.312100
# three A -1.391745  0.000000  1.376082  0.000000
#       B  0.000000 -0.931291  0.000000 -0.815416
#       C  0.294503  0.000000  0.196110  0.000000
# two   A  0.000000  0.829629  0.000000 -0.502089
#       B -1.357926  0.000000  0.486459  0.000000
#       C  0.000000  1.087976  0.000000 -1.465117

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# We may need to resample data to a different time-frequency.
# Like get data every second and resample to data every 5 minutes and so on...

# %%
rng = pd.date_range('01/01/2022', periods = 1000, freq = 'S')

# %%
ts = pd.Series(np.random.randint(0,500, len(rng)), index=rng)

# %%
ts.resample('5min').sum()
# Out:
# 2022-01-01 00:00:00    75749
# 2022-01-01 00:05:00    72847
# 2022-01-01 00:10:00    74648
# 2022-01-01 00:15:00    25793
# Freq: 5T, dtype: int32

# %% [markdown]
# read up on [date offset strings](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) like '5min' etc.

# %% [markdown]
# ## Timezones

# %%
# timezone representation
rng2 = pd.date_range('01/01/2022', periods = 500, freq='D')
ts2 = pd.Series(np.random.randint(0,365, len(rng2)), index=rng2)
ts2_utc = ts2.tz_localize('UTC')

# %%
# convert to US/Eastern
ts2_utc.tz_convert('US/Eastern')
# Out:
# 2021-12-31 19:00:00-05:00    312
# 2022-01-01 19:00:00-05:00    244
# 2022-01-02 19:00:00-05:00      8
# 2022-01-03 19:00:00-05:00    155
# 2022-01-04 19:00:00-05:00    328
#                             ...
# 2023-05-10 20:00:00-04:00    323
# 2023-05-11 20:00:00-04:00    242
# 2023-05-12 20:00:00-04:00    321
# 2023-05-13 20:00:00-04:00    140
# 2023-05-14 20:00:00-04:00     73
# Freq: D, Length: 500, dtype: int32

# %% [markdown]
# ## Time span representations
#
# Converting between periods and timestamps.
#
# Period is a _timespan_ - span of time between two timestamps.

# %%
# month - end of each 
rng3 = pd.date_range('01/01/2022', periods = 12, freq='M')
rng3
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts3 = pd.Series(np.random.randn(len(rng3)), index = rng3)
ts3
# Out:
# 2022-01-31   -0.844896
# 2022-02-28   -0.253412
# 2022-03-31    0.274103
# 2022-04-30   -0.497168
# 2022-05-31   -1.103661
# 2022-06-30    0.834969
# 2022-07-31    0.675874
# 2022-08-31   -0.829764
# 2022-09-30   -1.898212
# 2022-10-31    0.285239
# 2022-11-30    0.678720
# 2022-12-31    0.593479
# Freq: M, dtype: float64

# %%
ps = ts3.to_period()
ps
# Out:
# 2022-01   -0.844896
# 2022-02   -0.253412
# 2022-03    0.274103
# 2022-04   -0.497168
# 2022-05   -1.103661
# 2022-06    0.834969
# 2022-07    0.675874
# 2022-08   -0.829764
# 2022-09   -1.898212
# 2022-10    0.285239
# 2022-11    0.678720
# 2022-12    0.593479
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2022-01-01   -0.844896
# 2022-02-01   -0.253412
# 2022-03-01    0.274103
# 2022-04-01   -0.497168
# 2022-05-01   -1.103661
# 2022-06-01    0.834969
# 2022-07-01    0.675874
# 2022-08-01   -0.829764
# 2022-09-01   -1.898212
# 2022-10-01    0.285239
# 2022-11-01    0.678720
# 2022-12-01    0.593479
# Freq: MS, dtype: float64

# %% [markdown]
# A more complex use-case:
# convert a _quarterly frequency_ with _year ending in November_ to _9am_ of _the end of the month_ _following_ the _quarter end_

# %%
prng = pd.period_range('1990Q1', '2022Q4', freq='Q-NOV')
type(prng)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
ts4 = pd.Series(np.random.randn(len(prng)), index=prng)
ts4.head()
# Out:
# 1990Q1    0.946872
# 1990Q2    0.108983
# 1990Q3   -2.244801
# 1990Q4   -0.078195
# 1991Q1   -0.075243
# Freq: Q-NOV, dtype: float64

# %%
ts4.index = (prng.asfreq('M', 'e') +1).asfreq('H', 's')+9
ts4.head()
# Out:
# 1990-03-01 09:00    0.946872
# 1990-06-01 09:00    0.108983
# 1990-09-01 09:00   -2.244801
# 1990-12-01 09:00   -0.078195
# 1991-03-01 09:00   -0.075243
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
#
# [This page](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical).
#
# For e.g., gender, social class, blood type, country affiliation, observation time or rating via Likert scales.
# Categorical data. Categories allow (usually) fixed number of possible values. Categorical data may have some order, but not support numerical operations (for e.g., 'strongly agree', 'agree', 'disagree', 'strongly disagree').

# %%
cat_df = pd.DataFrame(
    {"id": list('123456'), "raw_grade":list('abbaae')}
)
cat_df
# Out:
#   id raw_grade
# 0  1         a
# 1  2         b
# 2  3         b
# 3  4         a
# 4  5         a
# 5  6         e

# %%
# convert the raw_grade col to categories
cat_df['grade'] = cat_df['raw_grade'].astype('category')
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
cat_df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# can give more meaningful names here
# direct assignment to Series.cat.categories()
cat_df['grade'].cat.categories = ['very good', 'meh', 'very bad']
cat_df['grade']
# Out:
# 0    very good
# 1          meh
# 2          meh
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'meh', 'very bad']

# %%
cat_df
# Out:
#   id raw_grade      grade
# 0  1         a  very good
# 1  2         b        meh
# 2  3         b        meh
# 3  4         a  very good
# 4  5         a  very good
# 5  6         e   very bad

# %%
# list of categories 
list(cat_df['grade'].cat.categories)

# categorical.CategoricalAccessor encapsulates all changes to categoricals
# for e.g., set_categories or remove_categories
# dir(cat_df['grade'].cat)
# Out:
# ['very good', 'meh', 'very bad']

# %%
# add more categories
cat_df['grade'] = cat_df['grade'].cat.set_categories(["very bad", "bad", "meh", "good", "very good"])
# new list of categories
list(cat_df['grade'].cat.categories)
# Out:
# ['very bad', 'bad', 'meh', 'good', 'very good']

# %%
# now when we can sort the dataframe in order of categories (not lexical)
sorted_cat_df = cat_df.sort_values(by='grade')
render_df_side_by_side(cat_df, sorted_cat_df, 'OG', 'Sorted')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9e577" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e577_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_9e577_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_9e577_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e577_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e577_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9e577_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_9e577_row0_col2" class="data row0 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_9e577_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e577_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_9e577_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_9e577_row1_col2" class="data row1 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_9e577_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e577_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_9e577_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_9e577_row2_col2" class="data row2 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_9e577_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9e577_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_9e577_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_9e577_row3_col2" class="data row3 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_9e577_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9e577_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_9e577_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_9e577_row4_col2" class="data row4 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_9e577_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9e577_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_9e577_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_9e577_row5_col2" class="data row5 col2" >very bad</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_eb66c" style='display:inline'>
#   <caption>Sorted</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb66c_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_eb66c_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_eb66c_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb66c_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_eb66c_row0_col0" class="data row0 col0" >6</td>
#       <td id="T_eb66c_row0_col1" class="data row0 col1" >e</td>
#       <td id="T_eb66c_row0_col2" class="data row0 col2" >very bad</td>
#     </tr>
#     <tr>
#       <th id="T_eb66c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb66c_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_eb66c_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_eb66c_row1_col2" class="data row1 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_eb66c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb66c_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_eb66c_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_eb66c_row2_col2" class="data row2 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_eb66c_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_eb66c_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_eb66c_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_eb66c_row3_col2" class="data row3 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_eb66c_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_eb66c_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_eb66c_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_eb66c_row4_col2" class="data row4 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_eb66c_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_eb66c_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_eb66c_row5_col1" class="data row5 col1" >a</td>
#       <td id="T_eb66c_row5_col2" class="data row5 col2" >very good</td>
#     </tr>
#   </tbody>
# </table>

# %%
# grouping
cat_grp = cat_df.groupby('grade')
cat_grp.get_group('very good')
# Out:
#   id raw_grade      grade
# 0  1         a  very good
# 3  4         a  very good
# 4  5         a  very good

# %%
# count elements
cat_grp.size()
# Out:
# grade
# very bad     1
# bad          0
# meh          2
# good         0
# very good    3
# dtype: int64
