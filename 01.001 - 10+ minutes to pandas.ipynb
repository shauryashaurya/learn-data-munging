# %% [markdown]
# # Setup
#
# This is following [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) for pandas 1.4.3 but may take a little more than 10 minutes to finish. Lot's of small changes, references etc.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Object creation

# %%
# Series - pass a list to pd.Series
s1 = pd.Series([1, 2, 3, np.nan, 5])

# %%
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
# create an index to use in the dataframe
# default frequency is D (day), so creates a DatetimeIndex of 10 days
dates = pd.date_range('20220619', periods=10)
dates
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# just in case you are wondering, here's [all the "offset aliases"](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases) for Datetime

# %%
# Dataframe - pass a Numpy array
# create a 10 row, 4 col random number array, index by dates, give some column names
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130

# %%
# Create a dataframe by passing a dictionary of objects
# where each object can be converted into a series-like structure
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220619"),
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([3]*6, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train", "test", "train"]),
        "F": list("foofoo"),
        "G": "foo"
    }
)

df2
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %%
# the datatype of each of the columns would be different
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# G            object
# dtype: object

# %% [markdown]
# # Viewing Data

# %%
# top of the dataframe
df.head()
# Out:
#                    A         B         C         D
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277

# %%
# bottom 3 records of the dataframe
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130

# %%
# index of the df
df.index
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# columns of the df
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# .to_numpy gives a NumPy representation of the dataframe
# this is expensive if all columns are of different data type
df.to_numpy()
# Out:
# array([[-1.25442083, -1.43486417,  1.18270559, -0.58958378],
#        [ 0.59874031, -1.01351136, -1.37627094,  1.17858966],
#        [-0.93234468, -0.19276094, -0.50058626,  0.72548088],
#        [ 0.73568502, -1.03607553, -0.05874773,  0.07767679],
#        [-1.0453942 , -1.02624559, -2.06350974,  1.53027666],
#        [-0.07928209, -1.42728668, -1.04624602,  2.19983156],
#        [ 0.38150343, -0.82934187,  0.27736259, -1.44563207],
#        [ 1.19100237, -0.75160124, -2.50910274,  0.50541861],
#        [ 0.37769338, -1.02347392, -0.51095114, -0.97238523],
#        [-1.0450854 ,  0.91581278,  0.46241808, -1.34213005]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo']], dtype=object)

# %%
# quick summary stats
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.107190  -0.781935  -0.614293   0.186754
# std     0.889799   0.692153   1.153426   1.255805
# min    -1.254421  -1.434864  -2.509103  -1.445632
# 25%    -1.016900  -1.033618  -1.293765  -0.876685
# 50%     0.149206  -1.018493  -0.505769   0.291548
# 75%     0.544431  -0.771036   0.193335   1.065312
# max     1.191002   0.915813   1.182706   2.199832

# %% [markdown]
# 1. **count** = Count number of non-NA/null observations
# 1. **max** = Maximum of the values in the object
# 1. **min** = Minimum of the values in the object
# 1. **mean** = Mean of the values
# 1. **std** = Standard deviation of the observations
# 1. **25%** = Default lower percentile
# 1. **50%** = 50 percentile - same as the median
# 1. **75%** = Default upper percentile

# %%
# change the percentiles
df.describe(percentiles=[.1, .5, .9])
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.107190  -0.781935  -0.614293   0.186754
# std     0.889799   0.692153   1.153426   1.255805
# min    -1.254421  -1.434864  -2.509103  -1.445632
# 10%    -1.066297  -1.428044  -2.108069  -1.352480
# 50%     0.149206  -1.018493  -0.505769   0.291548
# 90%     0.781217  -0.081904   0.534447   1.597232
# max     1.191002   0.915813   1.182706   2.199832

# %%
# E, F, G in d2 are not numeric, so do not come up in describe()
df2.describe()
# Out:
#          A    C    D
# count  6.0  6.0  6.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
# transpose the data
# turn rows to columns and vice versa
df.T
# Out:
#    2022-06-19  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# A   -1.254421    0.598740   -0.932345    0.735685   -1.045394   -0.079282
# B   -1.434864   -1.013511   -0.192761   -1.036076   -1.026246   -1.427287
# C    1.182706   -1.376271   -0.500586   -0.058748   -2.063510   -1.046246
# D   -0.589584    1.178590    0.725481    0.077677    1.530277    2.199832
#
#    2022-06-25  2022-06-26  2022-06-27  2022-06-28
# A    0.381503    1.191002    0.377693   -1.045085
# B   -0.829342   -0.751601   -1.023474    0.915813
# C    0.277363   -2.509103   -0.510951    0.462418
# D   -1.445632    0.505419   -0.972385   -1.342130

# %% [markdown]
# ### [Axis in pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html?highlight=set_ax#pandas.DataFrame.set_axis)
#
# ```axis{0 or ‘index’, 1 or ‘columns’}```
#
# Always remember that when you specify:
# * ```axis=0``` or ```axis='index'``` you indicate that the operation should be along the _index_ (aka across the rows). More often than not indexes will go from top to bottom (vertically), but sometimes they may not (for e.g. if you use columns as index or when you have hierarchical or multi-index data).
# * ```axis=1``` or ```axis='columns'``` indicates the operation is along the columns
#
# When in doubt use the explicit version ```'index'``` or ```'columns'``` instead of ```0``` or ```1```

# %%
# sort along the axis - 1 = horizontal
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-06-19 -0.589584  1.182706 -1.434864 -1.254421
# 2022-06-20  1.178590 -1.376271 -1.013511  0.598740
# 2022-06-21  0.725481 -0.500586 -0.192761 -0.932345
# 2022-06-22  0.077677 -0.058748 -1.036076  0.735685
# 2022-06-23  1.530277 -2.063510 -1.026246 -1.045394
# 2022-06-24  2.199832 -1.046246 -1.427287 -0.079282
# 2022-06-25 -1.445632  0.277363 -0.829342  0.381503
# 2022-06-26  0.505419 -2.509103 -0.751601  1.191002
# 2022-06-27 -0.972385 -0.510951 -1.023474  0.377693
# 2022-06-28 -1.342130  0.462418  0.915813 -1.045085

# %%
# sort along the axis - 0 = vertical
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584

# %%
# sort ascending by values in a column
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419

# %%
# sort by non-numerical values
df2.sort_values(by="F", ascending=False)
# Out:
#      A          B    C  D      E  F    G
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo

# %%
# sort by two or more columns
df2.sort_values(by=["F", "E"])
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %% [markdown]
# # Selection

# %% [markdown]
# For production prefer the following instead of other data access methods (typical python methods like ["col"] or [a:b] slices etc.):
#
# ```.at, .iat, .loc and .iloc.```

# %% [markdown]
# ## Getting

# %%
# selecting a single column returns a Series object
df["A"]
# Out:
# 2022-06-19   -1.254421
# 2022-06-20    0.598740
# 2022-06-21   -0.932345
# 2022-06-22    0.735685
# 2022-06-23   -1.045394
# 2022-06-24   -0.079282
# 2022-06-25    0.381503
# 2022-06-26    1.191002
# 2022-06-27    0.377693
# 2022-06-28   -1.045085
# Freq: D, Name: A, dtype: float64

# %%
# selecting a slice
df[1:5]
# Out:
#                    A         B         C         D
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277

# %% [markdown]
# ## Selection by label

# %%
# selecting based on a label
df.loc[dates[0]]
# Out:
# A   -1.254421
# B   -1.434864
# C    1.182706
# D   -0.589584
# Name: 2022-06-19 00:00:00, dtype: float64

# %%
# select on a multi-axis by lable
# I honestly do not know what the comment above means...help!
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-06-19 -1.254421 -1.434864
# 2022-06-20  0.598740 -1.013511
# 2022-06-21 -0.932345 -0.192761
# 2022-06-22  0.735685 -1.036076
# 2022-06-23 -1.045394 -1.026246
# 2022-06-24 -0.079282 -1.427287
# 2022-06-25  0.381503 -0.829342
# 2022-06-26  1.191002 -0.751601
# 2022-06-27  0.377693 -1.023474
# 2022-06-28 -1.045085  0.915813

# %%
# specific index value results in reduction of dimensions
res = df.loc["2022-06-20"]
print(res)
print("res.shape = ", res.shape, " vs. df.shape = ", df.shape)
# Out:
# A    0.598740
# B   -1.013511
# C   -1.376271
# D    1.178590
# Name: 2022-06-20 00:00:00, dtype: float64
# res.shape =  (4,)  vs. df.shape =  (10, 4)

# %%
# get to a specific scalar:
#
# method one
df.loc[dates[0], "A"]
# Out:
# -1.254420834683143

# %%
#
# method two (slightly faster than method one)
df.at[dates[0], "A"]
# Out:
# -1.254420834683143

# %% [markdown]
# ## Selection by position

# %%
df.iloc[2]
# Out:
# A   -0.932345
# B   -0.192761
# C   -0.500586
# D    0.725481
# Name: 2022-06-21 00:00:00, dtype: float64

# %%
# slices - similar to NumPy / Python - [row:slice, col:slice]
df.iloc[1:5, 0:2]
# Out:
#                    A         B
# 2022-06-20  0.598740 -1.013511
# 2022-06-21 -0.932345 -0.192761
# 2022-06-22  0.735685 -1.036076
# 2022-06-23 -1.045394 -1.026246

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
df.iloc[[0, 1, 2, 6], [0, 2]]
# Out:
#                    A         C
# 2022-06-19 -1.254421  1.182706
# 2022-06-20  0.598740 -1.376271
# 2022-06-21 -0.932345 -0.500586
# 2022-06-25  0.381503  0.277363

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
# change the order of columns, repeact a column
df.iloc[[0, 1, 2, 6], [2, 1, 0, 2]]
# Out:
#                    C         B         A         C
# 2022-06-19  1.182706 -1.434864 -1.254421  1.182706
# 2022-06-20 -1.376271 -1.013511  0.598740 -1.376271
# 2022-06-21 -0.500586 -0.192761 -0.932345 -0.500586
# 2022-06-25  0.277363 -0.829342  0.381503  0.277363

# %%
# slice rows explicitly, keep all columns
df.iloc[[1, 2], :]
# Out:
#                    A         B         C         D
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481

# %%
# slice columns, keep all rows
df.iloc[:, [2, 3]]
# Out:
#                    C         D
# 2022-06-19  1.182706 -0.589584
# 2022-06-20 -1.376271  1.178590
# 2022-06-21 -0.500586  0.725481
# 2022-06-22 -0.058748  0.077677
# 2022-06-23 -2.063510  1.530277
# 2022-06-24 -1.046246  2.199832
# 2022-06-25  0.277363 -1.445632
# 2022-06-26 -2.509103  0.505419
# 2022-06-27 -0.510951 -0.972385
# 2022-06-28  0.462418 -1.342130

# %%
# everything, because you can
df.iloc[:, :]
# Out:
#                    A         B         C         D
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130

# %%
# get to a scalar (2 methods, just like before)
#
# method one: use iloc
df.iloc[1, 2]
# Out:
# -1.3762709430378428

# %%
#
# method two: use iat
df.iat[1, 2]
# Out:
# -1.3762709430378428

# %% [markdown]
# ## Boolean Indexing

# %%
# use a value found in a single col to get data
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385

# %%
# boolean across the entire DF - vals that don't match go NaN
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-06-19       NaN       NaN  1.182706       NaN
# 2022-06-20  0.598740       NaN       NaN  1.178590
# 2022-06-21       NaN       NaN       NaN  0.725481
# 2022-06-22  0.735685       NaN       NaN  0.077677
# 2022-06-23       NaN       NaN       NaN  1.530277
# 2022-06-24       NaN       NaN       NaN  2.199832
# 2022-06-25  0.381503       NaN  0.277363       NaN
# 2022-06-26  1.191002       NaN       NaN  0.505419
# 2022-06-27  0.377693       NaN       NaN       NaN
# 2022-06-28       NaN  0.915813  0.462418       NaN

# %%
# add another column
df11 = df.copy()
df11["E"] = ["one", "two", "three", "four",
             "two", "five", "one", "two", "three", "four"]
df11
# Out:
#                    A         B         C         D      E
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584    one
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590    two
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  three
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677   four
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277    two
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832   five
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632    one
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419    two
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385  three
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130   four

# %%
# the isin() query - basically the in clause
df11[df11["E"].isin(["two", "five"])]
# Out:
#                    A         B         C         D     E
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590   two
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277   two
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832  five
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419   two

# %% [markdown]
# ## Setting values

# %%
# matching indexes auto-aligns values
s1 = pd.Series(range(11, 21), index=pd.date_range('20220619', periods=10))
s1
# Out:
# 2022-06-19    11
# 2022-06-20    12
# 2022-06-21    13
# 2022-06-22    14
# 2022-06-23    15
# 2022-06-24    16
# 2022-06-25    17
# 2022-06-26    18
# 2022-06-27    19
# 2022-06-28    20
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584  11
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590  12
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277  15
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832  16
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632  17
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419  18
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385  19
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130  20

# %%
# setting values by label and position
# first let's make a quick copy
df12 = df.copy()
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584  11
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590  12
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277  15
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832  16
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632  17
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419  18
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385  19
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130  20

# %%
# set by label
df12.at[dates[0], "A"] = 0
# set by position
df12.iat[0, 1] = 0
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.000000  0.000000  1.182706 -0.589584  11
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590  12
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277  15
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832  16
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632  17
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419  18
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385  19
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130  20

# %%
# kinda bigger replacement
df12.loc[:, "D"] = np.array([5]*len(df))
df12
# Out:
#                    A         B         C  D   F
# 2022-06-19  0.000000  0.000000  1.182706  5  11
# 2022-06-20  0.598740 -1.013511 -1.376271  5  12
# 2022-06-21 -0.932345 -0.192761 -0.500586  5  13
# 2022-06-22  0.735685 -1.036076 -0.058748  5  14
# 2022-06-23 -1.045394 -1.026246 -2.063510  5  15
# 2022-06-24 -0.079282 -1.427287 -1.046246  5  16
# 2022-06-25  0.381503 -0.829342  0.277363  5  17
# 2022-06-26  1.191002 -0.751601 -2.509103  5  18
# 2022-06-27  0.377693 -1.023474 -0.510951  5  19
# 2022-06-28 -1.045085  0.915813  0.462418  5  20

# %%
# setting values using a boolean selection (aka where clause)
df12[df12 > 0] = -df12
df12
# Out:
#                    A         B         C  D   F
# 2022-06-19  0.000000  0.000000 -1.182706 -5 -11
# 2022-06-20 -0.598740 -1.013511 -1.376271 -5 -12
# 2022-06-21 -0.932345 -0.192761 -0.500586 -5 -13
# 2022-06-22 -0.735685 -1.036076 -0.058748 -5 -14
# 2022-06-23 -1.045394 -1.026246 -2.063510 -5 -15
# 2022-06-24 -0.079282 -1.427287 -1.046246 -5 -16
# 2022-06-25 -0.381503 -0.829342 -0.277363 -5 -17
# 2022-06-26 -1.191002 -0.751601 -2.509103 -5 -18
# 2022-06-27 -0.377693 -1.023474 -0.510951 -5 -19
# 2022-06-28 -1.045085 -0.915813 -0.462418 -5 -20

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### _reindex_
# change/add/delete index on a specified axis, returns a new dataframe

# %%
df13 = df.reindex(index=dates[0:4], columns=list(df.columns)+["G"])
df13
# Out:
#                    A         B         C         D   F   G
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584  11 NaN
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590  12 NaN
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13 NaN
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14 NaN

# %% [markdown]
# ### handling missing data
# 1. _```np.nan```_
# 1. _```pandas.isna()```_
# 1. ```df.dropna()```
# 1. ```df.fillna()```

# %%
# missing data in pandas is np.nan
df13.iat[1, 0] = np.nan
df13.iloc[1:, 5] = np.random.randint(1)
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584  11  NaN
# 2022-06-20       NaN -1.013511 -1.376271  1.178590  12  0.0
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13  0.0
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14  0.0

# %%
# get a boolean mask where values are NaN
df131 = pd.isna(df13)
df131
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# or just
pd.isna(df13)
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# the original is still there
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584  11  NaN
# 2022-06-20       NaN -1.013511 -1.376271  1.178590  12  0.0
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13  0.0
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14  0.0

# %%
# we are going to drop / replace values now, let's make a couple of copies of the dataframe
df132 = df13.copy()
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584  11  NaN
# 2022-06-20       NaN -1.013511 -1.376271  1.178590  12  0.0
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13  0.0
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14  0.0

# %%
# drop rows/columns that have missing data
# by default it returns a new dataframe, you may want to specify inplace=True for modifying current dataframe:
df_no_na = df132.dropna(how="any")
# how=‘any’ : If any NA values are present, drop that row or column.
# how=‘all’ : If all values are NA, drop that row or column.

# %%
# all rows/cols with missing data stripped
df_no_na
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13  0.0
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14  0.0

# %%
# original still intact
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584  11  NaN
# 2022-06-20       NaN -1.013511 -1.376271  1.178590  12  0.0
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13  0.0
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14  0.0

# %%
# drop missing data from original
df132.dropna(how="any", inplace=True)
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13  0.0
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14  0.0

# %%
# fill missing data
df133 = df13.copy()
df133.fillna(np.pi*1000)
# Out:
#                       A         B         C         D   F            G
# 2022-06-19    -1.254421 -1.434864  1.182706 -0.589584  11  3141.592654
# 2022-06-20  3141.592654 -1.013511 -1.376271  1.178590  12     0.000000
# 2022-06-21    -0.932345 -0.192761 -0.500586  0.725481  13     0.000000
# 2022-06-22     0.735685 -1.036076 -0.058748  0.077677  14     0.000000

# %% [markdown]
# # Align and Join

# %% [markdown]
# There needs to be a bigger notebook for this topic.
# You need to know there's "joins" in Pandas just like in the SQL world,
# like join and left join and right join and inner and outer and all that...
# Here we'll explore these in the context of the align function - 'aligning' the indexes of two dataframes.
# Later we'll see these again in the context of _merging_ two data frames.

# %% [markdown]
# ## Create two datasets with _mismatched_ indexes

# %%
# date range indexes
idx1 = pd.date_range('2022-01-01',periods = 10)
# 2022-01-01', '2022-01-02' don't exist in idx2
# '2022-01-11', '2022-01-12' don't exist in idx1
idx2 = pd.date_range('2022-01-03',periods = 10)

# %%
# dataframes from indexes
d1 = pd.DataFrame(index = idx1, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

d2 = pd.DataFrame(index = idx2, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

# %% [markdown]
# ## Quick Aside: Rendering two dataframes side-by-side

# %% [markdown]
# The trick of rendering 2 dataframes side-by-side was from [this](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) stackoverflow question.

# %%
# we gon need to display both data frames side by side, so...
from IPython.display import display_html 
def render_df_side_by_side(a, b, a_title = "", b_title = ""):
    a_styler = a.style.set_table_attributes("style='display:inline'").set_caption(a_title)
    b_styler = b.style.set_table_attributes("style='display:inline'").set_caption(b_title)
    display_html(a_styler._repr_html_()+b_styler._repr_html_(), raw=True)

# %%
render_df_side_by_side(d1,d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_664a6" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_664a6_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_664a6_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_664a6_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_664a6_row0_col0" class="data row0 col0" >0.334246</td>
#       <td id="T_664a6_row0_col1" class="data row0 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_664a6_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_664a6_row1_col0" class="data row1 col0" >0.915275</td>
#       <td id="T_664a6_row1_col1" class="data row1 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_664a6_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_664a6_row2_col0" class="data row2 col0" >0.651394</td>
#       <td id="T_664a6_row2_col1" class="data row2 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_664a6_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_664a6_row3_col0" class="data row3 col0" >0.006219</td>
#       <td id="T_664a6_row3_col1" class="data row3 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_664a6_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_664a6_row4_col0" class="data row4 col0" >0.871732</td>
#       <td id="T_664a6_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_664a6_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_664a6_row5_col0" class="data row5 col0" >0.398248</td>
#       <td id="T_664a6_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_664a6_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_664a6_row6_col0" class="data row6 col0" >0.246332</td>
#       <td id="T_664a6_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_664a6_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_664a6_row7_col0" class="data row7 col0" >0.131168</td>
#       <td id="T_664a6_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_664a6_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_664a6_row8_col0" class="data row8 col0" >0.087849</td>
#       <td id="T_664a6_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_664a6_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_664a6_row9_col0" class="data row9 col0" >0.410720</td>
#       <td id="T_664a6_row9_col1" class="data row9 col1" >22</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_dc84c" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc84c_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_dc84c_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc84c_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_dc84c_row0_col0" class="data row0 col0" >0.226588</td>
#       <td id="T_dc84c_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dc84c_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_dc84c_row1_col0" class="data row1 col0" >0.539733</td>
#       <td id="T_dc84c_row1_col1" class="data row1 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_dc84c_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_dc84c_row2_col0" class="data row2 col0" >0.893120</td>
#       <td id="T_dc84c_row2_col1" class="data row2 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_dc84c_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_dc84c_row3_col0" class="data row3 col0" >0.018046</td>
#       <td id="T_dc84c_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_dc84c_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_dc84c_row4_col0" class="data row4 col0" >0.611021</td>
#       <td id="T_dc84c_row4_col1" class="data row4 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_dc84c_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_dc84c_row5_col0" class="data row5 col0" >0.696396</td>
#       <td id="T_dc84c_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_dc84c_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_dc84c_row6_col0" class="data row6 col0" >0.529217</td>
#       <td id="T_dc84c_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_dc84c_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_dc84c_row7_col0" class="data row7 col0" >0.178199</td>
#       <td id="T_dc84c_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_dc84c_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_dc84c_row8_col0" class="data row8 col0" >0.380462</td>
#       <td id="T_dc84c_row8_col1" class="data row8 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_dc84c_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_dc84c_row9_col0" class="data row9 col0" >0.380887</td>
#       <td id="T_dc84c_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table rendering/styling options is [a bigger discussion](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#) to be tackled later.

# %% [markdown]
# ## .add, .sub, .mul, .div etc.

# %% [markdown]
# flexible wrappers (```add, sub, mul, div, mod, pow```) to arithmetic operators: ```+, -, *, /, //, %, **```

# %%
# the +, -, *, /, //, %, ** operations align indexes to create a UNION of indexes
d3 = d1+d2
d4 = d1.sub(d2) #equivalent to d1-d2
d5 = d1*d2
d6 = d1.div(d2)

# %%
# indexs not present in the other dataframe get a NaN
d3.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_0159c_row0_col0, #T_0159c_row0_col1, #T_0159c_row1_col0, #T_0159c_row1_col1, #T_0159c_row10_col0, #T_0159c_row10_col1, #T_0159c_row11_col0, #T_0159c_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_0159c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0159c_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0159c_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0159c_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_0159c_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_0159c_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_0159c_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_0159c_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_0159c_row2_col0" class="data row2 col0" >0.877982</td>
#       <td id="T_0159c_row2_col1" class="data row2 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_0159c_row3_col0" class="data row3 col0" >0.545952</td>
#       <td id="T_0159c_row3_col1" class="data row3 col1" >39.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_0159c_row4_col0" class="data row4 col0" >1.764852</td>
#       <td id="T_0159c_row4_col1" class="data row4 col1" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_0159c_row5_col0" class="data row5 col0" >0.416294</td>
#       <td id="T_0159c_row5_col1" class="data row5 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_0159c_row6_col0" class="data row6 col0" >0.857353</td>
#       <td id="T_0159c_row6_col1" class="data row6 col1" >45.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_0159c_row7_col0" class="data row7 col0" >0.827564</td>
#       <td id="T_0159c_row7_col1" class="data row7 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_0159c_row8_col0" class="data row8 col0" >0.617066</td>
#       <td id="T_0159c_row8_col1" class="data row8 col1" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_0159c_row9_col0" class="data row9 col0" >0.588919</td>
#       <td id="T_0159c_row9_col1" class="data row9 col1" >37.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_0159c_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_0159c_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0159c_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_0159c_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_0159c_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# sub
d4.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_f18cf_row0_col0, #T_f18cf_row0_col1, #T_f18cf_row1_col0, #T_f18cf_row1_col1, #T_f18cf_row10_col0, #T_f18cf_row10_col1, #T_f18cf_row11_col0, #T_f18cf_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_f18cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f18cf_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f18cf_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f18cf_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_f18cf_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_f18cf_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_f18cf_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_f18cf_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_f18cf_row2_col0" class="data row2 col0" >0.424806</td>
#       <td id="T_f18cf_row2_col1" class="data row2 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_f18cf_row3_col0" class="data row3 col0" >-0.533514</td>
#       <td id="T_f18cf_row3_col1" class="data row3 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_f18cf_row4_col0" class="data row4 col0" >-0.021387</td>
#       <td id="T_f18cf_row4_col1" class="data row4 col1" >-18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_f18cf_row5_col0" class="data row5 col0" >0.380202</td>
#       <td id="T_f18cf_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_f18cf_row6_col0" class="data row6 col0" >-0.364689</td>
#       <td id="T_f18cf_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_f18cf_row7_col0" class="data row7 col0" >-0.565228</td>
#       <td id="T_f18cf_row7_col1" class="data row7 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_f18cf_row8_col0" class="data row8 col0" >-0.441367</td>
#       <td id="T_f18cf_row8_col1" class="data row8 col1" >-13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_f18cf_row9_col0" class="data row9 col0" >0.232521</td>
#       <td id="T_f18cf_row9_col1" class="data row9 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_f18cf_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_f18cf_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f18cf_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_f18cf_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_f18cf_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mul
d5.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_76ab6_row0_col0, #T_76ab6_row0_col1, #T_76ab6_row1_col0, #T_76ab6_row1_col1, #T_76ab6_row10_col0, #T_76ab6_row10_col1, #T_76ab6_row11_col0, #T_76ab6_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_76ab6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76ab6_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_76ab6_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76ab6_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_76ab6_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_76ab6_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_76ab6_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_76ab6_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_76ab6_row2_col0" class="data row2 col0" >0.147598</td>
#       <td id="T_76ab6_row2_col1" class="data row2 col1" >108.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_76ab6_row3_col0" class="data row3 col0" >0.003357</td>
#       <td id="T_76ab6_row3_col1" class="data row3 col1" >374.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_76ab6_row4_col0" class="data row4 col0" >0.778561</td>
#       <td id="T_76ab6_row4_col1" class="data row4 col1" >115.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_76ab6_row5_col0" class="data row5 col0" >0.007187</td>
#       <td id="T_76ab6_row5_col1" class="data row5 col1" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_76ab6_row6_col0" class="data row6 col0" >0.150514</td>
#       <td id="T_76ab6_row6_col1" class="data row6 col1" >506.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_76ab6_row7_col0" class="data row7 col0" >0.091345</td>
#       <td id="T_76ab6_row7_col1" class="data row7 col1" >133.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_76ab6_row8_col0" class="data row8 col0" >0.046491</td>
#       <td id="T_76ab6_row8_col1" class="data row8 col1" >230.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_76ab6_row9_col0" class="data row9 col0" >0.073190</td>
#       <td id="T_76ab6_row9_col1" class="data row9 col1" >330.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_76ab6_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_76ab6_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_76ab6_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_76ab6_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_76ab6_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# div
d6.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_b8a4d_row0_col0, #T_b8a4d_row0_col1, #T_b8a4d_row1_col0, #T_b8a4d_row1_col1, #T_b8a4d_row10_col0, #T_b8a4d_row10_col1, #T_b8a4d_row11_col0, #T_b8a4d_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_b8a4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8a4d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b8a4d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8a4d_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_b8a4d_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_b8a4d_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_b8a4d_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_b8a4d_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_b8a4d_row2_col0" class="data row2 col0" >2.874793</td>
#       <td id="T_b8a4d_row2_col1" class="data row2 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_b8a4d_row3_col0" class="data row3 col0" >0.011522</td>
#       <td id="T_b8a4d_row3_col1" class="data row3 col1" >1.294118</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_b8a4d_row4_col0" class="data row4 col0" >0.976053</td>
#       <td id="T_b8a4d_row4_col1" class="data row4 col1" >0.217391</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_b8a4d_row5_col0" class="data row5 col0" >22.068818</td>
#       <td id="T_b8a4d_row5_col1" class="data row5 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_b8a4d_row6_col0" class="data row6 col0" >0.403149</td>
#       <td id="T_b8a4d_row6_col1" class="data row6 col1" >1.045455</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_b8a4d_row7_col0" class="data row7 col0" >0.188353</td>
#       <td id="T_b8a4d_row7_col1" class="data row7 col1" >2.714286</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_b8a4d_row8_col0" class="data row8 col0" >0.165999</td>
#       <td id="T_b8a4d_row8_col1" class="data row8 col1" >0.434783</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_b8a4d_row9_col0" class="data row9 col0" >2.304843</td>
#       <td id="T_b8a4d_row9_col1" class="data row9 col1" >1.466667</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_b8a4d_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_b8a4d_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b8a4d_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_b8a4d_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_b8a4d_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### removing the NaN values from the resultant dataframe

# %%
# the + operation is UNION of indexes
d31 = d1+d2
# indexs not present in the other dataframe get a NaN
# do you can obvs remove nan values like before
d3.dropna().style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d6fff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6fff_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d6fff_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6fff_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_d6fff_row0_col0" class="data row0 col0" >0.877982</td>
#       <td id="T_d6fff_row0_col1" class="data row0 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6fff_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_d6fff_row1_col0" class="data row1 col0" >0.545952</td>
#       <td id="T_d6fff_row1_col1" class="data row1 col1" >39.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6fff_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_d6fff_row2_col0" class="data row2 col0" >1.764852</td>
#       <td id="T_d6fff_row2_col1" class="data row2 col1" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6fff_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_d6fff_row3_col0" class="data row3 col0" >0.416294</td>
#       <td id="T_d6fff_row3_col1" class="data row3 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6fff_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_d6fff_row4_col0" class="data row4 col0" >0.857353</td>
#       <td id="T_d6fff_row4_col1" class="data row4 col1" >45.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6fff_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_d6fff_row5_col0" class="data row5 col0" >0.827564</td>
#       <td id="T_d6fff_row5_col1" class="data row5 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6fff_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_d6fff_row6_col0" class="data row6 col0" >0.617066</td>
#       <td id="T_d6fff_row6_col1" class="data row6 col1" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d6fff_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_d6fff_row7_col0" class="data row7 col0" >0.588919</td>
#       <td id="T_d6fff_row7_col1" class="data row7 col1" >37.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## df.align()

# %% [markdown]
# Pandas [align](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.align.html) works to join the dataframes in interesting ways.

# %%
# align returns two dataframes - left and right as a result of a join
# default join is outer - the union of indices will be used as index for left and right
left, right = d1.align(d2, join='outer')
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_585d2" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_585d2_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_585d2_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_585d2_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_585d2_row0_col0" class="data row0 col0" >0.334246</td>
#       <td id="T_585d2_row0_col1" class="data row0 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_585d2_row1_col0" class="data row1 col0" >0.915275</td>
#       <td id="T_585d2_row1_col1" class="data row1 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_585d2_row2_col0" class="data row2 col0" >0.651394</td>
#       <td id="T_585d2_row2_col1" class="data row2 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_585d2_row3_col0" class="data row3 col0" >0.006219</td>
#       <td id="T_585d2_row3_col1" class="data row3 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_585d2_row4_col0" class="data row4 col0" >0.871732</td>
#       <td id="T_585d2_row4_col1" class="data row4 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_585d2_row5_col0" class="data row5 col0" >0.398248</td>
#       <td id="T_585d2_row5_col1" class="data row5 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_585d2_row6_col0" class="data row6 col0" >0.246332</td>
#       <td id="T_585d2_row6_col1" class="data row6 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_585d2_row7_col0" class="data row7 col0" >0.131168</td>
#       <td id="T_585d2_row7_col1" class="data row7 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_585d2_row8_col0" class="data row8 col0" >0.087849</td>
#       <td id="T_585d2_row8_col1" class="data row8 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_585d2_row9_col0" class="data row9 col0" >0.410720</td>
#       <td id="T_585d2_row9_col1" class="data row9 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_585d2_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_585d2_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_585d2_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_585d2_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_585d2_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_65d18" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65d18_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_65d18_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65d18_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_65d18_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_65d18_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_65d18_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_65d18_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_65d18_row2_col0" class="data row2 col0" >0.226588</td>
#       <td id="T_65d18_row2_col1" class="data row2 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_65d18_row3_col0" class="data row3 col0" >0.539733</td>
#       <td id="T_65d18_row3_col1" class="data row3 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_65d18_row4_col0" class="data row4 col0" >0.893120</td>
#       <td id="T_65d18_row4_col1" class="data row4 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_65d18_row5_col0" class="data row5 col0" >0.018046</td>
#       <td id="T_65d18_row5_col1" class="data row5 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_65d18_row6_col0" class="data row6 col0" >0.611021</td>
#       <td id="T_65d18_row6_col1" class="data row6 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_65d18_row7_col0" class="data row7 col0" >0.696396</td>
#       <td id="T_65d18_row7_col1" class="data row7 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_65d18_row8_col0" class="data row8 col0" >0.529217</td>
#       <td id="T_65d18_row8_col1" class="data row8 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_65d18_row9_col0" class="data row9 col0" >0.178199</td>
#       <td id="T_65d18_row9_col1" class="data row9 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_65d18_row10_col0" class="data row10 col0" >0.380462</td>
#       <td id="T_65d18_row10_col1" class="data row10 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65d18_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_65d18_row11_col0" class="data row11 col0" >0.380887</td>
#       <td id="T_65d18_row11_col1" class="data row11 col1" >6.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# inner join
left, right = d1.align(d2, join='inner')
render_df_side_by_side(d1,d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3a1aa" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a1aa_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_3a1aa_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a1aa_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_3a1aa_row0_col0" class="data row0 col0" >0.334246</td>
#       <td id="T_3a1aa_row0_col1" class="data row0 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_3a1aa_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_3a1aa_row1_col0" class="data row1 col0" >0.915275</td>
#       <td id="T_3a1aa_row1_col1" class="data row1 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_3a1aa_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_3a1aa_row2_col0" class="data row2 col0" >0.651394</td>
#       <td id="T_3a1aa_row2_col1" class="data row2 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_3a1aa_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_3a1aa_row3_col0" class="data row3 col0" >0.006219</td>
#       <td id="T_3a1aa_row3_col1" class="data row3 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_3a1aa_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_3a1aa_row4_col0" class="data row4 col0" >0.871732</td>
#       <td id="T_3a1aa_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3a1aa_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_3a1aa_row5_col0" class="data row5 col0" >0.398248</td>
#       <td id="T_3a1aa_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_3a1aa_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_3a1aa_row6_col0" class="data row6 col0" >0.246332</td>
#       <td id="T_3a1aa_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_3a1aa_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_3a1aa_row7_col0" class="data row7 col0" >0.131168</td>
#       <td id="T_3a1aa_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_3a1aa_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_3a1aa_row8_col0" class="data row8 col0" >0.087849</td>
#       <td id="T_3a1aa_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3a1aa_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_3a1aa_row9_col0" class="data row9 col0" >0.410720</td>
#       <td id="T_3a1aa_row9_col1" class="data row9 col1" >22</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2f150" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f150_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_2f150_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f150_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_2f150_row0_col0" class="data row0 col0" >0.226588</td>
#       <td id="T_2f150_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2f150_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_2f150_row1_col0" class="data row1 col0" >0.539733</td>
#       <td id="T_2f150_row1_col1" class="data row1 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_2f150_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_2f150_row2_col0" class="data row2 col0" >0.893120</td>
#       <td id="T_2f150_row2_col1" class="data row2 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_2f150_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_2f150_row3_col0" class="data row3 col0" >0.018046</td>
#       <td id="T_2f150_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_2f150_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_2f150_row4_col0" class="data row4 col0" >0.611021</td>
#       <td id="T_2f150_row4_col1" class="data row4 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_2f150_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_2f150_row5_col0" class="data row5 col0" >0.696396</td>
#       <td id="T_2f150_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_2f150_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_2f150_row6_col0" class="data row6 col0" >0.529217</td>
#       <td id="T_2f150_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_2f150_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_2f150_row7_col0" class="data row7 col0" >0.178199</td>
#       <td id="T_2f150_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_2f150_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_2f150_row8_col0" class="data row8 col0" >0.380462</td>
#       <td id="T_2f150_row8_col1" class="data row8 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_2f150_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_2f150_row9_col0" class="data row9 col0" >0.380887</td>
#       <td id="T_2f150_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
# we can fill the NaNs with a certain value if needed
# let's fill with -100 so we can see it clearly
left, right = d1.align(d2, join='outer', fill_value = -100) 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_05896" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05896_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_05896_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05896_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_05896_row0_col0" class="data row0 col0" >0.334246</td>
#       <td id="T_05896_row0_col1" class="data row0 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_05896_row1_col0" class="data row1 col0" >0.915275</td>
#       <td id="T_05896_row1_col1" class="data row1 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_05896_row2_col0" class="data row2 col0" >0.651394</td>
#       <td id="T_05896_row2_col1" class="data row2 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_05896_row3_col0" class="data row3 col0" >0.006219</td>
#       <td id="T_05896_row3_col1" class="data row3 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_05896_row4_col0" class="data row4 col0" >0.871732</td>
#       <td id="T_05896_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_05896_row5_col0" class="data row5 col0" >0.398248</td>
#       <td id="T_05896_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_05896_row6_col0" class="data row6 col0" >0.246332</td>
#       <td id="T_05896_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_05896_row7_col0" class="data row7 col0" >0.131168</td>
#       <td id="T_05896_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_05896_row8_col0" class="data row8 col0" >0.087849</td>
#       <td id="T_05896_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_05896_row9_col0" class="data row9 col0" >0.410720</td>
#       <td id="T_05896_row9_col1" class="data row9 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_05896_row10_col0" class="data row10 col0" >-100.000000</td>
#       <td id="T_05896_row10_col1" class="data row10 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_05896_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_05896_row11_col0" class="data row11 col0" >-100.000000</td>
#       <td id="T_05896_row11_col1" class="data row11 col1" >-100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_96a14" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96a14_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_96a14_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96a14_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_96a14_row0_col0" class="data row0 col0" >-100.000000</td>
#       <td id="T_96a14_row0_col1" class="data row0 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_96a14_row1_col0" class="data row1 col0" >-100.000000</td>
#       <td id="T_96a14_row1_col1" class="data row1 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_96a14_row2_col0" class="data row2 col0" >0.226588</td>
#       <td id="T_96a14_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_96a14_row3_col0" class="data row3 col0" >0.539733</td>
#       <td id="T_96a14_row3_col1" class="data row3 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_96a14_row4_col0" class="data row4 col0" >0.893120</td>
#       <td id="T_96a14_row4_col1" class="data row4 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_96a14_row5_col0" class="data row5 col0" >0.018046</td>
#       <td id="T_96a14_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_96a14_row6_col0" class="data row6 col0" >0.611021</td>
#       <td id="T_96a14_row6_col1" class="data row6 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_96a14_row7_col0" class="data row7 col0" >0.696396</td>
#       <td id="T_96a14_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_96a14_row8_col0" class="data row8 col0" >0.529217</td>
#       <td id="T_96a14_row8_col1" class="data row8 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_96a14_row9_col0" class="data row9 col0" >0.178199</td>
#       <td id="T_96a14_row9_col1" class="data row9 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_96a14_row10_col0" class="data row10 col0" >0.380462</td>
#       <td id="T_96a14_row10_col1" class="data row10 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_96a14_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_96a14_row11_col0" class="data row11 col0" >0.380887</td>
#       <td id="T_96a14_row11_col1" class="data row11 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
# left join: left index is added to right, but not the other way
left, right = d1.align(d2, join='left') 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_eafc0" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eafc0_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_eafc0_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eafc0_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_eafc0_row0_col0" class="data row0 col0" >0.334246</td>
#       <td id="T_eafc0_row0_col1" class="data row0 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_eafc0_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_eafc0_row1_col0" class="data row1 col0" >0.915275</td>
#       <td id="T_eafc0_row1_col1" class="data row1 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_eafc0_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_eafc0_row2_col0" class="data row2 col0" >0.651394</td>
#       <td id="T_eafc0_row2_col1" class="data row2 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_eafc0_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_eafc0_row3_col0" class="data row3 col0" >0.006219</td>
#       <td id="T_eafc0_row3_col1" class="data row3 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_eafc0_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_eafc0_row4_col0" class="data row4 col0" >0.871732</td>
#       <td id="T_eafc0_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_eafc0_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_eafc0_row5_col0" class="data row5 col0" >0.398248</td>
#       <td id="T_eafc0_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_eafc0_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_eafc0_row6_col0" class="data row6 col0" >0.246332</td>
#       <td id="T_eafc0_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_eafc0_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_eafc0_row7_col0" class="data row7 col0" >0.131168</td>
#       <td id="T_eafc0_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_eafc0_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_eafc0_row8_col0" class="data row8 col0" >0.087849</td>
#       <td id="T_eafc0_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_eafc0_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_eafc0_row9_col0" class="data row9 col0" >0.410720</td>
#       <td id="T_eafc0_row9_col1" class="data row9 col1" >22</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_13a62" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13a62_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_13a62_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13a62_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_13a62_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_13a62_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_13a62_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_13a62_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_13a62_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_13a62_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_13a62_row2_col0" class="data row2 col0" >0.226588</td>
#       <td id="T_13a62_row2_col1" class="data row2 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13a62_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_13a62_row3_col0" class="data row3 col0" >0.539733</td>
#       <td id="T_13a62_row3_col1" class="data row3 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13a62_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_13a62_row4_col0" class="data row4 col0" >0.893120</td>
#       <td id="T_13a62_row4_col1" class="data row4 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13a62_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_13a62_row5_col0" class="data row5 col0" >0.018046</td>
#       <td id="T_13a62_row5_col1" class="data row5 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13a62_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_13a62_row6_col0" class="data row6 col0" >0.611021</td>
#       <td id="T_13a62_row6_col1" class="data row6 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13a62_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_13a62_row7_col0" class="data row7 col0" >0.696396</td>
#       <td id="T_13a62_row7_col1" class="data row7 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13a62_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_13a62_row8_col0" class="data row8 col0" >0.529217</td>
#       <td id="T_13a62_row8_col1" class="data row8 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_13a62_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_13a62_row9_col0" class="data row9 col0" >0.178199</td>
#       <td id="T_13a62_row9_col1" class="data row9 col1" >15.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# right join: right index is added to left, but not the other way
left, right = d1.align(d2, join='right') 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_80c18" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80c18_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_80c18_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80c18_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_80c18_row0_col0" class="data row0 col0" >0.651394</td>
#       <td id="T_80c18_row0_col1" class="data row0 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80c18_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_80c18_row1_col0" class="data row1 col0" >0.006219</td>
#       <td id="T_80c18_row1_col1" class="data row1 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80c18_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_80c18_row2_col0" class="data row2 col0" >0.871732</td>
#       <td id="T_80c18_row2_col1" class="data row2 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80c18_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_80c18_row3_col0" class="data row3 col0" >0.398248</td>
#       <td id="T_80c18_row3_col1" class="data row3 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80c18_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_80c18_row4_col0" class="data row4 col0" >0.246332</td>
#       <td id="T_80c18_row4_col1" class="data row4 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80c18_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_80c18_row5_col0" class="data row5 col0" >0.131168</td>
#       <td id="T_80c18_row5_col1" class="data row5 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80c18_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_80c18_row6_col0" class="data row6 col0" >0.087849</td>
#       <td id="T_80c18_row6_col1" class="data row6 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80c18_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_80c18_row7_col0" class="data row7 col0" >0.410720</td>
#       <td id="T_80c18_row7_col1" class="data row7 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80c18_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_80c18_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_80c18_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_80c18_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_80c18_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_80c18_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_cd5cc" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd5cc_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_cd5cc_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd5cc_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_cd5cc_row0_col0" class="data row0 col0" >0.226588</td>
#       <td id="T_cd5cc_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_cd5cc_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_cd5cc_row1_col0" class="data row1 col0" >0.539733</td>
#       <td id="T_cd5cc_row1_col1" class="data row1 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_cd5cc_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_cd5cc_row2_col0" class="data row2 col0" >0.893120</td>
#       <td id="T_cd5cc_row2_col1" class="data row2 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_cd5cc_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_cd5cc_row3_col0" class="data row3 col0" >0.018046</td>
#       <td id="T_cd5cc_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_cd5cc_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_cd5cc_row4_col0" class="data row4 col0" >0.611021</td>
#       <td id="T_cd5cc_row4_col1" class="data row4 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_cd5cc_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_cd5cc_row5_col0" class="data row5 col0" >0.696396</td>
#       <td id="T_cd5cc_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_cd5cc_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_cd5cc_row6_col0" class="data row6 col0" >0.529217</td>
#       <td id="T_cd5cc_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_cd5cc_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_cd5cc_row7_col0" class="data row7 col0" >0.178199</td>
#       <td id="T_cd5cc_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_cd5cc_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_cd5cc_row8_col0" class="data row8 col0" >0.380462</td>
#       <td id="T_cd5cc_row8_col1" class="data row8 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_cd5cc_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_cd5cc_row9_col0" class="data row9 col0" >0.380887</td>
#       <td id="T_cd5cc_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's more to explore in align, and it can get confusing, so beginners be careful, take time and try to work out the result before you execute to build intuition.

# %% [markdown]
# # Operations on data

# %% [markdown]
# ## Stats
#
# Operations in general *exclude* missing data

# %%
# arithmetic mean, for each column (axis = 0)
df.mean()
# Out:
# A    -0.107190
# B    -0.781935
# C    -0.614293
# D     0.186754
# F    15.500000
# dtype: float64

# %%
# mean across a row (axis = 1)
df.mean(1)
# Out:
# 2022-06-19    1.780767
# 2022-06-20    2.277510
# 2022-06-21    2.419958
# 2022-06-22    2.743708
# 2022-06-23    2.479025
# 2022-06-24    3.129403
# 2022-06-25    3.076778
# 2022-06-26    3.287143
# 2022-06-27    3.374177
# 2022-06-28    3.798203
# Freq: D, dtype: float64

# %% [markdown]
# ## Apply

# %%
# apply custom lambdas
df.apply(lambda x: x.max()-x.min())
# Out:
# A    2.445423
# B    2.350677
# C    3.691808
# D    3.645464
# F    9.000000
# dtype: float64

# %%
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -1.254421 -1.434864  1.182706 -0.589584  11
# 2022-06-20  0.598740 -1.013511 -1.376271  1.178590  12
# 2022-06-21 -0.932345 -0.192761 -0.500586  0.725481  13
# 2022-06-22  0.735685 -1.036076 -0.058748  0.077677  14
# 2022-06-23 -1.045394 -1.026246 -2.063510  1.530277  15
# 2022-06-24 -0.079282 -1.427287 -1.046246  2.199832  16
# 2022-06-25  0.381503 -0.829342  0.277363 -1.445632  17
# 2022-06-26  1.191002 -0.751601 -2.509103  0.505419  18
# 2022-06-27  0.377693 -1.023474 -0.510951 -0.972385  19
# 2022-06-28 -1.045085  0.915813  0.462418 -1.342130  20

# %%
# each subsequent value is a sum of all values before it in the respective column
cumsum_df = df.apply(np.cumsum)
render_df_side_by_side(df, cumsum_df, "OG Dataframe", "Cumulative Sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_50c1f" style='display:inline'>
#   <caption>OG Dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50c1f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_50c1f_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_50c1f_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_50c1f_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_50c1f_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50c1f_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_50c1f_row0_col0" class="data row0 col0" >-1.254421</td>
#       <td id="T_50c1f_row0_col1" class="data row0 col1" >-1.434864</td>
#       <td id="T_50c1f_row0_col2" class="data row0 col2" >1.182706</td>
#       <td id="T_50c1f_row0_col3" class="data row0 col3" >-0.589584</td>
#       <td id="T_50c1f_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_50c1f_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_50c1f_row1_col0" class="data row1 col0" >0.598740</td>
#       <td id="T_50c1f_row1_col1" class="data row1 col1" >-1.013511</td>
#       <td id="T_50c1f_row1_col2" class="data row1 col2" >-1.376271</td>
#       <td id="T_50c1f_row1_col3" class="data row1 col3" >1.178590</td>
#       <td id="T_50c1f_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_50c1f_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_50c1f_row2_col0" class="data row2 col0" >-0.932345</td>
#       <td id="T_50c1f_row2_col1" class="data row2 col1" >-0.192761</td>
#       <td id="T_50c1f_row2_col2" class="data row2 col2" >-0.500586</td>
#       <td id="T_50c1f_row2_col3" class="data row2 col3" >0.725481</td>
#       <td id="T_50c1f_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_50c1f_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_50c1f_row3_col0" class="data row3 col0" >0.735685</td>
#       <td id="T_50c1f_row3_col1" class="data row3 col1" >-1.036076</td>
#       <td id="T_50c1f_row3_col2" class="data row3 col2" >-0.058748</td>
#       <td id="T_50c1f_row3_col3" class="data row3 col3" >0.077677</td>
#       <td id="T_50c1f_row3_col4" class="data row3 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_50c1f_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_50c1f_row4_col0" class="data row4 col0" >-1.045394</td>
#       <td id="T_50c1f_row4_col1" class="data row4 col1" >-1.026246</td>
#       <td id="T_50c1f_row4_col2" class="data row4 col2" >-2.063510</td>
#       <td id="T_50c1f_row4_col3" class="data row4 col3" >1.530277</td>
#       <td id="T_50c1f_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_50c1f_level0_row5" class="row_heading level0 row5" >2022-06-24 00:00:00</th>
#       <td id="T_50c1f_row5_col0" class="data row5 col0" >-0.079282</td>
#       <td id="T_50c1f_row5_col1" class="data row5 col1" >-1.427287</td>
#       <td id="T_50c1f_row5_col2" class="data row5 col2" >-1.046246</td>
#       <td id="T_50c1f_row5_col3" class="data row5 col3" >2.199832</td>
#       <td id="T_50c1f_row5_col4" class="data row5 col4" >16</td>
#     </tr>
#     <tr>
#       <th id="T_50c1f_level0_row6" class="row_heading level0 row6" >2022-06-25 00:00:00</th>
#       <td id="T_50c1f_row6_col0" class="data row6 col0" >0.381503</td>
#       <td id="T_50c1f_row6_col1" class="data row6 col1" >-0.829342</td>
#       <td id="T_50c1f_row6_col2" class="data row6 col2" >0.277363</td>
#       <td id="T_50c1f_row6_col3" class="data row6 col3" >-1.445632</td>
#       <td id="T_50c1f_row6_col4" class="data row6 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_50c1f_level0_row7" class="row_heading level0 row7" >2022-06-26 00:00:00</th>
#       <td id="T_50c1f_row7_col0" class="data row7 col0" >1.191002</td>
#       <td id="T_50c1f_row7_col1" class="data row7 col1" >-0.751601</td>
#       <td id="T_50c1f_row7_col2" class="data row7 col2" >-2.509103</td>
#       <td id="T_50c1f_row7_col3" class="data row7 col3" >0.505419</td>
#       <td id="T_50c1f_row7_col4" class="data row7 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_50c1f_level0_row8" class="row_heading level0 row8" >2022-06-27 00:00:00</th>
#       <td id="T_50c1f_row8_col0" class="data row8 col0" >0.377693</td>
#       <td id="T_50c1f_row8_col1" class="data row8 col1" >-1.023474</td>
#       <td id="T_50c1f_row8_col2" class="data row8 col2" >-0.510951</td>
#       <td id="T_50c1f_row8_col3" class="data row8 col3" >-0.972385</td>
#       <td id="T_50c1f_row8_col4" class="data row8 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_50c1f_level0_row9" class="row_heading level0 row9" >2022-06-28 00:00:00</th>
#       <td id="T_50c1f_row9_col0" class="data row9 col0" >-1.045085</td>
#       <td id="T_50c1f_row9_col1" class="data row9 col1" >0.915813</td>
#       <td id="T_50c1f_row9_col2" class="data row9 col2" >0.462418</td>
#       <td id="T_50c1f_row9_col3" class="data row9 col3" >-1.342130</td>
#       <td id="T_50c1f_row9_col4" class="data row9 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_099b3" style='display:inline'>
#   <caption>Cumulative Sum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_099b3_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_099b3_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_099b3_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_099b3_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_099b3_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_099b3_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_099b3_row0_col0" class="data row0 col0" >-1.254421</td>
#       <td id="T_099b3_row0_col1" class="data row0 col1" >-1.434864</td>
#       <td id="T_099b3_row0_col2" class="data row0 col2" >1.182706</td>
#       <td id="T_099b3_row0_col3" class="data row0 col3" >-0.589584</td>
#       <td id="T_099b3_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_099b3_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_099b3_row1_col0" class="data row1 col0" >-0.655681</td>
#       <td id="T_099b3_row1_col1" class="data row1 col1" >-2.448376</td>
#       <td id="T_099b3_row1_col2" class="data row1 col2" >-0.193565</td>
#       <td id="T_099b3_row1_col3" class="data row1 col3" >0.589006</td>
#       <td id="T_099b3_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_099b3_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_099b3_row2_col0" class="data row2 col0" >-1.588025</td>
#       <td id="T_099b3_row2_col1" class="data row2 col1" >-2.641136</td>
#       <td id="T_099b3_row2_col2" class="data row2 col2" >-0.694152</td>
#       <td id="T_099b3_row2_col3" class="data row2 col3" >1.314487</td>
#       <td id="T_099b3_row2_col4" class="data row2 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_099b3_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_099b3_row3_col0" class="data row3 col0" >-0.852340</td>
#       <td id="T_099b3_row3_col1" class="data row3 col1" >-3.677212</td>
#       <td id="T_099b3_row3_col2" class="data row3 col2" >-0.752899</td>
#       <td id="T_099b3_row3_col3" class="data row3 col3" >1.392164</td>
#       <td id="T_099b3_row3_col4" class="data row3 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_099b3_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_099b3_row4_col0" class="data row4 col0" >-1.897734</td>
#       <td id="T_099b3_row4_col1" class="data row4 col1" >-4.703458</td>
#       <td id="T_099b3_row4_col2" class="data row4 col2" >-2.816409</td>
#       <td

# %% [markdown]
# ## Histogramming
#
# Frequencies, 'nuff said
#
# ```value_counts()```

# %%
series1 = pd.Series(np.random.randint(0,5, size = 25))
series1.value_counts()
# Out:
# 4    8
# 2    7
# 0    4
# 1    4
# 3    2
# dtype: int64

# %% [markdown]
# ## String Methods

# %%
# build a series
some_string = "SERIes and Index are EqUIppeD WITh A seT Of stRINg PROCESSING METHoDs In tHe ```sTR``` attrIBute THAT MakE IT eASy To oPerATE ON EACh ELEmeNt OF The aRrAY. NOtE thAt PAtTERN-maTching in ```sTR``` gENeralLY UsES reGUlAr eXpreSsiONs bY DEfault (aND In Some cases AlwayS uSEs tHeM)."
str_series = pd.Series(some_string.split()) # split splits on whitespace by default

# %%
# manipulating the case - lower, upper etc.
# also the length of each string, split, replace, yada yada...
# very important when cleaning data (column names may have stupid whitespace, bad case, spacing etc.)
low = str_series.str.lower()
up = str_series.str.upper()

low_up_df = pd.DataFrame(
    {
        'og': str_series,
        'length': str_series.str.len(),
        'low': low,
        'up': up,
        'split_low_on_i': low.str.split('i', expand = False), # expand = True will break this usecase, try elsewhere
        'replace_a_with_star_in_low': low.str.replace('a','*', case=False, regex=True) # yeah, you can mess with regular expns
    })

low_up_df.tail(10)
# Out:
#              og  length          low           up  split_low_on_i  \
# 36  eXpreSsiONs      11  expressions  EXPRESSIONS  [express, ons]
# 37           bY       2           by           BY            [by]
# 38      DEfault       7      default      DEFAULT       [default]
# 39         (aND       4         (and         (AND          [(and]
# 40           In       2           in           IN           [, n]
# 41         Some       4         some         SOME          [some]
# 42        cases       5        cases        CASES         [cases]
# 43       AlwayS       6       always       ALWAYS        [always]
# 44         uSEs       4         uses         USES          [uses]
# 45       tHeM).       6       them).       THEM).        [them).]
#
#    replace_a_with_star_in_low
# 36                expressions
# 37                         by
# 38                    def*ult
# 39                       (*nd
# 40                         in
# 41                       some
# 42                      c*ses
# 43                     *lw*ys
# 44                       uses
# 45                     them).

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods) for more string operations.

# %% [markdown]
# # Merge
#
# Combine series and dataframes, use set logic for indexes and relational algebra for joins/merges

# %% [markdown]
# ## Concat
#
# Chill, we've done this before. The same join = inner/outer/left/right drill.

# %%
# let's make some more dataframes
concatDF = pd.DataFrame(np.random.randn(10,4)) # 10 rows and 4 columns of random numbers
pieces = [concatDF[:3], concatDF[3:7], concatDF[7:]]
reconstructedDF = pd.concat(pieces)
display('broken DFs: ',pieces)
render_df_side_by_side(concatDF, reconstructedDF, "OG", "Concatenated")
# Out:
# 'broken DFs: '
# [          0         1         2         3
#  0  0.938740  1.118979  0.256971 -0.474497
#  1  0.296029  0.439986 -0.101118 -0.254298
#  2  1.135001 -1.644927 -0.070290 -0.352566,
#            0         1         2         3
#  3  0.501511 -1.155815 -0.037134  0.240328
#  4 -1.314941 -0.554985  0.740891 -0.638633
#  5 -0.943834 -1.307964 -0.255397 -0.375013
#  6 -1.417240  1.891558 -1.454245  0.810447,
#            0         1         2         3
#  7 -0.039664  0.588622 -0.202164 -0.142715
#  8 -1.001210 -1.878327  1.577291 -0.415201
#  9  1.262178  1.760650  0.783426 -1.023833]
# <style type="text/css">
# </style>
# <table id="T_0bd90" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bd90_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_0bd90_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_0bd90_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_0bd90_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bd90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0bd90_row0_col0" class="data row0 col0" >0.938740</td>
#       <td id="T_0bd90_row0_col1" class="data row0 col1" >1.118979</td>
#       <td id="T_0bd90_row0_col2" class="data row0 col2" >0.256971</td>
#       <td id="T_0bd90_row0_col3" class="data row0 col3" >-0.474497</td>
#     </tr>
#     <tr>
#       <th id="T_0bd90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0bd90_row1_col0" class="data row1 col0" >0.296029</td>
#       <td id="T_0bd90_row1_col1" class="data row1 col1" >0.439986</td>
#       <td id="T_0bd90_row1_col2" class="data row1 col2" >-0.101118</td>
#       <td id="T_0bd90_row1_col3" class="data row1 col3" >-0.254298</td>
#     </tr>
#     <tr>
#       <th id="T_0bd90_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0bd90_row2_col0" class="data row2 col0" >1.135001</td>
#       <td id="T_0bd90_row2_col1" class="data row2 col1" >-1.644927</td>
#       <td id="T_0bd90_row2_col2" class="data row2 col2" >-0.070290</td>
#       <td id="T_0bd90_row2_col3" class="data row2 col3" >-0.352566</td>
#     </tr>
#     <tr>
#       <th id="T_0bd90_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0bd90_row3_col0" class="data row3 col0" >0.501511</td>
#       <td id="T_0bd90_row3_col1" class="data row3 col1" >-1.155815</td>
#       <td id="T_0bd90_row3_col2" class="data row3 col2" >-0.037134</td>
#       <td id="T_0bd90_row3_col3" class="data row3 col3" >0.240328</td>
#     </tr>
#     <tr>
#       <th id="T_0bd90_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0bd90_row4_col0" class="data row4 col0" >-1.314941</td>
#       <td id="T_0bd90_row4_col1" class="data row4 col1" >-0.554985</td>
#       <td id="T_0bd90_row4_col2" class="data row4 col2" >0.740891</td>
#       <td id="T_0bd90_row4_col3" class="data row4 col3" >-0.638633</td>
#     </tr>
#     <tr>
#       <th id="T_0bd90_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0bd90_row5_col0" class="data row5 col0" >-0.943834</td>
#       <td id="T_0bd90_row5_col1" class="data row5 col1" >-1.307964</td>
#       <td id="T_0bd90_row5_col2" class="data row5 col2" >-0.255397</td>
#       <td id="T_0bd90_row5_col3" class="data row5 col3" >-0.375013</td>
#     </tr>
#     <tr>
#       <th id="T_0bd90_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0bd90_row6_col0" class="data row6 col0" >-1.417240</td>
#       <td id="T_0bd90_row6_col1" class="data row6 col1" >1.891558</td>
#       <td id="T_0bd90_row6_col2" class="data row6 col2" >-1.454245</td>
#       <td id="T_0bd90_row6_col3" class="data row6 col3" >0.810447</td>
#     </tr>
#     <tr>
#       <th id="T_0bd90_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0bd90_row7_col0" class="data row7 col0" >-0.039664</td>
#       <td id="T_0bd90_row7_col1" class="data row7 col1" >0.588622</td>
#       <td id="T_0bd90_row7_col2" class="data row7 col2" >-0.202164</td>
#       <td id="T_0bd90_row7_col3" class="data row7 col3" >-0.142715</td>
#     </tr>
#     <tr>
#       <th id="T_0bd90_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0bd90_row8_col0" class="data row8 col0" >-1.001210</td>
#       <td id="T_0bd90_row8_col1" class="data row8 col1" >-1.878327</td>
#       <td id="T_0bd90_row8_col2" class="data row8 col2" >1.577291</td>
#       <td id="T_0bd90_row8_col3" class="data row8 col3" >-0.415201</td>
#     </tr>
#     <tr>
#       <th id="T_0bd90_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0bd90_row9_col0" class="data row9 col0" >1.262178</td>
#       <td id="T_0bd90_row9_col1" class="data row9 col1" >1.760650</td>
#       <td id="T_0bd90_row9_col2" class="data row9 col2" >0.783426</td>
#       <td id="T_0bd90_row9_col3" class="data row9 col3" >-1.023833</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_cbb74" style='display:inline'>
#   <caption>Concatenated</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbb74_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cbb74_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cbb74_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_cbb74_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbb74_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbb74_row0_col0" class="data row0 col0" >0.938740</td>
#       <td id="T_cbb74_row0_col1" class="data row0 col1" >1.118979</td>
#       <td id="T_cbb74_row0_col2" class="data row0 col2" >0.256971</td>
#       <td id="T_cbb74_row0_col3" class="data row0 col3" >-0.474497</td>
#     </tr>
#     <tr>
#       <th id="T_cbb74_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cbb74_row1_col0" class="data row1 col0" >0.296029</td>
#       <td id="T_cbb74_row1_col1" class="data row1 col1" >0.439986</td>
#       <td id="T_cbb74_row1_col2" class="data row1 col2" >-0.101118</td>
#       <td id="T_cbb74_row1_col3" class="data row1 col3" >-0.254298</td>
#     </tr>
#     <tr>
#       <th id="T_cbb74_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cbb74_row2_col0" class="data row2 col0" >1.135001</td>
#       <td id="T_cbb74_row2_col1" class="data row2 col1" >-1.644927</td>
#       <td id="T_cbb74_row2_col2" class="data row2 col2" >-0.070290</td>
#       <td id="T_cbb74_row2_col3" class="data row2 col3" >-0.352566</td>
#     </tr>
#     <tr>
#       <th id="T_cbb74_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cbb74_row3_col0" class="data row3 col0" >0.501511</td>
#       <td id="T_cbb74_row3_col1" class="data row3 col1" >-1.155815</td>
#       <td id="T_cbb74_row3_col2" class="data row3 col2" >-0.037134</td>
#       <td id="T_cbb74_row3_col3" class="data row3 col3" >0.240328</td>
#     </tr>
#     <tr>
#       <th id="T_cbb74_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cbb74_row4_col0" class="data row4 col0" >-1.314941</td>
#       <td id="T_cbb74_row4_col1" class="data row4 col1" >-0.554985</td>
#       <td id="T_cbb74_row4_col2" class="data row4 col2" >0.740891</td>
#       <td id="T_cbb74_row4_col3" class="data row4 col3" >-0.638633</td>
#     </tr>
#     <tr>
#       <th id="T_cbb74_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cbb74_row5_col0" class="data row5 col0" >-0.943834</td>
#       <td id="T_cbb74_row5_col1" class="data row5 col1" >-1.307964</td>
#       <td id="T_cbb74_row5_col2" class="data row5 col2" >-0.255397</td>
#       <td id="T_cbb74_row5_col3" class="data row5 col3" >-0.375013</td>
#     </tr>
#     <tr>
#       <th id="T_cbb74_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cbb74_row6_col0" class="data row6 col0" >-1.417240</td>
#       <td id="T_cbb74_row6_col1" class="data row6 col1" >1.891558</td>
#       <td id="T_cbb74_row6_col2" class="data row6 col2" >-1.454245</td>
#       <td id="T_cbb74_row6_col3" class="data row6 col3" >0.810447</td>
#     </tr>
#     <tr>
#       <th id="T_cbb74_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cbb74_row7_col0" class="data row7 col0" >-0.039664</td>
#       <td id="T_cbb74_row7_col1" class="data row7 col1" >0.588622</td>
#       <td id="T_cbb74_row7_col2" class="data row7 col2" >-0.202164</td>
#       <td id="T_cbb74_row7_col3" class="data row7 col3" >-0.142715</td>
#     </tr>
#     <tr>
#       <th id="T_cbb74_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cbb74_row8_col0" class="data row

# %% [markdown]
# _From the [page](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#concat)_:
# Adding a column to a DataFrame is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the DataFrame constructor instead of building a DataFrame by iteratively appending records to it.

# %% [markdown]
# ## Join
# SQL style merges.

# %%
# two data frames
sl = pd.Series(np.random.randint(10, size=6))
sr = sl.shift(2).fillna(0).astype(int)
left = pd.DataFrame(
    {
        'key': list('ABCDEF'),
        'lval': sl
    }
)

right = pd.DataFrame(
    {
        'key': list('ABBCDE'),
        'rval': sr
    }
)

# %%
render_df_side_by_side(left, right, 'left', 'right')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0d110" style='display:inline'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d110_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_0d110_level0_col1" class="col_heading level0 col1" >lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d110_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d110_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_0d110_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_0d110_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d110_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_0d110_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_0d110_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d110_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_0d110_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_0d110_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d110_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_0d110_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_0d110_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d110_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_0d110_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_0d110_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d110_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_0d110_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_20b3b" style='display:inline'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20b3b_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_20b3b_level0_col1" class="col_heading level0 col1" >rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20b3b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20b3b_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_20b3b_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_20b3b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20b3b_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_20b3b_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_20b3b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20b3b_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_20b3b_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_20b3b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20b3b_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_20b3b_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_20b3b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20b3b_row4_col0" class="data row4 col0" >D</td>
#       <td id="T_20b3b_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_20b3b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20b3b_row5_col0" class="data row5 col0" >E</td>
#       <td id="T_20b3b_row5_col1" class="data row5 col1" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pd.merge(left, right, on='key')
result
# Out:
#   key  lval  rval
# 0   A     9     0
# 1   B     8     0
# 2   B     8     9
# 3   C     2     8
# 4   D     9     2
# 5   E     4     9

# %% [markdown]
# # Grouping

# %% [markdown]
# "Group By" really means one or more of the following happening:
# 1. **Split**: data is broken into groups based on some criteria
# 2. **Apply**: a data operation is executed on each of those groups
# 3. **Combine**: the results are combined back into a data structure

# %%
grp_df = pd.DataFrame(
    {
        'colA': list('AABCAABDAA'),
        'colB': list('1234567890'),
        'colC': np.random.randn(10),
        'colD': np.random.randn(10)
    }
)
grp_df
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.575762  0.182023
# 1    A    2 -1.485301 -1.360486
# 2    B    3 -1.172573  0.294490
# 3    C    4 -0.338692 -0.675077
# 4    A    5  1.453206  0.605685
# 5    A    6  0.339581 -0.282844
# 6    B    7 -0.711212  0.566987
# 7    D    8  1.215038 -1.130758
# 8    A    9  1.500848 -1.234856
# 9    A    0  1.002373  1.636105

# %%
# a DataFrameGroupBy object object
grpby = grp_df.groupby('colA')

# list all the groups found
g = grpby.groups
g
# Out:
# {'A': [0, 1, 4, 5, 8, 9], 'B': [2, 6], 'C': [3], 'D': [7]}

# %%
# to create a dataframe from the group use something like
grpby.get_group('A')
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.575762  0.182023
# 1    A    2 -1.485301 -1.360486
# 4    A    5  1.453206  0.605685
# 5    A    6  0.339581 -0.282844
# 8    A    9  1.500848 -1.234856
# 9    A    0  1.002373  1.636105

# %% [markdown]
# ### Find all the groups

# %%
# but we may not know all the groups in the dataframe.
# so got to find a way to list all groups as dataframes.
# 
# some basic python helps create a list of groupby names
grpby_labels_list = [*g.keys()] # using the unpacking operator *
# alternatively
# grpby_labels_list = list(g.keys())
grpby_labels_list
# Out:
# ['A', 'B', 'C', 'D']

# %%
# create a dict where the group label is the key and the group dataframe is the value
grps = {lbl: grpby.get_group(lbl) for lbl in grpby_labels_list}

# now use the dict to access individual dataframes created out of the groupby operation
grps['B']

# question: can we create a dataframe of dataframes?
# Out:
#   colA colB      colC      colD
# 2    B    3 -1.172573  0.294490
# 6    B    7 -0.711212  0.566987

# %%
# You can see the datatype of the value is a pandas dataframe
type(grps['A'])
# Out:
# pandas.core.frame.DataFrame

# %%
# make a function of it all...
def get_all_groups(df_grpby):
    return {lbl: df_grpby.get_group(lbl) for lbl in list(df_grpby.groups.keys())}

# %%
grps = get_all_groups(grp_df.groupby('colA'))
grps
# Out:
# {'A':   colA colB      colC      colD
#  0    A    1 -0.575762  0.182023
#  1    A    2 -1.485301 -1.360486
#  4    A    5  1.453206  0.605685
#  5    A    6  0.339581 -0.282844
#  8    A    9  1.500848 -1.234856
#  9    A    0  1.002373  1.636105,
#  'B':   colA colB      colC      colD
#  2    B    3 -1.172573  0.294490
#  6    B    7 -0.711212  0.566987,
#  'C':   colA colB      colC      colD
#  3    C    4 -0.338692 -0.675077,
#  'D':   colA colB      colC      colD
#  7    D    8  1.215038 -1.130758}

# %%
# get a sum of values from each group
grp_df.groupby('colA').sum()
# Out:
#           colC      colD
# colA
# A     2.234945 -0.454373
# B    -1.883785  0.861477
# C    -0.338692 -0.675077
# D     1.215038 -1.130758

# %%
# let's add one more column to the dataframe
# we can try grouping on two columns
grp_df['colE'] = list('1231231231')
grp_df
# Out:
#   colA colB      colC      colD colE
# 0    A    1 -0.575762  0.182023    1
# 1    A    2 -1.485301 -1.360486    2
# 2    B    3 -1.172573  0.294490    3
# 3    C    4 -0.338692 -0.675077    1
# 4    A    5  1.453206  0.605685    2
# 5    A    6  0.339581 -0.282844    3
# 6    B    7 -0.711212  0.566987    1
# 7    D    8  1.215038 -1.130758    2
# 8    A    9  1.500848 -1.234856    3
# 9    A    0  1.002373  1.636105    1

# %%
g2 = grp_df.groupby(['colA','colE'])
grps2 = get_all_groups(g2)
grps2
# Out:
# {('A',
#   '1'):   colA colB      colC      colD colE
#  0    A    1 -0.575762  0.182023    1
#  9    A    0  1.002373  1.636105    1,
#  ('A',
#   '2'):   colA colB      colC      colD colE
#  1    A    2 -1.485301 -1.360486    2
#  4    A    5  1.453206  0.605685    2,
#  ('A',
#   '3'):   colA colB      colC      colD colE
#  5    A    6  0.339581 -0.282844    3
#  8    A    9  1.500848 -1.234856    3,
#  ('B',
#   '1'):   colA colB      colC      colD colE
#  6    B    7 -0.711212  0.566987    1,
#  ('B',
#   '3'):   colA colB      colC     colD colE
#  2    B    3 -1.172573  0.29449    3,
#  ('C',
#   '1'):   colA colB      colC      colD colE
#  3    C    4 -0.338692 -0.675077    1,
#  ('D',
#   '2'):   colA colB      colC      colD colE
#  7    D    8  1.215038 -1.130758    2}

# %%
render_df_side_by_side(grps2[('A','1')], grps2[('A','2')], 'A,1', 'A,2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_86090" style='display:inline'>
#   <caption>A,1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86090_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_86090_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_86090_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_86090_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_86090_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86090_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86090_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_86090_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_86090_row0_col2" class="data row0 col2" >-0.575762</td>
#       <td id="T_86090_row0_col3" class="data row0 col3" >0.182023</td>
#       <td id="T_86090_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_86090_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_86090_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_86090_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_86090_row1_col2" class="data row1 col2" >1.002373</td>
#       <td id="T_86090_row1_col3" class="data row1 col3" >1.636105</td>
#       <td id="T_86090_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2f1ee" style='display:inline'>
#   <caption>A,2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f1ee_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_2f1ee_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_2f1ee_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_2f1ee_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_2f1ee_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f1ee_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2f1ee_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_2f1ee_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_2f1ee_row0_col2" class="data row0 col2" >-1.485301</td>
#       <td id="T_2f1ee_row0_col3" class="data row0 col3" >-1.360486</td>
#       <td id="T_2f1ee_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2f1ee_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_2f1ee_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_2f1ee_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_2f1ee_row1_col2" class="data row1 col2" >1.453206</td>
#       <td id="T_2f1ee_row1_col3" class="data row1 col3" >0.605685</td>
#       <td id="T_2f1ee_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reshaping
#
# Stacking and Pivot Tables.
# This really warrants more practice, at least go through [the page](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#)

# %% [markdown]
# ## Stacking

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %% [markdown]
# If the syntax [*expression](https://docs.python.org/dev/reference/expressions.html#calls) appears in the function call, expression must evaluate to an iterable. Elements from these iterables are treated as if they were additional positional arguments.
#
# ...although the *expression syntax may appear after explicit keyword arguments, it is processed before the keyword arguments (and any **expression arguments)

# %%
# starred expressions...
def f(a,b):
    print(a, ' ', b)
    
f (b=1, *(2,)) # works, the tuple (iterable) is expanded, 2 is assigned to a, then b fills the next argument slot
# f (a=1, *(2,)) # FAILS, multiple values for argument 'a'
# Out:
# 2   1

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
stack_idx = pd.MultiIndex.from_tuples(tuples, names = ['first', 'second'])

# %%
stack_df = pd.DataFrame(np.random.randn(8,2), index = stack_idx, columns = ['a','b'])
stack_df
# Out:
#                      a         b
# first second
# bar   one     0.405742 -0.780948
#       two    -0.053313  0.299227
# baz   one     0.722976  1.292843
#       two    -0.523077 -0.579257
# foo   one    -1.067620  1.266449
#       two    -1.068163 -0.380004
# qux   one    -0.382983 -0.350548
#       two     0.528117 -0.423366

# %%
# stack really just combines the columns
stacked = stack_df.stack()
stacked
# Out:
# first  second
# bar    one     a    0.405742
#                b   -0.780948
#        two     a   -0.053313
#                b    0.299227
# baz    one     a    0.722976
#                b    1.292843
#        two     a   -0.523077
#                b   -0.579257
# foo    one     a   -1.067620
#                b    1.266449
#        two     a   -1.068163
#                b   -0.380004
# qux    one     a   -0.382983
#                b   -0.350548
#        two     a    0.528117
#                b   -0.423366
# dtype: float64

# %%
# unstacked brings back the two columns
# by default unstacks the last level
unstacked = stacked.unstack()
unstacked
# Out:
#                      a         b
# first second
# bar   one     0.405742 -0.780948
#       two    -0.053313  0.299227
# baz   one     0.722976  1.292843
#       two    -0.523077 -0.579257
# foo   one    -1.067620  1.266449
#       two    -1.068163 -0.380004
# qux   one    -0.382983 -0.350548
#       two     0.528117 -0.423366

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   a  0.405742 -0.053313
#       b -0.780948  0.299227
# baz   a  0.722976 -0.523077
#       b  1.292843 -0.579257
# foo   a -1.067620 -1.068163
#       b  1.266449 -0.380004
# qux   a -0.382983  0.528117
#       b -0.350548 -0.423366

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    a  0.405742  0.722976 -1.067620 -0.382983
#        b -0.780948  1.292843  1.266449 -0.350548
# two    a -0.053313 -0.523077 -1.068163  0.528117
#        b  0.299227 -0.579257 -0.380004 -0.423366

# %%
# you can basically pivot the columns and rows using a combination of stack() and unstack()
unstacked.unstack()
# Out:
#                a                   b
# second       one       two       one       two
# first
# bar     0.405742 -0.053313 -0.780948  0.299227
# baz     0.722976 -0.523077  1.292843 -0.579257
# foo    -1.067620 -1.068163  1.266449 -0.380004
# qux    -0.382983  0.528117 -0.350548 -0.423366

# %% [markdown]
# ## Pivot Tables

# %%
# we're now just using data created in the pandas documentation - just cause, time.
pivot_tables_df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
pivot_tables_df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.647814  0.265787
# 1     one  B  foo  0.660451 -0.967869
# 2     two  C  foo  0.597733  0.449024
# 3   three  A  bar -0.566478  0.693049
# 4     one  B  bar  0.130038  0.285467
# 5     one  C  bar -0.075259  1.411823
# 6     two  A  foo -0.497978  0.559481
# 7   three  B  foo  0.220280  0.055913
# 8     one  C  foo -0.303997 -1.386472
# 9     one  A  bar -0.695120  0.418752
# 10    two  B  bar  0.283957 -0.844941
# 11  three  C  bar -0.105855  0.933168

# %%
# simple pivot tables - data, values to aggregate, index, columns to pivot along
pd.pivot_table(pivot_tables_df, values = 'D', index = ['A', 'B'], columns = ['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.695120 -0.647814
#       B  0.130038  0.660451
#       C -0.075259 -0.303997
# three A -0.566478       NaN
#       B       NaN  0.220280
#       C -0.105855       NaN
# two   A       NaN -0.497978
#       B  0.283957       NaN
#       C       NaN  0.597733

# %%
# more'n one columns of values
# mark all NaN as zero (0)
pd.pivot_table(pivot_tables_df, values = ['D', 'E'], index = ['A', 'B'], columns = ['C']).fillna(0)
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A -0.695120 -0.647814  0.418752  0.265787
#       B  0.130038  0.660451  0.285467 -0.967869
#       C -0.075259 -0.303997  1.411823 -1.386472
# three A -0.566478  0.000000  0.693049  0.000000
#       B  0.000000  0.220280  0.000000  0.055913
#       C -0.105855  0.000000  0.933168  0.000000
# two   A  0.000000 -0.497978  0.000000  0.559481
#       B  0.283957  0.000000 -0.844941  0.000000
#       C  0.000000  0.597733  0.000000  0.449024

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# We may need to resample data to a different time-frequency.
# Like get data every second and resample to data every 5 minutes and so on...

# %%
rng = pd.date_range('01/01/2022', periods = 1000, freq = 'S')

# %%
ts = pd.Series(np.random.randint(0,500, len(rng)), index=rng)

# %%
ts.resample('5min').sum()
# Out:
# 2022-01-01 00:00:00    76495
# 2022-01-01 00:05:00    74376
# 2022-01-01 00:10:00    74412
# 2022-01-01 00:15:00    25622
# Freq: 5T, dtype: int32

# %% [markdown]
# read up on [date offset strings](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) like '5min' etc.

# %% [markdown]
# ## Timezones

# %%
# timezone representation
rng2 = pd.date_range('01/01/2022', periods = 500, freq='D')
ts2 = pd.Series(np.random.randint(0,365, len(rng2)), index=rng2)
ts2_utc = ts2.tz_localize('UTC')

# %%
# convert to US/Eastern
ts2_utc.tz_convert('US/Eastern')
# Out:
# 2021-12-31 19:00:00-05:00    290
# 2022-01-01 19:00:00-05:00     34
# 2022-01-02 19:00:00-05:00    262
# 2022-01-03 19:00:00-05:00    323
# 2022-01-04 19:00:00-05:00    143
#                             ...
# 2023-05-10 20:00:00-04:00    343
# 2023-05-11 20:00:00-04:00    298
# 2023-05-12 20:00:00-04:00    210
# 2023-05-13 20:00:00-04:00    174
# 2023-05-14 20:00:00-04:00    145
# Freq: D, Length: 500, dtype: int32

# %% [markdown]
# ## Time span representations
#
# Converting between periods and timestamps.
#
# Period is a _timespan_ - span of time between two timestamps.

# %%
# month - end of each 
rng3 = pd.date_range('01/01/2022', periods = 12, freq='M')
rng3
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts3 = pd.Series(np.random.randn(len(rng3)), index = rng3)
ts3
# Out:
# 2022-01-31    0.443354
# 2022-02-28    0.860018
# 2022-03-31   -0.359660
# 2022-04-30    0.128865
# 2022-05-31    1.421511
# 2022-06-30   -0.971241
# 2022-07-31   -0.112946
# 2022-08-31   -0.956876
# 2022-09-30    0.201586
# 2022-10-31   -0.305961
# 2022-11-30    0.186575
# 2022-12-31    0.468049
# Freq: M, dtype: float64

# %%
ps = ts3.to_period()
ps
# Out:
# 2022-01    0.443354
# 2022-02    0.860018
# 2022-03   -0.359660
# 2022-04    0.128865
# 2022-05    1.421511
# 2022-06   -0.971241
# 2022-07   -0.112946
# 2022-08   -0.956876
# 2022-09    0.201586
# 2022-10   -0.305961
# 2022-11    0.186575
# 2022-12    0.468049
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2022-01-01    0.443354
# 2022-02-01    0.860018
# 2022-03-01   -0.359660
# 2022-04-01    0.128865
# 2022-05-01    1.421511
# 2022-06-01   -0.971241
# 2022-07-01   -0.112946
# 2022-08-01   -0.956876
# 2022-09-01    0.201586
# 2022-10-01   -0.305961
# 2022-11-01    0.186575
# 2022-12-01    0.468049
# Freq: MS, dtype: float64

# %% [markdown]
# A more complex use-case:
# convert a _quarterly frequency_ with _year ending in November_ to _9am_ of _the end of the month_ _following_ the _quarter end_

# %%
prng = pd.period_range('1990Q1', '2022Q4', freq='Q-NOV')
type(prng)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
ts4 = pd.Series(np.random.randn(len(prng)), index=prng)
ts4.head()
# Out:
# 1990Q1    0.726627
# 1990Q2    0.023528
# 1990Q3    0.888664
# 1990Q4   -1.012258
# 1991Q1    2.298335
# Freq: Q-NOV, dtype: float64

# %%
ts4.index = (prng.asfreq('M', 'e') +1).asfreq('H', 's')+9
ts4.head()
# Out:
# 1990-03-01 09:00    0.726627
# 1990-06-01 09:00    0.023528
# 1990-09-01 09:00    0.888664
# 1990-12-01 09:00   -1.012258
# 1991-03-01 09:00    2.298335
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
#
# [This page](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical).
#
# For e.g., gender, social class, blood type, country affiliation, observation time or rating via Likert scales.
# Categorical data. Categories allow (usually) fixed number of possible values. Categorical data may have some order, but not support numerical operations (for e.g., 'strongly agree', 'agree', 'disagree', 'strongly disagree').

# %%
cat_df = pd.DataFrame(
    {"id": list('123456'), "raw_grade":list('abbaae')}
)
cat_df
# Out:
#   id raw_grade
# 0  1         a
# 1  2         b
# 2  3         b
# 3  4         a
# 4  5         a
# 5  6         e

# %%
# convert the raw_grade col to categories
cat_df['grade'] = cat_df['raw_grade'].astype('category')
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
cat_df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# can give more meaningful names here
# direct assignment to Series.cat.categories()
cat_df['grade'].cat.categories = ['very good', 'meh', 'very bad']
cat_df['grade']
# Out:
# 0    very good
# 1          meh
# 2          meh
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'meh', 'very bad']

# %%
cat_df
# Out:
#   id raw_grade      grade
# 0  1         a  very good
# 1  2         b        meh
# 2  3         b        meh
# 3  4         a  very good
# 4  5         a  very good
# 5  6         e   very bad

# %%
# list of categories 
list(cat_df['grade'].cat.categories)

# categorical.CategoricalAccessor encapsulates all changes to categoricals
# for e.g., set_categories or remove_categories
# dir(cat_df['grade'].cat)
# Out:
# ['very good', 'meh', 'very bad']

# %%
# add more categories
cat_df['grade'] = cat_df['grade'].cat.set_categories(["very bad", "bad", "meh", "good", "very good"])
# new list of categories
list(cat_df['grade'].cat.categories)
# Out:
# ['very bad', 'bad', 'meh', 'good', 'very good']

# %%
# now when we can sort the dataframe in order of categories (not lexical)
sorted_cat_df = cat_df.sort_values(by='grade')
render_df_side_by_side(cat_df, sorted_cat_df, 'OG', 'Sorted')
# Out:
# <style type="text/css">
# </style>
# <table id="T_cce55" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cce55_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_cce55_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_cce55_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cce55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cce55_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_cce55_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_cce55_row0_col2" class="data row0 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_cce55_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cce55_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_cce55_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_cce55_row1_col2" class="data row1 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_cce55_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cce55_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_cce55_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_cce55_row2_col2" class="data row2 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_cce55_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cce55_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_cce55_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_cce55_row3_col2" class="data row3 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_cce55_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cce55_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_cce55_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_cce55_row4_col2" class="data row4 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_cce55_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cce55_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_cce55_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_cce55_row5_col2" class="data row5 col2" >very bad</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_66bb2" style='display:inline'>
#   <caption>Sorted</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66bb2_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_66bb2_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_66bb2_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66bb2_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_66bb2_row0_col0" class="data row0 col0" >6</td>
#       <td id="T_66bb2_row0_col1" class="data row0 col1" >e</td>
#       <td id="T_66bb2_row0_col2" class="data row0 col2" >very bad</td>
#     </tr>
#     <tr>
#       <th id="T_66bb2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66bb2_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_66bb2_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_66bb2_row1_col2" class="data row1 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_66bb2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66bb2_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_66bb2_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_66bb2_row2_col2" class="data row2 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_66bb2_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_66bb2_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_66bb2_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_66bb2_row3_col2" class="data row3 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_66bb2_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_66bb2_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_66bb2_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_66bb2_row4_col2" class="data row4 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_66bb2_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_66bb2_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_66bb2_row5_col1" class="data row5 col1" >a</td>
#       <td id="T_66bb2_row5_col2" class="data row5 col2" >very good</td>
#     </tr>
#   </tbody>
# </table>

# %%
# grouping
cat_grp = cat_df.groupby('grade')
cat_grp.get_group('very good')
# Out:
#   id raw_grade      grade
# 0  1         a  very good
# 3  4         a  very good
# 4  5         a  very good

# %%
# count elements
cat_grp.size()
# Out:
# grade
# very bad     1
# bad          0
# meh          2
# good         0
# very good    3
# dtype: int64
