# %% [markdown]
# # Setup
#
# This is following [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) for pandas 1.4.3 but may take a little more than 10 minutes to finish. Lot's of small changes, references etc.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Object creation

# %%
# Series - pass a list to pd.Series
s1 = pd.Series([1, 2, 3, np.nan, 5])

# %%
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
# create an index to use in the dataframe
# default frequency is D (day), so creates a DatetimeIndex of 10 days
dates = pd.date_range('20220619', periods=10)
dates
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# just in case you are wondering, here's [all the "offset aliases"](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases) for Datetime

# %%
# Dataframe - pass a Numpy array
# create a 10 row, 4 col random number array, index by dates, give some column names
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455
# 2022-06-25 -1.582055  1.133541 -0.563134 -0.164781
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026
# 2022-06-28  0.063093  0.177579  0.439995  0.229786

# %%
# Create a dataframe by passing a dictionary of objects
# where each object can be converted into a series-like structure
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220619"),
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([3]*6, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train", "test", "train"]),
        "F": list("foofoo"),
        "G": "foo"
    }
)

df2
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %%
# the datatype of each of the columns would be different
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# G            object
# dtype: object

# %% [markdown]
# # Viewing Data

# %%
# top of the dataframe
df.head()
# Out:
#                    A         B         C         D
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991

# %%
# bottom 3 records of the dataframe
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026
# 2022-06-28  0.063093  0.177579  0.439995  0.229786

# %%
# index of the df
df.index
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# columns of the df
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# .to_numpy gives a NumPy representation of the dataframe
# this is expensive if all columns are of different data type
df.to_numpy()
# Out:
# array([[-0.09139364, -0.23245733,  0.78728491,  0.41545295],
#        [-1.11452595,  0.71921964,  0.99055441,  1.99841354],
#        [ 0.96639133, -0.26591311, -1.2619809 ,  0.20153794],
#        [-1.23819715,  0.21293015,  0.00839566, -0.55473052],
#        [-1.0839405 , -0.30002706,  0.71942136,  0.67699114],
#        [-0.36403807,  1.29155552, -0.03852321,  1.61145458],
#        [-1.58205499,  1.13354139, -0.56313357, -0.16478072],
#        [-1.2933808 , -0.23139963,  0.13804661, -1.70363182],
#        [-0.14753973,  0.39613665,  2.59383262, -0.82002593],
#        [ 0.06309268,  0.17757854,  0.43999474,  0.22978612]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo']], dtype=object)

# %%
# quick summary stats
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.588559   0.290116   0.381389   0.189047
# std     0.800172   0.589796   1.028261   1.098842
# min    -1.582055  -0.300027  -1.261981  -1.703632
# 25%    -1.207279  -0.232193  -0.026793  -0.457243
# 50%    -0.723989   0.195254   0.289021   0.215662
# 75%    -0.105430   0.638449   0.770319   0.611607
# max     0.966391   1.291556   2.593833   1.998414

# %% [markdown]
# 1. **count** = Count number of non-NA/null observations
# 1. **max** = Maximum of the values in the object
# 1. **min** = Minimum of the values in the object
# 1. **mean** = Mean of the values
# 1. **std** = Standard deviation of the observations
# 1. **25%** = Default lower percentile
# 1. **50%** = 50 percentile - same as the median
# 1. **75%** = Default upper percentile

# %%
# change the percentiles
df.describe(percentiles=[.1, .5, .9])
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.588559   0.290116   0.381389   0.189047
# std     0.800172   0.589796   1.028261   1.098842
# min    -1.582055  -0.300027  -1.261981  -1.703632
# 10%    -1.322248  -0.269325  -0.633018  -0.908387
# 50%    -0.723989   0.195254   0.289021   0.215662
# 90%     0.153423   1.149343   1.150882   1.650150
# max     0.966391   1.291556   2.593833   1.998414

# %%
# E, F, G in d2 are not numeric, so do not come up in describe()
df2.describe()
# Out:
#          A    C    D
# count  6.0  6.0  6.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
# transpose the data
# turn rows to columns and vice versa
df.T
# Out:
#    2022-06-19  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# A   -0.091394   -1.114526    0.966391   -1.238197   -1.083940   -0.364038
# B   -0.232457    0.719220   -0.265913    0.212930   -0.300027    1.291556
# C    0.787285    0.990554   -1.261981    0.008396    0.719421   -0.038523
# D    0.415453    1.998414    0.201538   -0.554731    0.676991    1.611455
#
#    2022-06-25  2022-06-26  2022-06-27  2022-06-28
# A   -1.582055   -1.293381   -0.147540    0.063093
# B    1.133541   -0.231400    0.396137    0.177579
# C   -0.563134    0.138047    2.593833    0.439995
# D   -0.164781   -1.703632   -0.820026    0.229786

# %% [markdown]
# ### [Axis in pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html?highlight=set_ax#pandas.DataFrame.set_axis)
#
# ```axis{0 or ‘index’, 1 or ‘columns’}```
#
# Always remember that when you specify:
# * ```axis=0``` or ```axis='index'``` you indicate that the operation should be along the _index_ (aka across the rows). More often than not indexes will go from top to bottom (vertically), but sometimes they may not (for e.g. if you use columns as index or when you have hierarchical or multi-index data).
# * ```axis=1``` or ```axis='columns'``` indicates the operation is along the columns
#
# When in doubt use the explicit version ```'index'``` or ```'columns'``` instead of ```0``` or ```1```

# %%
# sort along the axis - 1 = horizontal
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-06-19  0.415453  0.787285 -0.232457 -0.091394
# 2022-06-20  1.998414  0.990554  0.719220 -1.114526
# 2022-06-21  0.201538 -1.261981 -0.265913  0.966391
# 2022-06-22 -0.554731  0.008396  0.212930 -1.238197
# 2022-06-23  0.676991  0.719421 -0.300027 -1.083940
# 2022-06-24  1.611455 -0.038523  1.291556 -0.364038
# 2022-06-25 -0.164781 -0.563134  1.133541 -1.582055
# 2022-06-26 -1.703632  0.138047 -0.231400 -1.293381
# 2022-06-27 -0.820026  2.593833  0.396137 -0.147540
# 2022-06-28  0.229786  0.439995  0.177579  0.063093

# %%
# sort along the axis - 0 = vertical
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2022-06-28  0.063093  0.177579  0.439995  0.229786
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632
# 2022-06-25 -1.582055  1.133541 -0.563134 -0.164781
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453

# %%
# sort ascending by values in a column
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2022-06-25 -1.582055  1.133541 -0.563134 -0.164781
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453
# 2022-06-28  0.063093  0.177579  0.439995  0.229786
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538

# %%
# sort by non-numerical values
df2.sort_values(by="F", ascending=False)
# Out:
#      A          B    C  D      E  F    G
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo

# %%
# sort by two or more columns
df2.sort_values(by=["F", "E"])
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %% [markdown]
# # Selection

# %% [markdown]
# For production prefer the following instead of other data access methods (typical python methods like ["col"] or [a:b] slices etc.):
#
# ```.at, .iat, .loc and .iloc.```

# %% [markdown]
# ## Getting

# %%
# selecting a single column returns a Series object
df["A"]
# Out:
# 2022-06-19   -0.091394
# 2022-06-20   -1.114526
# 2022-06-21    0.966391
# 2022-06-22   -1.238197
# 2022-06-23   -1.083940
# 2022-06-24   -0.364038
# 2022-06-25   -1.582055
# 2022-06-26   -1.293381
# 2022-06-27   -0.147540
# 2022-06-28    0.063093
# Freq: D, Name: A, dtype: float64

# %%
# selecting a slice
df[1:5]
# Out:
#                    A         B         C         D
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991

# %% [markdown]
# ## Selection by label

# %%
# selecting based on a label
df.loc[dates[0]]
# Out:
# A   -0.091394
# B   -0.232457
# C    0.787285
# D    0.415453
# Name: 2022-06-19 00:00:00, dtype: float64

# %%
# select on a multi-axis by lable
# I honestly do not know what the comment above means...help!
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-06-19 -0.091394 -0.232457
# 2022-06-20 -1.114526  0.719220
# 2022-06-21  0.966391 -0.265913
# 2022-06-22 -1.238197  0.212930
# 2022-06-23 -1.083940 -0.300027
# 2022-06-24 -0.364038  1.291556
# 2022-06-25 -1.582055  1.133541
# 2022-06-26 -1.293381 -0.231400
# 2022-06-27 -0.147540  0.396137
# 2022-06-28  0.063093  0.177579

# %%
# specific index value results in reduction of dimensions
res = df.loc["2022-06-20"]
print(res)
print("res.shape = ", res.shape, " vs. df.shape = ", df.shape)
# Out:
# A   -1.114526
# B    0.719220
# C    0.990554
# D    1.998414
# Name: 2022-06-20 00:00:00, dtype: float64
# res.shape =  (4,)  vs. df.shape =  (10, 4)

# %%
# get to a specific scalar:
#
# method one
df.loc[dates[0], "A"]
# Out:
# -0.09139364325544024

# %%
#
# method two (slightly faster than method one)
df.at[dates[0], "A"]
# Out:
# -0.09139364325544024

# %% [markdown]
# ## Selection by position

# %%
df.iloc[2]
# Out:
# A    0.966391
# B   -0.265913
# C   -1.261981
# D    0.201538
# Name: 2022-06-21 00:00:00, dtype: float64

# %%
# slices - similar to NumPy / Python - [row:slice, col:slice]
df.iloc[1:5, 0:2]
# Out:
#                    A         B
# 2022-06-20 -1.114526  0.719220
# 2022-06-21  0.966391 -0.265913
# 2022-06-22 -1.238197  0.212930
# 2022-06-23 -1.083940 -0.300027

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
df.iloc[[0, 1, 2, 6], [0, 2]]
# Out:
#                    A         C
# 2022-06-19 -0.091394  0.787285
# 2022-06-20 -1.114526  0.990554
# 2022-06-21  0.966391 -1.261981
# 2022-06-25 -1.582055 -0.563134

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
# change the order of columns, repeact a column
df.iloc[[0, 1, 2, 6], [2, 1, 0, 2]]
# Out:
#                    C         B         A         C
# 2022-06-19  0.787285 -0.232457 -0.091394  0.787285
# 2022-06-20  0.990554  0.719220 -1.114526  0.990554
# 2022-06-21 -1.261981 -0.265913  0.966391 -1.261981
# 2022-06-25 -0.563134  1.133541 -1.582055 -0.563134

# %%
# slice rows explicitly, keep all columns
df.iloc[[1, 2], :]
# Out:
#                    A         B         C         D
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538

# %%
# slice columns, keep all rows
df.iloc[:, [2, 3]]
# Out:
#                    C         D
# 2022-06-19  0.787285  0.415453
# 2022-06-20  0.990554  1.998414
# 2022-06-21 -1.261981  0.201538
# 2022-06-22  0.008396 -0.554731
# 2022-06-23  0.719421  0.676991
# 2022-06-24 -0.038523  1.611455
# 2022-06-25 -0.563134 -0.164781
# 2022-06-26  0.138047 -1.703632
# 2022-06-27  2.593833 -0.820026
# 2022-06-28  0.439995  0.229786

# %%
# everything, because you can
df.iloc[:, :]
# Out:
#                    A         B         C         D
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455
# 2022-06-25 -1.582055  1.133541 -0.563134 -0.164781
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026
# 2022-06-28  0.063093  0.177579  0.439995  0.229786

# %%
# get to a scalar (2 methods, just like before)
#
# method one: use iloc
df.iloc[1, 2]
# Out:
# 0.9905544087809485

# %%
#
# method two: use iat
df.iat[1, 2]
# Out:
# 0.9905544087809485

# %% [markdown]
# ## Boolean Indexing

# %%
# use a value found in a single col to get data
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538
# 2022-06-28  0.063093  0.177579  0.439995  0.229786

# %%
# boolean across the entire DF - vals that don't match go NaN
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-06-19       NaN       NaN  0.787285  0.415453
# 2022-06-20       NaN  0.719220  0.990554  1.998414
# 2022-06-21  0.966391       NaN       NaN  0.201538
# 2022-06-22       NaN  0.212930  0.008396       NaN
# 2022-06-23       NaN       NaN  0.719421  0.676991
# 2022-06-24       NaN  1.291556       NaN  1.611455
# 2022-06-25       NaN  1.133541       NaN       NaN
# 2022-06-26       NaN       NaN  0.138047       NaN
# 2022-06-27       NaN  0.396137  2.593833       NaN
# 2022-06-28  0.063093  0.177579  0.439995  0.229786

# %%
# add another column
df11 = df.copy()
df11["E"] = ["one", "two", "three", "four",
             "two", "five", "one", "two", "three", "four"]
df11
# Out:
#                    A         B         C         D      E
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453    one
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414    two
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  three
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731   four
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991    two
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455   five
# 2022-06-25 -1.582055  1.133541 -0.563134 -0.164781    one
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632    two
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026  three
# 2022-06-28  0.063093  0.177579  0.439995  0.229786   four

# %%
# the isin() query - basically the in clause
df11[df11["E"].isin(["two", "five"])]
# Out:
#                    A         B         C         D     E
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414   two
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991   two
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455  five
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632   two

# %% [markdown]
# ## Setting values

# %%
# matching indexes auto-aligns values
s1 = pd.Series(range(11, 21), index=pd.date_range('20220619', periods=10))
s1
# Out:
# 2022-06-19    11
# 2022-06-20    12
# 2022-06-21    13
# 2022-06-22    14
# 2022-06-23    15
# 2022-06-24    16
# 2022-06-25    17
# 2022-06-26    18
# 2022-06-27    19
# 2022-06-28    20
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453  11
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414  12
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991  15
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455  16
# 2022-06-25 -1.582055  1.133541 -0.563134 -0.164781  17
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632  18
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026  19
# 2022-06-28  0.063093  0.177579  0.439995  0.229786  20

# %%
# setting values by label and position
# first let's make a quick copy
df12 = df.copy()
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453  11
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414  12
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991  15
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455  16
# 2022-06-25 -1.582055  1.133541 -0.563134 -0.164781  17
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632  18
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026  19
# 2022-06-28  0.063093  0.177579  0.439995  0.229786  20

# %%
# set by label
df12.at[dates[0], "A"] = 0
# set by position
df12.iat[0, 1] = 0
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.000000  0.000000  0.787285  0.415453  11
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414  12
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991  15
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455  16
# 2022-06-25 -1.582055  1.133541 -0.563134 -0.164781  17
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632  18
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026  19
# 2022-06-28  0.063093  0.177579  0.439995  0.229786  20

# %%
# kinda bigger replacement
df12.loc[:, "D"] = np.array([5]*len(df))
df12
# Out:
#                    A         B         C  D   F
# 2022-06-19  0.000000  0.000000  0.787285  5  11
# 2022-06-20 -1.114526  0.719220  0.990554  5  12
# 2022-06-21  0.966391 -0.265913 -1.261981  5  13
# 2022-06-22 -1.238197  0.212930  0.008396  5  14
# 2022-06-23 -1.083940 -0.300027  0.719421  5  15
# 2022-06-24 -0.364038  1.291556 -0.038523  5  16
# 2022-06-25 -1.582055  1.133541 -0.563134  5  17
# 2022-06-26 -1.293381 -0.231400  0.138047  5  18
# 2022-06-27 -0.147540  0.396137  2.593833  5  19
# 2022-06-28  0.063093  0.177579  0.439995  5  20

# %%
# setting values using a boolean selection (aka where clause)
df12[df12 > 0] = -df12
df12
# Out:
#                    A         B         C  D   F
# 2022-06-19  0.000000  0.000000 -0.787285 -5 -11
# 2022-06-20 -1.114526 -0.719220 -0.990554 -5 -12
# 2022-06-21 -0.966391 -0.265913 -1.261981 -5 -13
# 2022-06-22 -1.238197 -0.212930 -0.008396 -5 -14
# 2022-06-23 -1.083940 -0.300027 -0.719421 -5 -15
# 2022-06-24 -0.364038 -1.291556 -0.038523 -5 -16
# 2022-06-25 -1.582055 -1.133541 -0.563134 -5 -17
# 2022-06-26 -1.293381 -0.231400 -0.138047 -5 -18
# 2022-06-27 -0.147540 -0.396137 -2.593833 -5 -19
# 2022-06-28 -0.063093 -0.177579 -0.439995 -5 -20

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### _reindex_
# change/add/delete index on a specified axis, returns a new dataframe

# %%
df13 = df.reindex(index=dates[0:4], columns=list(df.columns)+["G"])
df13
# Out:
#                    A         B         C         D   F   G
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453  11 NaN
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414  12 NaN
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13 NaN
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14 NaN

# %% [markdown]
# ### handling missing data
# 1. _```np.nan```_
# 1. _```pandas.isna()```_
# 1. ```df.dropna()```
# 1. ```df.fillna()```

# %%
# missing data in pandas is np.nan
df13.iat[1, 0] = np.nan
df13.iloc[1:, 5] = np.random.randint(1)
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453  11  NaN
# 2022-06-20       NaN  0.719220  0.990554  1.998414  12  0.0
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13  0.0
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14  0.0

# %%
# get a boolean mask where values are NaN
df131 = pd.isna(df13)
df131
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# or just
pd.isna(df13)
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# the original is still there
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453  11  NaN
# 2022-06-20       NaN  0.719220  0.990554  1.998414  12  0.0
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13  0.0
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14  0.0

# %%
# we are going to drop / replace values now, let's make a couple of copies of the dataframe
df132 = df13.copy()
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453  11  NaN
# 2022-06-20       NaN  0.719220  0.990554  1.998414  12  0.0
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13  0.0
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14  0.0

# %%
# drop rows/columns that have missing data
# by default it returns a new dataframe, you may want to specify inplace=True for modifying current dataframe:
df_no_na = df132.dropna(how="any")
# how=‘any’ : If any NA values are present, drop that row or column.
# how=‘all’ : If all values are NA, drop that row or column.

# %%
# all rows/cols with missing data stripped
df_no_na
# Out:
#                    A         B         C         D   F    G
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13  0.0
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14  0.0

# %%
# original still intact
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453  11  NaN
# 2022-06-20       NaN  0.719220  0.990554  1.998414  12  0.0
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13  0.0
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14  0.0

# %%
# drop missing data from original
df132.dropna(how="any", inplace=True)
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13  0.0
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14  0.0

# %%
# fill missing data
df133 = df13.copy()
df133.fillna(np.pi*1000)
# Out:
#                       A         B         C         D   F            G
# 2022-06-19    -0.091394 -0.232457  0.787285  0.415453  11  3141.592654
# 2022-06-20  3141.592654  0.719220  0.990554  1.998414  12     0.000000
# 2022-06-21     0.966391 -0.265913 -1.261981  0.201538  13     0.000000
# 2022-06-22    -1.238197  0.212930  0.008396 -0.554731  14     0.000000

# %% [markdown]
# # Align and Join

# %% [markdown]
# There needs to be a bigger notebook for this topic.
# You need to know there's "joins" in Pandas just like in the SQL world,
# like join and left join and right join and inner and outer and all that...
# Here we'll explore these in the context of the align function - 'aligning' the indexes of two dataframes.
# Later we'll see these again in the context of _merging_ two data frames.

# %% [markdown]
# ## Create two datasets with _mismatched_ indexes

# %%
# date range indexes
idx1 = pd.date_range('2022-01-01',periods = 10)
# 2022-01-01', '2022-01-02' don't exist in idx2
# '2022-01-11', '2022-01-12' don't exist in idx1
idx2 = pd.date_range('2022-01-03',periods = 10)

# %%
# dataframes from indexes
d1 = pd.DataFrame(index = idx1, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

d2 = pd.DataFrame(index = idx2, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

# %% [markdown]
# ## Quick Aside: Rendering two dataframes side-by-side

# %% [markdown]
# The trick of rendering 2 dataframes side-by-side was from [this](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) stackoverflow question.

# %%
# we gon need to display both data frames side by side, so...
from IPython.display import display_html 
def render_df_side_by_side(a, b, a_title = "", b_title = ""):
    a_styler = a.style.set_table_attributes("style='display:inline'").set_caption(a_title)
    b_styler = b.style.set_table_attributes("style='display:inline'").set_caption(b_title)
    display_html(a_styler._repr_html_()+b_styler._repr_html_(), raw=True)

# %%
render_df_side_by_side(d1,d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_13f14" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13f14_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_13f14_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13f14_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_13f14_row0_col0" class="data row0 col0" >0.276765</td>
#       <td id="T_13f14_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_13f14_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_13f14_row1_col0" class="data row1 col0" >0.109126</td>
#       <td id="T_13f14_row1_col1" class="data row1 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_13f14_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_13f14_row2_col0" class="data row2 col0" >0.515511</td>
#       <td id="T_13f14_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_13f14_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_13f14_row3_col0" class="data row3 col0" >0.151551</td>
#       <td id="T_13f14_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_13f14_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_13f14_row4_col0" class="data row4 col0" >0.769688</td>
#       <td id="T_13f14_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_13f14_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_13f14_row5_col0" class="data row5 col0" >0.916613</td>
#       <td id="T_13f14_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_13f14_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_13f14_row6_col0" class="data row6 col0" >0.323030</td>
#       <td id="T_13f14_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_13f14_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_13f14_row7_col0" class="data row7 col0" >0.354983</td>
#       <td id="T_13f14_row7_col1" class="data row7 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_13f14_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_13f14_row8_col0" class="data row8 col0" >0.554333</td>
#       <td id="T_13f14_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_13f14_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_13f14_row9_col0" class="data row9 col0" >0.466011</td>
#       <td id="T_13f14_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f7795" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7795_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f7795_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7795_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_f7795_row0_col0" class="data row0 col0" >0.739484</td>
#       <td id="T_f7795_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f7795_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_f7795_row1_col0" class="data row1 col0" >0.681039</td>
#       <td id="T_f7795_row1_col1" class="data row1 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_f7795_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_f7795_row2_col0" class="data row2 col0" >0.074048</td>
#       <td id="T_f7795_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f7795_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_f7795_row3_col0" class="data row3 col0" >0.698205</td>
#       <td id="T_f7795_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f7795_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_f7795_row4_col0" class="data row4 col0" >0.953619</td>
#       <td id="T_f7795_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f7795_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_f7795_row5_col0" class="data row5 col0" >0.378571</td>
#       <td id="T_f7795_row5_col1" class="data row5 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_f7795_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_f7795_row6_col0" class="data row6 col0" >0.965773</td>
#       <td id="T_f7795_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f7795_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_f7795_row7_col0" class="data row7 col0" >0.181592</td>
#       <td id="T_f7795_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_f7795_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_f7795_row8_col0" class="data row8 col0" >0.356266</td>
#       <td id="T_f7795_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f7795_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_f7795_row9_col0" class="data row9 col0" >0.004515</td>
#       <td id="T_f7795_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table rendering/styling options is [a bigger discussion](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#) to be tackled later.

# %% [markdown]
# ## .add, .sub, .mul, .div etc.

# %% [markdown]
# flexible wrappers (```add, sub, mul, div, mod, pow```) to arithmetic operators: ```+, -, *, /, //, %, **```

# %%
# the +, -, *, /, //, %, ** operations align indexes to create a UNION of indexes
d3 = d1+d2
d4 = d1.sub(d2) #equivalent to d1-d2
d5 = d1*d2
d6 = d1.div(d2)

# %%
# indexs not present in the other dataframe get a NaN
d3.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_9aa50_row0_col0, #T_9aa50_row0_col1, #T_9aa50_row1_col0, #T_9aa50_row1_col1, #T_9aa50_row10_col0, #T_9aa50_row10_col1, #T_9aa50_row11_col0, #T_9aa50_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_9aa50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9aa50_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9aa50_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9aa50_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_9aa50_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_9aa50_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_9aa50_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_9aa50_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_9aa50_row2_col0" class="data row2 col0" >1.254995</td>
#       <td id="T_9aa50_row2_col1" class="data row2 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_9aa50_row3_col0" class="data row3 col0" >0.832590</td>
#       <td id="T_9aa50_row3_col1" class="data row3 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_9aa50_row4_col0" class="data row4 col0" >0.843736</td>
#       <td id="T_9aa50_row4_col1" class="data row4 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_9aa50_row5_col0" class="data row5 col0" >1.614818</td>
#       <td id="T_9aa50_row5_col1" class="data row5 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_9aa50_row6_col0" class="data row6 col0" >1.276649</td>
#       <td id="T_9aa50_row6_col1" class="data row6 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_9aa50_row7_col0" class="data row7 col0" >0.733555</td>
#       <td id="T_9aa50_row7_col1" class="data row7 col1" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_9aa50_row8_col0" class="data row8 col0" >1.520106</td>
#       <td id="T_9aa50_row8_col1" class="data row8 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_9aa50_row9_col0" class="data row9 col0" >0.647603</td>
#       <td id="T_9aa50_row9_col1" class="data row9 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_9aa50_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_9aa50_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9aa50_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_9aa50_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_9aa50_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# sub
d4.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_7f9d0_row0_col0, #T_7f9d0_row0_col1, #T_7f9d0_row1_col0, #T_7f9d0_row1_col1, #T_7f9d0_row10_col0, #T_7f9d0_row10_col1, #T_7f9d0_row11_col0, #T_7f9d0_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_7f9d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f9d0_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7f9d0_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f9d0_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_7f9d0_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_7f9d0_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_7f9d0_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_7f9d0_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_7f9d0_row2_col0" class="data row2 col0" >-0.223974</td>
#       <td id="T_7f9d0_row2_col1" class="data row2 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_7f9d0_row3_col0" class="data row3 col0" >-0.529488</td>
#       <td id="T_7f9d0_row3_col1" class="data row3 col1" >-6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_7f9d0_row4_col0" class="data row4 col0" >0.695639</td>
#       <td id="T_7f9d0_row4_col1" class="data row4 col1" >-10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_7f9d0_row5_col0" class="data row5 col0" >0.218408</td>
#       <td id="T_7f9d0_row5_col1" class="data row5 col1" >-8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_7f9d0_row6_col0" class="data row6 col0" >-0.630588</td>
#       <td id="T_7f9d0_row6_col1" class="data row6 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_7f9d0_row7_col0" class="data row7 col0" >-0.023588</td>
#       <td id="T_7f9d0_row7_col1" class="data row7 col1" >-1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_7f9d0_row8_col0" class="data row8 col0" >-0.411440</td>
#       <td id="T_7f9d0_row8_col1" class="data row8 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_7f9d0_row9_col0" class="data row9 col0" >0.284419</td>
#       <td id="T_7f9d0_row9_col1" class="data row9 col1" >-14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_7f9d0_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_7f9d0_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f9d0_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_7f9d0_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_7f9d0_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mul
d5.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_e5cfa_row0_col0, #T_e5cfa_row0_col1, #T_e5cfa_row1_col0, #T_e5cfa_row1_col1, #T_e5cfa_row10_col0, #T_e5cfa_row10_col1, #T_e5cfa_row11_col0, #T_e5cfa_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_e5cfa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5cfa_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e5cfa_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5cfa_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_e5cfa_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_e5cfa_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_e5cfa_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_e5cfa_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_e5cfa_row2_col0" class="data row2 col0" >0.381212</td>
#       <td id="T_e5cfa_row2_col1" class="data row2 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_e5cfa_row3_col0" class="data row3 col0" >0.103212</td>
#       <td id="T_e5cfa_row3_col1" class="data row3 col1" >135.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_e5cfa_row4_col0" class="data row4 col0" >0.056994</td>
#       <td id="T_e5cfa_row4_col1" class="data row4 col1" >39.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_e5cfa_row5_col0" class="data row5 col0" >0.639984</td>
#       <td id="T_e5cfa_row5_col1" class="data row5 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_e5cfa_row6_col0" class="data row6 col0" >0.308048</td>
#       <td id="T_e5cfa_row6_col1" class="data row6 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_e5cfa_row7_col0" class="data row7 col0" >0.134387</td>
#       <td id="T_e5cfa_row7_col1" class="data row7 col1" >552.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_e5cfa_row8_col0" class="data row8 col0" >0.535360</td>
#       <td id="T_e5cfa_row8_col1" class="data row8 col1" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_e5cfa_row9_col0" class="data row9 col0" >0.084624</td>
#       <td id="T_e5cfa_row9_col1" class="data row9 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_e5cfa_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_e5cfa_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e5cfa_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_e5cfa_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_e5cfa_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# div
d6.style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_6737d_row0_col0, #T_6737d_row0_col1, #T_6737d_row1_col0, #T_6737d_row1_col1, #T_6737d_row10_col0, #T_6737d_row10_col1, #T_6737d_row11_col0, #T_6737d_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_6737d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6737d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6737d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6737d_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_6737d_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_6737d_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_6737d_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_6737d_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_6737d_row2_col0" class="data row2 col0" >0.697122</td>
#       <td id="T_6737d_row2_col1" class="data row2 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_6737d_row3_col0" class="data row3 col0" >0.222529</td>
#       <td id="T_6737d_row3_col1" class="data row3 col1" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_6737d_row4_col0" class="data row4 col0" >10.394389</td>
#       <td id="T_6737d_row4_col1" class="data row4 col1" >0.230769</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_6737d_row5_col0" class="data row5 col0" >1.312814</td>
#       <td id="T_6737d_row5_col1" class="data row5 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_6737d_row6_col0" class="data row6 col0" >0.338741</td>
#       <td id="T_6737d_row6_col1" class="data row6 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_6737d_row7_col0" class="data row7 col0" >0.937692</td>
#       <td id="T_6737d_row7_col1" class="data row7 col1" >0.958333</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_6737d_row8_col0" class="data row8 col0" >0.573979</td>
#       <td id="T_6737d_row8_col1" class="data row8 col1" >6.500000</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_6737d_row9_col0" class="data row9 col0" >2.566255</td>
#       <td id="T_6737d_row9_col1" class="data row9 col1" >0.066667</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_6737d_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_6737d_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6737d_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_6737d_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_6737d_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### removing the NaN values from the resultant dataframe

# %%
# the + operation is UNION of indexes
d31 = d1+d2
# indexs not present in the other dataframe get a NaN
# do you can obvs remove nan values like before
d3.dropna().style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2fbf1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fbf1_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_2fbf1_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fbf1_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_2fbf1_row0_col0" class="data row0 col0" >1.254995</td>
#       <td id="T_2fbf1_row0_col1" class="data row0 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbf1_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_2fbf1_row1_col0" class="data row1 col0" >0.832590</td>
#       <td id="T_2fbf1_row1_col1" class="data row1 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbf1_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_2fbf1_row2_col0" class="data row2 col0" >0.843736</td>
#       <td id="T_2fbf1_row2_col1" class="data row2 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbf1_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_2fbf1_row3_col0" class="data row3 col0" >1.614818</td>
#       <td id="T_2fbf1_row3_col1" class="data row3 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbf1_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_2fbf1_row4_col0" class="data row4 col0" >1.276649</td>
#       <td id="T_2fbf1_row4_col1" class="data row4 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbf1_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_2fbf1_row5_col0" class="data row5 col0" >0.733555</td>
#       <td id="T_2fbf1_row5_col1" class="data row5 col1" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbf1_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_2fbf1_row6_col0" class="data row6 col0" >1.520106</td>
#       <td id="T_2fbf1_row6_col1" class="data row6 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbf1_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_2fbf1_row7_col0" class="data row7 col0" >0.647603</td>
#       <td id="T_2fbf1_row7_col1" class="data row7 col1" >16.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## df.align()

# %% [markdown]
# Pandas [align](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.align.html) works to join the dataframes in interesting ways.

# %%
# align returns two dataframes - left and right as a result of a join
# default join is outer - the union of indices will be used as index for left and right
left, right = d1.align(d2, join='outer')
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_29165" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29165_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_29165_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29165_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_29165_row0_col0" class="data row0 col0" >0.276765</td>
#       <td id="T_29165_row0_col1" class="data row0 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_29165_row1_col0" class="data row1 col0" >0.109126</td>
#       <td id="T_29165_row1_col1" class="data row1 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_29165_row2_col0" class="data row2 col0" >0.515511</td>
#       <td id="T_29165_row2_col1" class="data row2 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_29165_row3_col0" class="data row3 col0" >0.151551</td>
#       <td id="T_29165_row3_col1" class="data row3 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_29165_row4_col0" class="data row4 col0" >0.769688</td>
#       <td id="T_29165_row4_col1" class="data row4 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_29165_row5_col0" class="data row5 col0" >0.916613</td>
#       <td id="T_29165_row5_col1" class="data row5 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_29165_row6_col0" class="data row6 col0" >0.323030</td>
#       <td id="T_29165_row6_col1" class="data row6 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_29165_row7_col0" class="data row7 col0" >0.354983</td>
#       <td id="T_29165_row7_col1" class="data row7 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_29165_row8_col0" class="data row8 col0" >0.554333</td>
#       <td id="T_29165_row8_col1" class="data row8 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_29165_row9_col0" class="data row9 col0" >0.466011</td>
#       <td id="T_29165_row9_col1" class="data row9 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_29165_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_29165_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_29165_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_29165_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_29165_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2682e" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2682e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_2682e_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2682e_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_2682e_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_2682e_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_2682e_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_2682e_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_2682e_row2_col0" class="data row2 col0" >0.739484</td>
#       <td id="T_2682e_row2_col1" class="data row2 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_2682e_row3_col0" class="data row3 col0" >0.681039</td>
#       <td id="T_2682e_row3_col1" class="data row3 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_2682e_row4_col0" class="data row4 col0" >0.074048</td>
#       <td id="T_2682e_row4_col1" class="data row4 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_2682e_row5_col0" class="data row5 col0" >0.698205</td>
#       <td id="T_2682e_row5_col1" class="data row5 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_2682e_row6_col0" class="data row6 col0" >0.953619</td>
#       <td id="T_2682e_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_2682e_row7_col0" class="data row7 col0" >0.378571</td>
#       <td id="T_2682e_row7_col1" class="data row7 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_2682e_row8_col0" class="data row8 col0" >0.965773</td>
#       <td id="T_2682e_row8_col1" class="data row8 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_2682e_row9_col0" class="data row9 col0" >0.181592</td>
#       <td id="T_2682e_row9_col1" class="data row9 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_2682e_row10_col0" class="data row10 col0" >0.356266</td>
#       <td id="T_2682e_row10_col1" class="data row10 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2682e_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_2682e_row11_col0" class="data row11 col0" >0.004515</td>
#       <td id="T_2682e_row11_col1" class="data row11 col1" >8.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# inner join
left, right = d1.align(d2, join='inner')
render_df_side_by_side(d1,d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b08b2" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b08b2_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b08b2_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b08b2_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_b08b2_row0_col0" class="data row0 col0" >0.276765</td>
#       <td id="T_b08b2_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b08b2_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_b08b2_row1_col0" class="data row1 col0" >0.109126</td>
#       <td id="T_b08b2_row1_col1" class="data row1 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_b08b2_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_b08b2_row2_col0" class="data row2 col0" >0.515511</td>
#       <td id="T_b08b2_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_b08b2_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_b08b2_row3_col0" class="data row3 col0" >0.151551</td>
#       <td id="T_b08b2_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_b08b2_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_b08b2_row4_col0" class="data row4 col0" >0.769688</td>
#       <td id="T_b08b2_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b08b2_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_b08b2_row5_col0" class="data row5 col0" >0.916613</td>
#       <td id="T_b08b2_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b08b2_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_b08b2_row6_col0" class="data row6 col0" >0.323030</td>
#       <td id="T_b08b2_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_b08b2_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_b08b2_row7_col0" class="data row7 col0" >0.354983</td>
#       <td id="T_b08b2_row7_col1" class="data row7 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_b08b2_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_b08b2_row8_col0" class="data row8 col0" >0.554333</td>
#       <td id="T_b08b2_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_b08b2_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_b08b2_row9_col0" class="data row9 col0" >0.466011</td>
#       <td id="T_b08b2_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_bcdb8" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcdb8_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_bcdb8_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcdb8_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_bcdb8_row0_col0" class="data row0 col0" >0.739484</td>
#       <td id="T_bcdb8_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bcdb8_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_bcdb8_row1_col0" class="data row1 col0" >0.681039</td>
#       <td id="T_bcdb8_row1_col1" class="data row1 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_bcdb8_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_bcdb8_row2_col0" class="data row2 col0" >0.074048</td>
#       <td id="T_bcdb8_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_bcdb8_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_bcdb8_row3_col0" class="data row3 col0" >0.698205</td>
#       <td id="T_bcdb8_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_bcdb8_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_bcdb8_row4_col0" class="data row4 col0" >0.953619</td>
#       <td id="T_bcdb8_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bcdb8_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_bcdb8_row5_col0" class="data row5 col0" >0.378571</td>
#       <td id="T_bcdb8_row5_col1" class="data row5 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_bcdb8_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_bcdb8_row6_col0" class="data row6 col0" >0.965773</td>
#       <td id="T_bcdb8_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bcdb8_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_bcdb8_row7_col0" class="data row7 col0" >0.181592</td>
#       <td id="T_bcdb8_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_bcdb8_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_bcdb8_row8_col0" class="data row8 col0" >0.356266</td>
#       <td id="T_bcdb8_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bcdb8_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_bcdb8_row9_col0" class="data row9 col0" >0.004515</td>
#       <td id="T_bcdb8_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# we can fill the NaNs with a certain value if needed
# let's fill with -100 so we can see it clearly
left, right = d1.align(d2, join='outer', fill_value = -100) 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2e484" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e484_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_2e484_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e484_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_2e484_row0_col0" class="data row0 col0" >0.276765</td>
#       <td id="T_2e484_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_2e484_row1_col0" class="data row1 col0" >0.109126</td>
#       <td id="T_2e484_row1_col1" class="data row1 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_2e484_row2_col0" class="data row2 col0" >0.515511</td>
#       <td id="T_2e484_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_2e484_row3_col0" class="data row3 col0" >0.151551</td>
#       <td id="T_2e484_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_2e484_row4_col0" class="data row4 col0" >0.769688</td>
#       <td id="T_2e484_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_2e484_row5_col0" class="data row5 col0" >0.916613</td>
#       <td id="T_2e484_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_2e484_row6_col0" class="data row6 col0" >0.323030</td>
#       <td id="T_2e484_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_2e484_row7_col0" class="data row7 col0" >0.354983</td>
#       <td id="T_2e484_row7_col1" class="data row7 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_2e484_row8_col0" class="data row8 col0" >0.554333</td>
#       <td id="T_2e484_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_2e484_row9_col0" class="data row9 col0" >0.466011</td>
#       <td id="T_2e484_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_2e484_row10_col0" class="data row10 col0" >-100.000000</td>
#       <td id="T_2e484_row10_col1" class="data row10 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_2e484_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_2e484_row11_col0" class="data row11 col0" >-100.000000</td>
#       <td id="T_2e484_row11_col1" class="data row11 col1" >-100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_34629" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34629_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_34629_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34629_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_34629_row0_col0" class="data row0 col0" >-100.000000</td>
#       <td id="T_34629_row0_col1" class="data row0 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_34629_row1_col0" class="data row1 col0" >-100.000000</td>
#       <td id="T_34629_row1_col1" class="data row1 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_34629_row2_col0" class="data row2 col0" >0.739484</td>
#       <td id="T_34629_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_34629_row3_col0" class="data row3 col0" >0.681039</td>
#       <td id="T_34629_row3_col1" class="data row3 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_34629_row4_col0" class="data row4 col0" >0.074048</td>
#       <td id="T_34629_row4_col1" class="data row4 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_34629_row5_col0" class="data row5 col0" >0.698205</td>
#       <td id="T_34629_row5_col1" class="data row5 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_34629_row6_col0" class="data row6 col0" >0.953619</td>
#       <td id="T_34629_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_34629_row7_col0" class="data row7 col0" >0.378571</td>
#       <td id="T_34629_row7_col1" class="data row7 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_34629_row8_col0" class="data row8 col0" >0.965773</td>
#       <td id="T_34629_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_34629_row9_col0" class="data row9 col0" >0.181592</td>
#       <td id="T_34629_row9_col1" class="data row9 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_34629_row10_col0" class="data row10 col0" >0.356266</td>
#       <td id="T_34629_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_34629_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_34629_row11_col0" class="data row11 col0" >0.004515</td>
#       <td id="T_34629_row11_col1" class="data row11 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# left join: left index is added to right, but not the other way
left, right = d1.align(d2, join='left') 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_06109" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06109_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_06109_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06109_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_06109_row0_col0" class="data row0 col0" >0.276765</td>
#       <td id="T_06109_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_06109_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_06109_row1_col0" class="data row1 col0" >0.109126</td>
#       <td id="T_06109_row1_col1" class="data row1 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_06109_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_06109_row2_col0" class="data row2 col0" >0.515511</td>
#       <td id="T_06109_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_06109_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_06109_row3_col0" class="data row3 col0" >0.151551</td>
#       <td id="T_06109_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_06109_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_06109_row4_col0" class="data row4 col0" >0.769688</td>
#       <td id="T_06109_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_06109_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_06109_row5_col0" class="data row5 col0" >0.916613</td>
#       <td id="T_06109_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_06109_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_06109_row6_col0" class="data row6 col0" >0.323030</td>
#       <td id="T_06109_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_06109_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_06109_row7_col0" class="data row7 col0" >0.354983</td>
#       <td id="T_06109_row7_col1" class="data row7 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_06109_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_06109_row8_col0" class="data row8 col0" >0.554333</td>
#       <td id="T_06109_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_06109_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_06109_row9_col0" class="data row9 col0" >0.466011</td>
#       <td id="T_06109_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_71f9e" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71f9e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_71f9e_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71f9e_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_71f9e_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_71f9e_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_71f9e_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_71f9e_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_71f9e_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_71f9e_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_71f9e_row2_col0" class="data row2 col0" >0.739484</td>
#       <td id="T_71f9e_row2_col1" class="data row2 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71f9e_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_71f9e_row3_col0" class="data row3 col0" >0.681039</td>
#       <td id="T_71f9e_row3_col1" class="data row3 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71f9e_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_71f9e_row4_col0" class="data row4 col0" >0.074048</td>
#       <td id="T_71f9e_row4_col1" class="data row4 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71f9e_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_71f9e_row5_col0" class="data row5 col0" >0.698205</td>
#       <td id="T_71f9e_row5_col1" class="data row5 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71f9e_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_71f9e_row6_col0" class="data row6 col0" >0.953619</td>
#       <td id="T_71f9e_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71f9e_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_71f9e_row7_col0" class="data row7 col0" >0.378571</td>
#       <td id="T_71f9e_row7_col1" class="data row7 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71f9e_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_71f9e_row8_col0" class="data row8 col0" >0.965773</td>
#       <td id="T_71f9e_row8_col1" class="data row8 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71f9e_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_71f9e_row9_col0" class="data row9 col0" >0.181592</td>
#       <td id="T_71f9e_row9_col1" class="data row9 col1" >15.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# right join: right index is added to left, but not the other way
left, right = d1.align(d2, join='right') 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5d510" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d510_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_5d510_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d510_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_5d510_row0_col0" class="data row0 col0" >0.515511</td>
#       <td id="T_5d510_row0_col1" class="data row0 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5d510_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_5d510_row1_col0" class="data row1 col0" >0.151551</td>
#       <td id="T_5d510_row1_col1" class="data row1 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5d510_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_5d510_row2_col0" class="data row2 col0" >0.769688</td>
#       <td id="T_5d510_row2_col1" class="data row2 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5d510_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_5d510_row3_col0" class="data row3 col0" >0.916613</td>
#       <td id="T_5d510_row3_col1" class="data row3 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5d510_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_5d510_row4_col0" class="data row4 col0" >0.323030</td>
#       <td id="T_5d510_row4_col1" class="data row4 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5d510_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_5d510_row5_col0" class="data row5 col0" >0.354983</td>
#       <td id="T_5d510_row5_col1" class="data row5 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5d510_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_5d510_row6_col0" class="data row6 col0" >0.554333</td>
#       <td id="T_5d510_row6_col1" class="data row6 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5d510_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_5d510_row7_col0" class="data row7 col0" >0.466011</td>
#       <td id="T_5d510_row7_col1" class="data row7 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5d510_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_5d510_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_5d510_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_5d510_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_5d510_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_5d510_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6a35d" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a35d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6a35d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a35d_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_6a35d_row0_col0" class="data row0 col0" >0.739484</td>
#       <td id="T_6a35d_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6a35d_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_6a35d_row1_col0" class="data row1 col0" >0.681039</td>
#       <td id="T_6a35d_row1_col1" class="data row1 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_6a35d_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_6a35d_row2_col0" class="data row2 col0" >0.074048</td>
#       <td id="T_6a35d_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_6a35d_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_6a35d_row3_col0" class="data row3 col0" >0.698205</td>
#       <td id="T_6a35d_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_6a35d_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_6a35d_row4_col0" class="data row4 col0" >0.953619</td>
#       <td id="T_6a35d_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a35d_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_6a35d_row5_col0" class="data row5 col0" >0.378571</td>
#       <td id="T_6a35d_row5_col1" class="data row5 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_6a35d_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_6a35d_row6_col0" class="data row6 col0" >0.965773</td>
#       <td id="T_6a35d_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6a35d_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_6a35d_row7_col0" class="data row7 col0" >0.181592</td>
#       <td id="T_6a35d_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_6a35d_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_6a35d_row8_col0" class="data row8 col0" >0.356266</td>
#       <td id="T_6a35d_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6a35d_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_6a35d_row9_col0" class="data row9 col0" >0.004515</td>
#       <td id="T_6a35d_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's more to explore in align, and it can get confusing, so beginners be careful, take time and try to work out the result before you execute to build intuition.

# %% [markdown]
# # Operations on data

# %% [markdown]
# ## Stats
#
# Operations in general *exclude* missing data

# %%
# arithmetic mean, for each column (axis = 0)
df.mean()
# Out:
# A    -0.588559
# B     0.290116
# C     0.381389
# D     0.189047
# F    15.500000
# dtype: float64

# %%
# mean across a row (axis = 1)
df.mean(1)
# Out:
# 2022-06-19    2.375777
# 2022-06-20    2.918732
# 2022-06-21    2.528007
# 2022-06-22    2.485680
# 2022-06-23    3.002489
# 2022-06-24    3.700090
# 2022-06-25    3.164714
# 2022-06-26    2.981927
# 2022-06-27    4.204481
# 2022-06-28    4.182090
# Freq: D, dtype: float64

# %% [markdown]
# ## Apply

# %%
# apply custom lambdas
df.apply(lambda x: x.max()-x.min())
# Out:
# A    2.548446
# B    1.591583
# C    3.855814
# D    3.702045
# F    9.000000
# dtype: float64

# %%
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -0.091394 -0.232457  0.787285  0.415453  11
# 2022-06-20 -1.114526  0.719220  0.990554  1.998414  12
# 2022-06-21  0.966391 -0.265913 -1.261981  0.201538  13
# 2022-06-22 -1.238197  0.212930  0.008396 -0.554731  14
# 2022-06-23 -1.083940 -0.300027  0.719421  0.676991  15
# 2022-06-24 -0.364038  1.291556 -0.038523  1.611455  16
# 2022-06-25 -1.582055  1.133541 -0.563134 -0.164781  17
# 2022-06-26 -1.293381 -0.231400  0.138047 -1.703632  18
# 2022-06-27 -0.147540  0.396137  2.593833 -0.820026  19
# 2022-06-28  0.063093  0.177579  0.439995  0.229786  20

# %%
# each subsequent value is a sum of all values before it in the respective column
cumsum_df = df.apply(np.cumsum)
render_df_side_by_side(df, cumsum_df, "OG Dataframe", "Cumulative Sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2afc" style='display:inline'>
#   <caption>OG Dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2afc_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f2afc_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_f2afc_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_f2afc_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_f2afc_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2afc_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_f2afc_row0_col0" class="data row0 col0" >-0.091394</td>
#       <td id="T_f2afc_row0_col1" class="data row0 col1" >-0.232457</td>
#       <td id="T_f2afc_row0_col2" class="data row0 col2" >0.787285</td>
#       <td id="T_f2afc_row0_col3" class="data row0 col3" >0.415453</td>
#       <td id="T_f2afc_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_f2afc_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_f2afc_row1_col0" class="data row1 col0" >-1.114526</td>
#       <td id="T_f2afc_row1_col1" class="data row1 col1" >0.719220</td>
#       <td id="T_f2afc_row1_col2" class="data row1 col2" >0.990554</td>
#       <td id="T_f2afc_row1_col3" class="data row1 col3" >1.998414</td>
#       <td id="T_f2afc_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_f2afc_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_f2afc_row2_col0" class="data row2 col0" >0.966391</td>
#       <td id="T_f2afc_row2_col1" class="data row2 col1" >-0.265913</td>
#       <td id="T_f2afc_row2_col2" class="data row2 col2" >-1.261981</td>
#       <td id="T_f2afc_row2_col3" class="data row2 col3" >0.201538</td>
#       <td id="T_f2afc_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f2afc_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_f2afc_row3_col0" class="data row3 col0" >-1.238197</td>
#       <td id="T_f2afc_row3_col1" class="data row3 col1" >0.212930</td>
#       <td id="T_f2afc_row3_col2" class="data row3 col2" >0.008396</td>
#       <td id="T_f2afc_row3_col3" class="data row3 col3" >-0.554731</td>
#       <td id="T_f2afc_row3_col4" class="data row3 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_f2afc_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_f2afc_row4_col0" class="data row4 col0" >-1.083940</td>
#       <td id="T_f2afc_row4_col1" class="data row4 col1" >-0.300027</td>
#       <td id="T_f2afc_row4_col2" class="data row4 col2" >0.719421</td>
#       <td id="T_f2afc_row4_col3" class="data row4 col3" >0.676991</td>
#       <td id="T_f2afc_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_f2afc_level0_row5" class="row_heading level0 row5" >2022-06-24 00:00:00</th>
#       <td id="T_f2afc_row5_col0" class="data row5 col0" >-0.364038</td>
#       <td id="T_f2afc_row5_col1" class="data row5 col1" >1.291556</td>
#       <td id="T_f2afc_row5_col2" class="data row5 col2" >-0.038523</td>
#       <td id="T_f2afc_row5_col3" class="data row5 col3" >1.611455</td>
#       <td id="T_f2afc_row5_col4" class="data row5 col4" >16</td>
#     </tr>
#     <tr>
#       <th id="T_f2afc_level0_row6" class="row_heading level0 row6" >2022-06-25 00:00:00</th>
#       <td id="T_f2afc_row6_col0" class="data row6 col0" >-1.582055</td>
#       <td id="T_f2afc_row6_col1" class="data row6 col1" >1.133541</td>
#       <td id="T_f2afc_row6_col2" class="data row6 col2" >-0.563134</td>
#       <td id="T_f2afc_row6_col3" class="data row6 col3" >-0.164781</td>
#       <td id="T_f2afc_row6_col4" class="data row6 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_f2afc_level0_row7" class="row_heading level0 row7" >2022-06-26 00:00:00</th>
#       <td id="T_f2afc_row7_col0" class="data row7 col0" >-1.293381</td>
#       <td id="T_f2afc_row7_col1" class="data row7 col1" >-0.231400</td>
#       <td id="T_f2afc_row7_col2" class="data row7 col2" >0.138047</td>
#       <td id="T_f2afc_row7_col3" class="data row7 col3" >-1.703632</td>
#       <td id="T_f2afc_row7_col4" class="data row7 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_f2afc_level0_row8" class="row_heading level0 row8" >2022-06-27 00:00:00</th>
#       <td id="T_f2afc_row8_col0" class="data row8 col0" >-0.147540</td>
#       <td id="T_f2afc_row8_col1" class="data row8 col1" >0.396137</td>
#       <td id="T_f2afc_row8_col2" class="data row8 col2" >2.593833</td>
#       <td id="T_f2afc_row8_col3" class="data row8 col3" >-0.820026</td>
#       <td id="T_f2afc_row8_col4" class="data row8 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_f2afc_level0_row9" class="row_heading level0 row9" >2022-06-28 00:00:00</th>
#       <td id="T_f2afc_row9_col0" class="data row9 col0" >0.063093</td>
#       <td id="T_f2afc_row9_col1" class="data row9 col1" >0.177579</td>
#       <td id="T_f2afc_row9_col2" class="data row9 col2" >0.439995</td>
#       <td id="T_f2afc_row9_col3" class="data row9 col3" >0.229786</td>
#       <td id="T_f2afc_row9_col4" class="data row9 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0c8a0" style='display:inline'>
#   <caption>Cumulative Sum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c8a0_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0c8a0_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_0c8a0_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_0c8a0_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_0c8a0_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c8a0_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_0c8a0_row0_col0" class="data row0 col0" >-0.091394</td>
#       <td id="T_0c8a0_row0_col1" class="data row0 col1" >-0.232457</td>
#       <td id="T_0c8a0_row0_col2" class="data row0 col2" >0.787285</td>
#       <td id="T_0c8a0_row0_col3" class="data row0 col3" >0.415453</td>
#       <td id="T_0c8a0_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_0c8a0_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_0c8a0_row1_col0" class="data row1 col0" >-1.205920</td>
#       <td id="T_0c8a0_row1_col1" class="data row1 col1" >0.486762</td>
#       <td id="T_0c8a0_row1_col2" class="data row1 col2" >1.777839</td>
#       <td id="T_0c8a0_row1_col3" class="data row1 col3" >2.413866</td>
#       <td id="T_0c8a0_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_0c8a0_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_0c8a0_row2_col0" class="data row2 col0" >-0.239528</td>
#       <td id="T_0c8a0_row2_col1" class="data row2 col1" >0.220849</td>
#       <td id="T_0c8a0_row2_col2" class="data row2 col2" >0.515858</td>
#       <td id="T_0c8a0_row2_col3" class="data row2 col3" >2.615404</td>
#       <td id="T_0c8a0_row2_col4" class="data row2 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_0c8a0_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_0c8a0_row3_col0" class="data row3 col0" >-1.477725</td>
#       <td id="T_0c8a0_row3_col1" class="data row3 col1" >0.433779</td>
#       <td id="T_0c8a0_row3_col2" class="data row3 col2" >0.524254</td>
#       <td id="T_0c8a0_row3_col3" class="data row3 col3" >2.060674</td>
#       <td id="T_0c8a0_row3_col4" class="data row3 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_0c8a0_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_0c8a0_row4_col0" class="data row4 col0" >-2.561666</td>
#       <td id="T_0c8a0_row4_col1" class="data row4 col1" >0.133752</td>
#       <td id="T_0c8a0_row4_col2" class="data row4 col2" >1.243675</td>
#       <td id="T_0c8a0_ro

# %% [markdown]
# ## Histogramming
#
# Frequencies, 'nuff said
#
# ```value_counts()```

# %%
series1 = pd.Series(np.random.randint(0,5, size = 25))
series1.value_counts()
# Out:
# 2    9
# 3    6
# 0    4
# 4    4
# 1    2
# dtype: int64

# %% [markdown]
# ## String Methods

# %%
# build a series
some_string = "SERIes and Index are EqUIppeD WITh A seT Of stRINg PROCESSING METHoDs In tHe ```sTR``` attrIBute THAT MakE IT eASy To oPerATE ON EACh ELEmeNt OF The aRrAY. NOtE thAt PAtTERN-maTching in ```sTR``` gENeralLY UsES reGUlAr eXpreSsiONs bY DEfault (aND In Some cases AlwayS uSEs tHeM)."
str_series = pd.Series(some_string.split()) # split splits on whitespace by default

# %%
# manipulating the case - lower, upper etc.
# also the length of each string, split, replace, yada yada...
# very important when cleaning data (column names may have stupid whitespace, bad case, spacing etc.)
low = str_series.str.lower()
up = str_series.str.upper()

low_up_df = pd.DataFrame(
    {
        'og': str_series,
        'length': str_series.str.len(),
        'low': low,
        'up': up,
        'split_low_on_i': low.str.split('i', expand = False), # expand = True will break this usecase, try elsewhere
        'replace_a_with_star_in_low': low.str.replace('a','*', case=False, regex=True) # yeah, you can mess with regular expns
    })

low_up_df.tail(10)
# Out:
#              og  length          low           up  split_low_on_i  \
# 36  eXpreSsiONs      11  expressions  EXPRESSIONS  [express, ons]
# 37           bY       2           by           BY            [by]
# 38      DEfault       7      default      DEFAULT       [default]
# 39         (aND       4         (and         (AND          [(and]
# 40           In       2           in           IN           [, n]
# 41         Some       4         some         SOME          [some]
# 42        cases       5        cases        CASES         [cases]
# 43       AlwayS       6       always       ALWAYS        [always]
# 44         uSEs       4         uses         USES          [uses]
# 45       tHeM).       6       them).       THEM).        [them).]
#
#    replace_a_with_star_in_low
# 36                expressions
# 37                         by
# 38                    def*ult
# 39                       (*nd
# 40                         in
# 41                       some
# 42                      c*ses
# 43                     *lw*ys
# 44                       uses
# 45                     them).

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods) for more string operations.

# %% [markdown]
# # Merge
#
# Combine series and dataframes, use set logic for indexes and relational algebra for joins/merges

# %% [markdown]
# ## Concat
#
# Chill, we've done this before. The same join = inner/outer/left/right drill.

# %%
# let's make some more dataframes
concatDF = pd.DataFrame(np.random.randn(10,4)) # 10 rows and 4 columns of random numbers
pieces = [concatDF[:3], concatDF[3:7], concatDF[7:]]
reconstructedDF = pd.concat(pieces)
display('broken DFs: ',pieces)
render_df_side_by_side(concatDF, reconstructedDF, "OG", "Concatenated")
# Out:
# 'broken DFs: '
# [          0         1         2         3
#  0 -0.543653 -0.016503 -1.062328 -0.338274
#  1 -0.243079 -0.121480 -0.327128 -1.000054
#  2 -0.047256 -0.417095 -0.188088 -1.134630,
#            0         1         2         3
#  3  0.161013 -0.286477  0.647000 -0.537667
#  4 -2.270069 -1.913138 -0.002178  1.831463
#  5 -1.062015  0.452698  1.004637 -0.850530
#  6  0.123638  0.241981  0.714469 -1.787371,
#            0         1         2         3
#  7 -0.100657  0.008415 -1.774646 -0.424636
#  8 -1.296558  0.662375  0.349946 -0.252024
#  9  0.700710 -0.077555  0.375872  0.854397]
# <style type="text/css">
# </style>
# <table id="T_75075" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75075_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_75075_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_75075_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_75075_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75075_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75075_row0_col0" class="data row0 col0" >-0.543653</td>
#       <td id="T_75075_row0_col1" class="data row0 col1" >-0.016503</td>
#       <td id="T_75075_row0_col2" class="data row0 col2" >-1.062328</td>
#       <td id="T_75075_row0_col3" class="data row0 col3" >-0.338274</td>
#     </tr>
#     <tr>
#       <th id="T_75075_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75075_row1_col0" class="data row1 col0" >-0.243079</td>
#       <td id="T_75075_row1_col1" class="data row1 col1" >-0.121480</td>
#       <td id="T_75075_row1_col2" class="data row1 col2" >-0.327128</td>
#       <td id="T_75075_row1_col3" class="data row1 col3" >-1.000054</td>
#     </tr>
#     <tr>
#       <th id="T_75075_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75075_row2_col0" class="data row2 col0" >-0.047256</td>
#       <td id="T_75075_row2_col1" class="data row2 col1" >-0.417095</td>
#       <td id="T_75075_row2_col2" class="data row2 col2" >-0.188088</td>
#       <td id="T_75075_row2_col3" class="data row2 col3" >-1.134630</td>
#     </tr>
#     <tr>
#       <th id="T_75075_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75075_row3_col0" class="data row3 col0" >0.161013</td>
#       <td id="T_75075_row3_col1" class="data row3 col1" >-0.286477</td>
#       <td id="T_75075_row3_col2" class="data row3 col2" >0.647000</td>
#       <td id="T_75075_row3_col3" class="data row3 col3" >-0.537667</td>
#     </tr>
#     <tr>
#       <th id="T_75075_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_75075_row4_col0" class="data row4 col0" >-2.270069</td>
#       <td id="T_75075_row4_col1" class="data row4 col1" >-1.913138</td>
#       <td id="T_75075_row4_col2" class="data row4 col2" >-0.002178</td>
#       <td id="T_75075_row4_col3" class="data row4 col3" >1.831463</td>
#     </tr>
#     <tr>
#       <th id="T_75075_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_75075_row5_col0" class="data row5 col0" >-1.062015</td>
#       <td id="T_75075_row5_col1" class="data row5 col1" >0.452698</td>
#       <td id="T_75075_row5_col2" class="data row5 col2" >1.004637</td>
#       <td id="T_75075_row5_col3" class="data row5 col3" >-0.850530</td>
#     </tr>
#     <tr>
#       <th id="T_75075_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_75075_row6_col0" class="data row6 col0" >0.123638</td>
#       <td id="T_75075_row6_col1" class="data row6 col1" >0.241981</td>
#       <td id="T_75075_row6_col2" class="data row6 col2" >0.714469</td>
#       <td id="T_75075_row6_col3" class="data row6 col3" >-1.787371</td>
#     </tr>
#     <tr>
#       <th id="T_75075_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_75075_row7_col0" class="data row7 col0" >-0.100657</td>
#       <td id="T_75075_row7_col1" class="data row7 col1" >0.008415</td>
#       <td id="T_75075_row7_col2" class="data row7 col2" >-1.774646</td>
#       <td id="T_75075_row7_col3" class="data row7 col3" >-0.424636</td>
#     </tr>
#     <tr>
#       <th id="T_75075_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_75075_row8_col0" class="data row8 col0" >-1.296558</td>
#       <td id="T_75075_row8_col1" class="data row8 col1" >0.662375</td>
#       <td id="T_75075_row8_col2" class="data row8 col2" >0.349946</td>
#       <td id="T_75075_row8_col3" class="data row8 col3" >-0.252024</td>
#     </tr>
#     <tr>
#       <th id="T_75075_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_75075_row9_col0" class="data row9 col0" >0.700710</td>
#       <td id="T_75075_row9_col1" class="data row9 col1" >-0.077555</td>
#       <td id="T_75075_row9_col2" class="data row9 col2" >0.375872</td>
#       <td id="T_75075_row9_col3" class="data row9 col3" >0.854397</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_70f71" style='display:inline'>
#   <caption>Concatenated</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70f71_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_70f71_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_70f71_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_70f71_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70f71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70f71_row0_col0" class="data row0 col0" >-0.543653</td>
#       <td id="T_70f71_row0_col1" class="data row0 col1" >-0.016503</td>
#       <td id="T_70f71_row0_col2" class="data row0 col2" >-1.062328</td>
#       <td id="T_70f71_row0_col3" class="data row0 col3" >-0.338274</td>
#     </tr>
#     <tr>
#       <th id="T_70f71_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_70f71_row1_col0" class="data row1 col0" >-0.243079</td>
#       <td id="T_70f71_row1_col1" class="data row1 col1" >-0.121480</td>
#       <td id="T_70f71_row1_col2" class="data row1 col2" >-0.327128</td>
#       <td id="T_70f71_row1_col3" class="data row1 col3" >-1.000054</td>
#     </tr>
#     <tr>
#       <th id="T_70f71_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_70f71_row2_col0" class="data row2 col0" >-0.047256</td>
#       <td id="T_70f71_row2_col1" class="data row2 col1" >-0.417095</td>
#       <td id="T_70f71_row2_col2" class="data row2 col2" >-0.188088</td>
#       <td id="T_70f71_row2_col3" class="data row2 col3" >-1.134630</td>
#     </tr>
#     <tr>
#       <th id="T_70f71_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_70f71_row3_col0" class="data row3 col0" >0.161013</td>
#       <td id="T_70f71_row3_col1" class="data row3 col1" >-0.286477</td>
#       <td id="T_70f71_row3_col2" class="data row3 col2" >0.647000</td>
#       <td id="T_70f71_row3_col3" class="data row3 col3" >-0.537667</td>
#     </tr>
#     <tr>
#       <th id="T_70f71_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_70f71_row4_col0" class="data row4 col0" >-2.270069</td>
#       <td id="T_70f71_row4_col1" class="data row4 col1" >-1.913138</td>
#       <td id="T_70f71_row4_col2" class="data row4 col2" >-0.002178</td>
#       <td id="T_70f71_row4_col3" class="data row4 col3" >1.831463</td>
#     </tr>
#     <tr>
#       <th id="T_70f71_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_70f71_row5_col0" class="data row5 col0" >-1.062015</td>
#       <td id="T_70f71_row5_col1" class="data row5 col1" >0.452698</td>
#       <td id="T_70f71_row5_col2" class="data row5 col2" >1.004637</td>
#       <td id="T_70f71_row5_col3" class="data row5 col3" >-0.850530</td>
#     </tr>
#     <tr>
#       <th id="T_70f71_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_70f71_row6_col0" class="data row6 col0" >0.123638</td>
#       <td id="T_70f71_row6_col1" class="data row6 col1" >0.241981</td>
#       <td id="T_70f71_row6_col2" class="data row6 col2" >0.714469</td>
#       <td id="T_70f71_row6_col3" class="data row6 col3" >-1.787371</td>
#     </tr>
#     <tr>
#       <th id="T_70f71_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_70f71_row7_col0" class="data row7 col0" >-0.100657</td>
#       <td id="T_70f71_row7_col1" class="data row7 col1" >0.008415</td>
#       <td id="T_70f71_row7_col2" class="data row7 col2" >-1.774646</td>
#       <td id="T_70f71_row7_col3" class="data row7 col3" >-0.424636</td>
#     </tr>
#     <tr>
#       <th id="T_70f71_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_70f71_row8_col0" class="dat

# %% [markdown]
# _From the [page](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#concat)_:
# Adding a column to a DataFrame is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the DataFrame constructor instead of building a DataFrame by iteratively appending records to it.

# %% [markdown]
# ## Join
# SQL style merges.

# %%
# two data frames
sl = pd.Series(np.random.randint(10, size=6))
sr = sl.shift(2).fillna(0).astype(int)
left = pd.DataFrame(
    {
        'key': list('ABCDEF'),
        'lval': sl
    }
)

right = pd.DataFrame(
    {
        'key': list('ABBCDE'),
        'rval': sr
    }
)

# %%
render_df_side_by_side(left, right, 'left', 'right')
# Out:
# <style type="text/css">
# </style>
# <table id="T_00d6c" style='display:inline'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00d6c_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_00d6c_level0_col1" class="col_heading level0 col1" >lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00d6c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00d6c_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_00d6c_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_00d6c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00d6c_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_00d6c_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_00d6c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00d6c_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_00d6c_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_00d6c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00d6c_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_00d6c_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_00d6c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00d6c_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_00d6c_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_00d6c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_00d6c_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_00d6c_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_85df7" style='display:inline'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85df7_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_85df7_level0_col1" class="col_heading level0 col1" >rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85df7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85df7_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_85df7_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_85df7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85df7_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_85df7_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_85df7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85df7_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_85df7_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_85df7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85df7_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_85df7_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_85df7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85df7_row4_col0" class="data row4 col0" >D</td>
#       <td id="T_85df7_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_85df7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_85df7_row5_col0" class="data row5 col0" >E</td>
#       <td id="T_85df7_row5_col1" class="data row5 col1" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pd.merge(left, right, on='key')
result
# Out:
#   key  lval  rval
# 0   A     0     0
# 1   B     8     0
# 2   B     8     0
# 3   C     7     8
# 4   D     9     7
# 5   E     0     9

# %% [markdown]
# # Grouping

# %% [markdown]
# "Group By" really means one or more of the following happening:
# 1. **Split**: data is broken into groups based on some criteria
# 2. **Apply**: a data operation is executed on each of those groups
# 3. **Combine**: the results are combined back into a data structure

# %%
grp_df = pd.DataFrame(
    {
        'colA': list('AABCAABDAA'),
        'colB': list('1234567890'),
        'colC': np.random.randn(10),
        'colD': np.random.randn(10)
    }
)
grp_df
# Out:
#   colA colB      colC      colD
# 0    A    1  0.547327 -0.237943
# 1    A    2 -0.470711  0.164373
# 2    B    3  1.870100  0.940132
# 3    C    4  2.100350  2.232938
# 4    A    5  0.582920  0.566085
# 5    A    6  0.528269  0.741529
# 6    B    7 -0.974086  1.659660
# 7    D    8  0.646308 -0.913415
# 8    A    9  1.388734 -0.349800
# 9    A    0 -0.098304 -0.805733

# %%
# a DataFrameGroupBy object object
grpby = grp_df.groupby('colA')

# list all the groups found
g = grpby.groups
g
# Out:
# {'A': [0, 1, 4, 5, 8, 9], 'B': [2, 6], 'C': [3], 'D': [7]}

# %%
# to create a dataframe from the group use something like
grpby.get_group('A')
# Out:
#   colA colB      colC      colD
# 0    A    1  0.547327 -0.237943
# 1    A    2 -0.470711  0.164373
# 4    A    5  0.582920  0.566085
# 5    A    6  0.528269  0.741529
# 8    A    9  1.388734 -0.349800
# 9    A    0 -0.098304 -0.805733

# %% [markdown]
# ### Find all the groups

# %%
# but we may not know all the groups in the dataframe.
# so got to find a way to list all groups as dataframes.
# 
# some basic python helps create a list of groupby names
grpby_labels_list = [*g.keys()] # using the unpacking operator *
# alternatively
# grpby_labels_list = list(g.keys())
grpby_labels_list
# Out:
# ['A', 'B', 'C', 'D']

# %%
# create a dict where the group label is the key and the group dataframe is the value
grps = {lbl: grpby.get_group(lbl) for lbl in grpby_labels_list}

# now use the dict to access individual dataframes created out of the groupby operation
grps['B']

# question: can we create a dataframe of dataframes?
# Out:
#   colA colB      colC      colD
# 2    B    3  1.870100  0.940132
# 6    B    7 -0.974086  1.659660

# %%
# You can see the datatype of the value is a pandas dataframe
type(grps['A'])
# Out:
# pandas.core.frame.DataFrame

# %%
# make a function of it all...
def get_all_groups(df_grpby):
    return {lbl: df_grpby.get_group(lbl) for lbl in list(df_grpby.groups.keys())}

# %%
grps = get_all_groups(grp_df.groupby('colA'))
grps
# Out:
# {'A':   colA colB      colC      colD
#  0    A    1  0.547327 -0.237943
#  1    A    2 -0.470711  0.164373
#  4    A    5  0.582920  0.566085
#  5    A    6  0.528269  0.741529
#  8    A    9  1.388734 -0.349800
#  9    A    0 -0.098304 -0.805733,
#  'B':   colA colB      colC      colD
#  2    B    3  1.870100  0.940132
#  6    B    7 -0.974086  1.659660,
#  'C':   colA colB     colC      colD
#  3    C    4  2.10035  2.232938,
#  'D':   colA colB      colC      colD
#  7    D    8  0.646308 -0.913415}

# %%
# get a sum of values from each group
grp_df.groupby('colA').sum()
# Out:
#           colC      colD
# colA
# A     2.478235  0.078512
# B     0.896014  2.599793
# C     2.100350  2.232938
# D     0.646308 -0.913415

# %%
# let's add one more column to the dataframe
# we can try grouping on two columns
grp_df['colE'] = list('1231231231')
grp_df
# Out:
#   colA colB      colC      colD colE
# 0    A    1  0.547327 -0.237943    1
# 1    A    2 -0.470711  0.164373    2
# 2    B    3  1.870100  0.940132    3
# 3    C    4  2.100350  2.232938    1
# 4    A    5  0.582920  0.566085    2
# 5    A    6  0.528269  0.741529    3
# 6    B    7 -0.974086  1.659660    1
# 7    D    8  0.646308 -0.913415    2
# 8    A    9  1.388734 -0.349800    3
# 9    A    0 -0.098304 -0.805733    1

# %%
g2 = grp_df.groupby(['colA','colE'])
grps2 = get_all_groups(g2)
grps2
# Out:
# {('A',
#   '1'):   colA colB      colC      colD colE
#  0    A    1  0.547327 -0.237943    1
#  9    A    0 -0.098304 -0.805733    1,
#  ('A',
#   '2'):   colA colB      colC      colD colE
#  1    A    2 -0.470711  0.164373    2
#  4    A    5  0.582920  0.566085    2,
#  ('A',
#   '3'):   colA colB      colC      colD colE
#  5    A    6  0.528269  0.741529    3
#  8    A    9  1.388734 -0.349800    3,
#  ('B',
#   '1'):   colA colB      colC     colD colE
#  6    B    7 -0.974086  1.65966    1,
#  ('B',
#   '3'):   colA colB    colC      colD colE
#  2    B    3  1.8701  0.940132    3,
#  ('C',
#   '1'):   colA colB     colC      colD colE
#  3    C    4  2.10035  2.232938    1,
#  ('D',
#   '2'):   colA colB      colC      colD colE
#  7    D    8  0.646308 -0.913415    2}

# %%
render_df_side_by_side(grps2[('A','1')], grps2[('A','2')], 'A,1', 'A,2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4ab1d" style='display:inline'>
#   <caption>A,1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ab1d_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_4ab1d_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_4ab1d_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_4ab1d_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_4ab1d_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ab1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ab1d_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_4ab1d_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_4ab1d_row0_col2" class="data row0 col2" >0.547327</td>
#       <td id="T_4ab1d_row0_col3" class="data row0 col3" >-0.237943</td>
#       <td id="T_4ab1d_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4ab1d_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_4ab1d_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_4ab1d_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_4ab1d_row1_col2" class="data row1 col2" >-0.098304</td>
#       <td id="T_4ab1d_row1_col3" class="data row1 col3" >-0.805733</td>
#       <td id="T_4ab1d_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_5c7c0" style='display:inline'>
#   <caption>A,2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c7c0_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_5c7c0_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_5c7c0_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_5c7c0_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_5c7c0_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c7c0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5c7c0_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_5c7c0_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_5c7c0_row0_col2" class="data row0 col2" >-0.470711</td>
#       <td id="T_5c7c0_row0_col3" class="data row0 col3" >0.164373</td>
#       <td id="T_5c7c0_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5c7c0_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_5c7c0_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_5c7c0_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_5c7c0_row1_col2" class="data row1 col2" >0.582920</td>
#       <td id="T_5c7c0_row1_col3" class="data row1 col3" >0.566085</td>
#       <td id="T_5c7c0_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reshaping
#
# Stacking and Pivot Tables.
# This really warrants more practice, at least go through [the page](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#)

# %% [markdown]
# ## Stacking

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %% [markdown]
# If the syntax [*expression](https://docs.python.org/dev/reference/expressions.html#calls) appears in the function call, expression must evaluate to an iterable. Elements from these iterables are treated as if they were additional positional arguments.
#
# ...although the *expression syntax may appear after explicit keyword arguments, it is processed before the keyword arguments (and any **expression arguments)

# %%
# starred expressions...
def f(a,b):
    print(a, ' ', b)
    
f (b=1, *(2,)) # works, the tuple (iterable) is expanded, 2 is assigned to a, then b fills the next argument slot
# f (a=1, *(2,)) # FAILS, multiple values for argument 'a'
# Out:
# 2   1

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
stack_idx = pd.MultiIndex.from_tuples(tuples, names = ['first', 'second'])

# %%
stack_df = pd.DataFrame(np.random.randn(8,2), index = stack_idx, columns = ['a','b'])
stack_df
# Out:
#                      a         b
# first second
# bar   one    -1.422798  1.298633
#       two    -0.660550 -0.710763
# baz   one    -0.066918  0.500443
#       two     0.358782 -0.062747
# foo   one    -1.682336 -2.049614
#       two     1.391111 -1.411540
# qux   one     0.751701 -0.429402
#       two    -0.341028 -1.345707

# %%
# stack really just combines the columns
stacked = stack_df.stack()
stacked
# Out:
# first  second
# bar    one     a   -1.422798
#                b    1.298633
#        two     a   -0.660550
#                b   -0.710763
# baz    one     a   -0.066918
#                b    0.500443
#        two     a    0.358782
#                b   -0.062747
# foo    one     a   -1.682336
#                b   -2.049614
#        two     a    1.391111
#                b   -1.411540
# qux    one     a    0.751701
#                b   -0.429402
#        two     a   -0.341028
#                b   -1.345707
# dtype: float64

# %%
# unstacked brings back the two columns
# by default unstacks the last level
unstacked = stacked.unstack()
unstacked
# Out:
#                      a         b
# first second
# bar   one    -1.422798  1.298633
#       two    -0.660550 -0.710763
# baz   one    -0.066918  0.500443
#       two     0.358782 -0.062747
# foo   one    -1.682336 -2.049614
#       two     1.391111 -1.411540
# qux   one     0.751701 -0.429402
#       two    -0.341028 -1.345707

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   a -1.422798 -0.660550
#       b  1.298633 -0.710763
# baz   a -0.066918  0.358782
#       b  0.500443 -0.062747
# foo   a -1.682336  1.391111
#       b -2.049614 -1.411540
# qux   a  0.751701 -0.341028
#       b -0.429402 -1.345707

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    a -1.422798 -0.066918 -1.682336  0.751701
#        b  1.298633  0.500443 -2.049614 -0.429402
# two    a -0.660550  0.358782  1.391111 -0.341028
#        b -0.710763 -0.062747 -1.411540 -1.345707

# %%
# you can basically pivot the columns and rows using a combination of stack() and unstack()
unstacked.unstack()
# Out:
#                a                   b
# second       one       two       one       two
# first
# bar    -1.422798 -0.660550  1.298633 -0.710763
# baz    -0.066918  0.358782  0.500443 -0.062747
# foo    -1.682336  1.391111 -2.049614 -1.411540
# qux     0.751701 -0.341028 -0.429402 -1.345707

# %% [markdown]
# ## Pivot Tables

# %%
# we're now just using data created in the pandas documentation - just cause, time.
pivot_tables_df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
pivot_tables_df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.126384  1.353959
# 1     one  B  foo -0.116628 -1.565417
# 2     two  C  foo -0.700660  1.176152
# 3   three  A  bar  0.787943  0.109820
# 4     one  B  bar -0.969489 -0.464424
# 5     one  C  bar -1.564363 -0.588029
# 6     two  A  foo -0.626959  0.858606
# 7   three  B  foo  0.043848 -0.196932
# 8     one  C  foo  0.313904 -0.153362
# 9     one  A  bar  2.105841  0.032878
# 10    two  B  bar  0.408724 -0.442740
# 11  three  C  bar -0.828734  0.060523

# %%
# simple pivot tables - data, values to aggregate, index, columns to pivot along
pd.pivot_table(pivot_tables_df, values = 'D', index = ['A', 'B'], columns = ['C'])
# Out:
# C             bar       foo
# A     B
# one   A  2.105841  0.126384
#       B -0.969489 -0.116628
#       C -1.564363  0.313904
# three A  0.787943       NaN
#       B       NaN  0.043848
#       C -0.828734       NaN
# two   A       NaN -0.626959
#       B  0.408724       NaN
#       C       NaN -0.700660

# %%
# more'n one columns of values
# mark all NaN as zero (0)
pd.pivot_table(pivot_tables_df, values = ['D', 'E'], index = ['A', 'B'], columns = ['C']).fillna(0)
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A  2.105841  0.126384  0.032878  1.353959
#       B -0.969489 -0.116628 -0.464424 -1.565417
#       C -1.564363  0.313904 -0.588029 -0.153362
# three A  0.787943  0.000000  0.109820  0.000000
#       B  0.000000  0.043848  0.000000 -0.196932
#       C -0.828734  0.000000  0.060523  0.000000
# two   A  0.000000 -0.626959  0.000000  0.858606
#       B  0.408724  0.000000 -0.442740  0.000000
#       C  0.000000 -0.700660  0.000000  1.176152

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# We may need to resample data to a different time-frequency.
# Like get data every second and resample to data every 5 minutes and so on...

# %%
rng = pd.date_range('01/01/2022', periods = 1000, freq = 'S')

# %%
ts = pd.Series(np.random.randint(0,500, len(rng)), index=rng)

# %%
ts.resample('5min').sum()
# Out:
# 2022-01-01 00:00:00    76563
# 2022-01-01 00:05:00    76560
# 2022-01-01 00:10:00    74372
# 2022-01-01 00:15:00    25553
# Freq: 5T, dtype: int32

# %% [markdown]
# read up on [date offset strings](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) like '5min' etc.

# %% [markdown]
# ## Timezones

# %%
# timezone representation
rng2 = pd.date_range('01/01/2022', periods = 500, freq='D')
ts2 = pd.Series(np.random.randint(0,365, len(rng2)), index=rng2)
ts2_utc = ts2.tz_localize('UTC')

# %%
# convert to US/Eastern
ts2_utc.tz_convert('US/Eastern')
# Out:
# 2021-12-31 19:00:00-05:00    110
# 2022-01-01 19:00:00-05:00    235
# 2022-01-02 19:00:00-05:00    244
# 2022-01-03 19:00:00-05:00    156
# 2022-01-04 19:00:00-05:00    174
#                             ...
# 2023-05-10 20:00:00-04:00    147
# 2023-05-11 20:00:00-04:00     93
# 2023-05-12 20:00:00-04:00    298
# 2023-05-13 20:00:00-04:00    337
# 2023-05-14 20:00:00-04:00    195
# Freq: D, Length: 500, dtype: int32

# %% [markdown]
# ## Time span representations
#
# Converting between periods and timestamps.
#
# Period is a _timespan_ - span of time between two timestamps.

# %%
# month - end of each 
rng3 = pd.date_range('01/01/2022', periods = 12, freq='M')
rng3
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts3 = pd.Series(np.random.randn(len(rng3)), index = rng3)
ts3
# Out:
# 2022-01-31   -0.767232
# 2022-02-28   -0.841027
# 2022-03-31    1.077927
# 2022-04-30   -0.227048
# 2022-05-31    1.673222
# 2022-06-30   -1.098217
# 2022-07-31   -0.809242
# 2022-08-31   -0.390512
# 2022-09-30    0.193184
# 2022-10-31   -1.205932
# 2022-11-30    1.722972
# 2022-12-31   -0.250495
# Freq: M, dtype: float64

# %%
ps = ts3.to_period()
ps
# Out:
# 2022-01   -0.767232
# 2022-02   -0.841027
# 2022-03    1.077927
# 2022-04   -0.227048
# 2022-05    1.673222
# 2022-06   -1.098217
# 2022-07   -0.809242
# 2022-08   -0.390512
# 2022-09    0.193184
# 2022-10   -1.205932
# 2022-11    1.722972
# 2022-12   -0.250495
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2022-01-01   -0.767232
# 2022-02-01   -0.841027
# 2022-03-01    1.077927
# 2022-04-01   -0.227048
# 2022-05-01    1.673222
# 2022-06-01   -1.098217
# 2022-07-01   -0.809242
# 2022-08-01   -0.390512
# 2022-09-01    0.193184
# 2022-10-01   -1.205932
# 2022-11-01    1.722972
# 2022-12-01   -0.250495
# Freq: MS, dtype: float64

# %% [markdown]
# A more complex use-case:
# convert a _quarterly frequency_ with _year ending in November_ to _9am_ of _the end of the month_ _following_ the _quarter end_

# %%
prng = pd.period_range('1990Q1', '2022Q4', freq='Q-NOV')
type(prng)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
ts4 = pd.Series(np.random.randn(len(prng)), index=prng)
ts4.head()
# Out:
# 1990Q1   -0.010376
# 1990Q2    2.927529
# 1990Q3   -0.076932
# 1990Q4   -1.199375
# 1991Q1    0.462082
# Freq: Q-NOV, dtype: float64

# %%
ts4.index = (prng.asfreq('M', 'e') +1).asfreq('H', 's')+9
ts4.head()
# Out:
# 1990-03-01 09:00   -0.010376
# 1990-06-01 09:00    2.927529
# 1990-09-01 09:00   -0.076932
# 1990-12-01 09:00   -1.199375
# 1991-03-01 09:00    0.462082
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
#
# [This page](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical).
#
# For e.g., gender, social class, blood type, country affiliation, observation time or rating via Likert scales.
# Categorical data. Categories allow (usually) fixed number of possible values. Categorical data may have some order, but not support numerical operations (for e.g., 'strongly agree', 'agree', 'disagree', 'strongly disagree').

# %%
cat_df = pd.DataFrame(
    {"id": list('123456'), "raw_grade":list('abbaae')}
)
cat_df
# Out:
#   id raw_grade
# 0  1         a
# 1  2         b
# 2  3         b
# 3  4         a
# 4  5         a
# 5  6         e

# %%
# convert the raw_grade col to categories
cat_df['grade'] = cat_df['raw_grade'].astype('category')
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
cat_df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# can give more meaningful names here
# direct assignment to Series.cat.categories()
cat_df['grade'].cat.categories = ['very good', 'meh', 'very bad']
cat_df['grade']
# Out:
# 0    very good
# 1          meh
# 2          meh
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'meh', 'very bad']

# %%
cat_df
# Out:
#   id raw_grade      grade
# 0  1         a  very good
# 1  2         b        meh
# 2  3         b        meh
# 3  4         a  very good
# 4  5         a  very good
# 5  6         e   very bad

# %%
# list of categories 
list(cat_df['grade'].cat.categories)

# categorical.CategoricalAccessor encapsulates all changes to categoricals
# for e.g., set_categories or remove_categories
# dir(cat_df['grade'].cat)
# Out:
# ['very good', 'meh', 'very bad']

# %%
# add more categories
cat_df['grade'] = cat_df['grade'].cat.set_categories(["very bad", "bad", "meh", "good", "very good"])
# new list of categories
list(cat_df['grade'].cat.categories)
# Out:
# ['very bad', 'bad', 'meh', 'good', 'very good']

# %%
# now when we can sort the dataframe in order of categories (not lexical)
sorted_cat_df = cat_df.sort_values(by='grade')
render_df_side_by_side(cat_df, sorted_cat_df, 'OG', 'Sorted')
# Out:
# <style type="text/css">
# </style>
# <table id="T_25fb5" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25fb5_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_25fb5_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_25fb5_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25fb5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25fb5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_25fb5_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_25fb5_row0_col2" class="data row0 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_25fb5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25fb5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_25fb5_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_25fb5_row1_col2" class="data row1 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_25fb5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25fb5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_25fb5_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_25fb5_row2_col2" class="data row2 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_25fb5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25fb5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_25fb5_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_25fb5_row3_col2" class="data row3 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_25fb5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25fb5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_25fb5_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_25fb5_row4_col2" class="data row4 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_25fb5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_25fb5_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_25fb5_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_25fb5_row5_col2" class="data row5 col2" >very bad</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0b9b0" style='display:inline'>
#   <caption>Sorted</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b9b0_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_0b9b0_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_0b9b0_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b9b0_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_0b9b0_row0_col0" class="data row0 col0" >6</td>
#       <td id="T_0b9b0_row0_col1" class="data row0 col1" >e</td>
#       <td id="T_0b9b0_row0_col2" class="data row0 col2" >very bad</td>
#     </tr>
#     <tr>
#       <th id="T_0b9b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0b9b0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_0b9b0_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_0b9b0_row1_col2" class="data row1 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_0b9b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0b9b0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_0b9b0_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_0b9b0_row2_col2" class="data row2 col2" >meh</td>
#     </tr>
#     <tr>
#       <th id="T_0b9b0_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_0b9b0_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_0b9b0_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_0b9b0_row3_col2" class="data row3 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_0b9b0_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_0b9b0_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_0b9b0_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_0b9b0_row4_col2" class="data row4 col2" >very good</td>
#     </tr>
#     <tr>
#       <th id="T_0b9b0_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_0b9b0_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_0b9b0_row5_col1" class="data row5 col1" >a</td>
#       <td id="T_0b9b0_row5_col2" class="data row5 col2" >very good</td>
#     </tr>
#   </tbody>
# </table>

# %%
# grouping
cat_grp = cat_df.groupby('grade')
cat_grp.get_group('very good')
# Out:
#   id raw_grade      grade
# 0  1         a  very good
# 3  4         a  very good
# 4  5         a  very good

# %%
# count elements
cat_grp.size()
# Out:
# grade
# very bad     1
# bad          0
# meh          2
# good         0
# very good    3
# dtype: int64
