# %% [markdown]
# # Setup
#
# This is following [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) for Pandas (v 2.x.x, as of this writing) but may take a little more than 10 minutes to finish. Lot's of small changes, references etc.

# %% [markdown]
# You can also open this notebook in Google Colab
#
# <a href="https://colab.research.google.com/github/shauryashaurya/learn-data-munging/blob/main/01.001%20-%2010%2B%20minutes%20to%20pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.24.3'

# %%
pd.__version__
# Out:
# '2.0.2'

# %% [markdown]
# # Object creation

# %%
# Series - pass a list to pd.Series
s1 = pd.Series([1, 2, 3, np.nan, 5])

# %%
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
# create an index to use in the dataframe
# default frequency is D (day), so creates a DatetimeIndex of 10 days
dates = pd.date_range('20220619', periods=10)
dates
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# just in case you are wondering, here's [all the "offset aliases"](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases) for Datetime

# %%
# Dataframe - pass a Numpy array
# create a 10 row, 4 col random number array, index by dates, give some column names
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282

# %%
# Create a dataframe by passing a dictionary of objects
# where each object can be converted into a series-like structure
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220619"),
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([3]*6, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train", "test", "train"]),
        "F": list("foofoo"),
        "G": "foo"
    }
)

df2
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %%
# the datatype of each of the columns would be different
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# G            object
# dtype: object

# %% [markdown]
# # Viewing Data

# %%
# top of the dataframe
df.head()
# Out:
#                    A         B         C         D
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086

# %%
# bottom 3 records of the dataframe
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282

# %%
# index of the df
df.index
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# columns of the df
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# .to_numpy gives a NumPy representation of the dataframe
# this is expensive if all columns are of different data type
df.to_numpy()
# Out:
# array([[-0.52684285,  2.6567582 ,  0.13509452,  0.08180973],
#        [ 1.31174285,  0.00926331,  0.73134309, -0.41931885],
#        [-0.03112923,  0.98134773,  1.52727555, -1.23965165],
#        [ 0.04559521, -0.86522621, -0.4239737 ,  0.38222012],
#        [-0.7937114 ,  0.3058319 ,  0.22371497,  0.66808556],
#        [-2.06828434,  0.71385004,  1.4075276 ,  0.23156345],
#        [ 1.03909216,  0.40980933, -0.82723264, -0.27485404],
#        [-0.50374934,  0.1254132 ,  1.13361667,  1.05794097],
#        [ 0.16633882,  1.03173905, -2.08219366,  0.26117984],
#        [-2.00112468,  0.3700811 , -0.97795039,  0.4192823 ]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo']], dtype=object)

# %%
# quick summary stats
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.336207   0.573887   0.084722   0.116826
# std     1.112772   0.910731   1.168387   0.638368
# min    -2.068284  -0.865226  -2.082194  -1.239652
# 25%    -0.726994   0.170518  -0.726418  -0.185688
# 50%    -0.267439   0.389945   0.179405   0.246372
# 75%     0.136153   0.914473   1.033048   0.410017
# max     1.311743   2.656758   1.527276   1.057941

# %% [markdown]
# 1. **count** = Count number of non-NA/null observations
# 1. **max** = Maximum of the values in the object
# 1. **min** = Minimum of the values in the object
# 1. **mean** = Mean of the values
# 1. **std** = Standard deviation of the observations
# 1. **25%** = Default lower percentile
# 1. **50%** = 50 percentile - same as the median
# 1. **75%** = Default upper percentile

# %%
# change the percentiles
df.describe(percentiles=[.1, .5, .9])
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.336207   0.573887   0.084722   0.116826
# std     1.112772   0.910731   1.168387   0.638368
# min    -2.068284  -0.865226  -2.082194  -1.239652
# 10%    -2.007841  -0.078186  -1.088375  -0.501352
# 50%    -0.267439   0.389945   0.179405   0.246372
# 90%     1.066357   1.194241   1.419502   0.707071
# max     1.311743   2.656758   1.527276   1.057941

# %%
# E, F, G in d2 are not numeric, so do not come up in describe()
df2.describe()
# Out:
#          A                    B    C    D
# count  6.0                    6  6.0  6.0
# mean   1.0  2022-06-19 00:00:00  1.0  3.0
# min    1.0  2022-06-19 00:00:00  1.0  3.0
# 25%    1.0  2022-06-19 00:00:00  1.0  3.0
# 50%    1.0  2022-06-19 00:00:00  1.0  3.0
# 75%    1.0  2022-06-19 00:00:00  1.0  3.0
# max    1.0  2022-06-19 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
# transpose the data
# turn rows to columns and vice versa
df.T
# Out:
#    2022-06-19  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# A   -0.526843    1.311743   -0.031129    0.045595   -0.793711   -2.068284
# B    2.656758    0.009263    0.981348   -0.865226    0.305832    0.713850
# C    0.135095    0.731343    1.527276   -0.423974    0.223715    1.407528
# D    0.081810   -0.419319   -1.239652    0.382220    0.668086    0.231563
#
#    2022-06-25  2022-06-26  2022-06-27  2022-06-28
# A    1.039092   -0.503749    0.166339   -2.001125
# B    0.409809    0.125413    1.031739    0.370081
# C   -0.827233    1.133617   -2.082194   -0.977950
# D   -0.274854    1.057941    0.261180    0.419282

# %% [markdown]
# ### [Axis in pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html?highlight=set_ax#pandas.DataFrame.set_axis)
#
# ```axis{0 or ‘index’, 1 or ‘columns’}```
#
# Always remember that when you specify:
# * ```axis=0``` or ```axis='index'``` you indicate that the operation should be along the _index_ (aka across the rows). More often than not indexes will go from top to bottom (vertically), but sometimes they may not (for e.g. if you use columns as index or when you have hierarchical or multi-index data).
# * ```axis=1``` or ```axis='columns'``` indicates the operation is along the columns
#
# When in doubt use the explicit version ```'index'``` or ```'columns'``` instead of ```0``` or ```1```

# %%
# sort along the axis - 1 = horizontal
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-06-19  0.081810  0.135095  2.656758 -0.526843
# 2022-06-20 -0.419319  0.731343  0.009263  1.311743
# 2022-06-21 -1.239652  1.527276  0.981348 -0.031129
# 2022-06-22  0.382220 -0.423974 -0.865226  0.045595
# 2022-06-23  0.668086  0.223715  0.305832 -0.793711
# 2022-06-24  0.231563  1.407528  0.713850 -2.068284
# 2022-06-25 -0.274854 -0.827233  0.409809  1.039092
# 2022-06-26  1.057941  1.133617  0.125413 -0.503749
# 2022-06-27  0.261180 -2.082194  1.031739  0.166339
# 2022-06-28  0.419282 -0.977950  0.370081 -2.001125

# %%
# sort along the axis - 0 = vertical
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810

# %%
# sort ascending by values in a column
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319

# %%
# sort by non-numerical values
df2.sort_values(by="F", ascending=False)
# Out:
#      A          B    C  D      E  F    G
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo

# %%
# sort by two or more columns
df2.sort_values(by=["F", "E"])
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %% [markdown]
# # Selection

# %% [markdown]
# For production prefer the following instead of other data access methods (typical python methods like ["col"] or [a:b] slices etc.):
#
# ```.at, .iat, .loc and .iloc.```

# %% [markdown]
# ## Getting

# %%
# selecting a single column returns a Series object
df["A"]
# Out:
# 2022-06-19   -0.526843
# 2022-06-20    1.311743
# 2022-06-21   -0.031129
# 2022-06-22    0.045595
# 2022-06-23   -0.793711
# 2022-06-24   -2.068284
# 2022-06-25    1.039092
# 2022-06-26   -0.503749
# 2022-06-27    0.166339
# 2022-06-28   -2.001125
# Freq: D, Name: A, dtype: float64

# %%
# selecting a slice
df[1:5]
# Out:
#                    A         B         C         D
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086

# %% [markdown]
# ## Selection by label

# %%
# selecting based on a label
df.loc[dates[0]]
# Out:
# A   -0.526843
# B    2.656758
# C    0.135095
# D    0.081810
# Name: 2022-06-19 00:00:00, dtype: float64

# %%
# select on a multi-axis by lable
# I honestly do not know what the comment above means...help!
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-06-19 -0.526843  2.656758
# 2022-06-20  1.311743  0.009263
# 2022-06-21 -0.031129  0.981348
# 2022-06-22  0.045595 -0.865226
# 2022-06-23 -0.793711  0.305832
# 2022-06-24 -2.068284  0.713850
# 2022-06-25  1.039092  0.409809
# 2022-06-26 -0.503749  0.125413
# 2022-06-27  0.166339  1.031739
# 2022-06-28 -2.001125  0.370081

# %%
# specific index value results in reduction of dimensions
res = df.loc["2022-06-20"]
print(res)
print("res.shape = ", res.shape, " vs. df.shape = ", df.shape)
# Out:
# A    1.311743
# B    0.009263
# C    0.731343
# D   -0.419319
# Name: 2022-06-20 00:00:00, dtype: float64
# res.shape =  (4,)  vs. df.shape =  (10, 4)

# %%
# get to a specific scalar:
#
# method one
df.loc[dates[0], "A"]
# Out:
# -0.5268428522209753

# %%
#
# method two (slightly faster than method one)
df.at[dates[0], "A"]
# Out:
# -0.5268428522209753

# %% [markdown]
# ## Selection by position

# %%
df.iloc[2]
# Out:
# A   -0.031129
# B    0.981348
# C    1.527276
# D   -1.239652
# Name: 2022-06-21 00:00:00, dtype: float64

# %%
# slices - similar to NumPy / Python - [row:slice, col:slice]
df.iloc[1:5, 0:2]
# Out:
#                    A         B
# 2022-06-20  1.311743  0.009263
# 2022-06-21 -0.031129  0.981348
# 2022-06-22  0.045595 -0.865226
# 2022-06-23 -0.793711  0.305832

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
df.iloc[[0, 1, 2, 6], [0, 2]]
# Out:
#                    A         C
# 2022-06-19 -0.526843  0.135095
# 2022-06-20  1.311743  0.731343
# 2022-06-21 -0.031129  1.527276
# 2022-06-25  1.039092 -0.827233

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
# change the order of columns, repeact a column
df.iloc[[0, 1, 2, 6], [2, 1, 0, 2]]
# Out:
#                    C         B         A         C
# 2022-06-19  0.135095  2.656758 -0.526843  0.135095
# 2022-06-20  0.731343  0.009263  1.311743  0.731343
# 2022-06-21  1.527276  0.981348 -0.031129  1.527276
# 2022-06-25 -0.827233  0.409809  1.039092 -0.827233

# %%
# slice rows explicitly, keep all columns
df.iloc[[1, 2], :]
# Out:
#                    A         B         C         D
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652

# %%
# slice columns, keep all rows
df.iloc[:, [2, 3]]
# Out:
#                    C         D
# 2022-06-19  0.135095  0.081810
# 2022-06-20  0.731343 -0.419319
# 2022-06-21  1.527276 -1.239652
# 2022-06-22 -0.423974  0.382220
# 2022-06-23  0.223715  0.668086
# 2022-06-24  1.407528  0.231563
# 2022-06-25 -0.827233 -0.274854
# 2022-06-26  1.133617  1.057941
# 2022-06-27 -2.082194  0.261180
# 2022-06-28 -0.977950  0.419282

# %%
# everything, because you can
df.iloc[:, :]
# Out:
#                    A         B         C         D
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282

# %%
# get to a scalar (2 methods, just like before)
#
# method one: use iloc
df.iloc[1, 2]
# Out:
# 0.7313430930082255

# %%
#
# method two: use iat
df.iat[1, 2]
# Out:
# 0.7313430930082255

# %% [markdown]
# ## Boolean Indexing

# %%
# use a value found in a single col to get data
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180

# %%
# boolean across the entire DF - vals that don't match go NaN
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-06-19       NaN  2.656758  0.135095  0.081810
# 2022-06-20  1.311743  0.009263  0.731343       NaN
# 2022-06-21       NaN  0.981348  1.527276       NaN
# 2022-06-22  0.045595       NaN       NaN  0.382220
# 2022-06-23       NaN  0.305832  0.223715  0.668086
# 2022-06-24       NaN  0.713850  1.407528  0.231563
# 2022-06-25  1.039092  0.409809       NaN       NaN
# 2022-06-26       NaN  0.125413  1.133617  1.057941
# 2022-06-27  0.166339  1.031739       NaN  0.261180
# 2022-06-28       NaN  0.370081       NaN  0.419282

# %%
# add another column
df11 = df.copy()
df11["E"] = ["one", "two", "three", "four",
             "two", "five", "one", "two", "three", "four"]
df11
# Out:
#                    A         B         C         D      E
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810    one
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319    two
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  three
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220   four
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086    two
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563   five
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854    one
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941    two
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180  three
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282   four

# %%
# the isin() query - basically the in clause
df11[df11["E"].isin(["two", "five"])]
# Out:
#                    A         B         C         D     E
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319   two
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086   two
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563  five
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941   two

# %% [markdown]
# ## Setting values

# %%
# matching indexes auto-aligns values
s1 = pd.Series(range(11, 21), index=pd.date_range('20220619', periods=10))
s1
# Out:
# 2022-06-19    11
# 2022-06-20    12
# 2022-06-21    13
# 2022-06-22    14
# 2022-06-23    15
# 2022-06-24    16
# 2022-06-25    17
# 2022-06-26    18
# 2022-06-27    19
# 2022-06-28    20
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810  11
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319  12
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086  15
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563  16
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854  17
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941  18
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180  19
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282  20

# %%
# setting values by label and position
# first let's make a quick copy
df12 = df.copy()
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810  11
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319  12
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086  15
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563  16
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854  17
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941  18
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180  19
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282  20

# %%
# set by label
df12.at[dates[0], "A"] = 0
# set by position
df12.iat[0, 1] = 0
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.000000  0.000000  0.135095  0.081810  11
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319  12
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086  15
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563  16
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854  17
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941  18
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180  19
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282  20

# %%
# kinda bigger replacement
df12.loc[:, "D"] = np.array([5]*len(df))
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000  0.135095  5.0  11
# 2022-06-20  1.311743  0.009263  0.731343  5.0  12
# 2022-06-21 -0.031129  0.981348  1.527276  5.0  13
# 2022-06-22  0.045595 -0.865226 -0.423974  5.0  14
# 2022-06-23 -0.793711  0.305832  0.223715  5.0  15
# 2022-06-24 -2.068284  0.713850  1.407528  5.0  16
# 2022-06-25  1.039092  0.409809 -0.827233  5.0  17
# 2022-06-26 -0.503749  0.125413  1.133617  5.0  18
# 2022-06-27  0.166339  1.031739 -2.082194  5.0  19
# 2022-06-28 -2.001125  0.370081 -0.977950  5.0  20

# %%
# setting values using a boolean selection (aka where clause)
df12[df12 > 0] = -df12
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000 -0.135095 -5.0 -11
# 2022-06-20 -1.311743 -0.009263 -0.731343 -5.0 -12
# 2022-06-21 -0.031129 -0.981348 -1.527276 -5.0 -13
# 2022-06-22 -0.045595 -0.865226 -0.423974 -5.0 -14
# 2022-06-23 -0.793711 -0.305832 -0.223715 -5.0 -15
# 2022-06-24 -2.068284 -0.713850 -1.407528 -5.0 -16
# 2022-06-25 -1.039092 -0.409809 -0.827233 -5.0 -17
# 2022-06-26 -0.503749 -0.125413 -1.133617 -5.0 -18
# 2022-06-27 -0.166339 -1.031739 -2.082194 -5.0 -19
# 2022-06-28 -2.001125 -0.370081 -0.977950 -5.0 -20

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### _reindex_
# change/add/delete index on a specified axis, returns a new dataframe

# %%
df13 = df.reindex(index=dates[0:4], columns=list(df.columns)+["G"])
df13
# Out:
#                    A         B         C         D   F   G
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810  11 NaN
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319  12 NaN
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13 NaN
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14 NaN

# %% [markdown]
# ### handling missing data
# 1. _```np.nan```_
# 1. _```pandas.isna()```_
# 1. ```df.dropna()```
# 1. ```df.fillna()```

# %%
# missing data in pandas is np.nan
df13.iat[1, 0] = np.nan
df13.iloc[1:, 5] = np.random.randint(1)
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810  11  NaN
# 2022-06-20       NaN  0.009263  0.731343 -0.419319  12  0.0
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13  0.0
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14  0.0

# %%
# get a boolean mask where values are NaN
df131 = pd.isna(df13)
df131
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# or just
pd.isna(df13)
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# the original is still there
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810  11  NaN
# 2022-06-20       NaN  0.009263  0.731343 -0.419319  12  0.0
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13  0.0
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14  0.0

# %%
# we are going to drop / replace values now, let's make a couple of copies of the dataframe
df132 = df13.copy()
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810  11  NaN
# 2022-06-20       NaN  0.009263  0.731343 -0.419319  12  0.0
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13  0.0
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14  0.0

# %%
# drop rows/columns that have missing data
# by default it returns a new dataframe, you may want to specify inplace=True for modifying current dataframe:
df_no_na = df132.dropna(how="any")
# how=‘any’ : If any NA values are present, drop that row or column.
# how=‘all’ : If all values are NA, drop that row or column.

# %%
# all rows/cols with missing data stripped
df_no_na
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13  0.0
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14  0.0

# %%
# original still intact
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810  11  NaN
# 2022-06-20       NaN  0.009263  0.731343 -0.419319  12  0.0
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13  0.0
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14  0.0

# %%
# drop missing data from original
df132.dropna(how="any", inplace=True)
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13  0.0
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14  0.0

# %%
# fill missing data
df133 = df13.copy()
df133.fillna(np.pi*1000)
# Out:
#                       A         B         C         D   F            G
# 2022-06-19    -0.526843  2.656758  0.135095  0.081810  11  3141.592654
# 2022-06-20  3141.592654  0.009263  0.731343 -0.419319  12     0.000000
# 2022-06-21    -0.031129  0.981348  1.527276 -1.239652  13     0.000000
# 2022-06-22     0.045595 -0.865226 -0.423974  0.382220  14     0.000000

# %% [markdown]
# # Align and Join

# %% [markdown]
# There needs to be a bigger notebook for this topic.
# You need to know there's "joins" in Pandas just like in the SQL world,
# like join and left join and right join and inner and outer and all that...
# Here we'll explore these in the context of the align function - 'aligning' the indexes of two dataframes.
# Later we'll see these again in the context of _merging_ two data frames.

# %% [markdown]
# ## Create two datasets with _mismatched_ indexes

# %%
# date range indexes
idx1 = pd.date_range('2022-01-01',periods = 10)
# 2022-01-01', '2022-01-02' don't exist in idx2
# '2022-01-11', '2022-01-12' don't exist in idx1
idx2 = pd.date_range('2022-01-03',periods = 10)

# %%
# dataframes from indexes
d1 = pd.DataFrame(index = idx1, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

d2 = pd.DataFrame(index = idx2, data = 
    {
        'A': np.random.rand(10),
        'B': np.random.randint(1, high=25, size = 10)
    }
)

# %% [markdown]
# ## Quick Aside: Rendering two dataframes side-by-side

# %% [markdown]
# The trick of rendering 2 dataframes side-by-side was from [this](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) stackoverflow question.

# %%
# we gon need to display both data frames side by side, so...
from IPython.display import display_html 
def render_df_side_by_side(a, b, a_title = "", b_title = ""):
    a_styler = a.style.set_table_attributes("style='display:inline'").set_caption(a_title)
    b_styler = b.style.set_table_attributes("style='display:inline'").set_caption(b_title)
    display_html(a_styler._repr_html_()+b_styler._repr_html_(), raw=True)

# %%
render_df_side_by_side(d1,d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_21c55" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21c55_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_21c55_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21c55_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_21c55_row0_col0" class="data row0 col0" >0.611228</td>
#       <td id="T_21c55_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_21c55_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_21c55_row1_col0" class="data row1 col0" >0.638257</td>
#       <td id="T_21c55_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_21c55_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_21c55_row2_col0" class="data row2 col0" >0.383342</td>
#       <td id="T_21c55_row2_col1" class="data row2 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_21c55_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_21c55_row3_col0" class="data row3 col0" >0.561583</td>
#       <td id="T_21c55_row3_col1" class="data row3 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_21c55_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_21c55_row4_col0" class="data row4 col0" >0.853737</td>
#       <td id="T_21c55_row4_col1" class="data row4 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_21c55_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_21c55_row5_col0" class="data row5 col0" >0.536929</td>
#       <td id="T_21c55_row5_col1" class="data row5 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_21c55_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_21c55_row6_col0" class="data row6 col0" >0.183888</td>
#       <td id="T_21c55_row6_col1" class="data row6 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_21c55_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_21c55_row7_col0" class="data row7 col0" >0.005290</td>
#       <td id="T_21c55_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_21c55_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_21c55_row8_col0" class="data row8 col0" >0.434853</td>
#       <td id="T_21c55_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_21c55_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_21c55_row9_col0" class="data row9 col0" >0.871867</td>
#       <td id="T_21c55_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_63614" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63614_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_63614_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63614_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_63614_row0_col0" class="data row0 col0" >0.240739</td>
#       <td id="T_63614_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_63614_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_63614_row1_col0" class="data row1 col0" >0.877914</td>
#       <td id="T_63614_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_63614_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_63614_row2_col0" class="data row2 col0" >0.322013</td>
#       <td id="T_63614_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_63614_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_63614_row3_col0" class="data row3 col0" >0.630251</td>
#       <td id="T_63614_row3_col1" class="data row3 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_63614_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_63614_row4_col0" class="data row4 col0" >0.020301</td>
#       <td id="T_63614_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_63614_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_63614_row5_col0" class="data row5 col0" >0.787749</td>
#       <td id="T_63614_row5_col1" class="data row5 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_63614_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_63614_row6_col0" class="data row6 col0" >0.771967</td>
#       <td id="T_63614_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_63614_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_63614_row7_col0" class="data row7 col0" >0.490684</td>
#       <td id="T_63614_row7_col1" class="data row7 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_63614_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_63614_row8_col0" class="data row8 col0" >0.520994</td>
#       <td id="T_63614_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_63614_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_63614_row9_col0" class="data row9 col0" >0.452709</td>
#       <td id="T_63614_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table rendering/styling options is [a bigger discussion](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#) to be tackled later.

# %% [markdown]
# ## .add, .sub, .mul, .div etc.

# %% [markdown]
# flexible wrappers (```add, sub, mul, div, mod, pow```) to arithmetic operators: ```+, -, *, /, //, %, **```

# %%
# the +, -, *, /, //, %, ** operations align indexes to create a UNION of indexes
d3 = d1+d2
d4 = d1.sub(d2) #equivalent to d1-d2
d5 = d1*d2
d6 = d1.div(d2)

# %%
# indexs not present in the other dataframe get a NaN

# pandas v1.x
# d3.style.highlight_null(null_color='red')

# pandas v2.x+
d3.style.highlight_null(color='red')
# Out:
# <style type="text/css">
# #T_0e84f_row0_col0, #T_0e84f_row0_col1, #T_0e84f_row1_col0, #T_0e84f_row1_col1, #T_0e84f_row10_col0, #T_0e84f_row10_col1, #T_0e84f_row11_col0, #T_0e84f_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_0e84f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e84f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0e84f_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e84f_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_0e84f_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_0e84f_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_0e84f_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_0e84f_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_0e84f_row2_col0" class="data row2 col0" >0.624080</td>
#       <td id="T_0e84f_row2_col1" class="data row2 col1" >38.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_0e84f_row3_col0" class="data row3 col0" >1.439497</td>
#       <td id="T_0e84f_row3_col1" class="data row3 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_0e84f_row4_col0" class="data row4 col0" >1.175750</td>
#       <td id="T_0e84f_row4_col1" class="data row4 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_0e84f_row5_col0" class="data row5 col0" >1.167180</td>
#       <td id="T_0e84f_row5_col1" class="data row5 col1" >41.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_0e84f_row6_col0" class="data row6 col0" >0.204189</td>
#       <td id="T_0e84f_row6_col1" class="data row6 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_0e84f_row7_col0" class="data row7 col0" >0.793038</td>
#       <td id="T_0e84f_row7_col1" class="data row7 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_0e84f_row8_col0" class="data row8 col0" >1.206820</td>
#       <td id="T_0e84f_row8_col1" class="data row8 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_0e84f_row9_col0" class="data row9 col0" >1.362551</td>
#       <td id="T_0e84f_row9_col1" class="data row9 col1" >36.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_0e84f_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_0e84f_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0e84f_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_0e84f_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_0e84f_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# sub
d4.style.highlight_null(color='red')
# Out:
# <style type="text/css">
# #T_89213_row0_col0, #T_89213_row0_col1, #T_89213_row1_col0, #T_89213_row1_col1, #T_89213_row10_col0, #T_89213_row10_col1, #T_89213_row11_col0, #T_89213_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_89213">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89213_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_89213_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89213_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_89213_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_89213_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_89213_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_89213_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_89213_row2_col0" class="data row2 col0" >0.142603</td>
#       <td id="T_89213_row2_col1" class="data row2 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_89213_row3_col0" class="data row3 col0" >-0.316332</td>
#       <td id="T_89213_row3_col1" class="data row3 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_89213_row4_col0" class="data row4 col0" >0.531724</td>
#       <td id="T_89213_row4_col1" class="data row4 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_89213_row5_col0" class="data row5 col0" >-0.093322</td>
#       <td id="T_89213_row5_col1" class="data row5 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_89213_row6_col0" class="data row6 col0" >0.163587</td>
#       <td id="T_89213_row6_col1" class="data row6 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_89213_row7_col0" class="data row7 col0" >-0.782459</td>
#       <td id="T_89213_row7_col1" class="data row7 col1" >-13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_89213_row8_col0" class="data row8 col0" >-0.337114</td>
#       <td id="T_89213_row8_col1" class="data row8 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_89213_row9_col0" class="data row9 col0" >0.381183</td>
#       <td id="T_89213_row9_col1" class="data row9 col1" >-12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_89213_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_89213_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89213_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_89213_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_89213_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mul
d5.style.highlight_null(color='red')
# Out:
# <style type="text/css">
# #T_a48b7_row0_col0, #T_a48b7_row0_col1, #T_a48b7_row1_col0, #T_a48b7_row1_col1, #T_a48b7_row10_col0, #T_a48b7_row10_col1, #T_a48b7_row11_col0, #T_a48b7_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_a48b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a48b7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a48b7_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a48b7_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_a48b7_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a48b7_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_a48b7_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_a48b7_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_a48b7_row2_col0" class="data row2 col0" >0.092285</td>
#       <td id="T_a48b7_row2_col1" class="data row2 col1" >352.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_a48b7_row3_col0" class="data row3 col0" >0.493021</td>
#       <td id="T_a48b7_row3_col1" class="data row3 col1" >46.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_a48b7_row4_col0" class="data row4 col0" >0.274914</td>
#       <td id="T_a48b7_row4_col1" class="data row4 col1" >46.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_a48b7_row5_col0" class="data row5 col0" >0.338400</td>
#       <td id="T_a48b7_row5_col1" class="data row5 col1" >414.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_a48b7_row6_col0" class="data row6 col0" >0.003733</td>
#       <td id="T_a48b7_row6_col1" class="data row6 col1" >140.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_a48b7_row7_col0" class="data row7 col0" >0.004167</td>
#       <td id="T_a48b7_row7_col1" class="data row7 col1" >114.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_a48b7_row8_col0" class="data row8 col0" >0.335692</td>
#       <td id="T_a48b7_row8_col1" class="data row8 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_a48b7_row9_col0" class="data row9 col0" >0.427811</td>
#       <td id="T_a48b7_row9_col1" class="data row9 col1" >288.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_a48b7_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_a48b7_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a48b7_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_a48b7_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_a48b7_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# div
d6.style.highlight_null(color='red')
# Out:
# <style type="text/css">
# #T_92350_row0_col0, #T_92350_row0_col1, #T_92350_row1_col0, #T_92350_row1_col1, #T_92350_row10_col0, #T_92350_row10_col1, #T_92350_row11_col0, #T_92350_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_92350">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92350_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_92350_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92350_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_92350_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_92350_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_92350_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_92350_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_92350_row2_col0" class="data row2 col0" >1.592357</td>
#       <td id="T_92350_row2_col1" class="data row2 col1" >1.375000</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_92350_row3_col0" class="data row3 col0" >0.639678</td>
#       <td id="T_92350_row3_col1" class="data row3 col1" >11.500000</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_92350_row4_col0" class="data row4 col0" >2.651252</td>
#       <td id="T_92350_row4_col1" class="data row4 col1" >11.500000</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_92350_row5_col0" class="data row5 col0" >0.851929</td>
#       <td id="T_92350_row5_col1" class="data row5 col1" >1.277778</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_92350_row6_col0" class="data row6 col0" >9.057988</td>
#       <td id="T_92350_row6_col1" class="data row6 col1" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_92350_row7_col0" class="data row7 col0" >0.006715</td>
#       <td id="T_92350_row7_col1" class="data row7 col1" >0.315789</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_92350_row8_col0" class="data row8 col0" >0.563305</td>
#       <td id="T_92350_row8_col1" class="data row8 col1" >2.333333</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_92350_row9_col0" class="data row9 col0" >1.776840</td>
#       <td id="T_92350_row9_col1" class="data row9 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_92350_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_92350_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_92350_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_92350_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_92350_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### removing the NaN values from the resultant dataframe

# %%
# the + operation is UNION of indexes
d31 = d1+d2
# indexs not present in the other dataframe get a NaN
# do you can obvs remove nan values like before
d3.dropna().style.highlight_null(color='red')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8af61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8af61_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8af61_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8af61_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_8af61_row0_col0" class="data row0 col0" >0.624080</td>
#       <td id="T_8af61_row0_col1" class="data row0 col1" >38.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8af61_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_8af61_row1_col0" class="data row1 col0" >1.439497</td>
#       <td id="T_8af61_row1_col1" class="data row1 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8af61_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_8af61_row2_col0" class="data row2 col0" >1.175750</td>
#       <td id="T_8af61_row2_col1" class="data row2 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8af61_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_8af61_row3_col0" class="data row3 col0" >1.167180</td>
#       <td id="T_8af61_row3_col1" class="data row3 col1" >41.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8af61_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_8af61_row4_col0" class="data row4 col0" >0.204189</td>
#       <td id="T_8af61_row4_col1" class="data row4 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8af61_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_8af61_row5_col0" class="data row5 col0" >0.793038</td>
#       <td id="T_8af61_row5_col1" class="data row5 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8af61_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_8af61_row6_col0" class="data row6 col0" >1.206820</td>
#       <td id="T_8af61_row6_col1" class="data row6 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8af61_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_8af61_row7_col0" class="data row7 col0" >1.362551</td>
#       <td id="T_8af61_row7_col1" class="data row7 col1" >36.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## df.align()

# %% [markdown]
# Pandas [align](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.align.html) works to join the dataframes in interesting ways.

# %%
# align returns two dataframes - left and right as a result of a join
# default join is outer - the union of indices will be used as index for left and right
left, right = d1.align(d2, join='outer')
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ea59" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ea59_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6ea59_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ea59_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_6ea59_row0_col0" class="data row0 col0" >0.611228</td>
#       <td id="T_6ea59_row0_col1" class="data row0 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_6ea59_row1_col0" class="data row1 col0" >0.638257</td>
#       <td id="T_6ea59_row1_col1" class="data row1 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_6ea59_row2_col0" class="data row2 col0" >0.383342</td>
#       <td id="T_6ea59_row2_col1" class="data row2 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_6ea59_row3_col0" class="data row3 col0" >0.561583</td>
#       <td id="T_6ea59_row3_col1" class="data row3 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_6ea59_row4_col0" class="data row4 col0" >0.853737</td>
#       <td id="T_6ea59_row4_col1" class="data row4 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_6ea59_row5_col0" class="data row5 col0" >0.536929</td>
#       <td id="T_6ea59_row5_col1" class="data row5 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_6ea59_row6_col0" class="data row6 col0" >0.183888</td>
#       <td id="T_6ea59_row6_col1" class="data row6 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_6ea59_row7_col0" class="data row7 col0" >0.005290</td>
#       <td id="T_6ea59_row7_col1" class="data row7 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_6ea59_row8_col0" class="data row8 col0" >0.434853</td>
#       <td id="T_6ea59_row8_col1" class="data row8 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_6ea59_row9_col0" class="data row9 col0" >0.871867</td>
#       <td id="T_6ea59_row9_col1" class="data row9 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_6ea59_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_6ea59_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6ea59_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_6ea59_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_6ea59_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_18397" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18397_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_18397_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18397_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_18397_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_18397_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_18397_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_18397_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_18397_row2_col0" class="data row2 col0" >0.240739</td>
#       <td id="T_18397_row2_col1" class="data row2 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_18397_row3_col0" class="data row3 col0" >0.877914</td>
#       <td id="T_18397_row3_col1" class="data row3 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_18397_row4_col0" class="data row4 col0" >0.322013</td>
#       <td id="T_18397_row4_col1" class="data row4 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_18397_row5_col0" class="data row5 col0" >0.630251</td>
#       <td id="T_18397_row5_col1" class="data row5 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_18397_row6_col0" class="data row6 col0" >0.020301</td>
#       <td id="T_18397_row6_col1" class="data row6 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_18397_row7_col0" class="data row7 col0" >0.787749</td>
#       <td id="T_18397_row7_col1" class="data row7 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_18397_row8_col0" class="data row8 col0" >0.771967</td>
#       <td id="T_18397_row8_col1" class="data row8 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_18397_row9_col0" class="data row9 col0" >0.490684</td>
#       <td id="T_18397_row9_col1" class="data row9 col1" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_18397_row10_col0" class="data row10 col0" >0.520994</td>
#       <td id="T_18397_row10_col1" class="data row10 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18397_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_18397_row11_col0" class="data row11 col0" >0.452709</td>
#       <td id="T_18397_row11_col1" class="data row11 col1" >8.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# inner join
left, right = d1.align(d2, join='inner')
render_df_side_by_side(d1,d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6465f" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6465f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6465f_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6465f_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_6465f_row0_col0" class="data row0 col0" >0.611228</td>
#       <td id="T_6465f_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_6465f_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_6465f_row1_col0" class="data row1 col0" >0.638257</td>
#       <td id="T_6465f_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6465f_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_6465f_row2_col0" class="data row2 col0" >0.383342</td>
#       <td id="T_6465f_row2_col1" class="data row2 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_6465f_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_6465f_row3_col0" class="data row3 col0" >0.561583</td>
#       <td id="T_6465f_row3_col1" class="data row3 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_6465f_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_6465f_row4_col0" class="data row4 col0" >0.853737</td>
#       <td id="T_6465f_row4_col1" class="data row4 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_6465f_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_6465f_row5_col0" class="data row5 col0" >0.536929</td>
#       <td id="T_6465f_row5_col1" class="data row5 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_6465f_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_6465f_row6_col0" class="data row6 col0" >0.183888</td>
#       <td id="T_6465f_row6_col1" class="data row6 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_6465f_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_6465f_row7_col0" class="data row7 col0" >0.005290</td>
#       <td id="T_6465f_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6465f_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_6465f_row8_col0" class="data row8 col0" >0.434853</td>
#       <td id="T_6465f_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_6465f_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_6465f_row9_col0" class="data row9 col0" >0.871867</td>
#       <td id="T_6465f_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_27233" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27233_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_27233_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27233_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_27233_row0_col0" class="data row0 col0" >0.240739</td>
#       <td id="T_27233_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_27233_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_27233_row1_col0" class="data row1 col0" >0.877914</td>
#       <td id="T_27233_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_27233_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_27233_row2_col0" class="data row2 col0" >0.322013</td>
#       <td id="T_27233_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_27233_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_27233_row3_col0" class="data row3 col0" >0.630251</td>
#       <td id="T_27233_row3_col1" class="data row3 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_27233_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_27233_row4_col0" class="data row4 col0" >0.020301</td>
#       <td id="T_27233_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_27233_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_27233_row5_col0" class="data row5 col0" >0.787749</td>
#       <td id="T_27233_row5_col1" class="data row5 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_27233_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_27233_row6_col0" class="data row6 col0" >0.771967</td>
#       <td id="T_27233_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_27233_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_27233_row7_col0" class="data row7 col0" >0.490684</td>
#       <td id="T_27233_row7_col1" class="data row7 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_27233_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_27233_row8_col0" class="data row8 col0" >0.520994</td>
#       <td id="T_27233_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_27233_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_27233_row9_col0" class="data row9 col0" >0.452709</td>
#       <td id="T_27233_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# we can fill the NaNs with a certain value if needed
# let's fill with -100 so we can see it clearly
left, right = d1.align(d2, join='outer', fill_value = -100) 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e329" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e329_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_1e329_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e329_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_1e329_row0_col0" class="data row0 col0" >0.611228</td>
#       <td id="T_1e329_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_1e329_row1_col0" class="data row1 col0" >0.638257</td>
#       <td id="T_1e329_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_1e329_row2_col0" class="data row2 col0" >0.383342</td>
#       <td id="T_1e329_row2_col1" class="data row2 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_1e329_row3_col0" class="data row3 col0" >0.561583</td>
#       <td id="T_1e329_row3_col1" class="data row3 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_1e329_row4_col0" class="data row4 col0" >0.853737</td>
#       <td id="T_1e329_row4_col1" class="data row4 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_1e329_row5_col0" class="data row5 col0" >0.536929</td>
#       <td id="T_1e329_row5_col1" class="data row5 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_1e329_row6_col0" class="data row6 col0" >0.183888</td>
#       <td id="T_1e329_row6_col1" class="data row6 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_1e329_row7_col0" class="data row7 col0" >0.005290</td>
#       <td id="T_1e329_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_1e329_row8_col0" class="data row8 col0" >0.434853</td>
#       <td id="T_1e329_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_1e329_row9_col0" class="data row9 col0" >0.871867</td>
#       <td id="T_1e329_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_1e329_row10_col0" class="data row10 col0" >-100.000000</td>
#       <td id="T_1e329_row10_col1" class="data row10 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_1e329_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_1e329_row11_col0" class="data row11 col0" >-100.000000</td>
#       <td id="T_1e329_row11_col1" class="data row11 col1" >-100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b4127" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4127_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b4127_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4127_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_b4127_row0_col0" class="data row0 col0" >-100.000000</td>
#       <td id="T_b4127_row0_col1" class="data row0 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_b4127_row1_col0" class="data row1 col0" >-100.000000</td>
#       <td id="T_b4127_row1_col1" class="data row1 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_b4127_row2_col0" class="data row2 col0" >0.240739</td>
#       <td id="T_b4127_row2_col1" class="data row2 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_b4127_row3_col0" class="data row3 col0" >0.877914</td>
#       <td id="T_b4127_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_b4127_row4_col0" class="data row4 col0" >0.322013</td>
#       <td id="T_b4127_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_b4127_row5_col0" class="data row5 col0" >0.630251</td>
#       <td id="T_b4127_row5_col1" class="data row5 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_b4127_row6_col0" class="data row6 col0" >0.020301</td>
#       <td id="T_b4127_row6_col1" class="data row6 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_b4127_row7_col0" class="data row7 col0" >0.787749</td>
#       <td id="T_b4127_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_b4127_row8_col0" class="data row8 col0" >0.771967</td>
#       <td id="T_b4127_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_b4127_row9_col0" class="data row9 col0" >0.490684</td>
#       <td id="T_b4127_row9_col1" class="data row9 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_b4127_row10_col0" class="data row10 col0" >0.520994</td>
#       <td id="T_b4127_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b4127_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_b4127_row11_col0" class="data row11 col0" >0.452709</td>
#       <td id="T_b4127_row11_col1" class="data row11 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# left join: left index is added to right, but not the other way
left, right = d1.align(d2, join='left') 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_41503" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41503_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_41503_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41503_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_41503_row0_col0" class="data row0 col0" >0.611228</td>
#       <td id="T_41503_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_41503_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_41503_row1_col0" class="data row1 col0" >0.638257</td>
#       <td id="T_41503_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_41503_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_41503_row2_col0" class="data row2 col0" >0.383342</td>
#       <td id="T_41503_row2_col1" class="data row2 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_41503_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_41503_row3_col0" class="data row3 col0" >0.561583</td>
#       <td id="T_41503_row3_col1" class="data row3 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_41503_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_41503_row4_col0" class="data row4 col0" >0.853737</td>
#       <td id="T_41503_row4_col1" class="data row4 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_41503_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_41503_row5_col0" class="data row5 col0" >0.536929</td>
#       <td id="T_41503_row5_col1" class="data row5 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_41503_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_41503_row6_col0" class="data row6 col0" >0.183888</td>
#       <td id="T_41503_row6_col1" class="data row6 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_41503_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_41503_row7_col0" class="data row7 col0" >0.005290</td>
#       <td id="T_41503_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_41503_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_41503_row8_col0" class="data row8 col0" >0.434853</td>
#       <td id="T_41503_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_41503_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_41503_row9_col0" class="data row9 col0" >0.871867</td>
#       <td id="T_41503_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_8d631" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d631_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8d631_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d631_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_8d631_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_8d631_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8d631_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_8d631_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_8d631_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8d631_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_8d631_row2_col0" class="data row2 col0" >0.240739</td>
#       <td id="T_8d631_row2_col1" class="data row2 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d631_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_8d631_row3_col0" class="data row3 col0" >0.877914</td>
#       <td id="T_8d631_row3_col1" class="data row3 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d631_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_8d631_row4_col0" class="data row4 col0" >0.322013</td>
#       <td id="T_8d631_row4_col1" class="data row4 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d631_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_8d631_row5_col0" class="data row5 col0" >0.630251</td>
#       <td id="T_8d631_row5_col1" class="data row5 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d631_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_8d631_row6_col0" class="data row6 col0" >0.020301</td>
#       <td id="T_8d631_row6_col1" class="data row6 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d631_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_8d631_row7_col0" class="data row7 col0" >0.787749</td>
#       <td id="T_8d631_row7_col1" class="data row7 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d631_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_8d631_row8_col0" class="data row8 col0" >0.771967</td>
#       <td id="T_8d631_row8_col1" class="data row8 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d631_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_8d631_row9_col0" class="data row9 col0" >0.490684</td>
#       <td id="T_8d631_row9_col1" class="data row9 col1" >24.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# right join: right index is added to left, but not the other way
left, right = d1.align(d2, join='right') 
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b1d5f" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1d5f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b1d5f_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1d5f_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_b1d5f_row0_col0" class="data row0 col0" >0.383342</td>
#       <td id="T_b1d5f_row0_col1" class="data row0 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b1d5f_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_b1d5f_row1_col0" class="data row1 col0" >0.561583</td>
#       <td id="T_b1d5f_row1_col1" class="data row1 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b1d5f_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_b1d5f_row2_col0" class="data row2 col0" >0.853737</td>
#       <td id="T_b1d5f_row2_col1" class="data row2 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b1d5f_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_b1d5f_row3_col0" class="data row3 col0" >0.536929</td>
#       <td id="T_b1d5f_row3_col1" class="data row3 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b1d5f_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_b1d5f_row4_col0" class="data row4 col0" >0.183888</td>
#       <td id="T_b1d5f_row4_col1" class="data row4 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b1d5f_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_b1d5f_row5_col0" class="data row5 col0" >0.005290</td>
#       <td id="T_b1d5f_row5_col1" class="data row5 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b1d5f_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_b1d5f_row6_col0" class="data row6 col0" >0.434853</td>
#       <td id="T_b1d5f_row6_col1" class="data row6 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b1d5f_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_b1d5f_row7_col0" class="data row7 col0" >0.871867</td>
#       <td id="T_b1d5f_row7_col1" class="data row7 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b1d5f_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_b1d5f_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_b1d5f_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b1d5f_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_b1d5f_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_b1d5f_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_df13e" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df13e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_df13e_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df13e_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_df13e_row0_col0" class="data row0 col0" >0.240739</td>
#       <td id="T_df13e_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_df13e_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_df13e_row1_col0" class="data row1 col0" >0.877914</td>
#       <td id="T_df13e_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_df13e_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_df13e_row2_col0" class="data row2 col0" >0.322013</td>
#       <td id="T_df13e_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_df13e_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_df13e_row3_col0" class="data row3 col0" >0.630251</td>
#       <td id="T_df13e_row3_col1" class="data row3 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_df13e_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_df13e_row4_col0" class="data row4 col0" >0.020301</td>
#       <td id="T_df13e_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_df13e_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_df13e_row5_col0" class="data row5 col0" >0.787749</td>
#       <td id="T_df13e_row5_col1" class="data row5 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_df13e_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_df13e_row6_col0" class="data row6 col0" >0.771967</td>
#       <td id="T_df13e_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_df13e_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_df13e_row7_col0" class="data row7 col0" >0.490684</td>
#       <td id="T_df13e_row7_col1" class="data row7 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_df13e_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_df13e_row8_col0" class="data row8 col0" >0.520994</td>
#       <td id="T_df13e_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_df13e_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_df13e_row9_col0" class="data row9 col0" >0.452709</td>
#       <td id="T_df13e_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's more to explore in align, and it can get confusing, so beginners be careful, take time and try to work out the result before you execute to build intuition.

# %% [markdown]
# # Operations on data

# %% [markdown]
# ## Stats
#
# Operations in general *exclude* missing data

# %%
# arithmetic mean, for each column (axis = 0)
df.mean()
# Out:
# A    -0.336207
# B     0.573887
# C     0.084722
# D     0.116826
# F    15.500000
# dtype: float64

# %%
# mean across a row (axis = 1)
df.mean(1)
# Out:
# 2022-06-19    2.669364
# 2022-06-20    2.726606
# 2022-06-21    2.847568
# 2022-06-22    2.627723
# 2022-06-23    3.080784
# 2022-06-24    3.256931
# 2022-06-25    3.469363
# 2022-06-26    3.962644
# 2022-06-27    3.675413
# 2022-06-28    3.562058
# Freq: D, dtype: float64

# %% [markdown]
# ## Apply

# %%
# apply custom lambdas
df.apply(lambda x: x.max()-x.min())
# Out:
# A    3.380027
# B    3.521984
# C    3.609469
# D    2.297593
# F    9.000000
# dtype: float64

# %%
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -0.526843  2.656758  0.135095  0.081810  11
# 2022-06-20  1.311743  0.009263  0.731343 -0.419319  12
# 2022-06-21 -0.031129  0.981348  1.527276 -1.239652  13
# 2022-06-22  0.045595 -0.865226 -0.423974  0.382220  14
# 2022-06-23 -0.793711  0.305832  0.223715  0.668086  15
# 2022-06-24 -2.068284  0.713850  1.407528  0.231563  16
# 2022-06-25  1.039092  0.409809 -0.827233 -0.274854  17
# 2022-06-26 -0.503749  0.125413  1.133617  1.057941  18
# 2022-06-27  0.166339  1.031739 -2.082194  0.261180  19
# 2022-06-28 -2.001125  0.370081 -0.977950  0.419282  20

# %%
# each subsequent value is a sum of all values before it in the respective column
cumsum_df = df.apply(np.cumsum)
render_df_side_by_side(df, cumsum_df, "OG Dataframe", "Cumulative Sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_cb170" style='display:inline'>
#   <caption>OG Dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb170_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_cb170_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_cb170_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_cb170_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_cb170_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb170_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_cb170_row0_col0" class="data row0 col0" >-0.526843</td>
#       <td id="T_cb170_row0_col1" class="data row0 col1" >2.656758</td>
#       <td id="T_cb170_row0_col2" class="data row0 col2" >0.135095</td>
#       <td id="T_cb170_row0_col3" class="data row0 col3" >0.081810</td>
#       <td id="T_cb170_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_cb170_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_cb170_row1_col0" class="data row1 col0" >1.311743</td>
#       <td id="T_cb170_row1_col1" class="data row1 col1" >0.009263</td>
#       <td id="T_cb170_row1_col2" class="data row1 col2" >0.731343</td>
#       <td id="T_cb170_row1_col3" class="data row1 col3" >-0.419319</td>
#       <td id="T_cb170_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_cb170_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_cb170_row2_col0" class="data row2 col0" >-0.031129</td>
#       <td id="T_cb170_row2_col1" class="data row2 col1" >0.981348</td>
#       <td id="T_cb170_row2_col2" class="data row2 col2" >1.527276</td>
#       <td id="T_cb170_row2_col3" class="data row2 col3" >-1.239652</td>
#       <td id="T_cb170_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_cb170_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_cb170_row3_col0" class="data row3 col0" >0.045595</td>
#       <td id="T_cb170_row3_col1" class="data row3 col1" >-0.865226</td>
#       <td id="T_cb170_row3_col2" class="data row3 col2" >-0.423974</td>
#       <td id="T_cb170_row3_col3" class="data row3 col3" >0.382220</td>
#       <td id="T_cb170_row3_col4" class="data row3 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_cb170_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_cb170_row4_col0" class="data row4 col0" >-0.793711</td>
#       <td id="T_cb170_row4_col1" class="data row4 col1" >0.305832</td>
#       <td id="T_cb170_row4_col2" class="data row4 col2" >0.223715</td>
#       <td id="T_cb170_row4_col3" class="data row4 col3" >0.668086</td>
#       <td id="T_cb170_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_cb170_level0_row5" class="row_heading level0 row5" >2022-06-24 00:00:00</th>
#       <td id="T_cb170_row5_col0" class="data row5 col0" >-2.068284</td>
#       <td id="T_cb170_row5_col1" class="data row5 col1" >0.713850</td>
#       <td id="T_cb170_row5_col2" class="data row5 col2" >1.407528</td>
#       <td id="T_cb170_row5_col3" class="data row5 col3" >0.231563</td>
#       <td id="T_cb170_row5_col4" class="data row5 col4" >16</td>
#     </tr>
#     <tr>
#       <th id="T_cb170_level0_row6" class="row_heading level0 row6" >2022-06-25 00:00:00</th>
#       <td id="T_cb170_row6_col0" class="data row6 col0" >1.039092</td>
#       <td id="T_cb170_row6_col1" class="data row6 col1" >0.409809</td>
#       <td id="T_cb170_row6_col2" class="data row6 col2" >-0.827233</td>
#       <td id="T_cb170_row6_col3" class="data row6 col3" >-0.274854</td>
#       <td id="T_cb170_row6_col4" class="data row6 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_cb170_level0_row7" class="row_heading level0 row7" >2022-06-26 00:00:00</th>
#       <td id="T_cb170_row7_col0" class="data row7 col0" >-0.503749</td>
#       <td id="T_cb170_row7_col1" class="data row7 col1" >0.125413</td>
#       <td id="T_cb170_row7_col2" class="data row7 col2" >1.133617</td>
#       <td id="T_cb170_row7_col3" class="data row7 col3" >1.057941</td>
#       <td id="T_cb170_row7_col4" class="data row7 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_cb170_level0_row8" class="row_heading level0 row8" >2022-06-27 00:00:00</th>
#       <td id="T_cb170_row8_col0" class="data row8 col0" >0.166339</td>
#       <td id="T_cb170_row8_col1" class="data row8 col1" >1.031739</td>
#       <td id="T_cb170_row8_col2" class="data row8 col2" >-2.082194</td>
#       <td id="T_cb170_row8_col3" class="data row8 col3" >0.261180</td>
#       <td id="T_cb170_row8_col4" class="data row8 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_cb170_level0_row9" class="row_heading level0 row9" >2022-06-28 00:00:00</th>
#       <td id="T_cb170_row9_col0" class="data row9 col0" >-2.001125</td>
#       <td id="T_cb170_row9_col1" class="data row9 col1" >0.370081</td>
#       <td id="T_cb170_row9_col2" class="data row9 col2" >-0.977950</td>
#       <td id="T_cb170_row9_col3" class="data row9 col3" >0.419282</td>
#       <td id="T_cb170_row9_col4" class="data row9 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9f0fb" style='display:inline'>
#   <caption>Cumulative Sum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f0fb_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9f0fb_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9f0fb_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9f0fb_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_9f0fb_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f0fb_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_9f0fb_row0_col0" class="data row0 col0" >-0.526843</td>
#       <td id="T_9f0fb_row0_col1" class="data row0 col1" >2.656758</td>
#       <td id="T_9f0fb_row0_col2" class="data row0 col2" >0.135095</td>
#       <td id="T_9f0fb_row0_col3" class="data row0 col3" >0.081810</td>
#       <td id="T_9f0fb_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_9f0fb_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_9f0fb_row1_col0" class="data row1 col0" >0.784900</td>
#       <td id="T_9f0fb_row1_col1" class="data row1 col1" >2.666022</td>
#       <td id="T_9f0fb_row1_col2" class="data row1 col2" >0.866438</td>
#       <td id="T_9f0fb_row1_col3" class="data row1 col3" >-0.337509</td>
#       <td id="T_9f0fb_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_9f0fb_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_9f0fb_row2_col0" class="data row2 col0" >0.753771</td>
#       <td id="T_9f0fb_row2_col1" class="data row2 col1" >3.647369</td>
#       <td id="T_9f0fb_row2_col2" class="data row2 col2" >2.393713</td>
#       <td id="T_9f0fb_row2_col3" class="data row2 col3" >-1.577161</td>
#       <td id="T_9f0fb_row2_col4" class="data row2 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_9f0fb_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_9f0fb_row3_col0" class="data row3 col0" >0.799366</td>
#       <td id="T_9f0fb_row3_col1" class="data row3 col1" >2.782143</td>
#       <td id="T_9f0fb_row3_col2" class="data row3 col2" >1.969739</td>
#       <td id="T_9f0fb_row3_col3" class="data row3 col3" >-1.194941</td>
#       <td id="T_9f0fb_row3_col4" class="data row3 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_9f0fb_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_9f0fb_row4_col0" class="data row4 col0" >0.005655</td>
#       <td id="T_9f0fb_row4_col1" class="data row4 col1" >3.087975</td>
#       <td id="T_9f0fb_row4_col2" class="data row4 col2" >2.193454</td>
#       <td id="T_9f0fb_row4_col3

# %% [markdown]
# ## Histogramming
#
# Frequencies, 'nuff said
#
# ```value_counts()```

# %%
series1 = pd.Series(np.random.randint(0,5, size = 25))
series1.value_counts()
# Out:
# 2    7
# 1    6
# 4    5
# 3    5
# 0    2
# Name: count, dtype: int64

# %% [markdown]
# ## String Methods

# %%
# build a series
some_string = "SERIes and Index are EqUIppeD WITh A seT Of stRINg PROCESSING METHoDs In tHe ```sTR``` attrIBute THAT MakE IT eASy To oPerATE ON EACh ELEmeNt OF The aRrAY. NOtE thAt PAtTERN-maTching in ```sTR``` gENeralLY UsES reGUlAr eXpreSsiONs bY DEfault (aND In Some cases AlwayS uSEs tHeM)."
str_series = pd.Series(some_string.split()) # split splits on whitespace by default

# %%
# manipulating the case - lower, upper etc.
# also the length of each string, split, replace, yada yada...
# very important when cleaning data (column names may have stupid whitespace, bad case, spacing etc.)
low = str_series.str.lower()
up = str_series.str.upper()

low_up_df = pd.DataFrame(
    {
        'og': str_series,
        'length': str_series.str.len(),
        'low': low,
        'up': up,
        'split_low_on_i': low.str.split('i', expand = False), # expand = True will break this usecase, try elsewhere
        'replace_a_with_star_in_low': low.str.replace('a','*', case=False, regex=True) # yeah, you can mess with regular expns
    })

low_up_df.tail(10)
# Out:
#              og  length          low           up  split_low_on_i  \
# 36  eXpreSsiONs      11  expressions  EXPRESSIONS  [express, ons]
# 37           bY       2           by           BY            [by]
# 38      DEfault       7      default      DEFAULT       [default]
# 39         (aND       4         (and         (AND          [(and]
# 40           In       2           in           IN           [, n]
# 41         Some       4         some         SOME          [some]
# 42        cases       5        cases        CASES         [cases]
# 43       AlwayS       6       always       ALWAYS        [always]
# 44         uSEs       4         uses         USES          [uses]
# 45       tHeM).       6       them).       THEM).        [them).]
#
#    replace_a_with_star_in_low
# 36                expressions
# 37                         by
# 38                    def*ult
# 39                       (*nd
# 40                         in
# 41                       some
# 42                      c*ses
# 43                     *lw*ys
# 44                       uses
# 45                     them).

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods) for more string operations.

# %% [markdown]
# # Merge
#
# Combine series and dataframes, use set logic for indexes and relational algebra for joins/merges

# %% [markdown]
# ## Concat
#
# Chill, we've done this before. The same join = inner/outer/left/right drill.

# %%
# let's make some more dataframes
concatDF = pd.DataFrame(np.random.randn(10,4)) # 10 rows and 4 columns of random numbers
pieces = [concatDF[:3], concatDF[3:7], concatDF[7:]]
reconstructedDF = pd.concat(pieces)
display('broken DFs: ',pieces)
render_df_side_by_side(concatDF, reconstructedDF, "OG", "Concatenated")
# Out:
# 'broken DFs: '
# [          0         1         2         3
#  0  0.190312  0.624770 -0.509493 -1.073732
#  1  0.640315  0.490123 -0.298443  2.998636
#  2  0.404058  0.724159 -1.153824 -0.187937,
#            0         1         2         3
#  3 -0.481444 -0.671012  0.215015 -0.197797
#  4 -1.327660 -1.118672 -0.359768 -0.174164
#  5 -0.387755 -1.157328 -0.855570 -0.896246
#  6  0.109573 -0.792901 -1.418993  0.968320,
#            0         1         2         3
#  7 -1.624280 -0.356811  1.092402  1.239138
#  8 -1.653428 -0.081921  1.043601  1.533746
#  9 -1.216513 -1.113249  1.940233  0.306913]
# <style type="text/css">
# </style>
# <table id="T_6e68c" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e68c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6e68c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6e68c_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_6e68c_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e68c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e68c_row0_col0" class="data row0 col0" >0.190312</td>
#       <td id="T_6e68c_row0_col1" class="data row0 col1" >0.624770</td>
#       <td id="T_6e68c_row0_col2" class="data row0 col2" >-0.509493</td>
#       <td id="T_6e68c_row0_col3" class="data row0 col3" >-1.073732</td>
#     </tr>
#     <tr>
#       <th id="T_6e68c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e68c_row1_col0" class="data row1 col0" >0.640315</td>
#       <td id="T_6e68c_row1_col1" class="data row1 col1" >0.490123</td>
#       <td id="T_6e68c_row1_col2" class="data row1 col2" >-0.298443</td>
#       <td id="T_6e68c_row1_col3" class="data row1 col3" >2.998636</td>
#     </tr>
#     <tr>
#       <th id="T_6e68c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e68c_row2_col0" class="data row2 col0" >0.404058</td>
#       <td id="T_6e68c_row2_col1" class="data row2 col1" >0.724159</td>
#       <td id="T_6e68c_row2_col2" class="data row2 col2" >-1.153824</td>
#       <td id="T_6e68c_row2_col3" class="data row2 col3" >-0.187937</td>
#     </tr>
#     <tr>
#       <th id="T_6e68c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e68c_row3_col0" class="data row3 col0" >-0.481444</td>
#       <td id="T_6e68c_row3_col1" class="data row3 col1" >-0.671012</td>
#       <td id="T_6e68c_row3_col2" class="data row3 col2" >0.215015</td>
#       <td id="T_6e68c_row3_col3" class="data row3 col3" >-0.197797</td>
#     </tr>
#     <tr>
#       <th id="T_6e68c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e68c_row4_col0" class="data row4 col0" >-1.327660</td>
#       <td id="T_6e68c_row4_col1" class="data row4 col1" >-1.118672</td>
#       <td id="T_6e68c_row4_col2" class="data row4 col2" >-0.359768</td>
#       <td id="T_6e68c_row4_col3" class="data row4 col3" >-0.174164</td>
#     </tr>
#     <tr>
#       <th id="T_6e68c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e68c_row5_col0" class="data row5 col0" >-0.387755</td>
#       <td id="T_6e68c_row5_col1" class="data row5 col1" >-1.157328</td>
#       <td id="T_6e68c_row5_col2" class="data row5 col2" >-0.855570</td>
#       <td id="T_6e68c_row5_col3" class="data row5 col3" >-0.896246</td>
#     </tr>
#     <tr>
#       <th id="T_6e68c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6e68c_row6_col0" class="data row6 col0" >0.109573</td>
#       <td id="T_6e68c_row6_col1" class="data row6 col1" >-0.792901</td>
#       <td id="T_6e68c_row6_col2" class="data row6 col2" >-1.418993</td>
#       <td id="T_6e68c_row6_col3" class="data row6 col3" >0.968320</td>
#     </tr>
#     <tr>
#       <th id="T_6e68c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6e68c_row7_col0" class="data row7 col0" >-1.624280</td>
#       <td id="T_6e68c_row7_col1" class="data row7 col1" >-0.356811</td>
#       <td id="T_6e68c_row7_col2" class="data row7 col2" >1.092402</td>
#       <td id="T_6e68c_row7_col3" class="data row7 col3" >1.239138</td>
#     </tr>
#     <tr>
#       <th id="T_6e68c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6e68c_row8_col0" class="data row8 col0" >-1.653428</td>
#       <td id="T_6e68c_row8_col1" class="data row8 col1" >-0.081921</td>
#       <td id="T_6e68c_row8_col2" class="data row8 col2" >1.043601</td>
#       <td id="T_6e68c_row8_col3" class="data row8 col3" >1.533746</td>
#     </tr>
#     <tr>
#       <th id="T_6e68c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6e68c_row9_col0" class="data row9 col0" >-1.216513</td>
#       <td id="T_6e68c_row9_col1" class="data row9 col1" >-1.113249</td>
#       <td id="T_6e68c_row9_col2" class="data row9 col2" >1.940233</td>
#       <td id="T_6e68c_row9_col3" class="data row9 col3" >0.306913</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ce262" style='display:inline'>
#   <caption>Concatenated</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce262_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ce262_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ce262_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_ce262_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce262_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce262_row0_col0" class="data row0 col0" >0.190312</td>
#       <td id="T_ce262_row0_col1" class="data row0 col1" >0.624770</td>
#       <td id="T_ce262_row0_col2" class="data row0 col2" >-0.509493</td>
#       <td id="T_ce262_row0_col3" class="data row0 col3" >-1.073732</td>
#     </tr>
#     <tr>
#       <th id="T_ce262_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce262_row1_col0" class="data row1 col0" >0.640315</td>
#       <td id="T_ce262_row1_col1" class="data row1 col1" >0.490123</td>
#       <td id="T_ce262_row1_col2" class="data row1 col2" >-0.298443</td>
#       <td id="T_ce262_row1_col3" class="data row1 col3" >2.998636</td>
#     </tr>
#     <tr>
#       <th id="T_ce262_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce262_row2_col0" class="data row2 col0" >0.404058</td>
#       <td id="T_ce262_row2_col1" class="data row2 col1" >0.724159</td>
#       <td id="T_ce262_row2_col2" class="data row2 col2" >-1.153824</td>
#       <td id="T_ce262_row2_col3" class="data row2 col3" >-0.187937</td>
#     </tr>
#     <tr>
#       <th id="T_ce262_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce262_row3_col0" class="data row3 col0" >-0.481444</td>
#       <td id="T_ce262_row3_col1" class="data row3 col1" >-0.671012</td>
#       <td id="T_ce262_row3_col2" class="data row3 col2" >0.215015</td>
#       <td id="T_ce262_row3_col3" class="data row3 col3" >-0.197797</td>
#     </tr>
#     <tr>
#       <th id="T_ce262_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce262_row4_col0" class="data row4 col0" >-1.327660</td>
#       <td id="T_ce262_row4_col1" class="data row4 col1" >-1.118672</td>
#       <td id="T_ce262_row4_col2" class="data row4 col2" >-0.359768</td>
#       <td id="T_ce262_row4_col3" class="data row4 col3" >-0.174164</td>
#     </tr>
#     <tr>
#       <th id="T_ce262_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce262_row5_col0" class="data row5 col0" >-0.387755</td>
#       <td id="T_ce262_row5_col1" class="data row5 col1" >-1.157328</td>
#       <td id="T_ce262_row5_col2" class="data row5 col2" >-0.855570</td>
#       <td id="T_ce262_row5_col3" class="data row5 col3" >-0.896246</td>
#     </tr>
#     <tr>
#       <th id="T_ce262_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce262_row6_col0" class="data row6 col0" >0.109573</td>
#       <td id="T_ce262_row6_col1" class="data row6 col1" >-0.792901</td>
#       <td id="T_ce262_row6_col2" class="data row6 col2" >-1.418993</td>
#       <td id="T_ce262_row6_col3" class="data row6 col3" >0.968320</td>
#     </tr>
#     <tr>
#       <th id="T_ce262_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce262_row7_col0" class="data row7 col0" >-1.624280</td>
#       <td id="T_ce262_row7_col1" class="data row7 col1" >-0.356811</td>
#       <td id="T_ce262_row7_col2" class="data row7 col2" >1.092402</td>
#       <td id="T_ce262_row7_col3" class="data row7 col3" >1.239138</td>
#     </tr>
#     <tr>
#       <th id="T_ce262_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ce262_row8_col0" class="data row

# %% [markdown]
# _From the [page](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#concat)_:
# Adding a column to a DataFrame is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the DataFrame constructor instead of building a DataFrame by iteratively appending records to it.

# %% [markdown]
# ## Join
# SQL style merges.

# %%
# two data frames
sl = pd.Series(np.random.randint(10, size=6))
sr = sl.shift(2).fillna(0).astype(int)
left = pd.DataFrame(
    {
        'key': list('ABCDEF'),
        'lval': sl
    }
)

right = pd.DataFrame(
    {
        'key': list('ABBCDE'),
        'rval': sr
    }
)

# %%
render_df_side_by_side(left, right, 'left', 'right')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d9a00" style='display:inline'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9a00_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_d9a00_level0_col1" class="col_heading level0 col1" >lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9a00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9a00_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_d9a00_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d9a00_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9a00_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_d9a00_row1_col1" class="data row1 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_d9a00_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9a00_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_d9a00_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d9a00_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9a00_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_d9a00_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d9a00_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9a00_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_d9a00_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d9a00_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9a00_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_d9a00_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_a3e07" style='display:inline'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3e07_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_a3e07_level0_col1" class="col_heading level0 col1" >rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3e07_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3e07_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_a3e07_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a3e07_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3e07_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_a3e07_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a3e07_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3e07_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_a3e07_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a3e07_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a3e07_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_a3e07_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_a3e07_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a3e07_row4_col0" class="data row4 col0" >D</td>
#       <td id="T_a3e07_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a3e07_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a3e07_row5_col0" class="data row5 col0" >E</td>
#       <td id="T_a3e07_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pd.merge(left, right, on='key')
result
# Out:
#   key  lval  rval
# 0   A     3     0
# 1   B     9     0
# 2   B     9     3
# 3   C     1     9
# 4   D     4     1
# 5   E     4     4

# %% [markdown]
# # Grouping

# %% [markdown]
# "Group By" really means one or more of the following happening:
# 1. **Split**: data is broken into groups based on some criteria
# 2. **Apply**: a data operation is executed on each of those groups
# 3. **Combine**: the results are combined back into a data structure

# %%
grp_df = pd.DataFrame(
    {
        'colA': list('AABCAABDAA'),
        'colB': list('1234567890'),
        'colC': np.random.randn(10),
        'colD': np.random.randn(10)
    }
)
grp_df
# Out:
#   colA colB      colC      colD
# 0    A    1 -1.972114 -1.288767
# 1    A    2 -1.482828 -0.961468
# 2    B    3 -0.556864 -0.885327
# 3    C    4  0.504126 -0.190091
# 4    A    5  0.364099  1.382627
# 5    A    6 -1.291358 -0.375896
# 6    B    7 -0.692861  1.283759
# 7    D    8  1.409212 -0.456840
# 8    A    9 -1.208390  0.129246
# 9    A    0  0.623453  0.709579

# %%
# a DataFrameGroupBy object object
grpby = grp_df.groupby('colA')

# list all the groups found
g = grpby.groups
g
# Out:
# {'A': [0, 1, 4, 5, 8, 9], 'B': [2, 6], 'C': [3], 'D': [7]}

# %%
# to create a dataframe from the group use something like
grpby.get_group('A')
# Out:
#   colA colB      colC      colD
# 0    A    1 -1.972114 -1.288767
# 1    A    2 -1.482828 -0.961468
# 4    A    5  0.364099  1.382627
# 5    A    6 -1.291358 -0.375896
# 8    A    9 -1.208390  0.129246
# 9    A    0  0.623453  0.709579

# %% [markdown]
# ### Find all the groups

# %%
# but we may not know all the groups in the dataframe.
# so got to find a way to list all groups as dataframes.
# 
# some basic python helps create a list of groupby names
grpby_labels_list = [*g.keys()] # using the unpacking operator *
# alternatively
# grpby_labels_list = list(g.keys())
grpby_labels_list
# Out:
# ['A', 'B', 'C', 'D']

# %%
# create a dict where the group label is the key and the group dataframe is the value
grps = {lbl: grpby.get_group(lbl) for lbl in grpby_labels_list}

# now use the dict to access individual dataframes created out of the groupby operation
grps['B']

# question: can we create a dataframe of dataframes?
# Out:
#   colA colB      colC      colD
# 2    B    3 -0.556864 -0.885327
# 6    B    7 -0.692861  1.283759

# %%
# You can see the datatype of the value is a pandas dataframe
type(grps['A'])
# Out:
# pandas.core.frame.DataFrame

# %%
# make a function of it all...
def get_all_groups(df_grpby):
    return {lbl: df_grpby.get_group(lbl) for lbl in list(df_grpby.groups.keys())}

# %%
grps = get_all_groups(grp_df.groupby('colA'))
grps
# Out:
# {'A':   colA colB      colC      colD
#  0    A    1 -1.972114 -1.288767
#  1    A    2 -1.482828 -0.961468
#  4    A    5  0.364099  1.382627
#  5    A    6 -1.291358 -0.375896
#  8    A    9 -1.208390  0.129246
#  9    A    0  0.623453  0.709579,
#  'B':   colA colB      colC      colD
#  2    B    3 -0.556864 -0.885327
#  6    B    7 -0.692861  1.283759,
#  'C':   colA colB      colC      colD
#  3    C    4  0.504126 -0.190091,
#  'D':   colA colB      colC     colD
#  7    D    8  1.409212 -0.45684}

# %%
# get a sum of values from each group
grp_df.groupby('colA').sum()
# Out:
#         colB      colC      colD
# colA
# A     125690 -4.967139 -0.404680
# B         37 -1.249725  0.398432
# C          4  0.504126 -0.190091
# D          8  1.409212 -0.456840

# %%
# let's add one more column to the dataframe
# we can try grouping on two columns
grp_df['colE'] = list('1231231231')
grp_df
# Out:
#   colA colB      colC      colD colE
# 0    A    1 -1.972114 -1.288767    1
# 1    A    2 -1.482828 -0.961468    2
# 2    B    3 -0.556864 -0.885327    3
# 3    C    4  0.504126 -0.190091    1
# 4    A    5  0.364099  1.382627    2
# 5    A    6 -1.291358 -0.375896    3
# 6    B    7 -0.692861  1.283759    1
# 7    D    8  1.409212 -0.456840    2
# 8    A    9 -1.208390  0.129246    3
# 9    A    0  0.623453  0.709579    1

# %%
g2 = grp_df.groupby(['colA','colE'])
grps2 = get_all_groups(g2)
grps2
# Out:
# {('A',
#   '1'):   colA colB      colC      colD colE
#  0    A    1 -1.972114 -1.288767    1
#  9    A    0  0.623453  0.709579    1,
#  ('A',
#   '2'):   colA colB      colC      colD colE
#  1    A    2 -1.482828 -0.961468    2
#  4    A    5  0.364099  1.382627    2,
#  ('A',
#   '3'):   colA colB      colC      colD colE
#  5    A    6 -1.291358 -0.375896    3
#  8    A    9 -1.208390  0.129246    3,
#  ('B',
#   '1'):   colA colB      colC      colD colE
#  6    B    7 -0.692861  1.283759    1,
#  ('B',
#   '3'):   colA colB      colC      colD colE
#  2    B    3 -0.556864 -0.885327    3,
#  ('C',
#   '1'):   colA colB      colC      colD colE
#  3    C    4  0.504126 -0.190091    1,
#  ('D',
#   '2'):   colA colB      colC     colD colE
#  7    D    8  1.409212 -0.45684    2}

# %%
render_df_side_by_side(grps2[('A','1')], grps2[('A','2')], 'A,1', 'A,2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c419" style='display:inline'>
#   <caption>A,1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c419_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_5c419_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_5c419_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_5c419_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_5c419_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c419_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c419_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_5c419_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_5c419_row0_col2" class="data row0 col2" >-1.972114</td>
#       <td id="T_5c419_row0_col3" class="data row0 col3" >-1.288767</td>
#       <td id="T_5c419_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5c419_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_5c419_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_5c419_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_5c419_row1_col2" class="data row1 col2" >0.623453</td>
#       <td id="T_5c419_row1_col3" class="data row1 col3" >0.709579</td>
#       <td id="T_5c419_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ab59c" style='display:inline'>
#   <caption>A,2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab59c_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_ab59c_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_ab59c_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_ab59c_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_ab59c_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab59c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ab59c_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_ab59c_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_ab59c_row0_col2" class="data row0 col2" >-1.482828</td>
#       <td id="T_ab59c_row0_col3" class="data row0 col3" >-0.961468</td>
#       <td id="T_ab59c_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ab59c_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_ab59c_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_ab59c_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_ab59c_row1_col2" class="data row1 col2" >0.364099</td>
#       <td id="T_ab59c_row1_col3" class="data row1 col3" >1.382627</td>
#       <td id="T_ab59c_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reshaping
#
# Stacking and Pivot Tables.
# This really warrants more practice, at least go through [the page](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#)

# %% [markdown]
# ## Stacking

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %% [markdown]
# If the syntax [*expression](https://docs.python.org/dev/reference/expressions.html#calls) appears in the function call, expression must evaluate to an iterable. Elements from these iterables are treated as if they were additional positional arguments.
#
# ...although the *expression syntax may appear after explicit keyword arguments, it is processed before the keyword arguments (and any **expression arguments)

# %%
# starred expressions...
def f(a,b):
    print(a, ' ', b)
    
f (b=1, *(2,)) # works, the tuple (iterable) is expanded, 2 is assigned to a, then b fills the next argument slot
# f (a=1, *(2,)) # FAILS, multiple values for argument 'a'
# Out:
# 2   1

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
stack_idx = pd.MultiIndex.from_tuples(tuples, names = ['first', 'second'])

# %%
stack_df = pd.DataFrame(np.random.randn(8,2), index = stack_idx, columns = ['a','b'])
stack_df
# Out:
#                      a         b
# first second
# bar   one     0.712526 -0.171078
#       two    -0.231713 -0.138659
# baz   one     0.312856  0.588547
#       two    -0.053756  0.840305
# foo   one    -1.314565 -2.097859
#       two    -0.034750  0.813392
# qux   one    -0.180540  1.200072
#       two    -1.038505  1.390173

# %%
# stack really just combines the columns
stacked = stack_df.stack()
stacked
# Out:
# first  second
# bar    one     a    0.712526
#                b   -0.171078
#        two     a   -0.231713
#                b   -0.138659
# baz    one     a    0.312856
#                b    0.588547
#        two     a   -0.053756
#                b    0.840305
# foo    one     a   -1.314565
#                b   -2.097859
#        two     a   -0.034750
#                b    0.813392
# qux    one     a   -0.180540
#                b    1.200072
#        two     a   -1.038505
#                b    1.390173
# dtype: float64

# %%
# unstacked brings back the two columns
# by default unstacks the last level
unstacked = stacked.unstack()
unstacked
# Out:
#                      a         b
# first second
# bar   one     0.712526 -0.171078
#       two    -0.231713 -0.138659
# baz   one     0.312856  0.588547
#       two    -0.053756  0.840305
# foo   one    -1.314565 -2.097859
#       two    -0.034750  0.813392
# qux   one    -0.180540  1.200072
#       two    -1.038505  1.390173

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   a  0.712526 -0.231713
#       b -0.171078 -0.138659
# baz   a  0.312856 -0.053756
#       b  0.588547  0.840305
# foo   a -1.314565 -0.034750
#       b -2.097859  0.813392
# qux   a -0.180540 -1.038505
#       b  1.200072  1.390173

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    a  0.712526  0.312856 -1.314565 -0.180540
#        b -0.171078  0.588547 -2.097859  1.200072
# two    a -0.231713 -0.053756 -0.034750 -1.038505
#        b -0.138659  0.840305  0.813392  1.390173

# %%
# you can basically pivot the columns and rows using a combination of stack() and unstack()
unstacked.unstack()
# Out:
#                a                   b
# second       one       two       one       two
# first
# bar     0.712526 -0.231713 -0.171078 -0.138659
# baz     0.312856 -0.053756  0.588547  0.840305
# foo    -1.314565 -0.034750 -2.097859  0.813392
# qux    -0.180540 -1.038505  1.200072  1.390173

# %% [markdown]
# ## Pivot Tables

# %%
# we're now just using data created in the pandas documentation - just cause, time.
pivot_tables_df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
pivot_tables_df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.237768 -0.424571
# 1     one  B  foo  0.447764  1.207176
# 2     two  C  foo  1.094955 -0.307381
# 3   three  A  bar -1.651673  1.197092
# 4     one  B  bar  1.493710 -1.265726
# 5     one  C  bar  1.019573 -1.041227
# 6     two  A  foo -0.198685 -0.888341
# 7   three  B  foo -1.108142  0.447960
# 8     one  C  foo -0.650689 -0.838207
# 9     one  A  bar -2.681719  1.178023
# 10    two  B  bar  1.163378 -1.651013
# 11  three  C  bar  0.271909 -0.651632

# %%
# simple pivot tables - data, values to aggregate, index, columns to pivot along
pd.pivot_table(pivot_tables_df, values = 'D', index = ['A', 'B'], columns = ['C'])
# Out:
# C             bar       foo
# A     B
# one   A -2.681719 -0.237768
#       B  1.493710  0.447764
#       C  1.019573 -0.650689
# three A -1.651673       NaN
#       B       NaN -1.108142
#       C  0.271909       NaN
# two   A       NaN -0.198685
#       B  1.163378       NaN
#       C       NaN  1.094955

# %%
# more'n one columns of values
# mark all NaN as zero (0)
pd.pivot_table(pivot_tables_df, values = ['D', 'E'], index = ['A', 'B'], columns = ['C']).fillna(0)
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A -2.681719 -0.237768  1.178023 -0.424571
#       B  1.493710  0.447764 -1.265726  1.207176
#       C  1.019573 -0.650689 -1.041227 -0.838207
# three A -1.651673  0.000000  1.197092  0.000000
#       B  0.000000 -1.108142  0.000000  0.447960
#       C  0.271909  0.000000 -0.651632  0.000000
# two   A  0.000000 -0.198685  0.000000 -0.888341
#       B  1.163378  0.000000 -1.651013  0.000000
#       C  0.000000  1.094955  0.000000 -0.307381

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# We may need to resample data to a different time-frequency.
# Like get data every second and resample to data every 5 minutes and so on...

# %%
rng = pd.date_range('01/01/2022', periods = 1000, freq = 'S')

# %%
ts = pd.Series(np.random.randint(0,500, len(rng)), index=rng)

# %%
ts.resample('5min').sum()
# Out:
# 2022-01-01 00:00:00    75333
# 2022-01-01 00:05:00    75314
# 2022-01-01 00:10:00    74041
# 2022-01-01 00:15:00    23520
# Freq: 5T, dtype: int32

# %% [markdown]
# read up on [date offset strings](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) like '5min' etc.

# %% [markdown]
# ## Timezones

# %%
# timezone representation
rng2 = pd.date_range('01/01/2022', periods = 500, freq='D')
ts2 = pd.Series(np.random.randint(0,365, len(rng2)), index=rng2)
ts2_utc = ts2.tz_localize('UTC')

# %%
# convert to US/Eastern
ts2_utc.tz_convert('US/Eastern')
# Out:
# 2021-12-31 19:00:00-05:00    338
# 2022-01-01 19:00:00-05:00     72
# 2022-01-02 19:00:00-05:00    124
# 2022-01-03 19:00:00-05:00     29
# 2022-01-04 19:00:00-05:00     57
#                             ...
# 2023-05-10 20:00:00-04:00    227
# 2023-05-11 20:00:00-04:00     19
# 2023-05-12 20:00:00-04:00    211
# 2023-05-13 20:00:00-04:00    322
# 2023-05-14 20:00:00-04:00     90
# Freq: D, Length: 500, dtype: int32

# %% [markdown]
# ## Time span representations
#
# Converting between periods and timestamps.
#
# Period is a _timespan_ - span of time between two timestamps.

# %%
# month - end of each 
rng3 = pd.date_range('01/01/2022', periods = 12, freq='M')
rng3
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts3 = pd.Series(np.random.randn(len(rng3)), index = rng3)
ts3
# Out:
# 2022-01-31    2.331882
# 2022-02-28    0.558469
# 2022-03-31    1.193281
# 2022-04-30   -0.273589
# 2022-05-31    0.244189
# 2022-06-30   -1.488897
# 2022-07-31    0.257075
# 2022-08-31    0.366354
# 2022-09-30   -0.589676
# 2022-10-31   -0.062381
# 2022-11-30   -1.567184
# 2022-12-31   -1.529396
# Freq: M, dtype: float64

# %%
ps = ts3.to_period()
ps
# Out:
# 2022-01    2.331882
# 2022-02    0.558469
# 2022-03    1.193281
# 2022-04   -0.273589
# 2022-05    0.244189
# 2022-06   -1.488897
# 2022-07    0.257075
# 2022-08    0.366354
# 2022-09   -0.589676
# 2022-10   -0.062381
# 2022-11   -1.567184
# 2022-12   -1.529396
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2022-01-01    2.331882
# 2022-02-01    0.558469
# 2022-03-01    1.193281
# 2022-04-01   -0.273589
# 2022-05-01    0.244189
# 2022-06-01   -1.488897
# 2022-07-01    0.257075
# 2022-08-01    0.366354
# 2022-09-01   -0.589676
# 2022-10-01   -0.062381
# 2022-11-01   -1.567184
# 2022-12-01   -1.529396
# Freq: MS, dtype: float64

# %% [markdown]
# A more complex use-case:
# convert a _quarterly frequency_ with _year ending in November_ to _9am_ of _the end of the month_ _following_ the _quarter end_

# %%
prng = pd.period_range('1990Q1', '2022Q4', freq='Q-NOV')
type(prng)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
ts4 = pd.Series(np.random.randn(len(prng)), index=prng)
ts4.head()
# Out:
# 1990Q1   -0.616891
# 1990Q2    0.228661
# 1990Q3    1.560502
# 1990Q4    0.398815
# 1991Q1    0.218696
# Freq: Q-NOV, dtype: float64

# %%
ts4.index = (prng.asfreq('M', 'e') +1).asfreq('H', 's')+9
ts4.head()
# Out:
# 1990-03-01 09:00   -0.616891
# 1990-06-01 09:00    0.228661
# 1990-09-01 09:00    1.560502
# 1990-12-01 09:00    0.398815
# 1991-03-01 09:00    0.218696
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
#
# [This page](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical).
#
# For e.g., gender, social class, blood type, country affiliation, observation time or rating via Likert scales.
# Categorical data. Categories allow (usually) fixed number of possible values. Categorical data may have some order, but not support numerical operations (for e.g., 'strongly agree', 'agree', 'disagree', 'strongly disagree').

# %%
cat_df = pd.DataFrame(
    {"id": list('123456'), "raw_grade":list('abbaae')}
)
cat_df
# Out:
#   id raw_grade
# 0  1         a
# 1  2         b
# 2  3         b
# 3  4         a
# 4  5         a
# 5  6         e

# %%
# convert the raw_grade col to categories
cat_df['grade'] = cat_df['raw_grade'].astype('category')
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
cat_df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# can give more meaningful names here
# direct assignment to Series.cat.categories()
cat_df['grade'].cat.categories = ['very good', 'meh', 'very bad']
cat_df['grade']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[132], line 3
#       1 # can give more meaningful names here
#       2 # direct assignment to Series.cat.categories()
# ----> 3 cat_df['grade'].cat.categories = ['very good', 'meh', 'very bad']
#       4 cat_df['grade']
#
# File C:\1\a3\lib\site-packages\pandas\core\base.py:178, in NoNewAttributesMixin.__setattr__(self, key, value)
#     172 if getattr(self, "__frozen", False) and not (
#     173     key == "_cache"
#     174     or key in type(self).__dict__
#     175     or getattr(self, key, None) is not None
#     176 ):
#     177     raise AttributeError(f"You cannot add any new attribute '{key}'")
# --> 178 object.__setattr__(self, key, value)
#
# File C:\1\a3\lib\site-packages\pandas\core\accessor.py:99, in PandasDelegate._add_delegate_accessors.<locals>._create_delegator_property.<locals>._setter(self, new_values)
#      98 def _setter(self, new_values):
# ---> 99     return self._delegate_property_set(name, new_values)
#
# File C:\1\a3\lib\site-packages\pandas\core\arrays\categorical.py:2460, in CategoricalAccessor._delegate_property_set(self, name, new_values)
#    2459 def _delegate_property_set(self, name, new_values):
# -> 2460     return setattr(self._parent, name, new_values)
#
# AttributeError: can't set attribute 'categories'

# %%
cat_df

# %%
# list of categories 
list(cat_df['grade'].cat.categories)

# categorical.CategoricalAccessor encapsulates all changes to categoricals
# for e.g., set_categories or remove_categories
# dir(cat_df['grade'].cat)

# %%
# add more categories
cat_df['grade'] = cat_df['grade'].cat.set_categories(["very bad", "bad", "meh", "good", "very good"])
# new list of categories
list(cat_df['grade'].cat.categories)

# %%
# now when we can sort the dataframe in order of categories (not lexical)
sorted_cat_df = cat_df.sort_values(by='grade')
render_df_side_by_side(cat_df, sorted_cat_df, 'OG', 'Sorted')

# %%
# grouping
cat_grp = cat_df.groupby('grade')
cat_grp.get_group('very good')

# %%
# count elements
cat_grp.size()
